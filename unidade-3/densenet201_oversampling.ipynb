# %%
import os
os.environ["KERAS_BACKEND"] = "tensorflow"

import random
from pathlib import Path
from collections import Counter

import cv2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import tensorflow as tf
import keras
from keras import layers, models, regularizers

from tensorflow.keras.applications import DenseNet201
from tensorflow.keras.applications.densenet import preprocess_input

from sklearn.model_selection import train_test_split
from sklearn.metrics import (
    classification_report,
    confusion_matrix,
    accuracy_score,
    precision_score,
    recall_score,
    f1_score
)

from imblearn.over_sampling import RandomOverSampler

# %%
SEED = 42
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)

DATA_DIR = Path("../data")
IMAGES_DIR = DATA_DIR / "images"
MASKS_DIR = DATA_DIR / "masks"
CSV_PATH = DATA_DIR / "GroundTruth.csv"

IMG_SIZE = (320, 320)
BATCH_SIZE = 32
EPOCHS = 200
LEARNING_RATE = 0.0001

TEST_SIZE = 0.20
VAL_SIZE = 0.20

USE_DULL_RAZOR = True

USE_MASK_SEGMENTATION = False

USE_MASK_CROP = True
CROP_MARGIN = 20

BEST_MODEL_PATH = "best_densenet201_crop_oversampling_320.keras"
FINAL_MODEL_PATH = "densenet201_crop_oversampling_320_final.keras"
FEATURE_EXTRACTOR_PATH = "densenet201_crop_320_feature_extractor.keras"

classes = ["MEL", "NV", "BCC", "AKIEC", "BKL", "DF", "VASC"]
class_code = {label: idx for idx, label in enumerate(classes)}
class_name = {idx: label for label, idx in class_code.items()}

print("IMG_SIZE:", IMG_SIZE)
print("BATCH_SIZE:", BATCH_SIZE)
print("EPOCHS:", EPOCHS)
print("LEARNING_RATE:", LEARNING_RATE)
print("USE_DULL_RAZOR:", USE_DULL_RAZOR)
print("USE_MASK_SEGMENTATION:", USE_MASK_SEGMENTATION)
print("USE_MASK_CROP:", USE_MASK_CROP)
print("CROP_MARGIN:", CROP_MARGIN)
print(class_code)
# Out:
# IMG_SIZE: (320, 320)
# BATCH_SIZE: 32
# EPOCHS: 200
# LEARNING_RATE: 0.0001
# USE_DULL_RAZOR: True
# USE_MASK_SEGMENTATION: False
# USE_MASK_CROP: True
# CROP_MARGIN: 20
# {'MEL': 0, 'NV': 1, 'BCC': 2, 'AKIEC': 3, 'BKL': 4, 'DF': 5, 'VASC': 6}

# %%
print("Arquitetura: DenseNet201")
print("Balanceamento: Random Oversampling")
print("IMG_SIZE:", IMG_SIZE)
print("USE_DULL_RAZOR:", USE_DULL_RAZOR)
print("USE_MASK_SEGMENTATION:", USE_MASK_SEGMENTATION)
print("USE_MASK_CROP:", USE_MASK_CROP)
print("CROP_MARGIN:", CROP_MARGIN)
print("BEST_MODEL_PATH:", BEST_MODEL_PATH)
print("FINAL_MODEL_PATH:", FINAL_MODEL_PATH)
print("FEATURE_EXTRACTOR_PATH:", FEATURE_EXTRACTOR_PATH)
# Out:
# Arquitetura: DenseNet201
# Balanceamento: Random Oversampling
# IMG_SIZE: (320, 320)
# USE_DULL_RAZOR: True
# USE_MASK_SEGMENTATION: False
# USE_MASK_CROP: True
# CROP_MARGIN: 20
# BEST_MODEL_PATH: best_densenet201_crop_oversampling_320.keras
# FINAL_MODEL_PATH: densenet201_crop_oversampling_320_final.keras
# FEATURE_EXTRACTOR_PATH: densenet201_crop_320_feature_extractor.keras

# %%
def find_image_path(image_id, images_dir):
    for ext in [".jpg", ".jpeg", ".png"]:
        path = images_dir / f"{image_id}{ext}"
        if path.exists():
            return str(path)
    return None


def find_mask_path(image_id, masks_dir):
    if not masks_dir.exists():
        return None

    candidates = [
        masks_dir / f"{image_id}_segmentation.png",
        masks_dir / f"{image_id}_segmentation.jpg",
        masks_dir / f"{image_id}_mask.png",
        masks_dir / f"{image_id}_mask.jpg",
        masks_dir / f"{image_id}.png",
        masks_dir / f"{image_id}.jpg",
    ]

    for path in candidates:
        if path.exists():
            return str(path)

    matches = list(masks_dir.glob(f"{image_id}*"))
    if len(matches) > 0:
        return str(matches[0])

    return None


metadata = pd.read_csv(CSV_PATH)

rows = []
for _, row in metadata.iterrows():
    image_id = str(row["image"])
    image_path = find_image_path(image_id, IMAGES_DIR)
    mask_path = find_mask_path(image_id, MASKS_DIR)

    if image_path is None:
        continue

    label_name = row[classes].idxmax()
    label = class_code[label_name]

    rows.append({
        "image": image_id,
        "image_path": image_path,
        "mask_path": mask_path,
        "class_name": label_name,
        "label": label
    })

df = pd.DataFrame(rows)

print("Total de imagens localizadas:", len(df))
display(df.head())

print("\nDistribuição original:")
print(df["class_name"].value_counts().reindex(classes))

print("\nMáscaras encontradas:", df["mask_path"].notna().sum())
# Out:
# Total de imagens localizadas: 10015
#           image                       image_path  \
# 0  ISIC_0024306  ../data/images/ISIC_0024306.jpg
# 1  ISIC_0024307  ../data/images/ISIC_0024307.jpg
# 2  ISIC_0024308  ../data/images/ISIC_0024308.jpg
# 3  ISIC_0024309  ../data/images/ISIC_0024309.jpg
# 4  ISIC_0024310  ../data/images/ISIC_0024310.jpg
#
#                                      mask_path class_name  label
# 0  ../data/masks/ISIC_0024306_segmentation.png         NV      1
# 1  ../data/masks/ISIC_0024307_segmentation.png         NV      1
# 2  ../data/masks/ISIC_0024308_segmentation.png         NV      1
# 3  ../data/masks/ISIC_0024309_segmentation.png         NV      1
# 4  ../data/masks/ISIC_0024310_segmentation.png        MEL      0
# Distribuição original:
# class_name
# MEL      1113
# NV       6705
# BCC       514
# AKIEC     327
# BKL      1099
# DF        115
# VASC      142
# Name: count, dtype: int64
#
# Máscaras encontradas: 10015

# %%
train_df, test_df = train_test_split(
    df,
    test_size=TEST_SIZE,
    random_state=SEED,
    stratify=df["label"]
)

print("Treino original:", len(train_df))
print("Teste final:", len(test_df))

print("\nDistribuição treino original:")
print(train_df["class_name"].value_counts().reindex(classes))

print("\nDistribuição teste final:")
print(test_df["class_name"].value_counts().reindex(classes))
# Out:
# Treino original: 8012
# Teste final: 2003
#
# Distribuição treino original:
# class_name
# MEL       890
# NV       5364
# BCC       411
# AKIEC     262
# BKL       879
# DF         92
# VASC      114
# Name: count, dtype: int64
#
# Distribuição teste final:
# class_name
# MEL       223
# NV       1341
# BCC       103
# AKIEC      65
# BKL       220
# DF         23
# VASC       28
# Name: count, dtype: int64

# %%
def read_rgb_image(path):
    if isinstance(path, bytes):
        path = path.decode("utf-8")

    image_bgr = cv2.imread(str(path), cv2.IMREAD_COLOR)

    if image_bgr is None:
        raise ValueError(f"Não foi possível carregar a imagem: {path}")

    image_rgb = cv2.cvtColor(image_bgr, cv2.COLOR_BGR2RGB)

    return image_rgb


def dull_razor_remove_hair(image_rgb, kernel_size=(9, 9), threshold_value=10, inpaint_radius=6):
    image_rgb = image_rgb.astype(np.uint8)

    gray = cv2.cvtColor(image_rgb, cv2.COLOR_RGB2GRAY)

    kernel = cv2.getStructuringElement(cv2.MORPH_RECT, kernel_size)
    blackhat = cv2.morphologyEx(gray, cv2.MORPH_BLACKHAT, kernel)

    blackhat_blur = cv2.GaussianBlur(blackhat, (3, 3), 0)

    _, mask = cv2.threshold(
        blackhat_blur,
        threshold_value,
        255,
        cv2.THRESH_BINARY
    )

    image_bgr = cv2.cvtColor(image_rgb, cv2.COLOR_RGB2BGR)

    clean_bgr = cv2.inpaint(
        image_bgr,
        mask,
        inpaint_radius,
        cv2.INPAINT_TELEA
    )

    clean_rgb = cv2.cvtColor(clean_bgr, cv2.COLOR_BGR2RGB)

    return clean_rgb


def read_binary_mask(mask_path, target_shape):
    if mask_path is None or pd.isna(mask_path):
        return None

    if isinstance(mask_path, bytes):
        mask_path = mask_path.decode("utf-8")

    mask = cv2.imread(str(mask_path), cv2.IMREAD_GRAYSCALE)

    if mask is None:
        return None

    height, width = target_shape[:2]
    mask = cv2.resize(mask, (width, height))

    binary_mask = (mask > 127).astype(np.uint8)

    return binary_mask


def apply_mask_segmentation(image_rgb, mask_path):
    binary_mask = read_binary_mask(mask_path, target_shape=image_rgb.shape)

    if binary_mask is None:
        return image_rgb

    segmented = image_rgb * np.expand_dims(binary_mask, axis=-1)

    if np.mean(segmented) < 5:
        return image_rgb

    return segmented


def crop_lesion_with_margin(image_rgb, mask_path, margin=20):
    binary_mask = read_binary_mask(mask_path, target_shape=image_rgb.shape)

    if binary_mask is None:
        return image_rgb

    ys, xs = np.where(binary_mask > 0)

    if len(xs) == 0 or len(ys) == 0:
        return image_rgb

    height, width = image_rgb.shape[:2]

    x_min = max(xs.min() - margin, 0)
    x_max = min(xs.max() + margin, width - 1)
    y_min = max(ys.min() - margin, 0)
    y_max = min(ys.max() + margin, height - 1)

    cropped = image_rgb[y_min:y_max + 1, x_min:x_max + 1]

    if cropped.size == 0:
        return image_rgb

    return cropped


def preprocess_image_path(path, mask_path=None):
    image_rgb = read_rgb_image(path)

    if USE_DULL_RAZOR:
        image_rgb = dull_razor_remove_hair(image_rgb)

    if USE_MASK_CROP:
        image_rgb = crop_lesion_with_margin(
            image_rgb,
            mask_path,
            margin=CROP_MARGIN
        )
    elif USE_MASK_SEGMENTATION:
        image_rgb = apply_mask_segmentation(image_rgb, mask_path)

    image_rgb = cv2.resize(image_rgb, IMG_SIZE)

    return image_rgb.astype("float32")

# %%
sample_row = train_df.sample(1, random_state=SEED).iloc[0]

original = read_rgb_image(sample_row["image_path"])
dull = dull_razor_remove_hair(original) if USE_DULL_RAZOR else original
segmented = apply_mask_segmentation(dull, sample_row["mask_path"])
cropped = crop_lesion_with_margin(dull, sample_row["mask_path"], margin=CROP_MARGIN)
final_img = preprocess_image_path(sample_row["image_path"], sample_row["mask_path"])
final_img = np.clip(final_img, 0, 255).astype("uint8")

plt.figure(figsize=(16, 4))

plt.subplot(1, 5, 1)
plt.imshow(original)
plt.title("Original")
plt.axis("off")

plt.subplot(1, 5, 2)
plt.imshow(dull)
plt.title("Dull Razor")
plt.axis("off")

plt.subplot(1, 5, 3)
plt.imshow(np.clip(segmented, 0, 255).astype("uint8"))
plt.title("Máscara aplicada")
plt.axis("off")

plt.subplot(1, 5, 4)
plt.imshow(np.clip(cropped, 0, 255).astype("uint8"))
plt.title("Crop + margem")
plt.axis("off")

plt.subplot(1, 5, 5)
plt.imshow(final_img)
plt.title("Final 320x320")
plt.axis("off")

plt.tight_layout()
plt.savefig("pipeline_densenet201_crop_oversampling.png", dpi=300, bbox_inches="tight")
plt.show()

# %%
def load_image_for_features_py(image_path, mask_path, label):
    if isinstance(image_path, bytes):
        image_path = image_path.decode("utf-8")

    if isinstance(mask_path, bytes):
        mask_path = mask_path.decode("utf-8")

    if mask_path == "None" or mask_path == "":
        mask_path = None

    image = preprocess_image_path(image_path, mask_path)

    return image.astype("float32"), np.int32(label)


def tf_load_image_for_features(image_path, mask_path, label):
    image, label = tf.numpy_function(
        load_image_for_features_py,
        [image_path, mask_path, label],
        [tf.float32, tf.int32]
    )

    image.set_shape((IMG_SIZE[0], IMG_SIZE[1], 3))
    label.set_shape(())

    return image, label


def build_image_dataset(dataframe, batch_size=BATCH_SIZE, shuffle=False):
    mask_values = dataframe["mask_path"].fillna("None").astype(str).values

    ds = tf.data.Dataset.from_tensor_slices((
        dataframe["image_path"].astype(str).values,
        mask_values,
        dataframe["label"].values.astype("int32")
    ))

    if shuffle:
        ds = ds.shuffle(buffer_size=len(dataframe), seed=SEED)

    ds = ds.map(tf_load_image_for_features, num_parallel_calls=tf.data.AUTOTUNE)
    ds = ds.batch(batch_size)
    ds = ds.prefetch(tf.data.AUTOTUNE)

    return ds


train_image_ds = build_image_dataset(train_df, shuffle=False)
test_image_ds = build_image_dataset(test_df, shuffle=False)

print(train_image_ds)
print(test_image_ds)
# Out:
# <_PrefetchDataset element_spec=(TensorSpec(shape=(None, 320, 320, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>
# <_PrefetchDataset element_spec=(TensorSpec(shape=(None, 320, 320, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
def build_feature_extractor(input_shape=(320, 320, 3)):
    inputs = layers.Input(shape=input_shape)

    x = preprocess_input(inputs)

    base_model = DenseNet201(
        weights="imagenet",
        include_top=False,
        input_shape=input_shape
    )

    base_model.trainable = False

    x = base_model(x, training=False)
    x = layers.GlobalAveragePooling2D()(x)

    feature_extractor = models.Model(
        inputs=inputs,
        outputs=x,
        name="densenet201_crop_feature_extractor"
    )

    return feature_extractor


feature_extractor = build_feature_extractor(
    input_shape=(IMG_SIZE[0], IMG_SIZE[1], 3)
)

feature_extractor.summary()
# Out:
# Model: "densenet201_crop_feature_extractor"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 320, 320, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ true_divide (TrueDivide)        │ (None, 320, 320, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ add (Add)                       │ (None, 320, 320, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ true_divide_1 (TrueDivide)      │ (None, 320, 320, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ densenet201 (Functional)        │ (None, 10, 10, 1920)   │    18,321,984 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 1920)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 18,321,984 (69.89 MB)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 18,321,984 (69.89 MB)

# %%
def extract_features(dataset, feature_extractor):
    features_list = []
    labels_list = []

    for images, labels in dataset:
        features = feature_extractor.predict(images, verbose=0)
        features_list.append(features)
        labels_list.append(labels.numpy())

    X = np.concatenate(features_list, axis=0)
    y = np.concatenate(labels_list, axis=0)

    return X.astype("float32"), y.astype("int32")


X_train_features, y_train = extract_features(train_image_ds, feature_extractor)
X_test_features, y_test = extract_features(test_image_ds, feature_extractor)

print("X_train_features:", X_train_features.shape)
print("y_train:", y_train.shape)
print("X_test_features:", X_test_features.shape)
print("y_test:", y_test.shape)

print("\nDistribuição treino antes do Oversampling:")
print(Counter(y_train))
# Out:
# X_train_features: (8012, 1920)
# y_train: (8012,)
# X_test_features: (2003, 1920)
# y_test: (2003,)
#
# Distribuição treino antes do Oversampling:
# Counter({np.int32(1): 5364, np.int32(0): 890, np.int32(4): 879, np.int32(2): 411, np.int32(3): 262, np.int32(6): 114, np.int32(5): 92})

# %%
print("Distribuição treino antes do Random Oversampling:")
print(Counter(y_train))

oversampling = RandomOverSampler(
    random_state=SEED
)

X_train_oversampling, y_train_oversampling = oversampling.fit_resample(
    X_train_features,
    y_train
)

print("X_train_oversampling:", X_train_oversampling.shape)
print("y_train_oversampling:", y_train_oversampling.shape)

print("\nDistribuição treino após Random Oversampling:")
print(Counter(y_train_oversampling))
# Out:
# Distribuição treino antes do Random Oversampling:
# Counter({np.int32(1): 5364, np.int32(0): 890, np.int32(4): 879, np.int32(2): 411, np.int32(3): 262, np.int32(6): 114, np.int32(5): 92})
# X_train_oversampling: (37548, 1920)
# y_train_oversampling: (37548,)
#
# Distribuição treino após Random Oversampling:
# Counter({np.int32(1): 5364, np.int32(0): 5364, np.int32(4): 5364, np.int32(2): 5364, np.int32(5): 5364, np.int32(3): 5364, np.int32(6): 5364})

# %%
X_fit, X_val, y_fit, y_val = train_test_split(
    X_train_oversampling,
    y_train_oversampling,
    test_size=VAL_SIZE,
    random_state=SEED,
    stratify=y_train_oversampling
)

print("Treino para fit:", X_fit.shape)
print("Validação:", X_val.shape)
print("Teste final:", X_test_features.shape)

print("\nDistribuição fit:")
print(Counter(y_fit))

print("\nDistribuição validação:")
print(Counter(y_val))
# Out:
# Treino para fit: (30038, 1920)
# Validação: (7510, 1920)
# Teste final: (2003, 1920)
#
# Distribuição fit:
# Counter({np.int32(0): 4292, np.int32(4): 4291, np.int32(5): 4291, np.int32(6): 4291, np.int32(2): 4291, np.int32(3): 4291, np.int32(1): 4291})
#
# Distribuição validação:
# Counter({np.int32(2): 1073, np.int32(3): 1073, np.int32(6): 1073, np.int32(4): 1073, np.int32(1): 1073, np.int32(5): 1073, np.int32(0): 1072})

# %%
def build_classifier_head(input_dim, num_classes=len(classes)):
    inputs = layers.Input(shape=(input_dim,))

    x = layers.Dense(
        256,
        activation="relu",
        kernel_regularizer=regularizers.l2(0.001)
    )(inputs)

    x = layers.BatchNormalization()(x)
    x = layers.Dropout(0.5)(x)

    x = layers.Dense(
        128,
        activation="relu",
        kernel_regularizer=regularizers.l2(0.001)
    )(x)

    x = layers.Dropout(0.3)(x)

    outputs = layers.Dense(num_classes, activation="softmax")(x)

    model = models.Model(
        inputs=inputs,
        outputs=outputs,
        name="densenet201_crop_oversampling_classifier"
    )

    return model


classifier = build_classifier_head(
    input_dim=X_train_oversampling.shape[1],
    num_classes=len(classes)
)

classifier.compile(
    optimizer=keras.optimizers.Adam(learning_rate=LEARNING_RATE),
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)

classifier.summary()
# Out:
# Model: "densenet201_crop_oversampling_classifier"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_2 (InputLayer)      │ (None, 1920)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │       491,776 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 7)              │           903 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 526,599 (2.01 MB)
#  Trainable params: 526,087 (2.01 MB)
#  Non-trainable params: 512 (2.00 KB)

# %%
callbacks = [
    keras.callbacks.EarlyStopping(
        monitor="val_loss",
        patience=10,
        restore_best_weights=True,
        verbose=1
    ),
    keras.callbacks.ReduceLROnPlateau(
        monitor="val_loss",
        factor=0.2,
        patience=4,
        min_lr=1e-7,
        verbose=1
    ),
    keras.callbacks.ModelCheckpoint(
        BEST_MODEL_PATH,
        monitor="val_loss",
        save_best_only=True,
        verbose=1
    )
]

history = classifier.fit(
    X_fit,
    y_fit,
    validation_data=(X_val, y_val),
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    callbacks=callbacks
)
# Out:
# Epoch 1/200
# 914/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3938 - loss: 2.3093
# Epoch 1: val_loss improved from None to 1.06159, saving model to best_densenet201_crop_oversampling_320.keras
#
# Epoch 1: finished saving model to best_densenet201_crop_oversampling_320.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.5112 - loss: 1.8133 - val_accuracy: 0.7478 - val_loss: 1.0616 - learning_rate: 1.0000e-04
# Epoch 2/200
# 918/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6569 - loss: 1.2879
# Epoch 2: val_loss improved from 1.06159 to 0.85337, saving model to best_densenet201_crop_oversampling_320.keras
#
# Epoch 2: finished saving model to best_densenet201_crop_oversampling_320.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.6795 - loss: 1.2186 - val_accuracy: 0.8157 - val_loss: 0.8534 - learning_rate: 1.0000e-04
# Epoch 3/200
# 912/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7322 - loss: 1.0522
# Epoch 3: val_loss improved from 0.85337 to 0.73534, saving model to best_densenet201_crop_oversampling_320.keras
#
# Epoch 3: finished saving model to best_densenet201_crop_oversampling_320.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7447 - loss: 1.0137 - val_accuracy: 0.8571 - val_loss: 0.7353 - learning_rate: 1.0000e-04
# Epoch 4/200
# 916/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7818 - loss: 0.9030
# Epoch 4: val_loss improved from 0.73534 to 0.65000, saving model to best_densenet201_crop_oversampling_320.keras
#
# Epoch 4: finished saving model to best_densenet201_crop_oversampling_320.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7906 - loss: 0.8757 - val_accuracy: 0.8834 - val_loss: 0.6500 - learning_rate: 1.0000e-04
# Epoch 5/200
# 932/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8107 - loss: 0.8044
# Epoch 5: val_loss improved from 0.65000 to 0.56858, saving model to best_densenet201_crop_oversampling_320.keras
#
# Epoch 5: finished saving model to best_densenet201_crop_oversampling_320.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8210 - loss: 0.7790 - val_accuracy: 0.9051 - val_loss: 0.5686 - learning_rate: 1.0000e-04
# Epoch 6/200
# 938/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8394 - loss: 0.7168
# Epoch 6: val_loss improved from 0.56858 to 0.52600, saving model to best_densenet201_crop_oversampling_320.keras
#
# Epoch 6: finished saving model to best_densenet201_crop_oversampling_320.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8486 - loss: 0.6953 - val_accuracy: 0.9124 - val_loss: 0.5260 - learning_rate: 1.0000e-04
# Epoch 7/200
# 921/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8593 - loss: 0.6447
# Epoch 7: val_loss improved from 0.52600 to 0.48023, saving model to best_densenet201_crop_oversampling_320.keras
#
# Epoch 7: finished saving model to best_densenet201_crop_oversampling_320.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8625 - loss: 0.6328 - val_accuracy: 0.9224 - val_loss: 0.4802 - learning_rate: 1.0000e-04
# Epoch 8/200
# 936/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8761 - loss: 0.5908
# Epoch 8: val_loss improved from 0.48023 to 0.44865, saving model to best_densenet201_crop_oversampling_320.keras
#
# Epoch 8: finished saving model to best_densenet201_crop_oversampling_320.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8800 - loss: 0.5795 - val_accuracy: 0.9308 - val_loss: 0.4487 - learning_rate: 1.0000e-04
# Epoch 9/200
# 913/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8895 - loss: 0.5475
# Epoch 9: val_loss improved from 0.44865 to 0.40796, saving model to best_densenet201_crop_oversampling_320.keras
#
# Epoch 9: finished saving model to best_densenet201_crop_oversampling_320.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8923 - loss: 0.5358 - val_accuracy: 0.9429 - val_loss: 0.4080 - learning_rate: 1.0000e-04
# Epoch 10/200
# 935/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8975 - loss: 0.5054
# Epoch 10: val_loss improved from 0.40796 to 0.37947, saving model to best_densenet201_crop_oversampling_320.keras
#
# Epoch 10: finished saving model to best_densenet201_crop_oversampling_320.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9001 - loss: 0.4978 - val_accuracy: 0.9497 - val_loss: 0.3795 - learning_rate: 1.0000e-04
# Epoch 11/200
# 915/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9080 - loss: 0.4718
# Epoch 11: val_loss improved from 0.37947 to 0.35711, saving model to best_densenet201_crop_oversampling_320.keras
#
# Epoch 11: finished saving model to best_densenet201_crop_oversampling_320.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9101 - loss: 0.4649 - val_accuracy: 0.9531 - val_loss: 0.3571 - learning_rate: 1.0000e-04
# Epoch 12/200
# 936/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9144 - loss: 0.4482
# Epoch 12: val_loss improved from 0.35711 to 0.33677, saving model to best_densenet201_crop_oversampling_320.keras
#
# Epoch 12: finished saving model to best_densenet201_crop_oversampling_320.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9156 - loss: 0.4403 - val_accuracy: 0.9575 - val_loss: 0.3368 - learning_rate: 1.0000e-04
# Epoch 13/200
# 927/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9228 - loss: 0.4185
# Epoch 13: val_loss improved from 0.33677 to 0.32611, saving model to best_densenet201_crop_oversampling_320.keras
#
# Epoch 13: finished saving model to best_densenet201_crop_oversampling_320.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9235 - loss: 0.4168 - val_accuracy: 0.9551 - val_loss: 0.3261 - learning_rate: 1.0000e-04
# Epoch 14/200
# 928/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9292 - loss: 0.3962
# Epoch 14: val_loss improved from 0.32611 to 0.31086, saving model to best_densenet201_crop_oversampling_320.keras
#
# Epoch 14: finished saving model to best_densenet201_crop_oversampling_320.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9300 - loss: 0.3901 - val_accuracy: 0.9595 - val_loss: 0.3109 - learning_rate: 1.0000e-04
# Epoch 15/200
# 922/939 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9311 - loss: 0.3821
# Epoch 15: val_loss improved from 0.31086 to 0.29402, saving model to best_densenet201_crop_oversampling_320.keras
#
# Epoch 15: finished saving model to best_densenet201_crop_oversampling_320.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9333 - loss: 0.3767 - val_accuracy: 0.9654 - val_loss: 0.2940 - learning_rate: 1.0000e-04
# Epoch 16/200
# 916/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9368 - loss: 0.3663
# Epoch 16: val_loss improved from 0.29402 to 0.28665, saving model to best_densenet201_crop_oversampling_320.keras
#
# Epoch 16: finished saving model to best_densenet201_crop_oversampling_320.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9369 - loss: 0.3628 - val_accuracy: 0.9651 - val_loss: 0.2867 - learning_rate: 1.0000e-04
# Epoch 17/200
# 924/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9387 - loss: 0.3520
# Epoch 17: val_loss improved from 0.28665 to 0.27224, saving model to best_densenet201_crop_oversampling_320.keras
#
# Epoch 17: finished saving model to best_densenet201_crop_oversampling_320.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9381 - loss: 0.3521 - val_accuracy: 0.9686 - val_loss: 0.2722 - learning_rate: 1.0000e-04
# Epoch 18/200
# 925/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9376 - loss: 0.3461
# Epoch 18: val_loss improved from 0.27224 to 0.26631, saving model to best_densenet201_crop_oversampling_320.keras
#
# Epoch 18: finished saving model to best_densenet201_crop_oversampling_320.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9391 - loss: 0.3406 - val_accuracy: 0.9696 - val_loss: 0.2663 - learning_rate: 1.0000e-04
# Epoch 19/200
# 925/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9438 - loss: 0.3254
# Epoch 19: val_loss improved from 0.26631 to 0.25438, saving model to best_densenet201_crop_oversampling_320.keras
#
# Epoch 19: finished saving model to best_densenet201_crop_oversampling_320.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9453 - loss: 0.3194 - val_accuracy: 0.9703 - val_loss: 0.2544 - learning_rate: 1.0000e-04
# Epoch 20/200
# 927/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9401 - loss: 0.3233
# Epoch 20: val_loss improved from 0.25438 to 0.25333, saving model to best_densenet201_crop_oversampling_320.keras
#
# Epoch 20: finished saving model to best_densenet201_crop_oversampling_320.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9432 - loss: 0.3161 - val_accuracy: 0.9667 - val_loss: 0.2533 - learning_rate: 1.0000e-04
# Epoch 21/200
# 934/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9456 - loss: 0.3067
# Epoch 21: val_loss improved from 0.25333 to 0.23354, saving model to best_densenet201_crop_oversampling_320.keras
#
# Epoch 21: finished saving model to best_densenet201_crop_oversampling_320.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9482 - loss: 0.2998 - val_accuracy: 0.9740 - val_loss: 0.2335 - learning_rate: 1.0000e-04
# Epoch 22/200
# 935/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9501 - loss: 0.2943
# Epoch 22: val_loss improved from 0.23354 to 0.23105, saving model to best_densenet201_crop_oversampling_320.keras
#
# Epoch 22: finished saving model to best_densenet201_crop_oversampling_320.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9505 - loss: 0.2921 - val_accuracy: 0.9732 - val_loss: 0.2310 - learning_rate: 1.0000e-04
# Epoch 23/200
# 927/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9487 - loss: 0.2861
# Epoch 23: val_loss did not improve from 0.23105
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9521 - loss: 0.2792 - val_accuracy: 0.9699 - val_loss: 0.2375 - learning_rate: 1.0000e-04
# Epoch 24/200
# 918/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9559 - loss: 0.2697
# Epoch 24: val_loss improved from 0.23105 to 0.22228, saving model to best_densenet201_crop_oversampling_320.keras
#
# Epoch 24: finished saving model to best_densenet201_crop_oversampling_320.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9558 - loss: 0.2677 - val_accuracy: 0.9735 - val_loss: 0.2223 - learning_rate: 1.0000e-04
# Epoch 25/200
# 917/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9518 - loss: 0.2692
# Epoch 25: val_loss did not improve from 0.22228
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9530 - loss: 0.2666 - val_accuracy: 0.9724 - val_loss: 0.2264 - learning_rate: 1.0000e-04
# Epoch 26/200
# 932/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9587 - loss: 0.2506
# Epoch 26: val_loss improved from 0.22228 to 0.20679, saving model to best_densenet201_crop_oversampling_320.keras
#
# Epoch 26: finished saving model to best_densenet201_crop_oversampling_320.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9592 - loss: 0.2494 - val_accuracy: 0.9747 - val_loss: 0.2068 - learning_rate: 1.0000e-04
# Epoch 27/200
# 928/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9545 - loss: 0.2567
# Epoch 27: val_loss improved from 0.20679 to 0.20385, saving model to best_densenet201_crop_oversampling_320.keras
#
# Epoch 27: finished saving model to best_densenet201_crop_oversampling_320.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9555 - loss: 0.2550 - val_accuracy: 0.9747 - val_loss: 0.2038 - learning_rate: 1.0000e-04
# Epoch 28/200
# 926/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9603 - loss: 0.2440
# Epoch 28: val_loss did not improve from 0.20385
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9588 - loss: 0.2444 - val_accuracy: 0.9711 - val_loss: 0.2137 - learning_rate: 1.0000e-04
# Epoch 29/200
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9586 - loss: 0.2450
# Epoch 29: val_loss improved from 0.20385 to 0.18835, saving model to best_densenet201_crop_oversampling_320.keras
#
# Epoch 29: finished saving model to best_densenet201_crop_oversampling_320.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9594 - loss: 0.2406 - val_accuracy: 0.9794 - val_loss: 0.1883 - learning_rate: 1.0000e-04
# Epoch 30/200
# 938/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9581 - loss: 0.2384
# Epoch 30: val_loss did not improve from 0.18835
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9586 - loss: 0.2372 - val_accuracy: 0.9691 - val_loss: 0.2171 - learning_rate: 1.0000e-04
# Epoch 31/200
# 918/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9547 - loss: 0.2492
# Epoch 31: val_loss improved from 0.18835 to 0.18625, saving model to best_densenet201_crop_oversampling_320.keras
#
# Epoch 31: finished saving model to best_densenet201_crop_oversampling_320.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9567 - loss: 0.2427 - val_accuracy: 0.9782 - val_loss: 0.1862 - learning_rate: 1.0000e-04
# Epoch 32/200
# 932/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9591 - loss: 0.2281
# Epoch 32: val_loss did not improve from 0.18625
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9599 - loss: 0.2264 - val_accuracy: 0.9731 - val_loss: 0.2013 - learning_rate: 1.0000e-04
# Epoch 33/200
# 929/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9606 - loss: 0.2255
# Epoch 33: val_loss improved from 0.18625 to 0.17655, saving model to best_densenet201_crop_oversampling_320.keras
#
# Epoch 33: finished saving model to best_densenet201_crop_oversampling_320.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9594 - loss: 0.2273 - val_accuracy: 0.9788 - val_loss: 0.1766 - learning_rate: 1.0000e-04
# Epoch 34/200
# 931/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9611 - loss: 0.2240
# Epoch 34: val_loss did not improve from 0.17655
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9606 - loss: 0.2217 - val_accuracy: 0.9755 - val_loss: 0.1886 - learning_rate: 1.0000e-04
# Epoch 35/200
# 929/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9569 - loss: 0.2239
# Epoch 35: val_loss did not improve from 0.17655
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9601 - loss: 0.2176 - val_accuracy: 0.9770 - val_loss: 0.1821 - learning_rate: 1.0000e-04
# Epoch 36/200
# 926/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9611 - loss: 0.2138
# Epoch 36: val_loss improved from 0.17655 to 0.16304, saving model to best_densenet201_crop_oversampling_320.keras
#
# Epoch 36: finished saving model to best_densenet201_crop_oversampling_320.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9636 - loss: 0.2080 - val_accuracy: 0.9816 - val_loss: 0.1630 - learning_rate: 1.0000e-04
# Epoch 37/200
# 922/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9638 - loss: 0.2037
# Epoch 37: val_loss did not improve from 0.16304
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9645 - loss: 0.2039 - val_accuracy: 0.9712 - val_loss: 0.1904 - learning_rate: 1.0000e-04
# Epoch 38/200
# 938/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9577 - loss: 0.2164
# Epoch 38: val_loss improved from 0.16304 to 0.15844, saving model to best_densenet201_crop_oversampling_320.keras
#
# Epoch 38: finished saving model to best_densenet201_crop_oversampling_320.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9620 - loss: 0.2084 - val_accuracy: 0.9822 - val_loss: 0.1584 - learning_rate: 1.0000e-04
# Epoch 39/200
# 917/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9643 - loss: 0.1980
# Epoch 39: val_loss did not improve from 0.15844
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9626 - loss: 0.2015 - val_accuracy: 0.9780 - val_loss: 0.1679 - learning_rate: 1.0000e-04
# Epoch 40/200
# 931/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9630 - loss: 0.2009
# Epoch 40: val_loss did not improve from 0.15844
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9651 - loss: 0.1955 - val_accuracy: 0.9812 - val_loss: 0.1607 - learning_rate: 1.0000e-04
# Epoch 41/200
# 927/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9631 - loss: 0.1984
# Epoch 41: val_loss did not improve from 0.15844
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9655 - loss: 0.1946 - val_accuracy: 0.9788 - val_loss: 0.1619 - learning_rate: 1.0000e-04
# Epoch 42/200
# 933/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9632 - loss: 0.2062
# Epoch 42: val_loss improved from 0.15844 to 0.15763, saving model to best_densenet201_crop_oversampling_320.keras
#
# Epoch 42: finished saving model to best_densenet201_crop_oversampling_320.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9633 - loss: 0.2027 - val_accuracy: 0.9806 - val_loss: 0.1576 - learning_rate: 1.0000e-04
# Epoch 43/200
# 932/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9634 - loss: 0.1998
# Epoch 43: val_loss did not improve from 0.15763
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9657 - loss: 0.1927 - val_accuracy: 0.9784 - val_loss: 0.1592 - learning_rate: 1.0000e-04
# Epoch 44/200
# 938/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9660 - loss: 0.1875
# Epoch 44: val_loss did not improve from 0.15763
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9669 - loss: 0.1867 - val_accuracy: 0.9787 - val_loss: 0.1676 - learning_rate: 1.0000e-04
# Epoch 45/200
# 915/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9659 - loss: 0.1856
# Epoch 45: val_loss did not improve from 0.15763
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9664 - loss: 0.1857 - val_accuracy: 0.9760 - val_loss: 0.1673 - learning_rate: 1.0000e-04
# Epoch 46/200
# 929/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9587 - loss: 0.2030
# Epoch 46: ReduceLROnPlateau reducing learning rate to 1.9999999494757503e-05.
#
# Epoch 46: val_loss did not improve from 0.15763
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9631 - loss: 0.1918 - val_accuracy: 0.9743 - val_loss: 0.1677 - learning_rate: 1.0000e-04
# Epoch 47/200
# 934/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9721 - loss: 0.1673
# Epoch 47: val_loss improved from 0.15763 to 0.14256, saving model to best_densenet201_crop_oversampling_320.keras
#
# Epoch 47: finished saving model to best_densenet201_crop_oversampling_320.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9780 - loss: 0.1541 - val_accuracy: 0.9835 - val_loss: 0.1426 - learning_rate: 2.0000e-05
# Epoch 48/200
# 916/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9794 - loss: 0.1460
# Epoch 48: val_loss improved from 0.14256 to 0.14045, saving model to best_densenet201_crop_oversampling_320.keras
#
# Epoch 48: finished saving model to best_densenet201_crop_oversampling_320.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9808 - loss: 0.1438 - val_accuracy: 0.9844 - val_loss: 0.1405 - learning_rate: 2.0000e-05
# Epoch 49/200
# 930/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9822 - loss: 0.1404
# Epoch 49: val_loss improved from 0.14045 to 0.13972, saving model to best_densenet201_crop_oversampling_320.keras
#
# Epoch 49: finished saving model to best_densenet201_crop_oversampling_320.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9844 - loss: 0.1347 - val_accuracy: 0.9834 - val_loss: 0.1397 - learning_rate: 2.0000e-05
# Epoch 50/200
# 925/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9824 - loss: 0.1401
# Epoch 50: val_loss improved from 0.13972 to 0.13701, saving model to best_densenet201_crop_oversampling_320.keras
#
# Epoch 50: finished saving model to best_densenet201_crop_oversampling_320.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9839 - loss: 0.1347 - val_accuracy: 0.9846 - val_loss: 0.1370 - learning_rate: 2.0000e-05
# Epoch 51/200
# 937/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9861 - loss: 0.1311
# Epoch 51: val_loss improved from 0.13701 to 0.13444, saving model to best_densenet201_crop_oversampling_320.keras
#
# Epoch 51: finished saving model to best_densenet201_crop_oversampling_320.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9856 - loss: 0.1301 - val_accuracy: 0.9848 - val_loss: 0.1344 - learning_rate: 2.0000e-05
# Epoch 52/200
# 920/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9847 - loss: 0.1291
# Epoch 52: val_loss improved from 0.13444 to 0.13062, saving model to best_densenet201_crop_oversampling_320.keras
#
# Epoch 52: finished saving model to best_densenet201_crop_oversampling_320.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9855 - loss: 0.1265 - val_accuracy: 0.9854 - val_loss: 0.1306 - learning_rate: 2.0000e-05
# Epoch 53/200
# 919/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9862 - loss: 0.1268
# Epoch 53: val_loss did not improve from 0.13062
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9868 - loss: 0.1245 - val_accuracy: 0.9848 - val_loss: 0.1310 - learning_rate: 2.0000e-05
# Epoch 54/200
# 929/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9862 - loss: 0.1236
# Epoch 54: val_loss did not improve from 0.13062
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9862 - loss: 0.1227 - val_accuracy: 0.9854 - val_loss: 0.1311 - learning_rate: 2.0000e-05
# Epoch 55/200
# 924/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9858 - loss: 0.1234
# Epoch 55: val_loss improved from 0.13062 to 0.13028, saving model to best_densenet201_crop_oversampling_320.keras
#
# Epoch 55: finished saving model to best_densenet201_crop_oversampling_320.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9873 - loss: 0.1199 - val_accuracy: 0.9856 - val_loss: 0.1303 - learning_rate: 2.0000e-05
# Epoch 56/200
# 921/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9857 - loss: 0.1242
# Epoch 56: val_loss improved from 0.13028 to 0.12792, saving model to best_densenet201_crop_oversampling_320.keras
#
# Epoch 56: finished saving model to best_densenet201_crop_oversampling_320.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9874 - loss: 0.1185 - val_accuracy: 0.9851 - val_loss: 0.1279 - learning_rate: 2.0000e-05
# Epoch 57/200
# 936/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9876 - loss: 0.1174
# Epoch 57: val_loss did not improve from 0.12792
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9884 - loss: 0.1156 - val_accuracy: 0.9851 - val_loss: 0.1295 - learning_rate: 2.0000e-05
# Epoch 58/200
# 933/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9872 - loss: 0.1169
# Epoch 58: val_loss did not improve from 0.12792
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9886 - loss: 0.1135 - val_accuracy: 0.9859 - val_loss: 0.1286 - learning_rate: 2.0000e-05
# Epoch 59/200
# 917/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9885 - loss: 0.1132
# Epoch 59: val_loss did not improve from 0.12792
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9898 - loss: 0.1111 - val_accuracy: 0.9854 - val_loss: 0.1281 - learning_rate: 2.0000e-05
# Epoch 60/200
# 924/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9887 - loss: 0.1121
# Epoch 60: val_loss improved from 0.12792 to 0.12492, saving model to best_densenet201_crop_oversampling_320.keras
#
# Epoch 60: finished saving model to best_densenet201_crop_oversampling_320.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9888 - loss: 0.1126 - val_accuracy: 0.9858 - val_loss: 0.1249 - learning_rate: 2.0000e-05
# Epoch 61/200
# 919/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9889 - loss: 0.1126
# Epoch 61: val_loss did not improve from 0.12492
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9893 - loss: 0.1111 - val_accuracy: 0.9858 - val_loss: 0.1251 - learning_rate: 2.0000e-05
# Epoch 62/200
# 937/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9887 - loss: 0.1116
# Epoch 62: val_loss improved from 0.12492 to 0.12292, saving model to best_densenet201_crop_oversampling_320.keras
#
# Epoch 62: finished saving model to best_densenet201_crop_oversampling_320.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9894 - loss: 0.1099 - val_accuracy: 0.9860 - val_loss: 0.1229 - learning_rate: 2.0000e-05
# Epoch 63/200
# 937/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9889 - loss: 0.1068
# Epoch 63: val_loss did not improve from 0.12292
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9887 - loss: 0.1075 - val_accuracy: 0.9860 - val_loss: 0.1256 - learning_rate: 2.0000e-05
# Epoch 64/200
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9891 - loss: 0.1097
# Epoch 64: val_loss improved from 0.12292 to 0.11967, saving model to best_densenet201_crop_oversampling_320.keras
#
# Epoch 64: finished saving model to best_densenet201_crop_oversampling_320.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9903 - loss: 0.1072 - val_accuracy: 0.9866 - val_loss: 0.1197 - learning_rate: 2.0000e-05
# Epoch 65/200
# 937/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9895 - loss: 0.1069
# Epoch 65: val_loss improved from 0.11967 to 0.11920, saving model to best_densenet201_crop_oversampling_320.keras
#
# Epoch 65: finished saving model to best_densenet201_crop_oversampling_320.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9897 - loss: 0.1062 - val_accuracy: 0.9868 - val_loss: 0.1192 - learning_rate: 2.0000e-05
# Epoch 66/200
# 931/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9893 - loss: 0.1075
# Epoch 66: val_loss did not improve from 0.11920
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9899 - loss: 0.1053 - val_accuracy: 0.9866 - val_loss: 0.1223 - learning_rate: 2.0000e-05
# Epoch 67/200
# 929/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9908 - loss: 0.1035
# Epoch 67: val_loss did not improve from 0.11920
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9914 - loss: 0.1019 - val_accuracy: 0.9867 - val_loss: 0.1216 - learning_rate: 2.0000e-05
# Epoch 68/200
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9891 - loss: 0.1062
# Epoch 68: val_loss did not improve from 0.11920
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9907 - loss: 0.1025 - val_accuracy: 0.9862 - val_loss: 0.1202 - learning_rate: 2.0000e-05
# Epoch 69/200
# 932/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9901 - loss: 0.1039
# Epoch 69: ReduceLROnPlateau reducing learning rate to 3.999999898951501e-06.
#
# Epoch 69: val_loss did not improve from 0.11920
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9898 - loss: 0.1044 - val_accuracy: 0.9862 - val_loss: 0.1199 - learning_rate: 2.0000e-05
# Epoch 70/200
# 916/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9890 - loss: 0.1048
# Epoch 70: val_loss did not improve from 0.11920
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9915 - loss: 0.1003 - val_accuracy: 0.9866 - val_loss: 0.1199 - learning_rate: 4.0000e-06
# Epoch 71/200
# 918/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9928 - loss: 0.0969
# Epoch 71: val_loss did not improve from 0.11920
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9923 - loss: 0.0969 - val_accuracy: 0.9864 - val_loss: 0.1203 - learning_rate: 4.0000e-06
# Epoch 72/200
# 923/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9921 - loss: 0.0965
# Epoch 72: val_loss did not improve from 0.11920
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9923 - loss: 0.0960 - val_accuracy: 0.9864 - val_loss: 0.1202 - learning_rate: 4.0000e-06
# Epoch 73/200
# 928/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9914 - loss: 0.0987
# Epoch 73: ReduceLROnPlateau reducing learning rate to 7.999999979801942e-07.
#
# Epoch 73: val_loss did not improve from 0.11920
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9923 - loss: 0.0966 - val_accuracy: 0.9866 - val_loss: 0.1195 - learning_rate: 4.0000e-06
# Epoch 74/200
# 919/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9921 - loss: 0.0976
# Epoch 74: val_loss did not improve from 0.11920
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9925 - loss: 0.0960 - val_accuracy: 0.9866 - val_loss: 0.1198 - learning_rate: 8.0000e-07
# Epoch 75/200
# 921/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9920 - loss: 0.0977
# Epoch 75: val_loss did not improve from 0.11920
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9930 - loss: 0.0951 - val_accuracy: 0.9864 - val_loss: 0.1198 - learning_rate: 8.0000e-07
# Epoch 75: early stopping
# Restoring model weights from the end of the best epoch: 65.

# %%
plt.figure(figsize=(8, 5))
plt.plot(history.history["accuracy"], label="Treino")
plt.plot(history.history["val_accuracy"], label="Validação")
plt.title("Acurácia durante o treinamento")
plt.xlabel("Época")
plt.ylabel("Acurácia")
plt.legend()
plt.grid(True, alpha=0.3)
plt.savefig("acuracia_densenet201_crop_oversampling.png", dpi=300, bbox_inches="tight")
plt.show()

plt.figure(figsize=(8, 5))
plt.plot(history.history["loss"], label="Treino")
plt.plot(history.history["val_loss"], label="Validação")
plt.title("Perda durante o treinamento")
plt.xlabel("Época")
plt.ylabel("Loss")
plt.legend()
plt.grid(True, alpha=0.3)
plt.savefig("loss_densenet201_crop_oversampling.png", dpi=300, bbox_inches="tight")
plt.show()

# %%
best_classifier = keras.models.load_model(BEST_MODEL_PATH)

pred_probs = best_classifier.predict(X_test_features, verbose=0)
y_pred = np.argmax(pred_probs, axis=1)

print("Relatório de Classificação:")
print(classification_report(
    y_test,
    y_pred,
    target_names=classes,
    digits=4,
    zero_division=0
))

acc = accuracy_score(y_test, y_pred)

macro_precision = precision_score(y_test, y_pred, average="macro", zero_division=0)
macro_recall = recall_score(y_test, y_pred, average="macro", zero_division=0)
macro_f1 = f1_score(y_test, y_pred, average="macro", zero_division=0)

weighted_precision = precision_score(y_test, y_pred, average="weighted", zero_division=0)
weighted_recall = recall_score(y_test, y_pred, average="weighted", zero_division=0)
weighted_f1 = f1_score(y_test, y_pred, average="weighted", zero_division=0)

print("\nMÉTRICAS GERAIS DO MODELO")
print(f"Accuracy: {acc:.4f}")

print("\nMacro Average:")
print(f"  Precision: {macro_precision:.4f}")
print(f"  Recall: {macro_recall:.4f}")
print(f"  F1-Score: {macro_f1:.4f}")

print("\nWeighted Average:")
print(f"  Precision: {weighted_precision:.4f}")
print(f"  Recall: {weighted_recall:.4f}")
print(f"  F1-Score: {weighted_f1:.4f}")
# Out:
# Relatório de Classificação:
#               precision    recall  f1-score   support
#
#          MEL     0.6830    0.6861    0.6846       223
#           NV     0.9318    0.9366    0.9342      1341
#          BCC     0.7290    0.7573    0.7429       103
#        AKIEC     0.5395    0.6308    0.5816        65
#          BKL     0.7323    0.6591    0.6938       220
#           DF     0.7143    0.6522    0.6818        23
#         VASC     0.8276    0.8571    0.8421        28
#
#     accuracy                         0.8547      2003
#    macro avg     0.7368    0.7399    0.7373      2003
# weighted avg     0.8550    0.8547    0.8545      2003
#
#
# MÉTRICAS GERAIS DO MODELO
# Accuracy: 0.8547
#
# Macro Average:
#   Precision: 0.7368
#   Recall: 0.7399
#   F1-Score: 0.7373
#
# Weighted Average:
#   Precision: 0.8550
#   Recall: 0.8547
#   F1-Score: 0.8545

# %%
cm = confusion_matrix(y_test, y_pred, labels=list(range(len(classes))))
cm_percent = cm.astype("float") / cm.sum(axis=1, keepdims=True) * 100
cm_percent = np.nan_to_num(cm_percent)

plt.figure(figsize=(8, 7))
im = plt.imshow(cm_percent, interpolation="nearest", cmap="Blues", vmin=0, vmax=100)
plt.title("Matriz de Confusão (%) - DenseNet201 + Crop + Oversampling + 320x320")
plt.colorbar(im, label="%")

tick_marks = np.arange(len(classes))
plt.xticks(tick_marks, classes, rotation=45)
plt.yticks(tick_marks, classes)

for i in range(cm_percent.shape[0]):
    for j in range(cm_percent.shape[1]):
        color = "white" if cm_percent[i, j] > 50 else "black"
        plt.text(
            j,
            i,
            f"{cm_percent[i, j]:.1f}",
            ha="center",
            va="center",
            color=color,
            fontsize=8
        )

plt.ylabel("Classe Real")
plt.xlabel("Classe Predita")
plt.tight_layout()
plt.savefig("matriz_confusao_percent_densenet201_crop_oversampling.png", dpi=300, bbox_inches="tight")
plt.show()

# %%
test_eval_df = test_df.copy().reset_index(drop=True)
test_eval_df["y_true"] = y_test
test_eval_df["y_pred"] = y_pred
test_eval_df["correct"] = test_eval_df["y_true"] == test_eval_df["y_pred"]

correct_samples = test_eval_df[test_eval_df["correct"]].head(4)
incorrect_samples = test_eval_df[~test_eval_df["correct"]].head(4)

samples_to_plot = pd.concat([correct_samples, incorrect_samples], axis=0).reset_index(drop=True)

plt.figure(figsize=(12, 6))

for i, row in samples_to_plot.iterrows():
    image = preprocess_image_path(row["image_path"], row["mask_path"])
    image = np.clip(image, 0, 255).astype("uint8")

    plt.subplot(2, 4, i + 1)
    plt.imshow(image)

    true_label = class_name[int(row["y_true"])]
    pred_label = class_name[int(row["y_pred"])]

    plt.title(f"{true_label} → {pred_label}", fontsize=10)
    plt.axis("off")

plt.tight_layout()
plt.savefig("exemplos_classificacao_densenet201_crop_oversampling.png", dpi=300, bbox_inches="tight")
plt.show()

# %%
feature_extractor.save(FEATURE_EXTRACTOR_PATH)
best_classifier.save(FINAL_MODEL_PATH)

print("Extratora DenseNet201 salva em:", FEATURE_EXTRACTOR_PATH)
print("Classificador final salvo em:", FINAL_MODEL_PATH)
print("Melhor checkpoint salvo em:", BEST_MODEL_PATH)
# Out:
# Extratora DenseNet201 salva em: densenet201_crop_320_feature_extractor.keras
# Classificador final salvo em: densenet201_crop_oversampling_320_final.keras
# Melhor checkpoint salvo em: best_densenet201_crop_oversampling_320.keras
