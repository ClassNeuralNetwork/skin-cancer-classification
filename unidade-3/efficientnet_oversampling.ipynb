# %%
import os
os.environ["KERAS_BACKEND"] = "tensorflow"

import random
from pathlib import Path
from collections import Counter

import cv2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import tensorflow as tf
import keras
from keras import layers, models, regularizers

from tensorflow.keras.applications import EfficientNetB4
from tensorflow.keras.applications.efficientnet import preprocess_input

from sklearn.model_selection import train_test_split
from sklearn.metrics import (
    classification_report,
    confusion_matrix,
    accuracy_score,
    precision_score,
    recall_score,
    f1_score
)

from imblearn.over_sampling import RandomOverSampler

# %%
SEED = 42
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)

DATA_DIR = Path("../data")
IMAGES_DIR = DATA_DIR / "images"
MASKS_DIR = DATA_DIR / "masks"
CSV_PATH = DATA_DIR / "GroundTruth.csv"

IMG_SIZE = (380, 380)
BATCH_SIZE = 32
EPOCHS = 200
LEARNING_RATE = 0.0001

TEST_SIZE = 0.20
VAL_SIZE = 0.20

USE_DULL_RAZOR = True

USE_MASK_SEGMENTATION = False

USE_MASK_CROP = True
CROP_MARGIN = 20

BEST_MODEL_PATH = "best_efficientnetb4_crop_oversampling_380.keras"
FINAL_MODEL_PATH = "efficientnetb4_crop_oversampling_380_final.keras"
FEATURE_EXTRACTOR_PATH = "efficientnetb4_crop_380_feature_extractor.keras"

classes = ["MEL", "NV", "BCC", "AKIEC", "BKL", "DF", "VASC"]
class_code = {label: idx for idx, label in enumerate(classes)}
class_name = {idx: label for label, idx in class_code.items()}

print("IMG_SIZE:", IMG_SIZE)
print("BATCH_SIZE:", BATCH_SIZE)
print("EPOCHS:", EPOCHS)
print("LEARNING_RATE:", LEARNING_RATE)
print("USE_DULL_RAZOR:", USE_DULL_RAZOR)
print("USE_MASK_SEGMENTATION:", USE_MASK_SEGMENTATION)
print("USE_MASK_CROP:", USE_MASK_CROP)
print("CROP_MARGIN:", CROP_MARGIN)
print(class_code)
# Out:
# IMG_SIZE: (380, 380)
# BATCH_SIZE: 32
# EPOCHS: 200
# LEARNING_RATE: 0.0001
# USE_DULL_RAZOR: True
# USE_MASK_SEGMENTATION: False
# USE_MASK_CROP: True
# CROP_MARGIN: 20
# {'MEL': 0, 'NV': 1, 'BCC': 2, 'AKIEC': 3, 'BKL': 4, 'DF': 5, 'VASC': 6}

# %%
print("Arquitetura: EfficientNetB4")
print("Balanceamento: Random Oversampling")
print("IMG_SIZE:", IMG_SIZE)
print("USE_DULL_RAZOR:", USE_DULL_RAZOR)
print("USE_MASK_SEGMENTATION:", USE_MASK_SEGMENTATION)
print("USE_MASK_CROP:", USE_MASK_CROP)
print("CROP_MARGIN:", CROP_MARGIN)
print("BEST_MODEL_PATH:", BEST_MODEL_PATH)
print("FINAL_MODEL_PATH:", FINAL_MODEL_PATH)
print("FEATURE_EXTRACTOR_PATH:", FEATURE_EXTRACTOR_PATH)
# Out:
# Arquitetura: EfficientNetB4
# Balanceamento: Random Oversampling
# IMG_SIZE: (380, 380)
# USE_DULL_RAZOR: True
# USE_MASK_SEGMENTATION: False
# USE_MASK_CROP: True
# CROP_MARGIN: 20
# BEST_MODEL_PATH: best_efficientnetb4_crop_oversampling_380.keras
# FINAL_MODEL_PATH: efficientnetb4_crop_oversampling_380_final.keras
# FEATURE_EXTRACTOR_PATH: efficientnetb4_crop_380_feature_extractor.keras

# %%
print("Arquitetura: EfficientNetB4")
print("IMG_SIZE:", IMG_SIZE)
print("USE_DULL_RAZOR:", USE_DULL_RAZOR)
print("USE_MASK_SEGMENTATION:", USE_MASK_SEGMENTATION)
print("USE_MASK_CROP:", USE_MASK_CROP)
print("CROP_MARGIN:", CROP_MARGIN)
# Out:
# Arquitetura: EfficientNetB4
# IMG_SIZE: (380, 380)
# USE_DULL_RAZOR: True
# USE_MASK_SEGMENTATION: False
# USE_MASK_CROP: True
# CROP_MARGIN: 20

# %%
def find_image_path(image_id, images_dir):
    for ext in [".jpg", ".jpeg", ".png"]:
        path = images_dir / f"{image_id}{ext}"
        if path.exists():
            return str(path)
    return None


def find_mask_path(image_id, masks_dir):
    if not masks_dir.exists():
        return None

    candidates = [
        masks_dir / f"{image_id}_segmentation.png",
        masks_dir / f"{image_id}_segmentation.jpg",
        masks_dir / f"{image_id}_mask.png",
        masks_dir / f"{image_id}_mask.jpg",
        masks_dir / f"{image_id}.png",
        masks_dir / f"{image_id}.jpg",
    ]

    for path in candidates:
        if path.exists():
            return str(path)

    matches = list(masks_dir.glob(f"{image_id}*"))
    if len(matches) > 0:
        return str(matches[0])

    return None


metadata = pd.read_csv(CSV_PATH)

rows = []
for _, row in metadata.iterrows():
    image_id = str(row["image"])
    image_path = find_image_path(image_id, IMAGES_DIR)
    mask_path = find_mask_path(image_id, MASKS_DIR)

    if image_path is None:
        continue

    label_name = row[classes].idxmax()
    label = class_code[label_name]

    rows.append({
        "image": image_id,
        "image_path": image_path,
        "mask_path": mask_path,
        "class_name": label_name,
        "label": label
    })

df = pd.DataFrame(rows)

print("Total de imagens localizadas:", len(df))
display(df.head())

print("\nDistribuição original:")
print(df["class_name"].value_counts().reindex(classes))

print("\nMáscaras encontradas:", df["mask_path"].notna().sum())
# Out:
# Total de imagens localizadas: 10015
#           image                       image_path  \
# 0  ISIC_0024306  ../data/images/ISIC_0024306.jpg
# 1  ISIC_0024307  ../data/images/ISIC_0024307.jpg
# 2  ISIC_0024308  ../data/images/ISIC_0024308.jpg
# 3  ISIC_0024309  ../data/images/ISIC_0024309.jpg
# 4  ISIC_0024310  ../data/images/ISIC_0024310.jpg
#
#                                      mask_path class_name  label
# 0  ../data/masks/ISIC_0024306_segmentation.png         NV      1
# 1  ../data/masks/ISIC_0024307_segmentation.png         NV      1
# 2  ../data/masks/ISIC_0024308_segmentation.png         NV      1
# 3  ../data/masks/ISIC_0024309_segmentation.png         NV      1
# 4  ../data/masks/ISIC_0024310_segmentation.png        MEL      0
# Distribuição original:
# class_name
# MEL      1113
# NV       6705
# BCC       514
# AKIEC     327
# BKL      1099
# DF        115
# VASC      142
# Name: count, dtype: int64
#
# Máscaras encontradas: 10015

# %%
train_df, test_df = train_test_split(
    df,
    test_size=TEST_SIZE,
    random_state=SEED,
    stratify=df["label"]
)

print("Treino original:", len(train_df))
print("Teste final:", len(test_df))

print("\nDistribuição treino original:")
print(train_df["class_name"].value_counts().reindex(classes))

print("\nDistribuição teste final:")
print(test_df["class_name"].value_counts().reindex(classes))
# Out:
# Treino original: 8012
# Teste final: 2003
#
# Distribuição treino original:
# class_name
# MEL       890
# NV       5364
# BCC       411
# AKIEC     262
# BKL       879
# DF         92
# VASC      114
# Name: count, dtype: int64
#
# Distribuição teste final:
# class_name
# MEL       223
# NV       1341
# BCC       103
# AKIEC      65
# BKL       220
# DF         23
# VASC       28
# Name: count, dtype: int64

# %%
def read_rgb_image(path):
    if isinstance(path, bytes):
        path = path.decode("utf-8")

    image_bgr = cv2.imread(str(path), cv2.IMREAD_COLOR)

    if image_bgr is None:
        raise ValueError(f"Não foi possível carregar a imagem: {path}")

    image_rgb = cv2.cvtColor(image_bgr, cv2.COLOR_BGR2RGB)

    return image_rgb


def dull_razor_remove_hair(image_rgb, kernel_size=(9, 9), threshold_value=10, inpaint_radius=6):
    image_rgb = image_rgb.astype(np.uint8)

    gray = cv2.cvtColor(image_rgb, cv2.COLOR_RGB2GRAY)

    kernel = cv2.getStructuringElement(cv2.MORPH_RECT, kernel_size)
    blackhat = cv2.morphologyEx(gray, cv2.MORPH_BLACKHAT, kernel)

    blackhat_blur = cv2.GaussianBlur(blackhat, (3, 3), 0)

    _, mask = cv2.threshold(
        blackhat_blur,
        threshold_value,
        255,
        cv2.THRESH_BINARY
    )

    image_bgr = cv2.cvtColor(image_rgb, cv2.COLOR_RGB2BGR)

    clean_bgr = cv2.inpaint(
        image_bgr,
        mask,
        inpaint_radius,
        cv2.INPAINT_TELEA
    )

    clean_rgb = cv2.cvtColor(clean_bgr, cv2.COLOR_BGR2RGB)

    return clean_rgb


def read_binary_mask(mask_path, target_shape):
    if mask_path is None or pd.isna(mask_path):
        return None

    if isinstance(mask_path, bytes):
        mask_path = mask_path.decode("utf-8")

    mask = cv2.imread(str(mask_path), cv2.IMREAD_GRAYSCALE)

    if mask is None:
        return None

    height, width = target_shape[:2]
    mask = cv2.resize(mask, (width, height))

    binary_mask = (mask > 127).astype(np.uint8)

    return binary_mask


def apply_mask_segmentation(image_rgb, mask_path):
    binary_mask = read_binary_mask(mask_path, target_shape=image_rgb.shape)

    if binary_mask is None:
        return image_rgb

    segmented = image_rgb * np.expand_dims(binary_mask, axis=-1)

    # Proteção contra máscara ruim.
    if np.mean(segmented) < 5:
        return image_rgb

    return segmented


def crop_lesion_with_margin(image_rgb, mask_path, margin=20):
    binary_mask = read_binary_mask(mask_path, target_shape=image_rgb.shape)

    if binary_mask is None:
        return image_rgb

    ys, xs = np.where(binary_mask > 0)

    if len(xs) == 0 or len(ys) == 0:
        return image_rgb

    height, width = image_rgb.shape[:2]

    x_min = max(xs.min() - margin, 0)
    x_max = min(xs.max() + margin, width - 1)
    y_min = max(ys.min() - margin, 0)
    y_max = min(ys.max() + margin, height - 1)

    cropped = image_rgb[y_min:y_max + 1, x_min:x_max + 1]

    if cropped.size == 0:
        return image_rgb

    return cropped


def preprocess_image_path(path, mask_path=None):
    image_rgb = read_rgb_image(path)

    if USE_DULL_RAZOR:
        image_rgb = dull_razor_remove_hair(image_rgb)

    if USE_MASK_CROP:
        image_rgb = crop_lesion_with_margin(
            image_rgb,
            mask_path,
            margin=CROP_MARGIN
        )
    elif USE_MASK_SEGMENTATION:
        image_rgb = apply_mask_segmentation(image_rgb, mask_path)

    image_rgb = cv2.resize(image_rgb, IMG_SIZE)

    return image_rgb.astype("float32")

# %%
sample_row = train_df.sample(1, random_state=SEED).iloc[0]

original = read_rgb_image(sample_row["image_path"])
dull = dull_razor_remove_hair(original) if USE_DULL_RAZOR else original
segmented = apply_mask_segmentation(dull, sample_row["mask_path"])
cropped = crop_lesion_with_margin(dull, sample_row["mask_path"], margin=CROP_MARGIN)
final_img = preprocess_image_path(sample_row["image_path"], sample_row["mask_path"])
final_img = np.clip(final_img, 0, 255).astype("uint8")

plt.figure(figsize=(16, 4))

plt.subplot(1, 5, 1)
plt.imshow(original)
plt.title("Original")
plt.axis("off")

plt.subplot(1, 5, 2)
plt.imshow(dull)
plt.title("Dull Razor")
plt.axis("off")

plt.subplot(1, 5, 3)
plt.imshow(np.clip(segmented, 0, 255).astype("uint8"))
plt.title("Máscara aplicada")
plt.axis("off")

plt.subplot(1, 5, 4)
plt.imshow(np.clip(cropped, 0, 255).astype("uint8"))
plt.title("Crop + margem")
plt.axis("off")

plt.subplot(1, 5, 5)
plt.imshow(final_img)
plt.title("Final 256x256")
plt.axis("off")

plt.tight_layout()
plt.savefig("pipeline_efficientnetb3_crop_oversampling.png", dpi=300, bbox_inches="tight")
plt.show()

# %%
def load_image_for_features_py(image_path, mask_path, label):
    if isinstance(image_path, bytes):
        image_path = image_path.decode("utf-8")

    if isinstance(mask_path, bytes):
        mask_path = mask_path.decode("utf-8")

    if mask_path == "None" or mask_path == "":
        mask_path = None

    image = preprocess_image_path(image_path, mask_path)

    return image.astype("float32"), np.int32(label)


def tf_load_image_for_features(image_path, mask_path, label):
    image, label = tf.numpy_function(
        load_image_for_features_py,
        [image_path, mask_path, label],
        [tf.float32, tf.int32]
    )

    image.set_shape((IMG_SIZE[0], IMG_SIZE[1], 3))
    label.set_shape(())

    return image, label


def build_image_dataset(dataframe, batch_size=BATCH_SIZE, shuffle=False):
    mask_values = dataframe["mask_path"].fillna("None").astype(str).values

    ds = tf.data.Dataset.from_tensor_slices((
        dataframe["image_path"].astype(str).values,
        mask_values,
        dataframe["label"].values.astype("int32")
    ))

    if shuffle:
        ds = ds.shuffle(buffer_size=len(dataframe), seed=SEED)

    ds = ds.map(tf_load_image_for_features, num_parallel_calls=tf.data.AUTOTUNE)
    ds = ds.batch(batch_size)
    ds = ds.prefetch(tf.data.AUTOTUNE)

    return ds


train_image_ds = build_image_dataset(train_df, shuffle=False)
test_image_ds = build_image_dataset(test_df, shuffle=False)

print(train_image_ds)
print(test_image_ds)
# Out:
# <_PrefetchDataset element_spec=(TensorSpec(shape=(None, 380, 380, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>
# <_PrefetchDataset element_spec=(TensorSpec(shape=(None, 380, 380, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
def build_feature_extractor(input_shape=(380, 380, 3)):
    inputs = layers.Input(shape=input_shape)

    x = preprocess_input(inputs)

    base_model = EfficientNetB4(
        weights="imagenet",
        include_top=False,
        input_shape=input_shape
    )

    base_model.trainable = False

    x = base_model(x, training=False)
    x = layers.GlobalAveragePooling2D()(x)

    feature_extractor = models.Model(
        inputs=inputs,
        outputs=x,
        name="efficientnetb4_crop_feature_extractor"
    )

    return feature_extractor


feature_extractor = build_feature_extractor(
    input_shape=(IMG_SIZE[0], IMG_SIZE[1], 3)
)

feature_extractor.summary()
# Out:
# Model: "efficientnetb4_crop_feature_extractor"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 380, 380, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ efficientnetb4 (Functional)     │ (None, 12, 12, 1792)   │    17,673,823 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 1792)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 17,673,823 (67.42 MB)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 17,673,823 (67.42 MB)

# %%
def extract_features(dataset, feature_extractor):
    features_list = []
    labels_list = []

    for images, labels in dataset:
        features = feature_extractor.predict(images, verbose=0)
        features_list.append(features)
        labels_list.append(labels.numpy())

    X = np.concatenate(features_list, axis=0)
    y = np.concatenate(labels_list, axis=0)

    return X.astype("float32"), y.astype("int32")


X_train_features, y_train = extract_features(train_image_ds, feature_extractor)
X_test_features, y_test = extract_features(test_image_ds, feature_extractor)

print("X_train_features:", X_train_features.shape)
print("y_train:", y_train.shape)
print("X_test_features:", X_test_features.shape)
print("y_test:", y_test.shape)

print("\nDistribuição treino antes do Oversampling:")
print(Counter(y_train))
# Out:
# X_train_features: (8012, 1792)
# y_train: (8012,)
# X_test_features: (2003, 1792)
# y_test: (2003,)
#
# Distribuição treino antes do Oversampling:
# Counter({np.int32(1): 5364, np.int32(0): 890, np.int32(4): 879, np.int32(2): 411, np.int32(3): 262, np.int32(6): 114, np.int32(5): 92})

# %%
print("Distribuição treino antes do Random Oversampling:")
print(Counter(y_train))

oversampling = RandomOverSampler(
    random_state=SEED
)

X_train_oversampling, y_train_oversampling = oversampling.fit_resample(
    X_train_features,
    y_train
)

print("X_train_oversampling:", X_train_oversampling.shape)
print("y_train_oversampling:", y_train_oversampling.shape)

print("\nDistribuição treino após Random Oversampling:")
print(Counter(y_train_oversampling))
# Out:
# Distribuição treino antes do Random Oversampling:
# Counter({np.int32(1): 5364, np.int32(0): 890, np.int32(4): 879, np.int32(2): 411, np.int32(3): 262, np.int32(6): 114, np.int32(5): 92})
# X_train_oversampling: (37548, 1792)
# y_train_oversampling: (37548,)
#
# Distribuição treino após Random Oversampling:
# Counter({np.int32(1): 5364, np.int32(0): 5364, np.int32(4): 5364, np.int32(2): 5364, np.int32(5): 5364, np.int32(3): 5364, np.int32(6): 5364})

# %%
X_fit, X_val, y_fit, y_val = train_test_split(
    X_train_oversampling,
    y_train_oversampling,
    test_size=VAL_SIZE,
    random_state=SEED,
    stratify=y_train_oversampling
)

print("Treino para fit:", X_fit.shape)
print("Validação:", X_val.shape)
print("Teste final:", X_test_features.shape)

print("\nDistribuição fit:")
print(Counter(y_fit))

print("\nDistribuição validação:")
print(Counter(y_val))
# Out:
# Treino para fit: (30038, 1792)
# Validação: (7510, 1792)
# Teste final: (2003, 1792)
#
# Distribuição fit:
# Counter({np.int32(0): 4292, np.int32(4): 4291, np.int32(5): 4291, np.int32(6): 4291, np.int32(2): 4291, np.int32(3): 4291, np.int32(1): 4291})
#
# Distribuição validação:
# Counter({np.int32(2): 1073, np.int32(3): 1073, np.int32(6): 1073, np.int32(4): 1073, np.int32(1): 1073, np.int32(5): 1073, np.int32(0): 1072})

# %%
def build_classifier_head(input_dim, num_classes=len(classes)):
    inputs = layers.Input(shape=(input_dim,))

    x = layers.Dense(
        256,
        activation="relu",
        kernel_regularizer=regularizers.l2(0.001)
    )(inputs)

    x = layers.BatchNormalization()(x)
    x = layers.Dropout(0.5)(x)

    x = layers.Dense(
        128,
        activation="relu",
        kernel_regularizer=regularizers.l2(0.001)
    )(x)

    x = layers.Dropout(0.3)(x)

    outputs = layers.Dense(num_classes, activation="softmax")(x)

    model = models.Model(
        inputs=inputs,
        outputs=outputs,
        name="efficientnetb3_crop_oversampling_classifier"
    )

    return model


classifier = build_classifier_head(
    input_dim=X_train_oversampling.shape[1],
    num_classes=len(classes)
)

classifier.compile(
    optimizer=keras.optimizers.Adam(learning_rate=LEARNING_RATE),
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)

classifier.summary()
# Out:
# Model: "efficientnetb3_crop_oversampling_classifier"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_2 (InputLayer)      │ (None, 1792)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │       459,008 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 7)              │           903 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 493,831 (1.88 MB)
#  Trainable params: 493,319 (1.88 MB)
#  Non-trainable params: 512 (2.00 KB)

# %%
callbacks = [
    keras.callbacks.EarlyStopping(
        monitor="val_loss",
        patience=10,
        restore_best_weights=True,
        verbose=1
    ),
    keras.callbacks.ReduceLROnPlateau(
        monitor="val_loss",
        factor=0.2,
        patience=4,
        min_lr=1e-7,
        verbose=1
    ),
    keras.callbacks.ModelCheckpoint(
        BEST_MODEL_PATH,
        monitor="val_loss",
        save_best_only=True,
        verbose=1
    )
]

history = classifier.fit(
    X_fit,
    y_fit,
    validation_data=(X_val, y_val),
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    callbacks=callbacks
)
# Out:
# Epoch 1/200
# 921/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4250 - loss: 2.3035
# Epoch 1: val_loss improved from None to 1.30430, saving model to best_efficientnetb4_crop_oversampling_380.keras
#
# Epoch 1: finished saving model to best_efficientnetb4_crop_oversampling_380.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.5256 - loss: 1.9470 - val_accuracy: 0.7495 - val_loss: 1.3043 - learning_rate: 1.0000e-04
# Epoch 2/200
# 924/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6553 - loss: 1.5255
# Epoch 2: val_loss improved from 1.30430 to 1.10157, saving model to best_efficientnetb4_crop_oversampling_380.keras
#
# Epoch 2: finished saving model to best_efficientnetb4_crop_oversampling_380.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.6835 - loss: 1.4483 - val_accuracy: 0.8177 - val_loss: 1.1016 - learning_rate: 1.0000e-04
# Epoch 3/200
# 926/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7424 - loss: 1.2713
# Epoch 3: val_loss improved from 1.10157 to 0.96592, saving model to best_efficientnetb4_crop_oversampling_380.keras
#
# Epoch 3: finished saving model to best_efficientnetb4_crop_oversampling_380.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7530 - loss: 1.2322 - val_accuracy: 0.8581 - val_loss: 0.9659 - learning_rate: 1.0000e-04
# Epoch 4/200
# 927/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7824 - loss: 1.1266
# Epoch 4: val_loss improved from 0.96592 to 0.87736, saving model to best_efficientnetb4_crop_oversampling_380.keras
#
# Epoch 4: finished saving model to best_efficientnetb4_crop_oversampling_380.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7891 - loss: 1.0999 - val_accuracy: 0.8739 - val_loss: 0.8774 - learning_rate: 1.0000e-04
# Epoch 5/200
# 925/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8131 - loss: 1.0155
# Epoch 5: val_loss improved from 0.87736 to 0.79781, saving model to best_efficientnetb4_crop_oversampling_380.keras
#
# Epoch 5: finished saving model to best_efficientnetb4_crop_oversampling_380.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8192 - loss: 0.9901 - val_accuracy: 0.8883 - val_loss: 0.7978 - learning_rate: 1.0000e-04
# Epoch 6/200
# 929/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8316 - loss: 0.9341
# Epoch 6: val_loss improved from 0.79781 to 0.73252, saving model to best_efficientnetb4_crop_oversampling_380.keras
#
# Epoch 6: finished saving model to best_efficientnetb4_crop_oversampling_380.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8415 - loss: 0.9021 - val_accuracy: 0.8983 - val_loss: 0.7325 - learning_rate: 1.0000e-04
# Epoch 7/200
# 917/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8529 - loss: 0.8500
# Epoch 7: val_loss improved from 0.73252 to 0.66901, saving model to best_efficientnetb4_crop_oversampling_380.keras
#
# Epoch 7: finished saving model to best_efficientnetb4_crop_oversampling_380.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8561 - loss: 0.8297 - val_accuracy: 0.9189 - val_loss: 0.6690 - learning_rate: 1.0000e-04
# Epoch 8/200
# 917/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8641 - loss: 0.7896
# Epoch 8: val_loss improved from 0.66901 to 0.62158, saving model to best_efficientnetb4_crop_oversampling_380.keras
#
# Epoch 8: finished saving model to best_efficientnetb4_crop_oversampling_380.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8692 - loss: 0.7675 - val_accuracy: 0.9277 - val_loss: 0.6216 - learning_rate: 1.0000e-04
# Epoch 9/200
# 938/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8719 - loss: 0.7333
# Epoch 9: val_loss improved from 0.62158 to 0.59234, saving model to best_efficientnetb4_crop_oversampling_380.keras
#
# Epoch 9: finished saving model to best_efficientnetb4_crop_oversampling_380.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8772 - loss: 0.7170 - val_accuracy: 0.9241 - val_loss: 0.5923 - learning_rate: 1.0000e-04
# Epoch 10/200
# 931/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8791 - loss: 0.6945
# Epoch 10: val_loss improved from 0.59234 to 0.55136, saving model to best_efficientnetb4_crop_oversampling_380.keras
#
# Epoch 10: finished saving model to best_efficientnetb4_crop_oversampling_380.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8850 - loss: 0.6761 - val_accuracy: 0.9314 - val_loss: 0.5514 - learning_rate: 1.0000e-04
# Epoch 11/200
# 928/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8903 - loss: 0.6471
# Epoch 11: val_loss improved from 0.55136 to 0.52069, saving model to best_efficientnetb4_crop_oversampling_380.keras
#
# Epoch 11: finished saving model to best_efficientnetb4_crop_oversampling_380.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8935 - loss: 0.6339 - val_accuracy: 0.9389 - val_loss: 0.5207 - learning_rate: 1.0000e-04
# Epoch 12/200
# 935/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8956 - loss: 0.6189
# Epoch 12: val_loss improved from 0.52069 to 0.49235, saving model to best_efficientnetb4_crop_oversampling_380.keras
#
# Epoch 12: finished saving model to best_efficientnetb4_crop_oversampling_380.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8996 - loss: 0.6058 - val_accuracy: 0.9449 - val_loss: 0.4923 - learning_rate: 1.0000e-04
# Epoch 13/200
# 936/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9004 - loss: 0.5880
# Epoch 13: val_loss improved from 0.49235 to 0.47911, saving model to best_efficientnetb4_crop_oversampling_380.keras
#
# Epoch 13: finished saving model to best_efficientnetb4_crop_oversampling_380.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9043 - loss: 0.5762 - val_accuracy: 0.9443 - val_loss: 0.4791 - learning_rate: 1.0000e-04
# Epoch 14/200
# 937/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9071 - loss: 0.5588
# Epoch 14: val_loss did not improve from 0.47911
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9101 - loss: 0.5478 - val_accuracy: 0.9330 - val_loss: 0.4873 - learning_rate: 1.0000e-04
# Epoch 15/200
# 926/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9130 - loss: 0.5352
# Epoch 15: val_loss improved from 0.47911 to 0.43596, saving model to best_efficientnetb4_crop_oversampling_380.keras
#
# Epoch 15: finished saving model to best_efficientnetb4_crop_oversampling_380.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9150 - loss: 0.5235 - val_accuracy: 0.9479 - val_loss: 0.4360 - learning_rate: 1.0000e-04
# Epoch 16/200
# 916/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9185 - loss: 0.5054
# Epoch 16: val_loss improved from 0.43596 to 0.42157, saving model to best_efficientnetb4_crop_oversampling_380.keras
#
# Epoch 16: finished saving model to best_efficientnetb4_crop_oversampling_380.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9179 - loss: 0.4979 - val_accuracy: 0.9449 - val_loss: 0.4216 - learning_rate: 1.0000e-04
# Epoch 17/200
# 938/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9152 - loss: 0.4929
# Epoch 17: val_loss improved from 0.42157 to 0.39408, saving model to best_efficientnetb4_crop_oversampling_380.keras
#
# Epoch 17: finished saving model to best_efficientnetb4_crop_oversampling_380.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9190 - loss: 0.4823 - val_accuracy: 0.9585 - val_loss: 0.3941 - learning_rate: 1.0000e-04
# Epoch 18/200
# 926/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9218 - loss: 0.4729
# Epoch 18: val_loss did not improve from 0.39408
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9226 - loss: 0.4664 - val_accuracy: 0.9494 - val_loss: 0.3980 - learning_rate: 1.0000e-04
# Epoch 19/200
# 938/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9239 - loss: 0.4513
# Epoch 19: val_loss improved from 0.39408 to 0.36556, saving model to best_efficientnetb4_crop_oversampling_380.keras
#
# Epoch 19: finished saving model to best_efficientnetb4_crop_oversampling_380.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9266 - loss: 0.4423 - val_accuracy: 0.9589 - val_loss: 0.3656 - learning_rate: 1.0000e-04
# Epoch 20/200
# 923/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9293 - loss: 0.4329
# Epoch 20: val_loss improved from 0.36556 to 0.35117, saving model to best_efficientnetb4_crop_oversampling_380.keras
#
# Epoch 20: finished saving model to best_efficientnetb4_crop_oversampling_380.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9312 - loss: 0.4279 - val_accuracy: 0.9583 - val_loss: 0.3512 - learning_rate: 1.0000e-04
# Epoch 21/200
# 920/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9263 - loss: 0.4287
# Epoch 21: val_loss improved from 0.35117 to 0.34146, saving model to best_efficientnetb4_crop_oversampling_380.keras
#
# Epoch 21: finished saving model to best_efficientnetb4_crop_oversampling_380.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9288 - loss: 0.4192 - val_accuracy: 0.9591 - val_loss: 0.3415 - learning_rate: 1.0000e-04
# Epoch 22/200
# 922/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9276 - loss: 0.4141
# Epoch 22: val_loss improved from 0.34146 to 0.33101, saving model to best_efficientnetb4_crop_oversampling_380.keras
#
# Epoch 22: finished saving model to best_efficientnetb4_crop_oversampling_380.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9303 - loss: 0.4073 - val_accuracy: 0.9625 - val_loss: 0.3310 - learning_rate: 1.0000e-04
# Epoch 23/200
# 938/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9307 - loss: 0.4015
# Epoch 23: val_loss improved from 0.33101 to 0.31883, saving model to best_efficientnetb4_crop_oversampling_380.keras
#
# Epoch 23: finished saving model to best_efficientnetb4_crop_oversampling_380.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9333 - loss: 0.3967 - val_accuracy: 0.9658 - val_loss: 0.3188 - learning_rate: 1.0000e-04
# Epoch 24/200
# 929/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9306 - loss: 0.3962
# Epoch 24: val_loss improved from 0.31883 to 0.31680, saving model to best_efficientnetb4_crop_oversampling_380.keras
#
# Epoch 24: finished saving model to best_efficientnetb4_crop_oversampling_380.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9356 - loss: 0.3859 - val_accuracy: 0.9602 - val_loss: 0.3168 - learning_rate: 1.0000e-04
# Epoch 25/200
# 926/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9314 - loss: 0.3841
# Epoch 25: val_loss improved from 0.31680 to 0.29415, saving model to best_efficientnetb4_crop_oversampling_380.keras
#
# Epoch 25: finished saving model to best_efficientnetb4_crop_oversampling_380.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9342 - loss: 0.3758 - val_accuracy: 0.9698 - val_loss: 0.2942 - learning_rate: 1.0000e-04
# Epoch 26/200
# 929/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9341 - loss: 0.3735
# Epoch 26: val_loss did not improve from 0.29415
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9358 - loss: 0.3707 - val_accuracy: 0.9626 - val_loss: 0.3003 - learning_rate: 1.0000e-04
# Epoch 27/200
# 937/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9375 - loss: 0.3605
# Epoch 27: val_loss did not improve from 0.29415
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9371 - loss: 0.3577 - val_accuracy: 0.9632 - val_loss: 0.2942 - learning_rate: 1.0000e-04
# Epoch 28/200
# 933/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9397 - loss: 0.3485
# Epoch 28: val_loss improved from 0.29415 to 0.27257, saving model to best_efficientnetb4_crop_oversampling_380.keras
#
# Epoch 28: finished saving model to best_efficientnetb4_crop_oversampling_380.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9424 - loss: 0.3397 - val_accuracy: 0.9694 - val_loss: 0.2726 - learning_rate: 1.0000e-04
# Epoch 29/200
# 915/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9381 - loss: 0.3430
# Epoch 29: val_loss did not improve from 0.27257
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9403 - loss: 0.3346 - val_accuracy: 0.9670 - val_loss: 0.2731 - learning_rate: 1.0000e-04
# Epoch 30/200
# 922/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9456 - loss: 0.3229
# Epoch 30: val_loss improved from 0.27257 to 0.26428, saving model to best_efficientnetb4_crop_oversampling_380.keras
#
# Epoch 30: finished saving model to best_efficientnetb4_crop_oversampling_380.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9438 - loss: 0.3239 - val_accuracy: 0.9690 - val_loss: 0.2643 - learning_rate: 1.0000e-04
# Epoch 31/200
# 929/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9401 - loss: 0.3322
# Epoch 31: val_loss improved from 0.26428 to 0.26143, saving model to best_efficientnetb4_crop_oversampling_380.keras
#
# Epoch 31: finished saving model to best_efficientnetb4_crop_oversampling_380.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9424 - loss: 0.3232 - val_accuracy: 0.9702 - val_loss: 0.2614 - learning_rate: 1.0000e-04
# Epoch 32/200
# 918/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9389 - loss: 0.3278
# Epoch 32: val_loss improved from 0.26143 to 0.25979, saving model to best_efficientnetb4_crop_oversampling_380.keras
#
# Epoch 32: finished saving model to best_efficientnetb4_crop_oversampling_380.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9422 - loss: 0.3199 - val_accuracy: 0.9651 - val_loss: 0.2598 - learning_rate: 1.0000e-04
# Epoch 33/200
# 926/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9390 - loss: 0.3195
# Epoch 33: val_loss improved from 0.25979 to 0.25544, saving model to best_efficientnetb4_crop_oversampling_380.keras
#
# Epoch 33: finished saving model to best_efficientnetb4_crop_oversampling_380.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9429 - loss: 0.3129 - val_accuracy: 0.9668 - val_loss: 0.2554 - learning_rate: 1.0000e-04
# Epoch 34/200
# 920/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9464 - loss: 0.3038
# Epoch 34: val_loss improved from 0.25544 to 0.24647, saving model to best_efficientnetb4_crop_oversampling_380.keras
#
# Epoch 34: finished saving model to best_efficientnetb4_crop_oversampling_380.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9472 - loss: 0.3029 - val_accuracy: 0.9711 - val_loss: 0.2465 - learning_rate: 1.0000e-04
# Epoch 35/200
# 923/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9423 - loss: 0.3115
# Epoch 35: val_loss did not improve from 0.24647
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9438 - loss: 0.3086 - val_accuracy: 0.9627 - val_loss: 0.2593 - learning_rate: 1.0000e-04
# Epoch 36/200
# 921/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9433 - loss: 0.3053
# Epoch 36: val_loss did not improve from 0.24647
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9460 - loss: 0.2985 - val_accuracy: 0.9688 - val_loss: 0.2472 - learning_rate: 1.0000e-04
# Epoch 37/200
# 930/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9463 - loss: 0.2929
# Epoch 37: val_loss improved from 0.24647 to 0.23939, saving model to best_efficientnetb4_crop_oversampling_380.keras
#
# Epoch 37: finished saving model to best_efficientnetb4_crop_oversampling_380.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9496 - loss: 0.2837 - val_accuracy: 0.9676 - val_loss: 0.2394 - learning_rate: 1.0000e-04
# Epoch 38/200
# 932/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9433 - loss: 0.2978
# Epoch 38: val_loss improved from 0.23939 to 0.22478, saving model to best_efficientnetb4_crop_oversampling_380.keras
#
# Epoch 38: finished saving model to best_efficientnetb4_crop_oversampling_380.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9466 - loss: 0.2897 - val_accuracy: 0.9728 - val_loss: 0.2248 - learning_rate: 1.0000e-04
# Epoch 39/200
# 922/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9443 - loss: 0.2943
# Epoch 39: val_loss did not improve from 0.22478
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9472 - loss: 0.2868 - val_accuracy: 0.9679 - val_loss: 0.2329 - learning_rate: 1.0000e-04
# Epoch 40/200
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9478 - loss: 0.2821
# Epoch 40: val_loss did not improve from 0.22478
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9486 - loss: 0.2795 - val_accuracy: 0.9597 - val_loss: 0.2521 - learning_rate: 1.0000e-04
# Epoch 41/200
# 925/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9463 - loss: 0.2827
# Epoch 41: val_loss improved from 0.22478 to 0.21202, saving model to best_efficientnetb4_crop_oversampling_380.keras
#
# Epoch 41: finished saving model to best_efficientnetb4_crop_oversampling_380.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9488 - loss: 0.2750 - val_accuracy: 0.9735 - val_loss: 0.2120 - learning_rate: 1.0000e-04
# Epoch 42/200
# 934/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9490 - loss: 0.2708
# Epoch 42: val_loss did not improve from 0.21202
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9506 - loss: 0.2687 - val_accuracy: 0.9695 - val_loss: 0.2196 - learning_rate: 1.0000e-04
# Epoch 43/200
# 928/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9485 - loss: 0.2703
# Epoch 43: val_loss did not improve from 0.21202
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9486 - loss: 0.2699 - val_accuracy: 0.9571 - val_loss: 0.2587 - learning_rate: 1.0000e-04
# Epoch 44/200
# 935/939 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9480 - loss: 0.2676
# Epoch 44: val_loss did not improve from 0.21202
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9524 - loss: 0.2581 - val_accuracy: 0.9690 - val_loss: 0.2194 - learning_rate: 1.0000e-04
# Epoch 45/200
# 921/939 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9482 - loss: 0.2654
# Epoch 45: val_loss improved from 0.21202 to 0.21164, saving model to best_efficientnetb4_crop_oversampling_380.keras
#
# Epoch 45: finished saving model to best_efficientnetb4_crop_oversampling_380.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9513 - loss: 0.2598 - val_accuracy: 0.9719 - val_loss: 0.2116 - learning_rate: 1.0000e-04
# Epoch 46/200
# 930/939 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9518 - loss: 0.2566
# Epoch 46: val_loss improved from 0.21164 to 0.20258, saving model to best_efficientnetb4_crop_oversampling_380.keras
#
# Epoch 46: finished saving model to best_efficientnetb4_crop_oversampling_380.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9522 - loss: 0.2555 - val_accuracy: 0.9750 - val_loss: 0.2026 - learning_rate: 1.0000e-04
# Epoch 47/200
# 936/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9498 - loss: 0.2621
# Epoch 47: val_loss did not improve from 0.20258
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9514 - loss: 0.2600 - val_accuracy: 0.9727 - val_loss: 0.2029 - learning_rate: 1.0000e-04
# Epoch 48/200
# 936/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9509 - loss: 0.2567
# Epoch 48: val_loss improved from 0.20258 to 0.20060, saving model to best_efficientnetb4_crop_oversampling_380.keras
#
# Epoch 48: finished saving model to best_efficientnetb4_crop_oversampling_380.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9527 - loss: 0.2512 - val_accuracy: 0.9748 - val_loss: 0.2006 - learning_rate: 1.0000e-04
# Epoch 49/200
# 931/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9512 - loss: 0.2535
# Epoch 49: val_loss did not improve from 0.20060
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9499 - loss: 0.2544 - val_accuracy: 0.9712 - val_loss: 0.2065 - learning_rate: 1.0000e-04
# Epoch 50/200
# 925/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9528 - loss: 0.2471
# Epoch 50: val_loss improved from 0.20060 to 0.19285, saving model to best_efficientnetb4_crop_oversampling_380.keras
#
# Epoch 50: finished saving model to best_efficientnetb4_crop_oversampling_380.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9530 - loss: 0.2488 - val_accuracy: 0.9755 - val_loss: 0.1928 - learning_rate: 1.0000e-04
# Epoch 51/200
# 933/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9502 - loss: 0.2489
# Epoch 51: val_loss did not improve from 0.19285
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9528 - loss: 0.2455 - val_accuracy: 0.9666 - val_loss: 0.2156 - learning_rate: 1.0000e-04
# Epoch 52/200
# 916/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9556 - loss: 0.2384
# Epoch 52: val_loss did not improve from 0.19285
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9535 - loss: 0.2448 - val_accuracy: 0.9722 - val_loss: 0.2078 - learning_rate: 1.0000e-04
# Epoch 53/200
# 920/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9508 - loss: 0.2470
# Epoch 53: val_loss improved from 0.19285 to 0.19162, saving model to best_efficientnetb4_crop_oversampling_380.keras
#
# Epoch 53: finished saving model to best_efficientnetb4_crop_oversampling_380.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9520 - loss: 0.2447 - val_accuracy: 0.9756 - val_loss: 0.1916 - learning_rate: 1.0000e-04
# Epoch 54/200
# 930/939 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9545 - loss: 0.2392
# Epoch 54: val_loss improved from 0.19162 to 0.18015, saving model to best_efficientnetb4_crop_oversampling_380.keras
#
# Epoch 54: finished saving model to best_efficientnetb4_crop_oversampling_380.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9544 - loss: 0.2382 - val_accuracy: 0.9780 - val_loss: 0.1802 - learning_rate: 1.0000e-04
# Epoch 55/200
# 937/939 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9530 - loss: 0.2382
# Epoch 55: val_loss did not improve from 0.18015
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9529 - loss: 0.2375 - val_accuracy: 0.9655 - val_loss: 0.2137 - learning_rate: 1.0000e-04
# Epoch 56/200
# 929/939 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9513 - loss: 0.2457
# Epoch 56: val_loss did not improve from 0.18015
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9511 - loss: 0.2415 - val_accuracy: 0.9707 - val_loss: 0.2003 - learning_rate: 1.0000e-04
# Epoch 57/200
# 934/939 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9547 - loss: 0.2381
# Epoch 57: val_loss improved from 0.18015 to 0.17030, saving model to best_efficientnetb4_crop_oversampling_380.keras
#
# Epoch 57: finished saving model to best_efficientnetb4_crop_oversampling_380.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - accuracy: 0.9545 - loss: 0.2361 - val_accuracy: 0.9796 - val_loss: 0.1703 - learning_rate: 1.0000e-04
# Epoch 58/200
# 929/939 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9540 - loss: 0.2338
# Epoch 58: val_loss did not improve from 0.17030
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9563 - loss: 0.2287 - val_accuracy: 0.9736 - val_loss: 0.1881 - learning_rate: 1.0000e-04
# Epoch 59/200
# 925/939 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9526 - loss: 0.2362
# Epoch 59: val_loss did not improve from 0.17030
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9563 - loss: 0.2254 - val_accuracy: 0.9684 - val_loss: 0.2045 - learning_rate: 1.0000e-04
# Epoch 60/200
# 931/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9567 - loss: 0.2267
# Epoch 60: val_loss did not improve from 0.17030
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9580 - loss: 0.2236 - val_accuracy: 0.9659 - val_loss: 0.2079 - learning_rate: 1.0000e-04
# Epoch 61/200
# 937/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9569 - loss: 0.2239
# Epoch 61: ReduceLROnPlateau reducing learning rate to 1.9999999494757503e-05.
#
# Epoch 61: val_loss did not improve from 0.17030
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9550 - loss: 0.2300 - val_accuracy: 0.9772 - val_loss: 0.1784 - learning_rate: 1.0000e-04
# Epoch 62/200
# 928/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9669 - loss: 0.2005
# Epoch 62: val_loss improved from 0.17030 to 0.15607, saving model to best_efficientnetb4_crop_oversampling_380.keras
#
# Epoch 62: finished saving model to best_efficientnetb4_crop_oversampling_380.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9725 - loss: 0.1853 - val_accuracy: 0.9834 - val_loss: 0.1561 - learning_rate: 2.0000e-05
# Epoch 63/200
# 930/939 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9766 - loss: 0.1727
# Epoch 63: val_loss improved from 0.15607 to 0.15093, saving model to best_efficientnetb4_crop_oversampling_380.keras
#
# Epoch 63: finished saving model to best_efficientnetb4_crop_oversampling_380.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9779 - loss: 0.1683 - val_accuracy: 0.9842 - val_loss: 0.1509 - learning_rate: 2.0000e-05
# Epoch 64/200
# 929/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9787 - loss: 0.1633
# Epoch 64: val_loss improved from 0.15093 to 0.14880, saving model to best_efficientnetb4_crop_oversampling_380.keras
#
# Epoch 64: finished saving model to best_efficientnetb4_crop_oversampling_380.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9797 - loss: 0.1613 - val_accuracy: 0.9856 - val_loss: 0.1488 - learning_rate: 2.0000e-05
# Epoch 65/200
# 938/939 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9810 - loss: 0.1571
# Epoch 65: val_loss improved from 0.14880 to 0.14728, saving model to best_efficientnetb4_crop_oversampling_380.keras
#
# Epoch 65: finished saving model to best_efficientnetb4_crop_oversampling_380.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9816 - loss: 0.1557 - val_accuracy: 0.9851 - val_loss: 0.1473 - learning_rate: 2.0000e-05
# Epoch 66/200
# 930/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9817 - loss: 0.1533
# Epoch 66: val_loss did not improve from 0.14728
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9830 - loss: 0.1494 - val_accuracy: 0.9839 - val_loss: 0.1519 - learning_rate: 2.0000e-05
# Epoch 67/200
# 927/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9830 - loss: 0.1502
# Epoch 67: val_loss did not improve from 0.14728
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9833 - loss: 0.1481 - val_accuracy: 0.9827 - val_loss: 0.1530 - learning_rate: 2.0000e-05
# Epoch 68/200
# 938/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9842 - loss: 0.1468
# Epoch 68: val_loss improved from 0.14728 to 0.14429, saving model to best_efficientnetb4_crop_oversampling_380.keras
#
# Epoch 68: finished saving model to best_efficientnetb4_crop_oversampling_380.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9837 - loss: 0.1460 - val_accuracy: 0.9850 - val_loss: 0.1443 - learning_rate: 2.0000e-05
# Epoch 69/200
# 921/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9835 - loss: 0.1459
# Epoch 69: val_loss did not improve from 0.14429
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9840 - loss: 0.1443 - val_accuracy: 0.9839 - val_loss: 0.1464 - learning_rate: 2.0000e-05
# Epoch 70/200
# 932/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9841 - loss: 0.1438
# Epoch 70: val_loss improved from 0.14429 to 0.13925, saving model to best_efficientnetb4_crop_oversampling_380.keras
#
# Epoch 70: finished saving model to best_efficientnetb4_crop_oversampling_380.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9842 - loss: 0.1425 - val_accuracy: 0.9870 - val_loss: 0.1392 - learning_rate: 2.0000e-05
# Epoch 71/200
# 937/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9838 - loss: 0.1421
# Epoch 71: val_loss did not improve from 0.13925
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9851 - loss: 0.1383 - val_accuracy: 0.9852 - val_loss: 0.1423 - learning_rate: 2.0000e-05
# Epoch 72/200
# 929/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9836 - loss: 0.1409
# Epoch 72: val_loss did not improve from 0.13925
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9845 - loss: 0.1385 - val_accuracy: 0.9840 - val_loss: 0.1425 - learning_rate: 2.0000e-05
# Epoch 73/200
# 927/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9843 - loss: 0.1382
# Epoch 73: val_loss improved from 0.13925 to 0.13781, saving model to best_efficientnetb4_crop_oversampling_380.keras
#
# Epoch 73: finished saving model to best_efficientnetb4_crop_oversampling_380.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9864 - loss: 0.1350 - val_accuracy: 0.9863 - val_loss: 0.1378 - learning_rate: 2.0000e-05
# Epoch 74/200
# 926/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9857 - loss: 0.1368
# Epoch 74: val_loss did not improve from 0.13781
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9867 - loss: 0.1346 - val_accuracy: 0.9839 - val_loss: 0.1430 - learning_rate: 2.0000e-05
# Epoch 75/200
# 919/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9852 - loss: 0.1349
# Epoch 75: val_loss improved from 0.13781 to 0.13776, saving model to best_efficientnetb4_crop_oversampling_380.keras
#
# Epoch 75: finished saving model to best_efficientnetb4_crop_oversampling_380.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9855 - loss: 0.1339 - val_accuracy: 0.9848 - val_loss: 0.1378 - learning_rate: 2.0000e-05
# Epoch 76/200
# 938/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9846 - loss: 0.1368
# Epoch 76: val_loss improved from 0.13776 to 0.12951, saving model to best_efficientnetb4_crop_oversampling_380.keras
#
# Epoch 76: finished saving model to best_efficientnetb4_crop_oversampling_380.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9857 - loss: 0.1337 - val_accuracy: 0.9884 - val_loss: 0.1295 - learning_rate: 2.0000e-05
# Epoch 77/200
# 919/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9874 - loss: 0.1309
# Epoch 77: val_loss did not improve from 0.12951
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9881 - loss: 0.1292 - val_accuracy: 0.9855 - val_loss: 0.1362 - learning_rate: 2.0000e-05
# Epoch 78/200
# 923/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9853 - loss: 0.1320
# Epoch 78: val_loss did not improve from 0.12951
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9868 - loss: 0.1286 - val_accuracy: 0.9855 - val_loss: 0.1329 - learning_rate: 2.0000e-05
# Epoch 79/200
# 930/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9854 - loss: 0.1319
# Epoch 79: val_loss did not improve from 0.12951
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9869 - loss: 0.1290 - val_accuracy: 0.9870 - val_loss: 0.1322 - learning_rate: 2.0000e-05
# Epoch 80/200
# 931/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9869 - loss: 0.1283
# Epoch 80: ReduceLROnPlateau reducing learning rate to 3.999999898951501e-06.
#
# Epoch 80: val_loss did not improve from 0.12951
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9875 - loss: 0.1273 - val_accuracy: 0.9855 - val_loss: 0.1367 - learning_rate: 2.0000e-05
# Epoch 81/200
# 934/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9887 - loss: 0.1243
# Epoch 81: val_loss did not improve from 0.12951
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9894 - loss: 0.1218 - val_accuracy: 0.9862 - val_loss: 0.1328 - learning_rate: 4.0000e-06
# Epoch 82/200
# 931/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9877 - loss: 0.1243
# Epoch 82: val_loss did not improve from 0.12951
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9889 - loss: 0.1221 - val_accuracy: 0.9867 - val_loss: 0.1298 - learning_rate: 4.0000e-06
# Epoch 83/200
# 934/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9877 - loss: 0.1225
# Epoch 83: val_loss improved from 0.12951 to 0.12925, saving model to best_efficientnetb4_crop_oversampling_380.keras
#
# Epoch 83: finished saving model to best_efficientnetb4_crop_oversampling_380.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9888 - loss: 0.1205 - val_accuracy: 0.9875 - val_loss: 0.1292 - learning_rate: 4.0000e-06
# Epoch 84/200
# 928/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9906 - loss: 0.1182
# Epoch 84: val_loss did not improve from 0.12925
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9901 - loss: 0.1189 - val_accuracy: 0.9867 - val_loss: 0.1309 - learning_rate: 4.0000e-06
# Epoch 85/200
# 937/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9905 - loss: 0.1178
# Epoch 85: val_loss improved from 0.12925 to 0.12921, saving model to best_efficientnetb4_crop_oversampling_380.keras
#
# Epoch 85: finished saving model to best_efficientnetb4_crop_oversampling_380.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9903 - loss: 0.1178 - val_accuracy: 0.9875 - val_loss: 0.1292 - learning_rate: 4.0000e-06
# Epoch 86/200
# 923/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9897 - loss: 0.1199
# Epoch 86: val_loss improved from 0.12921 to 0.12905, saving model to best_efficientnetb4_crop_oversampling_380.keras
#
# Epoch 86: finished saving model to best_efficientnetb4_crop_oversampling_380.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9908 - loss: 0.1170 - val_accuracy: 0.9874 - val_loss: 0.1290 - learning_rate: 4.0000e-06
# Epoch 87/200
# 931/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9896 - loss: 0.1198
# Epoch 87: val_loss improved from 0.12905 to 0.12854, saving model to best_efficientnetb4_crop_oversampling_380.keras
#
# Epoch 87: finished saving model to best_efficientnetb4_crop_oversampling_380.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9902 - loss: 0.1184 - val_accuracy: 0.9877 - val_loss: 0.1285 - learning_rate: 4.0000e-06
# Epoch 88/200
# 936/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9906 - loss: 0.1182
# Epoch 88: val_loss did not improve from 0.12854
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9905 - loss: 0.1174 - val_accuracy: 0.9875 - val_loss: 0.1287 - learning_rate: 4.0000e-06
# Epoch 89/200
# 918/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9898 - loss: 0.1183
# Epoch 89: val_loss did not improve from 0.12854
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9900 - loss: 0.1169 - val_accuracy: 0.9871 - val_loss: 0.1295 - learning_rate: 4.0000e-06
# Epoch 90/200
# 923/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9895 - loss: 0.1171
# Epoch 90: val_loss improved from 0.12854 to 0.12743, saving model to best_efficientnetb4_crop_oversampling_380.keras
#
# Epoch 90: finished saving model to best_efficientnetb4_crop_oversampling_380.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9902 - loss: 0.1163 - val_accuracy: 0.9876 - val_loss: 0.1274 - learning_rate: 4.0000e-06
# Epoch 91/200
# 927/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9916 - loss: 0.1152
# Epoch 91: val_loss did not improve from 0.12743
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9918 - loss: 0.1134 - val_accuracy: 0.9871 - val_loss: 0.1284 - learning_rate: 4.0000e-06
# Epoch 92/200
# 932/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9896 - loss: 0.1160
# Epoch 92: val_loss improved from 0.12743 to 0.12730, saving model to best_efficientnetb4_crop_oversampling_380.keras
#
# Epoch 92: finished saving model to best_efficientnetb4_crop_oversampling_380.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9900 - loss: 0.1161 - val_accuracy: 0.9879 - val_loss: 0.1273 - learning_rate: 4.0000e-06
# Epoch 93/200
# 927/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9900 - loss: 0.1152
# Epoch 93: val_loss did not improve from 0.12730
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9907 - loss: 0.1151 - val_accuracy: 0.9872 - val_loss: 0.1280 - learning_rate: 4.0000e-06
# Epoch 94/200
# 938/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9916 - loss: 0.1137
# Epoch 94: val_loss improved from 0.12730 to 0.12674, saving model to best_efficientnetb4_crop_oversampling_380.keras
#
# Epoch 94: finished saving model to best_efficientnetb4_crop_oversampling_380.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9912 - loss: 0.1144 - val_accuracy: 0.9879 - val_loss: 0.1267 - learning_rate: 4.0000e-06
# Epoch 95/200
# 931/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9912 - loss: 0.1136
# Epoch 95: val_loss improved from 0.12674 to 0.12647, saving model to best_efficientnetb4_crop_oversampling_380.keras
#
# Epoch 95: finished saving model to best_efficientnetb4_crop_oversampling_380.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9922 - loss: 0.1124 - val_accuracy: 0.9881 - val_loss: 0.1265 - learning_rate: 4.0000e-06
# Epoch 96/200
# 937/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9912 - loss: 0.1139
# Epoch 96: val_loss did not improve from 0.12647
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9913 - loss: 0.1142 - val_accuracy: 0.9876 - val_loss: 0.1277 - learning_rate: 4.0000e-06
# Epoch 97/200
# 921/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9908 - loss: 0.1143
# Epoch 97: val_loss did not improve from 0.12647
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9913 - loss: 0.1134 - val_accuracy: 0.9871 - val_loss: 0.1286 - learning_rate: 4.0000e-06
# Epoch 98/200
# 933/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9910 - loss: 0.1127
# Epoch 98: val_loss improved from 0.12647 to 0.12552, saving model to best_efficientnetb4_crop_oversampling_380.keras
#
# Epoch 98: finished saving model to best_efficientnetb4_crop_oversampling_380.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9902 - loss: 0.1145 - val_accuracy: 0.9881 - val_loss: 0.1255 - learning_rate: 4.0000e-06
# Epoch 99/200
# 925/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9920 - loss: 0.1118
# Epoch 99: val_loss did not improve from 0.12552
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9920 - loss: 0.1114 - val_accuracy: 0.9875 - val_loss: 0.1263 - learning_rate: 4.0000e-06
# Epoch 100/200
# 935/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9905 - loss: 0.1140
# Epoch 100: val_loss did not improve from 0.12552
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9922 - loss: 0.1111 - val_accuracy: 0.9885 - val_loss: 0.1256 - learning_rate: 4.0000e-06
# Epoch 101/200
# 938/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9913 - loss: 0.1139
# Epoch 101: val_loss did not improve from 0.12552
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9919 - loss: 0.1117 - val_accuracy: 0.9876 - val_loss: 0.1261 - learning_rate: 4.0000e-06
# Epoch 102/200
# 926/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9897 - loss: 0.1136
# Epoch 102: ReduceLROnPlateau reducing learning rate to 7.999999979801942e-07.
#
# Epoch 102: val_loss did not improve from 0.12552
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9901 - loss: 0.1135 - val_accuracy: 0.9879 - val_loss: 0.1257 - learning_rate: 4.0000e-06
# Epoch 103/200
# 921/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9921 - loss: 0.1114
# Epoch 103: val_loss did not improve from 0.12552
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9922 - loss: 0.1113 - val_accuracy: 0.9875 - val_loss: 0.1261 - learning_rate: 8.0000e-07
# Epoch 104/200
# 927/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9916 - loss: 0.1108
# Epoch 104: val_loss did not improve from 0.12552
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9921 - loss: 0.1106 - val_accuracy: 0.9877 - val_loss: 0.1258 - learning_rate: 8.0000e-07
# Epoch 105/200
# 925/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9921 - loss: 0.1117
# Epoch 105: val_loss improved from 0.12552 to 0.12532, saving model to best_efficientnetb4_crop_oversampling_380.keras
#
# Epoch 105: finished saving model to best_efficientnetb4_crop_oversampling_380.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9915 - loss: 0.1115 - val_accuracy: 0.9884 - val_loss: 0.1253 - learning_rate: 8.0000e-07
# Epoch 106/200
# 937/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9919 - loss: 0.1106
# Epoch 106: val_loss did not improve from 0.12532
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9920 - loss: 0.1098 - val_accuracy: 0.9879 - val_loss: 0.1256 - learning_rate: 8.0000e-07
# Epoch 107/200
# 920/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9924 - loss: 0.1099
# Epoch 107: val_loss did not improve from 0.12532
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9930 - loss: 0.1090 - val_accuracy: 0.9876 - val_loss: 0.1259 - learning_rate: 8.0000e-07
# Epoch 108/200
# 921/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9918 - loss: 0.1115
# Epoch 108: val_loss did not improve from 0.12532
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9927 - loss: 0.1099 - val_accuracy: 0.9874 - val_loss: 0.1260 - learning_rate: 8.0000e-07
# Epoch 109/200
# 922/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9915 - loss: 0.1111
# Epoch 109: ReduceLROnPlateau reducing learning rate to 1.600000018697756e-07.
#
# Epoch 109: val_loss did not improve from 0.12532
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9912 - loss: 0.1113 - val_accuracy: 0.9879 - val_loss: 0.1259 - learning_rate: 8.0000e-07
# Epoch 110/200
# 925/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9915 - loss: 0.1105
# Epoch 110: val_loss did not improve from 0.12532
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9914 - loss: 0.1105 - val_accuracy: 0.9877 - val_loss: 0.1262 - learning_rate: 1.6000e-07
# Epoch 111/200
# 919/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9919 - loss: 0.1100
# Epoch 111: val_loss did not improve from 0.12532
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9916 - loss: 0.1106 - val_accuracy: 0.9877 - val_loss: 0.1262 - learning_rate: 1.6000e-07
# Epoch 112/200
# 923/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9923 - loss: 0.1093
# Epoch 112: val_loss did not improve from 0.12532
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9920 - loss: 0.1101 - val_accuracy: 0.9877 - val_loss: 0.1261 - learning_rate: 1.6000e-07
# Epoch 113/200
# 935/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9908 - loss: 0.1114
# Epoch 113: ReduceLROnPlateau reducing learning rate to 1e-07.
#
# Epoch 113: val_loss did not improve from 0.12532
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9913 - loss: 0.1111 - val_accuracy: 0.9877 - val_loss: 0.1261 - learning_rate: 1.6000e-07
# Epoch 114/200
# 932/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9918 - loss: 0.1109
# Epoch 114: val_loss did not improve from 0.12532
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9926 - loss: 0.1096 - val_accuracy: 0.9877 - val_loss: 0.1261 - learning_rate: 1.0000e-07
# Epoch 115/200
# 919/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9917 - loss: 0.1102
# Epoch 115: val_loss did not improve from 0.12532
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9922 - loss: 0.1098 - val_accuracy: 0.9877 - val_loss: 0.1261 - learning_rate: 1.0000e-07
# Epoch 115: early stopping
# Restoring model weights from the end of the best epoch: 105.

# %%
plt.figure(figsize=(8, 5))
plt.plot(history.history["accuracy"], label="Treino")
plt.plot(history.history["val_accuracy"], label="Validação")
plt.title("Acurácia durante o treinamento")
plt.xlabel("Época")
plt.ylabel("Acurácia")
plt.legend()
plt.grid(True, alpha=0.3)
plt.savefig(f"acuracia_{EfficientNetB4}_crop_oversampling_{IMG_SIZE[0]}.png", dpi=300, bbox_inches="tight")
plt.show()

plt.figure(figsize=(8, 5))
plt.plot(history.history["loss"], label="Treino")
plt.plot(history.history["val_loss"], label="Validação")
plt.title("Perda durante o treinamento")
plt.xlabel("Época")
plt.ylabel("Loss")
plt.legend()
plt.grid(True, alpha=0.3)
plt.savefig(f"loss_{EfficientNetB4}_crop_oversampling_{IMG_SIZE[0]}.png", dpi=300, bbox_inches="tight")
plt.show()

# %%
best_classifier = keras.models.load_model(BEST_MODEL_PATH)

pred_probs = best_classifier.predict(X_test_features, verbose=0)
y_pred = np.argmax(pred_probs, axis=1)

print("Relatório de Classificação:")
print(classification_report(
    y_test,
    y_pred,
    target_names=classes,
    digits=4,
    zero_division=0
))

acc = accuracy_score(y_test, y_pred)

macro_precision = precision_score(y_test, y_pred, average="macro", zero_division=0)
macro_recall = recall_score(y_test, y_pred, average="macro", zero_division=0)
macro_f1 = f1_score(y_test, y_pred, average="macro", zero_division=0)

weighted_precision = precision_score(y_test, y_pred, average="weighted", zero_division=0)
weighted_recall = recall_score(y_test, y_pred, average="weighted", zero_division=0)
weighted_f1 = f1_score(y_test, y_pred, average="weighted", zero_division=0)

print("\nMÉTRICAS GERAIS DO MODELO")
print(f"Accuracy: {acc:.4f}")

print("\nMacro Average:")
print(f"  Precision: {macro_precision:.4f}")
print(f"  Recall: {macro_recall:.4f}")
print(f"  F1-Score: {macro_f1:.4f}")

print("\nWeighted Average:")
print(f"  Precision: {weighted_precision:.4f}")
print(f"  Recall: {weighted_recall:.4f}")
print(f"  F1-Score: {weighted_f1:.4f}")
# Out:
# Relatório de Classificação:
#               precision    recall  f1-score   support
#
#          MEL     0.6239    0.6547    0.6389       223
#           NV     0.9237    0.9210    0.9223      1341
#          BCC     0.6525    0.7476    0.6968       103
#        AKIEC     0.6197    0.6769    0.6471        65
#          BKL     0.6667    0.6091    0.6366       220
#           DF     0.8000    0.6957    0.7442        23
#         VASC     0.9545    0.7500    0.8400        28
#
#     accuracy                         0.8352      2003
#    macro avg     0.7487    0.7221    0.7323      2003
# weighted avg     0.8373    0.8352    0.8357      2003
#
#
# MÉTRICAS GERAIS DO MODELO
# Accuracy: 0.8352
#
# Macro Average:
#   Precision: 0.7487
#   Recall: 0.7221
#   F1-Score: 0.7323
#
# Weighted Average:
#   Precision: 0.8373
#   Recall: 0.8352
#   F1-Score: 0.8357

# %%
cm = confusion_matrix(y_test, y_pred, labels=list(range(len(classes))))
cm_percent = cm.astype("float") / cm.sum(axis=1, keepdims=True) * 100
cm_percent = np.nan_to_num(cm_percent)

plt.figure(figsize=(8, 7))
im = plt.imshow(cm_percent, interpolation="nearest", cmap="Blues", vmin=0, vmax=100)
plt.title(f"Matriz de Confusão (%) - EfficientNetB4 + Crop + Oversampling + {IMG_SIZE[0]}x{IMG_SIZE[1]}")
plt.colorbar(im, label="%")

tick_marks = np.arange(len(classes))
plt.xticks(tick_marks, classes, rotation=45)
plt.yticks(tick_marks, classes)

for i in range(cm_percent.shape[0]):
    for j in range(cm_percent.shape[1]):
        color = "white" if cm_percent[i, j] > 50 else "black"
        plt.text(
            j,
            i,
            f"{cm_percent[i, j]:.1f}",
            ha="center",
            va="center",
            color=color,
            fontsize=8
        )

plt.ylabel("Classe Real")
plt.xlabel("Classe Predita")
plt.tight_layout()
plt.savefig(f"matriz_confusao_percent_{EfficientNetB4}_crop_oversampling_{IMG_SIZE[0]}.png", dpi=300, bbox_inches="tight")
plt.show()

# %%
test_eval_df = test_df.copy().reset_index(drop=True)
test_eval_df["y_true"] = y_test
test_eval_df["y_pred"] = y_pred
test_eval_df["correct"] = test_eval_df["y_true"] == test_eval_df["y_pred"]

correct_samples = test_eval_df[test_eval_df["correct"]].head(4)
incorrect_samples = test_eval_df[~test_eval_df["correct"]].head(4)

samples_to_plot = pd.concat([correct_samples, incorrect_samples], axis=0).reset_index(drop=True)

plt.figure(figsize=(12, 6))

for i, row in samples_to_plot.iterrows():
    image = preprocess_image_path(row["image_path"], row["mask_path"])
    image = np.clip(image, 0, 255).astype("uint8")

    plt.subplot(2, 4, i + 1)
    plt.imshow(image)

    true_label = class_name[int(row["y_true"])]
    pred_label = class_name[int(row["y_pred"])]

    plt.title(f"{true_label} → {pred_label}", fontsize=10)
    plt.axis("off")

plt.tight_layout()
plt.savefig(f"exemplos_classificacao_{EfficientNetB4}_crop_oversampling_{IMG_SIZE[0]}.png", dpi=300, bbox_inches="tight")
plt.show()

# %%
feature_extractor.save(FEATURE_EXTRACTOR_PATH)
best_classifier.save(FINAL_MODEL_PATH)

print(f"Extratora EfficientNetB4 salva em:", FEATURE_EXTRACTOR_PATH)
print("Classificador final salvo em:", FINAL_MODEL_PATH)
print("Melhor checkpoint salvo em:", BEST_MODEL_PATH)
# Out:
# Extratora EfficientNetB4 salva em: efficientnetb4_crop_380_feature_extractor.keras
# Classificador final salvo em: efficientnetb4_crop_oversampling_380_final.keras
# Melhor checkpoint salvo em: best_efficientnetb4_crop_oversampling_380.keras
