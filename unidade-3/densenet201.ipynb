# %%
import os
os.environ["KERAS_BACKEND"] = "tensorflow"

import random
from pathlib import Path
from collections import Counter

import cv2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import tensorflow as tf
import keras
from keras import layers, models, regularizers

from tensorflow.keras.applications import DenseNet201
from tensorflow.keras.applications.densenet import preprocess_input

from sklearn.model_selection import train_test_split
from sklearn.metrics import (
    classification_report,
    confusion_matrix,
    accuracy_score,
    precision_score,
    recall_score,
    f1_score
)

from imblearn.over_sampling import SMOTE

# %%
SEED = 42
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)

DATA_DIR = Path("../data")
IMAGES_DIR = DATA_DIR / "images"
MASKS_DIR = DATA_DIR / "masks"
CSV_PATH = DATA_DIR / "GroundTruth.csv"

IMG_SIZE = (320, 320)
BATCH_SIZE = 32
EPOCHS = 200
LEARNING_RATE = 0.0001

TEST_SIZE = 0.20
VAL_SIZE = 0.20

USE_DULL_RAZOR = False

USE_MASK_SEGMENTATION = False

USE_MASK_CROP = True
CROP_MARGIN = 20

BEST_MODEL_PATH = "best_densenet201_crop_smote_256.keras"
FINAL_MODEL_PATH = "densenet201_crop_smote_256_final.keras"
FEATURE_EXTRACTOR_PATH = "densenet201_crop_256_feature_extractor.keras"

classes = ["MEL", "NV", "BCC", "AKIEC", "BKL", "DF", "VASC"]
class_code = {label: idx for idx, label in enumerate(classes)}
class_name = {idx: label for label, idx in class_code.items()}

print("IMG_SIZE:", IMG_SIZE)
print("BATCH_SIZE:", BATCH_SIZE)
print("EPOCHS:", EPOCHS)
print("LEARNING_RATE:", LEARNING_RATE)
print("USE_DULL_RAZOR:", USE_DULL_RAZOR)
print("USE_MASK_SEGMENTATION:", USE_MASK_SEGMENTATION)
print("USE_MASK_CROP:", USE_MASK_CROP)
print("CROP_MARGIN:", CROP_MARGIN)
print(class_code)
# Out:
# IMG_SIZE: (320, 320)
# BATCH_SIZE: 32
# EPOCHS: 200
# LEARNING_RATE: 0.0001
# USE_DULL_RAZOR: False
# USE_MASK_SEGMENTATION: False
# USE_MASK_CROP: True
# CROP_MARGIN: 20
# {'MEL': 0, 'NV': 1, 'BCC': 2, 'AKIEC': 3, 'BKL': 4, 'DF': 5, 'VASC': 6}

# %%
print("Arquitetura: DenseNet201")
print("IMG_SIZE:", IMG_SIZE)
print("USE_DULL_RAZOR:", USE_DULL_RAZOR)
print("USE_MASK_SEGMENTATION:", USE_MASK_SEGMENTATION)
print("USE_MASK_CROP:", USE_MASK_CROP)
print("CROP_MARGIN:", CROP_MARGIN)
# Out:
# Arquitetura: DenseNet201
# IMG_SIZE: (320, 320)
# USE_DULL_RAZOR: False
# USE_MASK_SEGMENTATION: False
# USE_MASK_CROP: True
# CROP_MARGIN: 20

# %%
def find_image_path(image_id, images_dir):
    for ext in [".jpg", ".jpeg", ".png"]:
        path = images_dir / f"{image_id}{ext}"
        if path.exists():
            return str(path)
    return None


def find_mask_path(image_id, masks_dir):
    if not masks_dir.exists():
        return None

    candidates = [
        masks_dir / f"{image_id}_segmentation.png",
        masks_dir / f"{image_id}_segmentation.jpg",
        masks_dir / f"{image_id}_mask.png",
        masks_dir / f"{image_id}_mask.jpg",
        masks_dir / f"{image_id}.png",
        masks_dir / f"{image_id}.jpg",
    ]

    for path in candidates:
        if path.exists():
            return str(path)

    matches = list(masks_dir.glob(f"{image_id}*"))
    if len(matches) > 0:
        return str(matches[0])

    return None


metadata = pd.read_csv(CSV_PATH)

rows = []
for _, row in metadata.iterrows():
    image_id = str(row["image"])
    image_path = find_image_path(image_id, IMAGES_DIR)
    mask_path = find_mask_path(image_id, MASKS_DIR)

    if image_path is None:
        continue

    label_name = row[classes].idxmax()
    label = class_code[label_name]

    rows.append({
        "image": image_id,
        "image_path": image_path,
        "mask_path": mask_path,
        "class_name": label_name,
        "label": label
    })

df = pd.DataFrame(rows)

print("Total de imagens localizadas:", len(df))
display(df.head())

print("\nDistribuição original:")
print(df["class_name"].value_counts().reindex(classes))

print("\nMáscaras encontradas:", df["mask_path"].notna().sum())
# Out:
# Total de imagens localizadas: 10015
#           image                       image_path  \
# 0  ISIC_0024306  ../data/images/ISIC_0024306.jpg
# 1  ISIC_0024307  ../data/images/ISIC_0024307.jpg
# 2  ISIC_0024308  ../data/images/ISIC_0024308.jpg
# 3  ISIC_0024309  ../data/images/ISIC_0024309.jpg
# 4  ISIC_0024310  ../data/images/ISIC_0024310.jpg
#
#                                      mask_path class_name  label
# 0  ../data/masks/ISIC_0024306_segmentation.png         NV      1
# 1  ../data/masks/ISIC_0024307_segmentation.png         NV      1
# 2  ../data/masks/ISIC_0024308_segmentation.png         NV      1
# 3  ../data/masks/ISIC_0024309_segmentation.png         NV      1
# 4  ../data/masks/ISIC_0024310_segmentation.png        MEL      0
# Distribuição original:
# class_name
# MEL      1113
# NV       6705
# BCC       514
# AKIEC     327
# BKL      1099
# DF        115
# VASC      142
# Name: count, dtype: int64
#
# Máscaras encontradas: 10015

# %%
train_df, test_df = train_test_split(
    df,
    test_size=TEST_SIZE,
    random_state=SEED,
    stratify=df["label"]
)

print("Treino original:", len(train_df))
print("Teste final:", len(test_df))

print("\nDistribuição treino original:")
print(train_df["class_name"].value_counts().reindex(classes))

print("\nDistribuição teste final:")
print(test_df["class_name"].value_counts().reindex(classes))
# Out:
# Treino original: 8012
# Teste final: 2003
#
# Distribuição treino original:
# class_name
# MEL       890
# NV       5364
# BCC       411
# AKIEC     262
# BKL       879
# DF         92
# VASC      114
# Name: count, dtype: int64
#
# Distribuição teste final:
# class_name
# MEL       223
# NV       1341
# BCC       103
# AKIEC      65
# BKL       220
# DF         23
# VASC       28
# Name: count, dtype: int64

# %%
def read_rgb_image(path):
    if isinstance(path, bytes):
        path = path.decode("utf-8")

    image_bgr = cv2.imread(str(path), cv2.IMREAD_COLOR)

    if image_bgr is None:
        raise ValueError(f"Não foi possível carregar a imagem: {path}")

    image_rgb = cv2.cvtColor(image_bgr, cv2.COLOR_BGR2RGB)

    return image_rgb


def dull_razor_remove_hair(image_rgb, kernel_size=(9, 9), threshold_value=10, inpaint_radius=6):
    image_rgb = image_rgb.astype(np.uint8)

    gray = cv2.cvtColor(image_rgb, cv2.COLOR_RGB2GRAY)

    kernel = cv2.getStructuringElement(cv2.MORPH_RECT, kernel_size)
    blackhat = cv2.morphologyEx(gray, cv2.MORPH_BLACKHAT, kernel)

    blackhat_blur = cv2.GaussianBlur(blackhat, (3, 3), 0)

    _, mask = cv2.threshold(
        blackhat_blur,
        threshold_value,
        255,
        cv2.THRESH_BINARY
    )

    image_bgr = cv2.cvtColor(image_rgb, cv2.COLOR_RGB2BGR)

    clean_bgr = cv2.inpaint(
        image_bgr,
        mask,
        inpaint_radius,
        cv2.INPAINT_TELEA
    )

    clean_rgb = cv2.cvtColor(clean_bgr, cv2.COLOR_BGR2RGB)

    return clean_rgb


def read_binary_mask(mask_path, target_shape):
    if mask_path is None or pd.isna(mask_path):
        return None

    if isinstance(mask_path, bytes):
        mask_path = mask_path.decode("utf-8")

    mask = cv2.imread(str(mask_path), cv2.IMREAD_GRAYSCALE)

    if mask is None:
        return None

    height, width = target_shape[:2]
    mask = cv2.resize(mask, (width, height))

    binary_mask = (mask > 127).astype(np.uint8)

    return binary_mask


def apply_mask_segmentation(image_rgb, mask_path):
    binary_mask = read_binary_mask(mask_path, target_shape=image_rgb.shape)

    if binary_mask is None:
        return image_rgb

    segmented = image_rgb * np.expand_dims(binary_mask, axis=-1)

    # Proteção contra máscara ruim.
    if np.mean(segmented) < 5:
        return image_rgb

    return segmented


def crop_lesion_with_margin(image_rgb, mask_path, margin=20):
    binary_mask = read_binary_mask(mask_path, target_shape=image_rgb.shape)

    if binary_mask is None:
        return image_rgb

    ys, xs = np.where(binary_mask > 0)

    if len(xs) == 0 or len(ys) == 0:
        return image_rgb

    height, width = image_rgb.shape[:2]

    x_min = max(xs.min() - margin, 0)
    x_max = min(xs.max() + margin, width - 1)
    y_min = max(ys.min() - margin, 0)
    y_max = min(ys.max() + margin, height - 1)

    cropped = image_rgb[y_min:y_max + 1, x_min:x_max + 1]

    if cropped.size == 0:
        return image_rgb

    return cropped


def preprocess_image_path(path, mask_path=None):
    image_rgb = read_rgb_image(path)

    if USE_DULL_RAZOR:
        image_rgb = dull_razor_remove_hair(image_rgb)

    if USE_MASK_CROP:
        image_rgb = crop_lesion_with_margin(
            image_rgb,
            mask_path,
            margin=CROP_MARGIN
        )
    elif USE_MASK_SEGMENTATION:
        image_rgb = apply_mask_segmentation(image_rgb, mask_path)

    image_rgb = cv2.resize(image_rgb, IMG_SIZE)

    return image_rgb.astype("float32")

# %%
sample_row = train_df.sample(1, random_state=SEED).iloc[0]

original = read_rgb_image(sample_row["image_path"])
dull = dull_razor_remove_hair(original) if USE_DULL_RAZOR else original
segmented = apply_mask_segmentation(dull, sample_row["mask_path"])
cropped = crop_lesion_with_margin(dull, sample_row["mask_path"], margin=CROP_MARGIN)
final_img = preprocess_image_path(sample_row["image_path"], sample_row["mask_path"])
final_img = np.clip(final_img, 0, 255).astype("uint8")

plt.figure(figsize=(16, 4))

plt.subplot(1, 5, 1)
plt.imshow(original)
plt.title("Original")
plt.axis("off")

plt.subplot(1, 5, 2)
plt.imshow(dull)
plt.title("Dull Razor")
plt.axis("off")

plt.subplot(1, 5, 3)
plt.imshow(np.clip(segmented, 0, 255).astype("uint8"))
plt.title("Máscara aplicada")
plt.axis("off")

plt.subplot(1, 5, 4)
plt.imshow(np.clip(cropped, 0, 255).astype("uint8"))
plt.title("Crop + margem")
plt.axis("off")

plt.subplot(1, 5, 5)
plt.imshow(final_img)
plt.title("Final 256x256")
plt.axis("off")

plt.tight_layout()
plt.savefig("pipeline_densenet201_crop_smote.png", dpi=300, bbox_inches="tight")
plt.show()

# %%
def load_image_for_features_py(image_path, mask_path, label):
    if isinstance(image_path, bytes):
        image_path = image_path.decode("utf-8")

    if isinstance(mask_path, bytes):
        mask_path = mask_path.decode("utf-8")

    if mask_path == "None" or mask_path == "":
        mask_path = None

    image = preprocess_image_path(image_path, mask_path)

    return image.astype("float32"), np.int32(label)


def tf_load_image_for_features(image_path, mask_path, label):
    image, label = tf.numpy_function(
        load_image_for_features_py,
        [image_path, mask_path, label],
        [tf.float32, tf.int32]
    )

    image.set_shape((IMG_SIZE[0], IMG_SIZE[1], 3))
    label.set_shape(())

    return image, label


def build_image_dataset(dataframe, batch_size=BATCH_SIZE, shuffle=False):
    mask_values = dataframe["mask_path"].fillna("None").astype(str).values

    ds = tf.data.Dataset.from_tensor_slices((
        dataframe["image_path"].astype(str).values,
        mask_values,
        dataframe["label"].values.astype("int32")
    ))

    if shuffle:
        ds = ds.shuffle(buffer_size=len(dataframe), seed=SEED)

    ds = ds.map(tf_load_image_for_features, num_parallel_calls=tf.data.AUTOTUNE)
    ds = ds.batch(batch_size)
    ds = ds.prefetch(tf.data.AUTOTUNE)

    return ds


train_image_ds = build_image_dataset(train_df, shuffle=False)
test_image_ds = build_image_dataset(test_df, shuffle=False)

print(train_image_ds)
print(test_image_ds)
# Out:
# <_PrefetchDataset element_spec=(TensorSpec(shape=(None, 320, 320, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>
# <_PrefetchDataset element_spec=(TensorSpec(shape=(None, 320, 320, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
def build_feature_extractor(input_shape=(256, 256, 3)):
    inputs = layers.Input(shape=input_shape)

    x = preprocess_input(inputs)

    base_model = DenseNet201(
        weights="imagenet",
        include_top=False,
        input_shape=input_shape
    )

    base_model.trainable = False

    x = base_model(x, training=False)
    x = layers.GlobalAveragePooling2D()(x)

    feature_extractor = models.Model(
        inputs=inputs,
        outputs=x,
        name="densenet201_crop_feature_extractor"
    )

    return feature_extractor


feature_extractor = build_feature_extractor(
    input_shape=(IMG_SIZE[0], IMG_SIZE[1], 3)
)

feature_extractor.summary()
# Out:
# Model: "densenet201_crop_feature_extractor"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 320, 320, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ true_divide (TrueDivide)        │ (None, 320, 320, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ add (Add)                       │ (None, 320, 320, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ true_divide_1 (TrueDivide)      │ (None, 320, 320, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ densenet201 (Functional)        │ (None, 10, 10, 1920)   │    18,321,984 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 1920)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 18,321,984 (69.89 MB)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 18,321,984 (69.89 MB)

# %%
def extract_features(dataset, feature_extractor):
    features_list = []
    labels_list = []

    for images, labels in dataset:
        features = feature_extractor.predict(images, verbose=0)
        features_list.append(features)
        labels_list.append(labels.numpy())

    X = np.concatenate(features_list, axis=0)
    y = np.concatenate(labels_list, axis=0)

    return X.astype("float32"), y.astype("int32")


X_train_features, y_train = extract_features(train_image_ds, feature_extractor)
X_test_features, y_test = extract_features(test_image_ds, feature_extractor)

print("X_train_features:", X_train_features.shape)
print("y_train:", y_train.shape)
print("X_test_features:", X_test_features.shape)
print("y_test:", y_test.shape)

print("\nDistribuição treino antes do SMOTE:")
print(Counter(y_train))
# Out:
# X_train_features: (8012, 1920)
# y_train: (8012,)
# X_test_features: (2003, 1920)
# y_test: (2003,)
#
# Distribuição treino antes do SMOTE:
# Counter({np.int32(1): 5364, np.int32(0): 890, np.int32(4): 879, np.int32(2): 411, np.int32(3): 262, np.int32(6): 114, np.int32(5): 92})

# %%
min_class_count = min(Counter(y_train).values())
k_neighbors = min(5, min_class_count - 1)

print("Menor classe no treino:", min_class_count)
print("k_neighbors usado no SMOTE:", k_neighbors)

smote = SMOTE(
    random_state=SEED,
    k_neighbors=k_neighbors
)

X_train_smote, y_train_smote = smote.fit_resample(
    X_train_features,
    y_train
)

print("X_train_smote:", X_train_smote.shape)
print("y_train_smote:", y_train_smote.shape)

print("\nDistribuição treino após SMOTE:")
print(Counter(y_train_smote))
# Out:
# Menor classe no treino: 92
# k_neighbors usado no SMOTE: 5
# X_train_smote: (37548, 1920)
# y_train_smote: (37548,)
#
# Distribuição treino após SMOTE:
# Counter({np.int32(1): 5364, np.int32(0): 5364, np.int32(4): 5364, np.int32(2): 5364, np.int32(5): 5364, np.int32(3): 5364, np.int32(6): 5364})

# %%
X_fit, X_val, y_fit, y_val = train_test_split(
    X_train_smote,
    y_train_smote,
    test_size=VAL_SIZE,
    random_state=SEED,
    stratify=y_train_smote
)

print("Treino para fit:", X_fit.shape)
print("Validação:", X_val.shape)
print("Teste final:", X_test_features.shape)

print("\nDistribuição fit:")
print(Counter(y_fit))

print("\nDistribuição validação:")
print(Counter(y_val))
# Out:
# Treino para fit: (30038, 1920)
# Validação: (7510, 1920)
# Teste final: (2003, 1920)
#
# Distribuição fit:
# Counter({np.int32(0): 4292, np.int32(4): 4291, np.int32(5): 4291, np.int32(6): 4291, np.int32(2): 4291, np.int32(3): 4291, np.int32(1): 4291})
#
# Distribuição validação:
# Counter({np.int32(2): 1073, np.int32(3): 1073, np.int32(6): 1073, np.int32(4): 1073, np.int32(1): 1073, np.int32(5): 1073, np.int32(0): 1072})

# %%
def build_classifier_head(input_dim, num_classes=len(classes)):
    inputs = layers.Input(shape=(input_dim,))

    x = layers.Dense(
        256,
        activation="relu",
        kernel_regularizer=regularizers.l2(0.001)
    )(inputs)

    x = layers.BatchNormalization()(x)
    x = layers.Dropout(0.5)(x)

    x = layers.Dense(
        128,
        activation="relu",
        kernel_regularizer=regularizers.l2(0.001)
    )(x)

    x = layers.Dropout(0.3)(x)

    outputs = layers.Dense(num_classes, activation="softmax")(x)

    model = models.Model(
        inputs=inputs,
        outputs=outputs,
        name="densenet201_crop_smote_classifier"
    )

    return model


classifier = build_classifier_head(
    input_dim=X_train_smote.shape[1],
    num_classes=len(classes)
)

classifier.compile(
    optimizer=keras.optimizers.Adam(learning_rate=LEARNING_RATE),
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)

classifier.summary()
# Out:
# Model: "densenet201_crop_smote_classifier"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_2 (InputLayer)      │ (None, 1920)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │       491,776 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 7)              │           903 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 526,599 (2.01 MB)
#  Trainable params: 526,087 (2.01 MB)
#  Non-trainable params: 512 (2.00 KB)

# %%
callbacks = [
    keras.callbacks.EarlyStopping(
        monitor="val_loss",
        patience=10,
        restore_best_weights=True,
        verbose=1
    ),
    keras.callbacks.ReduceLROnPlateau(
        monitor="val_loss",
        factor=0.2,
        patience=4,
        min_lr=1e-7,
        verbose=1
    ),
    keras.callbacks.ModelCheckpoint(
        BEST_MODEL_PATH,
        monitor="val_loss",
        save_best_only=True,
        verbose=1
    )
]

history = classifier.fit(
    X_fit,
    y_fit,
    validation_data=(X_val, y_val),
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    callbacks=callbacks
)
# Out:
# Epoch 1/200
# 913/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4278 - loss: 2.1919
# Epoch 1: val_loss improved from None to 0.94787, saving model to best_densenet201_crop_smote_256.keras
#
# Epoch 1: finished saving model to best_densenet201_crop_smote_256.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.5548 - loss: 1.6893 - val_accuracy: 0.7940 - val_loss: 0.9479 - learning_rate: 1.0000e-04
# Epoch 2/200
# 930/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7186 - loss: 1.1362
# Epoch 2: val_loss improved from 0.94787 to 0.73972, saving model to best_densenet201_crop_smote_256.keras
#
# Epoch 2: finished saving model to best_densenet201_crop_smote_256.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7451 - loss: 1.0623 - val_accuracy: 0.8593 - val_loss: 0.7397 - learning_rate: 1.0000e-04
# Epoch 3/200
# 937/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7939 - loss: 0.9111
# Epoch 3: val_loss improved from 0.73972 to 0.61506, saving model to best_densenet201_crop_smote_256.keras
#
# Epoch 3: finished saving model to best_densenet201_crop_smote_256.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8090 - loss: 0.8630 - val_accuracy: 0.8971 - val_loss: 0.6151 - learning_rate: 1.0000e-04
# Epoch 4/200
# 937/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8363 - loss: 0.7696
# Epoch 4: val_loss improved from 0.61506 to 0.54479, saving model to best_densenet201_crop_smote_256.keras
#
# Epoch 4: finished saving model to best_densenet201_crop_smote_256.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8462 - loss: 0.7386 - val_accuracy: 0.9185 - val_loss: 0.5448 - learning_rate: 1.0000e-04
# Epoch 5/200
# 931/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8677 - loss: 0.6731
# Epoch 5: val_loss improved from 0.54479 to 0.48158, saving model to best_densenet201_crop_smote_256.keras
#
# Epoch 5: finished saving model to best_densenet201_crop_smote_256.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8751 - loss: 0.6483 - val_accuracy: 0.9375 - val_loss: 0.4816 - learning_rate: 1.0000e-04
# Epoch 6/200
# 920/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8893 - loss: 0.6007
# Epoch 6: val_loss improved from 0.48158 to 0.45297, saving model to best_densenet201_crop_smote_256.keras
#
# Epoch 6: finished saving model to best_densenet201_crop_smote_256.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8936 - loss: 0.5810 - val_accuracy: 0.9397 - val_loss: 0.4530 - learning_rate: 1.0000e-04
# Epoch 7/200
# 926/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8983 - loss: 0.5433
# Epoch 7: val_loss improved from 0.45297 to 0.42357, saving model to best_densenet201_crop_smote_256.keras
#
# Epoch 7: finished saving model to best_densenet201_crop_smote_256.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9042 - loss: 0.5292 - val_accuracy: 0.9451 - val_loss: 0.4236 - learning_rate: 1.0000e-04
# Epoch 8/200
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9128 - loss: 0.4995
# Epoch 8: val_loss improved from 0.42357 to 0.37209, saving model to best_densenet201_crop_smote_256.keras
#
# Epoch 8: finished saving model to best_densenet201_crop_smote_256.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9173 - loss: 0.4857 - val_accuracy: 0.9586 - val_loss: 0.3721 - learning_rate: 1.0000e-04
# Epoch 9/200
# 916/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9231 - loss: 0.4620
# Epoch 9: val_loss improved from 0.37209 to 0.35785, saving model to best_densenet201_crop_smote_256.keras
#
# Epoch 9: finished saving model to best_densenet201_crop_smote_256.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9264 - loss: 0.4508 - val_accuracy: 0.9594 - val_loss: 0.3578 - learning_rate: 1.0000e-04
# Epoch 10/200
# 928/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9298 - loss: 0.4336
# Epoch 10: val_loss improved from 0.35785 to 0.34754, saving model to best_densenet201_crop_smote_256.keras
#
# Epoch 10: finished saving model to best_densenet201_crop_smote_256.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9309 - loss: 0.4252 - val_accuracy: 0.9586 - val_loss: 0.3475 - learning_rate: 1.0000e-04
# Epoch 11/200
# 917/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9384 - loss: 0.4012
# Epoch 11: val_loss improved from 0.34754 to 0.33310, saving model to best_densenet201_crop_smote_256.keras
#
# Epoch 11: finished saving model to best_densenet201_crop_smote_256.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9398 - loss: 0.3944 - val_accuracy: 0.9605 - val_loss: 0.3331 - learning_rate: 1.0000e-04
# Epoch 12/200
# 914/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9398 - loss: 0.3842
# Epoch 12: val_loss improved from 0.33310 to 0.30524, saving model to best_densenet201_crop_smote_256.keras
#
# Epoch 12: finished saving model to best_densenet201_crop_smote_256.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9435 - loss: 0.3717 - val_accuracy: 0.9671 - val_loss: 0.3052 - learning_rate: 1.0000e-04
# Epoch 13/200
# 918/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9445 - loss: 0.3558
# Epoch 13: val_loss improved from 0.30524 to 0.29830, saving model to best_densenet201_crop_smote_256.keras
#
# Epoch 13: finished saving model to best_densenet201_crop_smote_256.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9472 - loss: 0.3494 - val_accuracy: 0.9654 - val_loss: 0.2983 - learning_rate: 1.0000e-04
# Epoch 14/200
# 919/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9474 - loss: 0.3466
# Epoch 14: val_loss improved from 0.29830 to 0.27595, saving model to best_densenet201_crop_smote_256.keras
#
# Epoch 14: finished saving model to best_densenet201_crop_smote_256.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9494 - loss: 0.3392 - val_accuracy: 0.9711 - val_loss: 0.2760 - learning_rate: 1.0000e-04
# Epoch 15/200
# 917/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9517 - loss: 0.3253
# Epoch 15: val_loss improved from 0.27595 to 0.26534, saving model to best_densenet201_crop_smote_256.keras
#
# Epoch 15: finished saving model to best_densenet201_crop_smote_256.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9539 - loss: 0.3194 - val_accuracy: 0.9742 - val_loss: 0.2653 - learning_rate: 1.0000e-04
# Epoch 16/200
# 934/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9549 - loss: 0.3138
# Epoch 16: val_loss improved from 0.26534 to 0.25220, saving model to best_densenet201_crop_smote_256.keras
#
# Epoch 16: finished saving model to best_densenet201_crop_smote_256.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9581 - loss: 0.3054 - val_accuracy: 0.9742 - val_loss: 0.2522 - learning_rate: 1.0000e-04
# Epoch 17/200
# 919/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9571 - loss: 0.2979
# Epoch 17: val_loss improved from 0.25220 to 0.24889, saving model to best_densenet201_crop_smote_256.keras
#
# Epoch 17: finished saving model to best_densenet201_crop_smote_256.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9594 - loss: 0.2902 - val_accuracy: 0.9755 - val_loss: 0.2489 - learning_rate: 1.0000e-04
# Epoch 18/200
# 916/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9602 - loss: 0.2876
# Epoch 18: val_loss improved from 0.24889 to 0.23840, saving model to best_densenet201_crop_smote_256.keras
#
# Epoch 18: finished saving model to best_densenet201_crop_smote_256.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9632 - loss: 0.2775 - val_accuracy: 0.9740 - val_loss: 0.2384 - learning_rate: 1.0000e-04
# Epoch 19/200
# 915/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9624 - loss: 0.2721
# Epoch 19: val_loss improved from 0.23840 to 0.22302, saving model to best_densenet201_crop_smote_256.keras
#
# Epoch 19: finished saving model to best_densenet201_crop_smote_256.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9638 - loss: 0.2662 - val_accuracy: 0.9778 - val_loss: 0.2230 - learning_rate: 1.0000e-04
# Epoch 20/200
# 928/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9652 - loss: 0.2599
# Epoch 20: val_loss did not improve from 0.22302
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9648 - loss: 0.2560 - val_accuracy: 0.9723 - val_loss: 0.2314 - learning_rate: 1.0000e-04
# Epoch 21/200
# 937/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9650 - loss: 0.2541
# Epoch 21: val_loss improved from 0.22302 to 0.20927, saving model to best_densenet201_crop_smote_256.keras
#
# Epoch 21: finished saving model to best_densenet201_crop_smote_256.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9666 - loss: 0.2467 - val_accuracy: 0.9783 - val_loss: 0.2093 - learning_rate: 1.0000e-04
# Epoch 22/200
# 934/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9683 - loss: 0.2407
# Epoch 22: val_loss did not improve from 0.20927
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9693 - loss: 0.2345 - val_accuracy: 0.9748 - val_loss: 0.2182 - learning_rate: 1.0000e-04
# Epoch 23/200
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9674 - loss: 0.2357
# Epoch 23: val_loss did not improve from 0.20927
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9675 - loss: 0.2321 - val_accuracy: 0.9759 - val_loss: 0.2141 - learning_rate: 1.0000e-04
# Epoch 24/200
# 935/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9637 - loss: 0.2378
# Epoch 24: val_loss improved from 0.20927 to 0.18947, saving model to best_densenet201_crop_smote_256.keras
#
# Epoch 24: finished saving model to best_densenet201_crop_smote_256.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9683 - loss: 0.2263 - val_accuracy: 0.9803 - val_loss: 0.1895 - learning_rate: 1.0000e-04
# Epoch 25/200
# 932/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9700 - loss: 0.2221
# Epoch 25: val_loss did not improve from 0.18947
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9709 - loss: 0.2160 - val_accuracy: 0.9800 - val_loss: 0.1896 - learning_rate: 1.0000e-04
# Epoch 26/200
# 935/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9686 - loss: 0.2162
# Epoch 26: val_loss improved from 0.18947 to 0.17851, saving model to best_densenet201_crop_smote_256.keras
#
# Epoch 26: finished saving model to best_densenet201_crop_smote_256.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9695 - loss: 0.2119 - val_accuracy: 0.9822 - val_loss: 0.1785 - learning_rate: 1.0000e-04
# Epoch 27/200
# 936/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9674 - loss: 0.2158
# Epoch 27: val_loss did not improve from 0.17851
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9693 - loss: 0.2096 - val_accuracy: 0.9766 - val_loss: 0.1921 - learning_rate: 1.0000e-04
# Epoch 28/200
# 916/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9727 - loss: 0.2018
# Epoch 28: val_loss did not improve from 0.17851
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9728 - loss: 0.1972 - val_accuracy: 0.9750 - val_loss: 0.1895 - learning_rate: 1.0000e-04
# Epoch 29/200
# 938/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9719 - loss: 0.2009
# Epoch 29: val_loss did not improve from 0.17851
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9720 - loss: 0.1988 - val_accuracy: 0.9788 - val_loss: 0.1850 - learning_rate: 1.0000e-04
# Epoch 30/200
# 938/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9676 - loss: 0.2040
# Epoch 30: ReduceLROnPlateau reducing learning rate to 1.9999999494757503e-05.
#
# Epoch 30: val_loss did not improve from 0.17851
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9706 - loss: 0.1962 - val_accuracy: 0.9767 - val_loss: 0.1808 - learning_rate: 1.0000e-04
# Epoch 31/200
# 914/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9774 - loss: 0.1793
# Epoch 31: val_loss improved from 0.17851 to 0.15493, saving model to best_densenet201_crop_smote_256.keras
#
# Epoch 31: finished saving model to best_densenet201_crop_smote_256.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9811 - loss: 0.1685 - val_accuracy: 0.9854 - val_loss: 0.1549 - learning_rate: 2.0000e-05
# Epoch 32/200
# 929/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9832 - loss: 0.1614
# Epoch 32: val_loss improved from 0.15493 to 0.15441, saving model to best_densenet201_crop_smote_256.keras
#
# Epoch 32: finished saving model to best_densenet201_crop_smote_256.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9852 - loss: 0.1557 - val_accuracy: 0.9844 - val_loss: 0.1544 - learning_rate: 2.0000e-05
# Epoch 33/200
# 937/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9857 - loss: 0.1518
# Epoch 33: val_loss improved from 0.15441 to 0.15413, saving model to best_densenet201_crop_smote_256.keras
#
# Epoch 33: finished saving model to best_densenet201_crop_smote_256.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9867 - loss: 0.1488 - val_accuracy: 0.9847 - val_loss: 0.1541 - learning_rate: 2.0000e-05
# Epoch 34/200
# 915/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9867 - loss: 0.1525
# Epoch 34: val_loss improved from 0.15413 to 0.14800, saving model to best_densenet201_crop_smote_256.keras
#
# Epoch 34: finished saving model to best_densenet201_crop_smote_256.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9876 - loss: 0.1477 - val_accuracy: 0.9860 - val_loss: 0.1480 - learning_rate: 2.0000e-05
# Epoch 35/200
# 924/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9877 - loss: 0.1448
# Epoch 35: val_loss did not improve from 0.14800
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9881 - loss: 0.1417 - val_accuracy: 0.9855 - val_loss: 0.1485 - learning_rate: 2.0000e-05
# Epoch 36/200
# 937/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9890 - loss: 0.1389
# Epoch 36: val_loss improved from 0.14800 to 0.14728, saving model to best_densenet201_crop_smote_256.keras
#
# Epoch 36: finished saving model to best_densenet201_crop_smote_256.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9889 - loss: 0.1374 - val_accuracy: 0.9848 - val_loss: 0.1473 - learning_rate: 2.0000e-05
# Epoch 37/200
# 933/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9895 - loss: 0.1378
# Epoch 37: val_loss did not improve from 0.14728
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9896 - loss: 0.1356 - val_accuracy: 0.9856 - val_loss: 0.1475 - learning_rate: 2.0000e-05
# Epoch 38/200
# 927/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9881 - loss: 0.1368
# Epoch 38: val_loss improved from 0.14728 to 0.14129, saving model to best_densenet201_crop_smote_256.keras
#
# Epoch 38: finished saving model to best_densenet201_crop_smote_256.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9893 - loss: 0.1341 - val_accuracy: 0.9859 - val_loss: 0.1413 - learning_rate: 2.0000e-05
# Epoch 39/200
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9879 - loss: 0.1332
# Epoch 39: val_loss improved from 0.14129 to 0.13911, saving model to best_densenet201_crop_smote_256.keras
#
# Epoch 39: finished saving model to best_densenet201_crop_smote_256.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9888 - loss: 0.1312 - val_accuracy: 0.9862 - val_loss: 0.1391 - learning_rate: 2.0000e-05
# Epoch 40/200
# 932/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9898 - loss: 0.1301
# Epoch 40: val_loss improved from 0.13911 to 0.13691, saving model to best_densenet201_crop_smote_256.keras
#
# Epoch 40: finished saving model to best_densenet201_crop_smote_256.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9903 - loss: 0.1282 - val_accuracy: 0.9866 - val_loss: 0.1369 - learning_rate: 2.0000e-05
# Epoch 41/200
# 926/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9906 - loss: 0.1266
# Epoch 41: val_loss improved from 0.13691 to 0.13540, saving model to best_densenet201_crop_smote_256.keras
#
# Epoch 41: finished saving model to best_densenet201_crop_smote_256.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9911 - loss: 0.1253 - val_accuracy: 0.9875 - val_loss: 0.1354 - learning_rate: 2.0000e-05
# Epoch 42/200
# 931/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9897 - loss: 0.1271
# Epoch 42: val_loss improved from 0.13540 to 0.13165, saving model to best_densenet201_crop_smote_256.keras
#
# Epoch 42: finished saving model to best_densenet201_crop_smote_256.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9910 - loss: 0.1242 - val_accuracy: 0.9880 - val_loss: 0.1317 - learning_rate: 2.0000e-05
# Epoch 43/200
# 936/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9910 - loss: 0.1257
# Epoch 43: val_loss did not improve from 0.13165
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9916 - loss: 0.1226 - val_accuracy: 0.9876 - val_loss: 0.1326 - learning_rate: 2.0000e-05
# Epoch 44/200
# 936/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9908 - loss: 0.1247
# Epoch 44: val_loss did not improve from 0.13165
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9913 - loss: 0.1216 - val_accuracy: 0.9860 - val_loss: 0.1369 - learning_rate: 2.0000e-05
# Epoch 45/200
# 932/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9914 - loss: 0.1206
# Epoch 45: val_loss did not improve from 0.13165
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9920 - loss: 0.1190 - val_accuracy: 0.9872 - val_loss: 0.1327 - learning_rate: 2.0000e-05
# Epoch 46/200
# 926/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9916 - loss: 0.1209
# Epoch 46: val_loss improved from 0.13165 to 0.13113, saving model to best_densenet201_crop_smote_256.keras
#
# Epoch 46: finished saving model to best_densenet201_crop_smote_256.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9922 - loss: 0.1183 - val_accuracy: 0.9870 - val_loss: 0.1311 - learning_rate: 2.0000e-05
# Epoch 47/200
# 931/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9922 - loss: 0.1191
# Epoch 47: val_loss improved from 0.13113 to 0.13106, saving model to best_densenet201_crop_smote_256.keras
#
# Epoch 47: finished saving model to best_densenet201_crop_smote_256.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9922 - loss: 0.1172 - val_accuracy: 0.9877 - val_loss: 0.1311 - learning_rate: 2.0000e-05
# Epoch 48/200
# 937/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9926 - loss: 0.1160
# Epoch 48: val_loss improved from 0.13106 to 0.12946, saving model to best_densenet201_crop_smote_256.keras
#
# Epoch 48: finished saving model to best_densenet201_crop_smote_256.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9931 - loss: 0.1142 - val_accuracy: 0.9872 - val_loss: 0.1295 - learning_rate: 2.0000e-05
# Epoch 49/200
# 927/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9920 - loss: 0.1149
# Epoch 49: val_loss improved from 0.12946 to 0.12821, saving model to best_densenet201_crop_smote_256.keras
#
# Epoch 49: finished saving model to best_densenet201_crop_smote_256.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9926 - loss: 0.1142 - val_accuracy: 0.9880 - val_loss: 0.1282 - learning_rate: 2.0000e-05
# Epoch 50/200
# 934/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9917 - loss: 0.1164
# Epoch 50: val_loss did not improve from 0.12821
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9924 - loss: 0.1131 - val_accuracy: 0.9868 - val_loss: 0.1287 - learning_rate: 2.0000e-05
# Epoch 51/200
# 937/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9925 - loss: 0.1125
# Epoch 51: val_loss improved from 0.12821 to 0.12363, saving model to best_densenet201_crop_smote_256.keras
#
# Epoch 51: finished saving model to best_densenet201_crop_smote_256.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9924 - loss: 0.1125 - val_accuracy: 0.9892 - val_loss: 0.1236 - learning_rate: 2.0000e-05
# Epoch 52/200
# 924/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9923 - loss: 0.1122
# Epoch 52: val_loss improved from 0.12363 to 0.12351, saving model to best_densenet201_crop_smote_256.keras
#
# Epoch 52: finished saving model to best_densenet201_crop_smote_256.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9927 - loss: 0.1107 - val_accuracy: 0.9884 - val_loss: 0.1235 - learning_rate: 2.0000e-05
# Epoch 53/200
# 935/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9925 - loss: 0.1119
# Epoch 53: val_loss did not improve from 0.12351
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9924 - loss: 0.1109 - val_accuracy: 0.9879 - val_loss: 0.1242 - learning_rate: 2.0000e-05
# Epoch 54/200
# 913/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9929 - loss: 0.1101
# Epoch 54: val_loss improved from 0.12351 to 0.12127, saving model to best_densenet201_crop_smote_256.keras
#
# Epoch 54: finished saving model to best_densenet201_crop_smote_256.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9927 - loss: 0.1091 - val_accuracy: 0.9885 - val_loss: 0.1213 - learning_rate: 2.0000e-05
# Epoch 55/200
# 922/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9928 - loss: 0.1095
# Epoch 55: val_loss did not improve from 0.12127
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9939 - loss: 0.1070 - val_accuracy: 0.9881 - val_loss: 0.1217 - learning_rate: 2.0000e-05
# Epoch 56/200
# 936/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9940 - loss: 0.1050
# Epoch 56: val_loss did not improve from 0.12127
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9943 - loss: 0.1043 - val_accuracy: 0.9883 - val_loss: 0.1226 - learning_rate: 2.0000e-05
# Epoch 57/200
# 917/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9923 - loss: 0.1085
# Epoch 57: val_loss did not improve from 0.12127
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9925 - loss: 0.1069 - val_accuracy: 0.9879 - val_loss: 0.1232 - learning_rate: 2.0000e-05
# Epoch 58/200
# 935/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9928 - loss: 0.1061
# Epoch 58: val_loss improved from 0.12127 to 0.11770, saving model to best_densenet201_crop_smote_256.keras
#
# Epoch 58: finished saving model to best_densenet201_crop_smote_256.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9936 - loss: 0.1041 - val_accuracy: 0.9885 - val_loss: 0.1177 - learning_rate: 2.0000e-05
# Epoch 59/200
# 935/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9925 - loss: 0.1065
# Epoch 59: val_loss did not improve from 0.11770
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9937 - loss: 0.1034 - val_accuracy: 0.9895 - val_loss: 0.1188 - learning_rate: 2.0000e-05
# Epoch 60/200
# 922/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9940 - loss: 0.1014
# Epoch 60: val_loss did not improve from 0.11770
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9942 - loss: 0.1009 - val_accuracy: 0.9887 - val_loss: 0.1186 - learning_rate: 2.0000e-05
# Epoch 61/200
# 922/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9941 - loss: 0.1012
# Epoch 61: val_loss did not improve from 0.11770
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9945 - loss: 0.0999 - val_accuracy: 0.9880 - val_loss: 0.1187 - learning_rate: 2.0000e-05
# Epoch 62/200
# 931/939 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9940 - loss: 0.1025
# Epoch 62: val_loss improved from 0.11770 to 0.11560, saving model to best_densenet201_crop_smote_256.keras
#
# Epoch 62: finished saving model to best_densenet201_crop_smote_256.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9939 - loss: 0.1010 - val_accuracy: 0.9888 - val_loss: 0.1156 - learning_rate: 2.0000e-05
# Epoch 63/200
# 926/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9943 - loss: 0.0989
# Epoch 63: val_loss improved from 0.11560 to 0.11497, saving model to best_densenet201_crop_smote_256.keras
#
# Epoch 63: finished saving model to best_densenet201_crop_smote_256.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9942 - loss: 0.0979 - val_accuracy: 0.9893 - val_loss: 0.1150 - learning_rate: 2.0000e-05
# Epoch 64/200
# 932/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9940 - loss: 0.0980
# Epoch 64: val_loss did not improve from 0.11497
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9938 - loss: 0.0986 - val_accuracy: 0.9887 - val_loss: 0.1165 - learning_rate: 2.0000e-05
# Epoch 65/200
# 922/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9944 - loss: 0.0974
# Epoch 65: val_loss did not improve from 0.11497
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9946 - loss: 0.0967 - val_accuracy: 0.9880 - val_loss: 0.1173 - learning_rate: 2.0000e-05
# Epoch 66/200
# 937/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9940 - loss: 0.0972
# Epoch 66: val_loss improved from 0.11497 to 0.11028, saving model to best_densenet201_crop_smote_256.keras
#
# Epoch 66: finished saving model to best_densenet201_crop_smote_256.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9933 - loss: 0.0971 - val_accuracy: 0.9900 - val_loss: 0.1103 - learning_rate: 2.0000e-05
# Epoch 67/200
# 922/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9939 - loss: 0.0956
# Epoch 67: val_loss did not improve from 0.11028
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9945 - loss: 0.0944 - val_accuracy: 0.9887 - val_loss: 0.1135 - learning_rate: 2.0000e-05
# Epoch 68/200
# 929/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9944 - loss: 0.0950
# Epoch 68: val_loss improved from 0.11028 to 0.10853, saving model to best_densenet201_crop_smote_256.keras
#
# Epoch 68: finished saving model to best_densenet201_crop_smote_256.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9950 - loss: 0.0935 - val_accuracy: 0.9901 - val_loss: 0.1085 - learning_rate: 2.0000e-05
# Epoch 69/200
# 927/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9945 - loss: 0.0944
# Epoch 69: val_loss did not improve from 0.10853
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9942 - loss: 0.0938 - val_accuracy: 0.9880 - val_loss: 0.1168 - learning_rate: 2.0000e-05
# Epoch 70/200
# 921/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9942 - loss: 0.0930
# Epoch 70: val_loss improved from 0.10853 to 0.10827, saving model to best_densenet201_crop_smote_256.keras
#
# Epoch 70: finished saving model to best_densenet201_crop_smote_256.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9946 - loss: 0.0919 - val_accuracy: 0.9904 - val_loss: 0.1083 - learning_rate: 2.0000e-05
# Epoch 71/200
# 936/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9949 - loss: 0.0930
# Epoch 71: val_loss did not improve from 0.10827
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9951 - loss: 0.0916 - val_accuracy: 0.9876 - val_loss: 0.1120 - learning_rate: 2.0000e-05
# Epoch 72/200
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9943 - loss: 0.0920
# Epoch 72: val_loss did not improve from 0.10827
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9943 - loss: 0.0911 - val_accuracy: 0.9891 - val_loss: 0.1100 - learning_rate: 2.0000e-05
# Epoch 73/200
# 934/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9943 - loss: 0.0927
# Epoch 73: val_loss improved from 0.10827 to 0.10678, saving model to best_densenet201_crop_smote_256.keras
#
# Epoch 73: finished saving model to best_densenet201_crop_smote_256.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9944 - loss: 0.0904 - val_accuracy: 0.9905 - val_loss: 0.1068 - learning_rate: 2.0000e-05
# Epoch 74/200
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9946 - loss: 0.0911
# Epoch 74: val_loss improved from 0.10678 to 0.10671, saving model to best_densenet201_crop_smote_256.keras
#
# Epoch 74: finished saving model to best_densenet201_crop_smote_256.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9946 - loss: 0.0904 - val_accuracy: 0.9901 - val_loss: 0.1067 - learning_rate: 2.0000e-05
# Epoch 75/200
# 921/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9958 - loss: 0.0886
# Epoch 75: val_loss did not improve from 0.10671
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9950 - loss: 0.0882 - val_accuracy: 0.9891 - val_loss: 0.1073 - learning_rate: 2.0000e-05
# Epoch 76/200
# 916/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9933 - loss: 0.0917
# Epoch 76: val_loss improved from 0.10671 to 0.10606, saving model to best_densenet201_crop_smote_256.keras
#
# Epoch 76: finished saving model to best_densenet201_crop_smote_256.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9946 - loss: 0.0889 - val_accuracy: 0.9889 - val_loss: 0.1061 - learning_rate: 2.0000e-05
# Epoch 77/200
# 926/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9941 - loss: 0.0891
# Epoch 77: val_loss did not improve from 0.10606
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9945 - loss: 0.0877 - val_accuracy: 0.9895 - val_loss: 0.1073 - learning_rate: 2.0000e-05
# Epoch 78/200
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9942 - loss: 0.0905
# Epoch 78: val_loss improved from 0.10606 to 0.10294, saving model to best_densenet201_crop_smote_256.keras
#
# Epoch 78: finished saving model to best_densenet201_crop_smote_256.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9950 - loss: 0.0873 - val_accuracy: 0.9901 - val_loss: 0.1029 - learning_rate: 2.0000e-05
# Epoch 79/200
# 918/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9944 - loss: 0.0883
# Epoch 79: val_loss did not improve from 0.10294
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9950 - loss: 0.0869 - val_accuracy: 0.9893 - val_loss: 0.1050 - learning_rate: 2.0000e-05
# Epoch 80/200
# 926/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9949 - loss: 0.0856
# Epoch 80: val_loss did not improve from 0.10294
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9945 - loss: 0.0859 - val_accuracy: 0.9903 - val_loss: 0.1035 - learning_rate: 2.0000e-05
# Epoch 81/200
# 931/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9947 - loss: 0.0866
# Epoch 81: val_loss did not improve from 0.10294
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9949 - loss: 0.0855 - val_accuracy: 0.9896 - val_loss: 0.1055 - learning_rate: 2.0000e-05
# Epoch 82/200
# 923/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9943 - loss: 0.0863
# Epoch 82: ReduceLROnPlateau reducing learning rate to 3.999999898951501e-06.
#
# Epoch 82: val_loss did not improve from 0.10294
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9948 - loss: 0.0851 - val_accuracy: 0.9892 - val_loss: 0.1049 - learning_rate: 2.0000e-05
# Epoch 83/200
# 925/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9937 - loss: 0.0858
# Epoch 83: val_loss did not improve from 0.10294
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9951 - loss: 0.0833 - val_accuracy: 0.9893 - val_loss: 0.1035 - learning_rate: 4.0000e-06
# Epoch 84/200
# 935/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9959 - loss: 0.0815
# Epoch 84: val_loss improved from 0.10294 to 0.10175, saving model to best_densenet201_crop_smote_256.keras
#
# Epoch 84: finished saving model to best_densenet201_crop_smote_256.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9963 - loss: 0.0805 - val_accuracy: 0.9897 - val_loss: 0.1018 - learning_rate: 4.0000e-06
# Epoch 85/200
# 933/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9951 - loss: 0.0822
# Epoch 85: val_loss did not improve from 0.10175
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9955 - loss: 0.0814 - val_accuracy: 0.9896 - val_loss: 0.1019 - learning_rate: 4.0000e-06
# Epoch 86/200
# 934/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9961 - loss: 0.0798
# Epoch 86: val_loss improved from 0.10175 to 0.10146, saving model to best_densenet201_crop_smote_256.keras
#
# Epoch 86: finished saving model to best_densenet201_crop_smote_256.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9965 - loss: 0.0791 - val_accuracy: 0.9897 - val_loss: 0.1015 - learning_rate: 4.0000e-06
# Epoch 87/200
# 918/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9963 - loss: 0.0794
# Epoch 87: val_loss did not improve from 0.10146
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9964 - loss: 0.0789 - val_accuracy: 0.9903 - val_loss: 0.1021 - learning_rate: 4.0000e-06
# Epoch 88/200
# 921/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9970 - loss: 0.0784
# Epoch 88: val_loss improved from 0.10146 to 0.10029, saving model to best_densenet201_crop_smote_256.keras
#
# Epoch 88: finished saving model to best_densenet201_crop_smote_256.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9965 - loss: 0.0789 - val_accuracy: 0.9907 - val_loss: 0.1003 - learning_rate: 4.0000e-06
# Epoch 89/200
# 932/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9973 - loss: 0.0792
# Epoch 89: val_loss did not improve from 0.10029
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9971 - loss: 0.0784 - val_accuracy: 0.9901 - val_loss: 0.1011 - learning_rate: 4.0000e-06
# Epoch 90/200
# 921/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9970 - loss: 0.0784
# Epoch 90: val_loss did not improve from 0.10029
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9967 - loss: 0.0781 - val_accuracy: 0.9905 - val_loss: 0.1004 - learning_rate: 4.0000e-06
# Epoch 91/200
# 922/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9978 - loss: 0.0760
# Epoch 91: val_loss did not improve from 0.10029
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9972 - loss: 0.0770 - val_accuracy: 0.9895 - val_loss: 0.1006 - learning_rate: 4.0000e-06
# Epoch 92/200
# 915/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9971 - loss: 0.0773
# Epoch 92: val_loss improved from 0.10029 to 0.09986, saving model to best_densenet201_crop_smote_256.keras
#
# Epoch 92: finished saving model to best_densenet201_crop_smote_256.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9969 - loss: 0.0778 - val_accuracy: 0.9904 - val_loss: 0.0999 - learning_rate: 4.0000e-06
# Epoch 93/200
# 928/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9973 - loss: 0.0763
# Epoch 93: val_loss did not improve from 0.09986
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9973 - loss: 0.0763 - val_accuracy: 0.9897 - val_loss: 0.1012 - learning_rate: 4.0000e-06
# Epoch 94/200
# 920/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9970 - loss: 0.0776
# Epoch 94: val_loss did not improve from 0.09986
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9971 - loss: 0.0772 - val_accuracy: 0.9901 - val_loss: 0.1002 - learning_rate: 4.0000e-06
# Epoch 95/200
# 916/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9973 - loss: 0.0762
# Epoch 95: val_loss did not improve from 0.09986
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9970 - loss: 0.0765 - val_accuracy: 0.9900 - val_loss: 0.1005 - learning_rate: 4.0000e-06
# Epoch 96/200
# 932/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9964 - loss: 0.0778
# Epoch 96: ReduceLROnPlateau reducing learning rate to 7.999999979801942e-07.
#
# Epoch 96: val_loss did not improve from 0.09986
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9968 - loss: 0.0772 - val_accuracy: 0.9903 - val_loss: 0.0999 - learning_rate: 4.0000e-06
# Epoch 97/200
# 933/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9968 - loss: 0.0775
# Epoch 97: val_loss improved from 0.09986 to 0.09980, saving model to best_densenet201_crop_smote_256.keras
#
# Epoch 97: finished saving model to best_densenet201_crop_smote_256.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9968 - loss: 0.0768 - val_accuracy: 0.9903 - val_loss: 0.0998 - learning_rate: 8.0000e-07
# Epoch 98/200
# 916/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9968 - loss: 0.0773
# Epoch 98: val_loss improved from 0.09980 to 0.09961, saving model to best_densenet201_crop_smote_256.keras
#
# Epoch 98: finished saving model to best_densenet201_crop_smote_256.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9973 - loss: 0.0765 - val_accuracy: 0.9901 - val_loss: 0.0996 - learning_rate: 8.0000e-07
# Epoch 99/200
# 924/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9960 - loss: 0.0775
# Epoch 99: val_loss did not improve from 0.09961
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9966 - loss: 0.0771 - val_accuracy: 0.9904 - val_loss: 0.0996 - learning_rate: 8.0000e-07
# Epoch 100/200
# 923/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9974 - loss: 0.0752
# Epoch 100: val_loss did not improve from 0.09961
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9973 - loss: 0.0749 - val_accuracy: 0.9905 - val_loss: 0.1000 - learning_rate: 8.0000e-07
# Epoch 101/200
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9964 - loss: 0.0770
# Epoch 101: val_loss did not improve from 0.09961
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9967 - loss: 0.0764 - val_accuracy: 0.9904 - val_loss: 0.0998 - learning_rate: 8.0000e-07
# Epoch 102/200
# 926/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9972 - loss: 0.0755
# Epoch 102: ReduceLROnPlateau reducing learning rate to 1.600000018697756e-07.
#
# Epoch 102: val_loss did not improve from 0.09961
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9975 - loss: 0.0748 - val_accuracy: 0.9903 - val_loss: 0.0997 - learning_rate: 8.0000e-07
# Epoch 103/200
# 932/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9969 - loss: 0.0762
# Epoch 103: val_loss did not improve from 0.09961
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9976 - loss: 0.0752 - val_accuracy: 0.9903 - val_loss: 0.0998 - learning_rate: 1.6000e-07
# Epoch 104/200
# 918/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9969 - loss: 0.0765
# Epoch 104: val_loss did not improve from 0.09961
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9969 - loss: 0.0765 - val_accuracy: 0.9903 - val_loss: 0.0997 - learning_rate: 1.6000e-07
# Epoch 105/200
# 929/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9975 - loss: 0.0752
# Epoch 105: val_loss did not improve from 0.09961
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9978 - loss: 0.0747 - val_accuracy: 0.9904 - val_loss: 0.0997 - learning_rate: 1.6000e-07
# Epoch 106/200
# 936/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9975 - loss: 0.0756
# Epoch 106: ReduceLROnPlateau reducing learning rate to 1e-07.
#
# Epoch 106: val_loss did not improve from 0.09961
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9972 - loss: 0.0758 - val_accuracy: 0.9904 - val_loss: 0.0996 - learning_rate: 1.6000e-07
# Epoch 107/200
# 920/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9975 - loss: 0.0751
# Epoch 107: val_loss did not improve from 0.09961
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9974 - loss: 0.0752 - val_accuracy: 0.9904 - val_loss: 0.0996 - learning_rate: 1.0000e-07
# Epoch 108/200
# 938/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9970 - loss: 0.0750
# Epoch 108: val_loss improved from 0.09961 to 0.09960, saving model to best_densenet201_crop_smote_256.keras
#
# Epoch 108: finished saving model to best_densenet201_crop_smote_256.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9973 - loss: 0.0752 - val_accuracy: 0.9905 - val_loss: 0.0996 - learning_rate: 1.0000e-07
# Epoch 109/200
# 931/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9965 - loss: 0.0772
# Epoch 109: val_loss did not improve from 0.09960
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9970 - loss: 0.0757 - val_accuracy: 0.9905 - val_loss: 0.0996 - learning_rate: 1.0000e-07
# Epoch 110/200
# 935/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9973 - loss: 0.0760
# Epoch 110: val_loss improved from 0.09960 to 0.09957, saving model to best_densenet201_crop_smote_256.keras
#
# Epoch 110: finished saving model to best_densenet201_crop_smote_256.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9972 - loss: 0.0757 - val_accuracy: 0.9905 - val_loss: 0.0996 - learning_rate: 1.0000e-07
# Epoch 111/200
# 917/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9970 - loss: 0.0764
# Epoch 111: val_loss did not improve from 0.09957
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9972 - loss: 0.0761 - val_accuracy: 0.9905 - val_loss: 0.0996 - learning_rate: 1.0000e-07
# Epoch 112/200
# 930/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9964 - loss: 0.0778
# Epoch 112: val_loss improved from 0.09957 to 0.09957, saving model to best_densenet201_crop_smote_256.keras
#
# Epoch 112: finished saving model to best_densenet201_crop_smote_256.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9965 - loss: 0.0777 - val_accuracy: 0.9904 - val_loss: 0.0996 - learning_rate: 1.0000e-07
# Epoch 113/200
# 915/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9971 - loss: 0.0763
# Epoch 113: val_loss improved from 0.09957 to 0.09953, saving model to best_densenet201_crop_smote_256.keras
#
# Epoch 113: finished saving model to best_densenet201_crop_smote_256.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9971 - loss: 0.0759 - val_accuracy: 0.9907 - val_loss: 0.0995 - learning_rate: 1.0000e-07
# Epoch 114/200
# 932/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9976 - loss: 0.0760
# Epoch 114: val_loss improved from 0.09953 to 0.09952, saving model to best_densenet201_crop_smote_256.keras
#
# Epoch 114: finished saving model to best_densenet201_crop_smote_256.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9977 - loss: 0.0749 - val_accuracy: 0.9907 - val_loss: 0.0995 - learning_rate: 1.0000e-07
# Epoch 115/200
# 917/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9976 - loss: 0.0749
# Epoch 115: val_loss improved from 0.09952 to 0.09951, saving model to best_densenet201_crop_smote_256.keras
#
# Epoch 115: finished saving model to best_densenet201_crop_smote_256.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9972 - loss: 0.0755 - val_accuracy: 0.9907 - val_loss: 0.0995 - learning_rate: 1.0000e-07
# Epoch 116/200
# 928/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9962 - loss: 0.0776
# Epoch 116: val_loss improved from 0.09951 to 0.09947, saving model to best_densenet201_crop_smote_256.keras
#
# Epoch 116: finished saving model to best_densenet201_crop_smote_256.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9965 - loss: 0.0772 - val_accuracy: 0.9907 - val_loss: 0.0995 - learning_rate: 1.0000e-07
# Epoch 117/200
# 934/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9967 - loss: 0.0768
# Epoch 117: val_loss did not improve from 0.09947
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9974 - loss: 0.0755 - val_accuracy: 0.9907 - val_loss: 0.0995 - learning_rate: 1.0000e-07
# Epoch 118/200
# 924/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9972 - loss: 0.0759
# Epoch 118: val_loss did not improve from 0.09947
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9975 - loss: 0.0750 - val_accuracy: 0.9908 - val_loss: 0.0995 - learning_rate: 1.0000e-07
# Epoch 119/200
# 924/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9969 - loss: 0.0760
# Epoch 119: val_loss improved from 0.09947 to 0.09946, saving model to best_densenet201_crop_smote_256.keras
#
# Epoch 119: finished saving model to best_densenet201_crop_smote_256.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9972 - loss: 0.0753 - val_accuracy: 0.9907 - val_loss: 0.0995 - learning_rate: 1.0000e-07
# Epoch 120/200
# 933/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9971 - loss: 0.0752
# Epoch 120: val_loss did not improve from 0.09946
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9972 - loss: 0.0753 - val_accuracy: 0.9907 - val_loss: 0.0995 - learning_rate: 1.0000e-07
# Epoch 121/200
# 920/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9973 - loss: 0.0760
# Epoch 121: val_loss improved from 0.09946 to 0.09942, saving model to best_densenet201_crop_smote_256.keras
#
# Epoch 121: finished saving model to best_densenet201_crop_smote_256.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9973 - loss: 0.0756 - val_accuracy: 0.9905 - val_loss: 0.0994 - learning_rate: 1.0000e-07
# Epoch 122/200
# 934/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9971 - loss: 0.0759
# Epoch 122: val_loss did not improve from 0.09942
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9968 - loss: 0.0759 - val_accuracy: 0.9907 - val_loss: 0.0994 - learning_rate: 1.0000e-07
# Epoch 123/200
# 919/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9974 - loss: 0.0753
# Epoch 123: val_loss did not improve from 0.09942
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9973 - loss: 0.0751 - val_accuracy: 0.9908 - val_loss: 0.0994 - learning_rate: 1.0000e-07
# Epoch 124/200
# 930/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9966 - loss: 0.0765
# Epoch 124: val_loss improved from 0.09942 to 0.09937, saving model to best_densenet201_crop_smote_256.keras
#
# Epoch 124: finished saving model to best_densenet201_crop_smote_256.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9969 - loss: 0.0760 - val_accuracy: 0.9907 - val_loss: 0.0994 - learning_rate: 1.0000e-07
# Epoch 125/200
# 928/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9967 - loss: 0.0763
# Epoch 125: val_loss did not improve from 0.09937
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9968 - loss: 0.0758 - val_accuracy: 0.9908 - val_loss: 0.0994 - learning_rate: 1.0000e-07
# Epoch 126/200
# 936/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9969 - loss: 0.0766
# Epoch 126: val_loss improved from 0.09937 to 0.09936, saving model to best_densenet201_crop_smote_256.keras
#
# Epoch 126: finished saving model to best_densenet201_crop_smote_256.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9973 - loss: 0.0757 - val_accuracy: 0.9908 - val_loss: 0.0994 - learning_rate: 1.0000e-07
# Epoch 127/200
# 931/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9976 - loss: 0.0752
# Epoch 127: val_loss did not improve from 0.09936
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9973 - loss: 0.0757 - val_accuracy: 0.9908 - val_loss: 0.0994 - learning_rate: 1.0000e-07
# Epoch 128/200
# 929/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9965 - loss: 0.0765
# Epoch 128: val_loss improved from 0.09936 to 0.09935, saving model to best_densenet201_crop_smote_256.keras
#
# Epoch 128: finished saving model to best_densenet201_crop_smote_256.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9970 - loss: 0.0757 - val_accuracy: 0.9908 - val_loss: 0.0993 - learning_rate: 1.0000e-07
# Epoch 129/200
# 926/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9972 - loss: 0.0754
# Epoch 129: val_loss did not improve from 0.09935
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9972 - loss: 0.0748 - val_accuracy: 0.9908 - val_loss: 0.0994 - learning_rate: 1.0000e-07
# Epoch 130/200
# 927/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9970 - loss: 0.0764
# Epoch 130: val_loss improved from 0.09935 to 0.09934, saving model to best_densenet201_crop_smote_256.keras
#
# Epoch 130: finished saving model to best_densenet201_crop_smote_256.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9974 - loss: 0.0756 - val_accuracy: 0.9908 - val_loss: 0.0993 - learning_rate: 1.0000e-07
# Epoch 131/200
# 933/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9970 - loss: 0.0757
# Epoch 131: val_loss improved from 0.09934 to 0.09933, saving model to best_densenet201_crop_smote_256.keras
#
# Epoch 131: finished saving model to best_densenet201_crop_smote_256.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9970 - loss: 0.0758 - val_accuracy: 0.9908 - val_loss: 0.0993 - learning_rate: 1.0000e-07
# Epoch 132/200
# 929/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9964 - loss: 0.0765
# Epoch 132: val_loss did not improve from 0.09933
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9968 - loss: 0.0759 - val_accuracy: 0.9908 - val_loss: 0.0994 - learning_rate: 1.0000e-07
# Epoch 133/200
# 931/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9962 - loss: 0.0781
# Epoch 133: val_loss did not improve from 0.09933
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9971 - loss: 0.0759 - val_accuracy: 0.9908 - val_loss: 0.0994 - learning_rate: 1.0000e-07
# Epoch 134/200
# 934/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9971 - loss: 0.0770
# Epoch 134: val_loss did not improve from 0.09933
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9976 - loss: 0.0752 - val_accuracy: 0.9908 - val_loss: 0.0994 - learning_rate: 1.0000e-07
# Epoch 135/200
# 918/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9962 - loss: 0.0770
# Epoch 135: val_loss did not improve from 0.09933
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9969 - loss: 0.0758 - val_accuracy: 0.9908 - val_loss: 0.0993 - learning_rate: 1.0000e-07
# Epoch 136/200
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9973 - loss: 0.0757
# Epoch 136: val_loss did not improve from 0.09933
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9972 - loss: 0.0753 - val_accuracy: 0.9908 - val_loss: 0.0993 - learning_rate: 1.0000e-07
# Epoch 137/200
# 933/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9969 - loss: 0.0760
# Epoch 137: val_loss did not improve from 0.09933
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9974 - loss: 0.0754 - val_accuracy: 0.9908 - val_loss: 0.0993 - learning_rate: 1.0000e-07
# Epoch 138/200
# 935/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9971 - loss: 0.0754
# Epoch 138: val_loss did not improve from 0.09933
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9974 - loss: 0.0747 - val_accuracy: 0.9908 - val_loss: 0.0994 - learning_rate: 1.0000e-07
# Epoch 139/200
# 936/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9977 - loss: 0.0749
# Epoch 139: val_loss did not improve from 0.09933
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9980 - loss: 0.0745 - val_accuracy: 0.9908 - val_loss: 0.0994 - learning_rate: 1.0000e-07
# Epoch 140/200
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9970 - loss: 0.0766
# Epoch 140: val_loss did not improve from 0.09933
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9972 - loss: 0.0757 - val_accuracy: 0.9908 - val_loss: 0.0994 - learning_rate: 1.0000e-07
# Epoch 141/200
# 932/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9974 - loss: 0.0758
# Epoch 141: val_loss did not improve from 0.09933
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9974 - loss: 0.0749 - val_accuracy: 0.9908 - val_loss: 0.0994 - learning_rate: 1.0000e-07
# Epoch 141: early stopping
# Restoring model weights from the end of the best epoch: 131.

# %%
plt.figure(figsize=(8, 5))
plt.plot(history.history["accuracy"], label="Treino")
plt.plot(history.history["val_accuracy"], label="Validação")
plt.title("Acurácia durante o treinamento")
plt.xlabel("Época")
plt.ylabel("Acurácia")
plt.legend()
plt.grid(True, alpha=0.3)
plt.savefig("acuracia_densenet201_crop_smote.png", dpi=300, bbox_inches="tight")
plt.show()

plt.figure(figsize=(8, 5))
plt.plot(history.history["loss"], label="Treino")
plt.plot(history.history["val_loss"], label="Validação")
plt.title("Perda durante o treinamento")
plt.xlabel("Época")
plt.ylabel("Loss")
plt.legend()
plt.grid(True, alpha=0.3)
plt.savefig("loss_densenet201_crop_smote.png", dpi=300, bbox_inches="tight")
plt.show()

# %%
best_classifier = keras.models.load_model(BEST_MODEL_PATH)

pred_probs = best_classifier.predict(X_test_features, verbose=0)
y_pred = np.argmax(pred_probs, axis=1)

print("Relatório de Classificação:")
print(classification_report(
    y_test,
    y_pred,
    target_names=classes,
    digits=4,
    zero_division=0
))

acc = accuracy_score(y_test, y_pred)

macro_precision = precision_score(y_test, y_pred, average="macro", zero_division=0)
macro_recall = recall_score(y_test, y_pred, average="macro", zero_division=0)
macro_f1 = f1_score(y_test, y_pred, average="macro", zero_division=0)

weighted_precision = precision_score(y_test, y_pred, average="weighted", zero_division=0)
weighted_recall = recall_score(y_test, y_pred, average="weighted", zero_division=0)
weighted_f1 = f1_score(y_test, y_pred, average="weighted", zero_division=0)

print("\nMÉTRICAS GERAIS DO MODELO")
print(f"Accuracy: {acc:.4f}")

print("\nMacro Average:")
print(f"  Precision: {macro_precision:.4f}")
print(f"  Recall: {macro_recall:.4f}")
print(f"  F1-Score: {macro_f1:.4f}")

print("\nWeighted Average:")
print(f"  Precision: {weighted_precision:.4f}")
print(f"  Recall: {weighted_recall:.4f}")
print(f"  F1-Score: {weighted_f1:.4f}")
# Out:
# Relatório de Classificação:
#               precision    recall  f1-score   support
#
#          MEL     0.6943    0.7130    0.7035       223
#           NV     0.9305    0.9389    0.9347      1341
#          BCC     0.7119    0.8155    0.7602       103
#        AKIEC     0.6094    0.6000    0.6047        65
#          BKL     0.7368    0.6364    0.6829       220
#           DF     0.7727    0.7391    0.7556        23
#         VASC     0.9259    0.8929    0.9091        28
#
#     accuracy                         0.8602      2003
#    macro avg     0.7688    0.7622    0.7644      2003
# weighted avg     0.8594    0.8602    0.8592      2003
#
#
# MÉTRICAS GERAIS DO MODELO
# Accuracy: 0.8602
#
# Macro Average:
#   Precision: 0.7688
#   Recall: 0.7622
#   F1-Score: 0.7644
#
# Weighted Average:
#   Precision: 0.8594
#   Recall: 0.8602
#   F1-Score: 0.8592

# %%
cm = confusion_matrix(y_test, y_pred, labels=list(range(len(classes))))
cm_percent = cm.astype("float") / cm.sum(axis=1, keepdims=True) * 100
cm_percent = np.nan_to_num(cm_percent)

plt.figure(figsize=(8, 7))
im = plt.imshow(cm_percent, interpolation="nearest", cmap="Blues", vmin=0, vmax=100)
plt.title("Matriz de Confusão (%) - DenseNet201 + Crop + SMOTE + 256x256")
plt.colorbar(im, label="%")

tick_marks = np.arange(len(classes))
plt.xticks(tick_marks, classes, rotation=45)
plt.yticks(tick_marks, classes)

for i in range(cm_percent.shape[0]):
    for j in range(cm_percent.shape[1]):
        color = "white" if cm_percent[i, j] > 50 else "black"
        plt.text(
            j,
            i,
            f"{cm_percent[i, j]:.1f}",
            ha="center",
            va="center",
            color=color,
            fontsize=8
        )

plt.ylabel("Classe Real")
plt.xlabel("Classe Predita")
plt.tight_layout()
plt.savefig("matriz_confusao_percent_densenet201_crop_smote.png", dpi=300, bbox_inches="tight")
plt.show()

# %%
test_eval_df = test_df.copy().reset_index(drop=True)
test_eval_df["y_true"] = y_test
test_eval_df["y_pred"] = y_pred
test_eval_df["correct"] = test_eval_df["y_true"] == test_eval_df["y_pred"]

correct_samples = test_eval_df[test_eval_df["correct"]].head(4)
incorrect_samples = test_eval_df[~test_eval_df["correct"]].head(4)

samples_to_plot = pd.concat([correct_samples, incorrect_samples], axis=0).reset_index(drop=True)

plt.figure(figsize=(12, 6))

for i, row in samples_to_plot.iterrows():
    image = preprocess_image_path(row["image_path"], row["mask_path"])
    image = np.clip(image, 0, 255).astype("uint8")

    plt.subplot(2, 4, i + 1)
    plt.imshow(image)

    true_label = class_name[int(row["y_true"])]
    pred_label = class_name[int(row["y_pred"])]

    plt.title(f"{true_label} → {pred_label}", fontsize=10)
    plt.axis("off")

plt.tight_layout()
plt.savefig("exemplos_classificacao_densenet201_crop_smote.png", dpi=300, bbox_inches="tight")
plt.show()

# %%
feature_extractor.save(FEATURE_EXTRACTOR_PATH)
best_classifier.save(FINAL_MODEL_PATH)

print("Extratora DenseNet201 salva em:", FEATURE_EXTRACTOR_PATH)
print("Classificador final salvo em:", FINAL_MODEL_PATH)
print("Melhor checkpoint salvo em:", BEST_MODEL_PATH)
# Out:
# Extratora DenseNet201 salva em: densenet201_crop_256_feature_extractor.keras
# Classificador final salvo em: densenet201_crop_smote_256_final.keras
# Melhor checkpoint salvo em: best_densenet201_crop_smote_256.keras
