# %%
import os
os.environ["KERAS_BACKEND"] = "tensorflow"

import random
from pathlib import Path
from collections import Counter

import cv2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import tensorflow as tf
import keras
from keras import layers, models, regularizers

from tensorflow.keras.applications import EfficientNetB3, EfficientNetB4
from tensorflow.keras.applications.efficientnet import preprocess_input

from sklearn.model_selection import train_test_split
from sklearn.metrics import (
    classification_report,
    confusion_matrix,
    accuracy_score,
    precision_score,
    recall_score,
    f1_score
)

from imblearn.over_sampling import SMOTE

# %%
SEED = 42
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)

DATA_DIR = Path("../data")
IMAGES_DIR = DATA_DIR / "images"
MASKS_DIR = DATA_DIR / "masks"
CSV_PATH = DATA_DIR / "GroundTruth.csv"

IMG_SIZE = (380, 380)
BATCH_SIZE = 32
EPOCHS = 200
LEARNING_RATE = 0.0001

TEST_SIZE = 0.20
VAL_SIZE = 0.20

USE_DULL_RAZOR = False

USE_MASK_SEGMENTATION = False

USE_MASK_CROP = True
CROP_MARGIN = 20

BEST_MODEL_PATH = "best_efficientnetb3_crop_smote_320.keras"
FINAL_MODEL_PATH = "efficientnetb3_crop_smote_320_final.keras"
FEATURE_EXTRACTOR_PATH = "efficientnetb3_crop_320_feature_extractor.keras"

classes = ["MEL", "NV", "BCC", "AKIEC", "BKL", "DF", "VASC"]
class_code = {label: idx for idx, label in enumerate(classes)}
class_name = {idx: label for label, idx in class_code.items()}

print("IMG_SIZE:", IMG_SIZE)
print("BATCH_SIZE:", BATCH_SIZE)
print("EPOCHS:", EPOCHS)
print("LEARNING_RATE:", LEARNING_RATE)
print("USE_DULL_RAZOR:", USE_DULL_RAZOR)
print("USE_MASK_SEGMENTATION:", USE_MASK_SEGMENTATION)
print("USE_MASK_CROP:", USE_MASK_CROP)
print("CROP_MARGIN:", CROP_MARGIN)
print(class_code)
# Out:
# IMG_SIZE: (380, 380)
# BATCH_SIZE: 32
# EPOCHS: 200
# LEARNING_RATE: 0.0001
# USE_DULL_RAZOR: False
# USE_MASK_SEGMENTATION: False
# USE_MASK_CROP: True
# CROP_MARGIN: 20
# {'MEL': 0, 'NV': 1, 'BCC': 2, 'AKIEC': 3, 'BKL': 4, 'DF': 5, 'VASC': 6}

# %%
EFFICIENTNET_VERSION = "B4"

if EFFICIENTNET_VERSION == "B3":
    EfficientNetModel = EfficientNetB3
    ARCHITECTURE_NAME = "EfficientNetB3"
elif EFFICIENTNET_VERSION == "B4":
    EfficientNetModel = EfficientNetB4
    ARCHITECTURE_NAME = "EfficientNetB4"
else:
    raise ValueError("EFFICIENTNET_VERSION deve ser 'B3' ou 'B4'.")

BEST_MODEL_PATH = f"best_{ARCHITECTURE_NAME.lower()}_crop_smote_{IMG_SIZE[0]}.keras"
FINAL_MODEL_PATH = f"{ARCHITECTURE_NAME.lower()}_crop_smote_{IMG_SIZE[0]}_final.keras"
FEATURE_EXTRACTOR_PATH = f"{ARCHITECTURE_NAME.lower()}_crop_{IMG_SIZE[0]}_feature_extractor.keras"

print("Arquitetura:", ARCHITECTURE_NAME)
print("IMG_SIZE:", IMG_SIZE)
print("BEST_MODEL_PATH:", BEST_MODEL_PATH)
print("FINAL_MODEL_PATH:", FINAL_MODEL_PATH)
print("FEATURE_EXTRACTOR_PATH:", FEATURE_EXTRACTOR_PATH)
# Out:
# Arquitetura: EfficientNetB4
# IMG_SIZE: (380, 380)
# BEST_MODEL_PATH: best_efficientnetb4_crop_smote_380.keras
# FINAL_MODEL_PATH: efficientnetb4_crop_smote_380_final.keras
# FEATURE_EXTRACTOR_PATH: efficientnetb4_crop_380_feature_extractor.keras

# %%
print("Arquitetura: EfficientNetB3")
print("IMG_SIZE:", IMG_SIZE)
print("USE_DULL_RAZOR:", USE_DULL_RAZOR)
print("USE_MASK_SEGMENTATION:", USE_MASK_SEGMENTATION)
print("USE_MASK_CROP:", USE_MASK_CROP)
print("CROP_MARGIN:", CROP_MARGIN)
# Out:
# Arquitetura: EfficientNetB3
# IMG_SIZE: (380, 380)
# USE_DULL_RAZOR: False
# USE_MASK_SEGMENTATION: False
# USE_MASK_CROP: True
# CROP_MARGIN: 20

# %%
def find_image_path(image_id, images_dir):
    for ext in [".jpg", ".jpeg", ".png"]:
        path = images_dir / f"{image_id}{ext}"
        if path.exists():
            return str(path)
    return None


def find_mask_path(image_id, masks_dir):
    if not masks_dir.exists():
        return None

    candidates = [
        masks_dir / f"{image_id}_segmentation.png",
        masks_dir / f"{image_id}_segmentation.jpg",
        masks_dir / f"{image_id}_mask.png",
        masks_dir / f"{image_id}_mask.jpg",
        masks_dir / f"{image_id}.png",
        masks_dir / f"{image_id}.jpg",
    ]

    for path in candidates:
        if path.exists():
            return str(path)

    matches = list(masks_dir.glob(f"{image_id}*"))
    if len(matches) > 0:
        return str(matches[0])

    return None


metadata = pd.read_csv(CSV_PATH)

rows = []
for _, row in metadata.iterrows():
    image_id = str(row["image"])
    image_path = find_image_path(image_id, IMAGES_DIR)
    mask_path = find_mask_path(image_id, MASKS_DIR)

    if image_path is None:
        continue

    label_name = row[classes].idxmax()
    label = class_code[label_name]

    rows.append({
        "image": image_id,
        "image_path": image_path,
        "mask_path": mask_path,
        "class_name": label_name,
        "label": label
    })

df = pd.DataFrame(rows)

print("Total de imagens localizadas:", len(df))
display(df.head())

print("\nDistribuição original:")
print(df["class_name"].value_counts().reindex(classes))

print("\nMáscaras encontradas:", df["mask_path"].notna().sum())
# Out:
# Total de imagens localizadas: 10015
#           image                       image_path  \
# 0  ISIC_0024306  ../data/images/ISIC_0024306.jpg
# 1  ISIC_0024307  ../data/images/ISIC_0024307.jpg
# 2  ISIC_0024308  ../data/images/ISIC_0024308.jpg
# 3  ISIC_0024309  ../data/images/ISIC_0024309.jpg
# 4  ISIC_0024310  ../data/images/ISIC_0024310.jpg
#
#                                      mask_path class_name  label
# 0  ../data/masks/ISIC_0024306_segmentation.png         NV      1
# 1  ../data/masks/ISIC_0024307_segmentation.png         NV      1
# 2  ../data/masks/ISIC_0024308_segmentation.png         NV      1
# 3  ../data/masks/ISIC_0024309_segmentation.png         NV      1
# 4  ../data/masks/ISIC_0024310_segmentation.png        MEL      0
# Distribuição original:
# class_name
# MEL      1113
# NV       6705
# BCC       514
# AKIEC     327
# BKL      1099
# DF        115
# VASC      142
# Name: count, dtype: int64
#
# Máscaras encontradas: 10015

# %%
train_df, test_df = train_test_split(
    df,
    test_size=TEST_SIZE,
    random_state=SEED,
    stratify=df["label"]
)

print("Treino original:", len(train_df))
print("Teste final:", len(test_df))

print("\nDistribuição treino original:")
print(train_df["class_name"].value_counts().reindex(classes))

print("\nDistribuição teste final:")
print(test_df["class_name"].value_counts().reindex(classes))
# Out:
# Treino original: 8012
# Teste final: 2003
#
# Distribuição treino original:
# class_name
# MEL       890
# NV       5364
# BCC       411
# AKIEC     262
# BKL       879
# DF         92
# VASC      114
# Name: count, dtype: int64
#
# Distribuição teste final:
# class_name
# MEL       223
# NV       1341
# BCC       103
# AKIEC      65
# BKL       220
# DF         23
# VASC       28
# Name: count, dtype: int64

# %%
def read_rgb_image(path):
    if isinstance(path, bytes):
        path = path.decode("utf-8")

    image_bgr = cv2.imread(str(path), cv2.IMREAD_COLOR)

    if image_bgr is None:
        raise ValueError(f"Não foi possível carregar a imagem: {path}")

    image_rgb = cv2.cvtColor(image_bgr, cv2.COLOR_BGR2RGB)

    return image_rgb


def dull_razor_remove_hair(image_rgb, kernel_size=(9, 9), threshold_value=10, inpaint_radius=6):
    image_rgb = image_rgb.astype(np.uint8)

    gray = cv2.cvtColor(image_rgb, cv2.COLOR_RGB2GRAY)

    kernel = cv2.getStructuringElement(cv2.MORPH_RECT, kernel_size)
    blackhat = cv2.morphologyEx(gray, cv2.MORPH_BLACKHAT, kernel)

    blackhat_blur = cv2.GaussianBlur(blackhat, (3, 3), 0)

    _, mask = cv2.threshold(
        blackhat_blur,
        threshold_value,
        255,
        cv2.THRESH_BINARY
    )

    image_bgr = cv2.cvtColor(image_rgb, cv2.COLOR_RGB2BGR)

    clean_bgr = cv2.inpaint(
        image_bgr,
        mask,
        inpaint_radius,
        cv2.INPAINT_TELEA
    )

    clean_rgb = cv2.cvtColor(clean_bgr, cv2.COLOR_BGR2RGB)

    return clean_rgb


def read_binary_mask(mask_path, target_shape):
    if mask_path is None or pd.isna(mask_path):
        return None

    if isinstance(mask_path, bytes):
        mask_path = mask_path.decode("utf-8")

    mask = cv2.imread(str(mask_path), cv2.IMREAD_GRAYSCALE)

    if mask is None:
        return None

    height, width = target_shape[:2]
    mask = cv2.resize(mask, (width, height))

    binary_mask = (mask > 127).astype(np.uint8)

    return binary_mask


def apply_mask_segmentation(image_rgb, mask_path):
    binary_mask = read_binary_mask(mask_path, target_shape=image_rgb.shape)

    if binary_mask is None:
        return image_rgb

    segmented = image_rgb * np.expand_dims(binary_mask, axis=-1)

    # Proteção contra máscara ruim.
    if np.mean(segmented) < 5:
        return image_rgb

    return segmented


def crop_lesion_with_margin(image_rgb, mask_path, margin=20):
    binary_mask = read_binary_mask(mask_path, target_shape=image_rgb.shape)

    if binary_mask is None:
        return image_rgb

    ys, xs = np.where(binary_mask > 0)

    if len(xs) == 0 or len(ys) == 0:
        return image_rgb

    height, width = image_rgb.shape[:2]

    x_min = max(xs.min() - margin, 0)
    x_max = min(xs.max() + margin, width - 1)
    y_min = max(ys.min() - margin, 0)
    y_max = min(ys.max() + margin, height - 1)

    cropped = image_rgb[y_min:y_max + 1, x_min:x_max + 1]

    if cropped.size == 0:
        return image_rgb

    return cropped


def preprocess_image_path(path, mask_path=None):
    image_rgb = read_rgb_image(path)

    if USE_DULL_RAZOR:
        image_rgb = dull_razor_remove_hair(image_rgb)

    if USE_MASK_CROP:
        image_rgb = crop_lesion_with_margin(
            image_rgb,
            mask_path,
            margin=CROP_MARGIN
        )
    elif USE_MASK_SEGMENTATION:
        image_rgb = apply_mask_segmentation(image_rgb, mask_path)

    image_rgb = cv2.resize(image_rgb, IMG_SIZE)

    return image_rgb.astype("float32")

# %%
sample_row = train_df.sample(1, random_state=SEED).iloc[0]

original = read_rgb_image(sample_row["image_path"])
dull = dull_razor_remove_hair(original) if USE_DULL_RAZOR else original
segmented = apply_mask_segmentation(dull, sample_row["mask_path"])
cropped = crop_lesion_with_margin(dull, sample_row["mask_path"], margin=CROP_MARGIN)
final_img = preprocess_image_path(sample_row["image_path"], sample_row["mask_path"])
final_img = np.clip(final_img, 0, 255).astype("uint8")

plt.figure(figsize=(16, 4))

plt.subplot(1, 5, 1)
plt.imshow(original)
plt.title("Original")
plt.axis("off")

plt.subplot(1, 5, 2)
plt.imshow(dull)
plt.title("Dull Razor")
plt.axis("off")

plt.subplot(1, 5, 3)
plt.imshow(np.clip(segmented, 0, 255).astype("uint8"))
plt.title("Máscara aplicada")
plt.axis("off")

plt.subplot(1, 5, 4)
plt.imshow(np.clip(cropped, 0, 255).astype("uint8"))
plt.title("Crop + margem")
plt.axis("off")

plt.subplot(1, 5, 5)
plt.imshow(final_img)
plt.title("Final 256x256")
plt.axis("off")

plt.tight_layout()
plt.savefig("pipeline_efficientnetb3_crop_smote.png", dpi=300, bbox_inches="tight")
plt.show()

# %%
def load_image_for_features_py(image_path, mask_path, label):
    if isinstance(image_path, bytes):
        image_path = image_path.decode("utf-8")

    if isinstance(mask_path, bytes):
        mask_path = mask_path.decode("utf-8")

    if mask_path == "None" or mask_path == "":
        mask_path = None

    image = preprocess_image_path(image_path, mask_path)

    return image.astype("float32"), np.int32(label)


def tf_load_image_for_features(image_path, mask_path, label):
    image, label = tf.numpy_function(
        load_image_for_features_py,
        [image_path, mask_path, label],
        [tf.float32, tf.int32]
    )

    image.set_shape((IMG_SIZE[0], IMG_SIZE[1], 3))
    label.set_shape(())

    return image, label


def build_image_dataset(dataframe, batch_size=BATCH_SIZE, shuffle=False):
    mask_values = dataframe["mask_path"].fillna("None").astype(str).values

    ds = tf.data.Dataset.from_tensor_slices((
        dataframe["image_path"].astype(str).values,
        mask_values,
        dataframe["label"].values.astype("int32")
    ))

    if shuffle:
        ds = ds.shuffle(buffer_size=len(dataframe), seed=SEED)

    ds = ds.map(tf_load_image_for_features, num_parallel_calls=tf.data.AUTOTUNE)
    ds = ds.batch(batch_size)
    ds = ds.prefetch(tf.data.AUTOTUNE)

    return ds


train_image_ds = build_image_dataset(train_df, shuffle=False)
test_image_ds = build_image_dataset(test_df, shuffle=False)

print(train_image_ds)
print(test_image_ds)
# Out:
# <_PrefetchDataset element_spec=(TensorSpec(shape=(None, 380, 380, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>
# <_PrefetchDataset element_spec=(TensorSpec(shape=(None, 380, 380, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
def build_feature_extractor(input_shape=(256, 256, 3)):
    inputs = layers.Input(shape=input_shape)

    x = preprocess_input(inputs)

    base_model = EfficientNetModel(
        weights="imagenet",
        include_top=False,
        input_shape=input_shape
    )

    base_model.trainable = False

    x = base_model(x, training=False)
    x = layers.GlobalAveragePooling2D()(x)

    feature_extractor = models.Model(
        inputs=inputs,
        outputs=x,
        name=f"{ARCHITECTURE_NAME.lower()}_crop_feature_extractor"
    )

    return feature_extractor


feature_extractor = build_feature_extractor(
    input_shape=(IMG_SIZE[0], IMG_SIZE[1], 3)
)

feature_extractor.summary()
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb4_notop.h5
# 71686520/71686520 ━━━━━━━━━━━━━━━━━━━━ 5s 0us/step
# Model: "efficientnetb4_crop_feature_extractor"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 380, 380, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ efficientnetb4 (Functional)     │ (None, 12, 12, 1792)   │    17,673,823 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 1792)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 17,673,823 (67.42 MB)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 17,673,823 (67.42 MB)

# %%
def extract_features(dataset, feature_extractor):
    features_list = []
    labels_list = []

    for images, labels in dataset:
        features = feature_extractor.predict(images, verbose=0)
        features_list.append(features)
        labels_list.append(labels.numpy())

    X = np.concatenate(features_list, axis=0)
    y = np.concatenate(labels_list, axis=0)

    return X.astype("float32"), y.astype("int32")


X_train_features, y_train = extract_features(train_image_ds, feature_extractor)
X_test_features, y_test = extract_features(test_image_ds, feature_extractor)

print("X_train_features:", X_train_features.shape)
print("y_train:", y_train.shape)
print("X_test_features:", X_test_features.shape)
print("y_test:", y_test.shape)

print("\nDistribuição treino antes do SMOTE:")
print(Counter(y_train))
# Out:
# X_train_features: (8012, 1792)
# y_train: (8012,)
# X_test_features: (2003, 1792)
# y_test: (2003,)
#
# Distribuição treino antes do SMOTE:
# Counter({np.int32(1): 5364, np.int32(0): 890, np.int32(4): 879, np.int32(2): 411, np.int32(3): 262, np.int32(6): 114, np.int32(5): 92})

# %%
min_class_count = min(Counter(y_train).values())
k_neighbors = min(5, min_class_count - 1)

print("Menor classe no treino:", min_class_count)
print("k_neighbors usado no SMOTE:", k_neighbors)

smote = SMOTE(
    random_state=SEED,
    k_neighbors=k_neighbors
)

X_train_smote, y_train_smote = smote.fit_resample(
    X_train_features,
    y_train
)

print("X_train_smote:", X_train_smote.shape)
print("y_train_smote:", y_train_smote.shape)

print("\nDistribuição treino após SMOTE:")
print(Counter(y_train_smote))
# Out:
# Menor classe no treino: 92
# k_neighbors usado no SMOTE: 5
# X_train_smote: (37548, 1792)
# y_train_smote: (37548,)
#
# Distribuição treino após SMOTE:
# Counter({np.int32(1): 5364, np.int32(0): 5364, np.int32(4): 5364, np.int32(2): 5364, np.int32(5): 5364, np.int32(3): 5364, np.int32(6): 5364})

# %%
X_fit, X_val, y_fit, y_val = train_test_split(
    X_train_smote,
    y_train_smote,
    test_size=VAL_SIZE,
    random_state=SEED,
    stratify=y_train_smote
)

print("Treino para fit:", X_fit.shape)
print("Validação:", X_val.shape)
print("Teste final:", X_test_features.shape)

print("\nDistribuição fit:")
print(Counter(y_fit))

print("\nDistribuição validação:")
print(Counter(y_val))
# Out:
# Treino para fit: (30038, 1792)
# Validação: (7510, 1792)
# Teste final: (2003, 1792)
#
# Distribuição fit:
# Counter({np.int32(0): 4292, np.int32(4): 4291, np.int32(5): 4291, np.int32(6): 4291, np.int32(2): 4291, np.int32(3): 4291, np.int32(1): 4291})
#
# Distribuição validação:
# Counter({np.int32(2): 1073, np.int32(3): 1073, np.int32(6): 1073, np.int32(4): 1073, np.int32(1): 1073, np.int32(5): 1073, np.int32(0): 1072})

# %%
def build_classifier_head(input_dim, num_classes=len(classes)):
    inputs = layers.Input(shape=(input_dim,))

    x = layers.Dense(
        256,
        activation="relu",
        kernel_regularizer=regularizers.l2(0.001)
    )(inputs)

    x = layers.BatchNormalization()(x)
    x = layers.Dropout(0.5)(x)

    x = layers.Dense(
        128,
        activation="relu",
        kernel_regularizer=regularizers.l2(0.001)
    )(x)

    x = layers.Dropout(0.3)(x)

    outputs = layers.Dense(num_classes, activation="softmax")(x)

    model = models.Model(
        inputs=inputs,
        outputs=outputs,
        name="efficientnetb3_crop_smote_classifier"
    )

    return model


classifier = build_classifier_head(
    input_dim=X_train_smote.shape[1],
    num_classes=len(classes)
)

classifier.compile(
    optimizer=keras.optimizers.Adam(learning_rate=LEARNING_RATE),
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)

classifier.summary()
# Out:
# Model: "efficientnetb3_crop_smote_classifier"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_2 (InputLayer)      │ (None, 1792)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │       459,008 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 7)              │           903 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 493,831 (1.88 MB)
#  Trainable params: 493,319 (1.88 MB)
#  Non-trainable params: 512 (2.00 KB)

# %%
callbacks = [
    keras.callbacks.EarlyStopping(
        monitor="val_loss",
        patience=10,
        restore_best_weights=True,
        verbose=1
    ),
    keras.callbacks.ReduceLROnPlateau(
        monitor="val_loss",
        factor=0.2,
        patience=4,
        min_lr=1e-7,
        verbose=1
    ),
    keras.callbacks.ModelCheckpoint(
        BEST_MODEL_PATH,
        monitor="val_loss",
        save_best_only=True,
        verbose=1
    )
]

history = classifier.fit(
    X_fit,
    y_fit,
    validation_data=(X_val, y_val),
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    callbacks=callbacks
)
# Out:
# Epoch 1/200
# 907/939 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4498 - loss: 2.2539
# Epoch 1: val_loss improved from None to 1.17136, saving model to best_efficientnetb4_crop_smote_380.keras
#
# Epoch 1: finished saving model to best_efficientnetb4_crop_smote_380.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.5716 - loss: 1.8397 - val_accuracy: 0.8087 - val_loss: 1.1714 - learning_rate: 1.0000e-04
# Epoch 2/200
# 926/939 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7200 - loss: 1.3752
# Epoch 2: val_loss improved from 1.17136 to 0.97536, saving model to best_efficientnetb4_crop_smote_380.keras
#
# Epoch 2: finished saving model to best_efficientnetb4_crop_smote_380.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7425 - loss: 1.3125 - val_accuracy: 0.8686 - val_loss: 0.9754 - learning_rate: 1.0000e-04
# Epoch 3/200
# 914/939 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7929 - loss: 1.1587
# Epoch 3: val_loss improved from 0.97536 to 0.84891, saving model to best_efficientnetb4_crop_smote_380.keras
#
# Epoch 3: finished saving model to best_efficientnetb4_crop_smote_380.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8042 - loss: 1.1139 - val_accuracy: 0.8985 - val_loss: 0.8489 - learning_rate: 1.0000e-04
# Epoch 4/200
# 913/939 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8332 - loss: 1.0130
# Epoch 4: val_loss improved from 0.84891 to 0.76025, saving model to best_efficientnetb4_crop_smote_380.keras
#
# Epoch 4: finished saving model to best_efficientnetb4_crop_smote_380.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8431 - loss: 0.9812 - val_accuracy: 0.9202 - val_loss: 0.7603 - learning_rate: 1.0000e-04
# Epoch 5/200
# 916/939 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8649 - loss: 0.8975
# Epoch 5: val_loss improved from 0.76025 to 0.68676, saving model to best_efficientnetb4_crop_smote_380.keras
#
# Epoch 5: finished saving model to best_efficientnetb4_crop_smote_380.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8700 - loss: 0.8756 - val_accuracy: 0.9344 - val_loss: 0.6868 - learning_rate: 1.0000e-04
# Epoch 6/200
# 927/939 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8796 - loss: 0.8201
# Epoch 6: val_loss improved from 0.68676 to 0.63421, saving model to best_efficientnetb4_crop_smote_380.keras
#
# Epoch 6: finished saving model to best_efficientnetb4_crop_smote_380.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8852 - loss: 0.7997 - val_accuracy: 0.9415 - val_loss: 0.6342 - learning_rate: 1.0000e-04
# Epoch 7/200
# 914/939 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8954 - loss: 0.7532
# Epoch 7: val_loss improved from 0.63421 to 0.58756, saving model to best_efficientnetb4_crop_smote_380.keras
#
# Epoch 7: finished saving model to best_efficientnetb4_crop_smote_380.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8985 - loss: 0.7371 - val_accuracy: 0.9482 - val_loss: 0.5876 - learning_rate: 1.0000e-04
# Epoch 8/200
# 916/939 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9052 - loss: 0.6944
# Epoch 8: val_loss improved from 0.58756 to 0.55872, saving model to best_efficientnetb4_crop_smote_380.keras
#
# Epoch 8: finished saving model to best_efficientnetb4_crop_smote_380.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9117 - loss: 0.6747 - val_accuracy: 0.9471 - val_loss: 0.5587 - learning_rate: 1.0000e-04
# Epoch 9/200
# 911/939 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9164 - loss: 0.6416
# Epoch 9: val_loss improved from 0.55872 to 0.50845, saving model to best_efficientnetb4_crop_smote_380.keras
#
# Epoch 9: finished saving model to best_efficientnetb4_crop_smote_380.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9207 - loss: 0.6257 - val_accuracy: 0.9575 - val_loss: 0.5085 - learning_rate: 1.0000e-04
# Epoch 10/200
# 910/939 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9251 - loss: 0.5943
# Epoch 10: val_loss improved from 0.50845 to 0.48166, saving model to best_efficientnetb4_crop_smote_380.keras
#
# Epoch 10: finished saving model to best_efficientnetb4_crop_smote_380.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9258 - loss: 0.5864 - val_accuracy: 0.9621 - val_loss: 0.4817 - learning_rate: 1.0000e-04
# Epoch 11/200
# 916/939 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9306 - loss: 0.5574
# Epoch 11: val_loss improved from 0.48166 to 0.45024, saving model to best_efficientnetb4_crop_smote_380.keras
#
# Epoch 11: finished saving model to best_efficientnetb4_crop_smote_380.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9310 - loss: 0.5511 - val_accuracy: 0.9652 - val_loss: 0.4502 - learning_rate: 1.0000e-04
# Epoch 12/200
# 928/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9371 - loss: 0.5262
# Epoch 12: val_loss improved from 0.45024 to 0.42977, saving model to best_efficientnetb4_crop_smote_380.keras
#
# Epoch 12: finished saving model to best_efficientnetb4_crop_smote_380.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9393 - loss: 0.5153 - val_accuracy: 0.9686 - val_loss: 0.4298 - learning_rate: 1.0000e-04
# Epoch 13/200
# 930/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9395 - loss: 0.4988
# Epoch 13: val_loss improved from 0.42977 to 0.41721, saving model to best_efficientnetb4_crop_smote_380.keras
#
# Epoch 13: finished saving model to best_efficientnetb4_crop_smote_380.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9397 - loss: 0.4928 - val_accuracy: 0.9662 - val_loss: 0.4172 - learning_rate: 1.0000e-04
# Epoch 14/200
# 908/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9414 - loss: 0.4840
# Epoch 14: val_loss improved from 0.41721 to 0.40847, saving model to best_efficientnetb4_crop_smote_380.keras
#
# Epoch 14: finished saving model to best_efficientnetb4_crop_smote_380.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9432 - loss: 0.4742 - val_accuracy: 0.9634 - val_loss: 0.4085 - learning_rate: 1.0000e-04
# Epoch 15/200
# 918/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9465 - loss: 0.4537
# Epoch 15: val_loss improved from 0.40847 to 0.38112, saving model to best_efficientnetb4_crop_smote_380.keras
#
# Epoch 15: finished saving model to best_efficientnetb4_crop_smote_380.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9480 - loss: 0.4426 - val_accuracy: 0.9696 - val_loss: 0.3811 - learning_rate: 1.0000e-04
# Epoch 16/200
# 933/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9498 - loss: 0.4272
# Epoch 16: val_loss did not improve from 0.38112
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9506 - loss: 0.4231 - val_accuracy: 0.9551 - val_loss: 0.3971 - learning_rate: 1.0000e-04
# Epoch 17/200
# 936/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9517 - loss: 0.4125
# Epoch 17: val_loss improved from 0.38112 to 0.35342, saving model to best_efficientnetb4_crop_smote_380.keras
#
# Epoch 17: finished saving model to best_efficientnetb4_crop_smote_380.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9526 - loss: 0.4075 - val_accuracy: 0.9691 - val_loss: 0.3534 - learning_rate: 1.0000e-04
# Epoch 18/200
# 928/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9557 - loss: 0.3881
# Epoch 18: val_loss improved from 0.35342 to 0.33317, saving model to best_efficientnetb4_crop_smote_380.keras
#
# Epoch 18: finished saving model to best_efficientnetb4_crop_smote_380.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9552 - loss: 0.3859 - val_accuracy: 0.9736 - val_loss: 0.3332 - learning_rate: 1.0000e-04
# Epoch 19/200
# 929/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9558 - loss: 0.3804
# Epoch 19: val_loss improved from 0.33317 to 0.32581, saving model to best_efficientnetb4_crop_smote_380.keras
#
# Epoch 19: finished saving model to best_efficientnetb4_crop_smote_380.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9553 - loss: 0.3771 - val_accuracy: 0.9716 - val_loss: 0.3258 - learning_rate: 1.0000e-04
# Epoch 20/200
# 936/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9562 - loss: 0.3664
# Epoch 20: val_loss improved from 0.32581 to 0.32472, saving model to best_efficientnetb4_crop_smote_380.keras
#
# Epoch 20: finished saving model to best_efficientnetb4_crop_smote_380.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9575 - loss: 0.3620 - val_accuracy: 0.9695 - val_loss: 0.3247 - learning_rate: 1.0000e-04
# Epoch 21/200
# 922/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9574 - loss: 0.3532
# Epoch 21: val_loss improved from 0.32472 to 0.30434, saving model to best_efficientnetb4_crop_smote_380.keras
#
# Epoch 21: finished saving model to best_efficientnetb4_crop_smote_380.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9596 - loss: 0.3467 - val_accuracy: 0.9719 - val_loss: 0.3043 - learning_rate: 1.0000e-04
# Epoch 22/200
# 936/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9580 - loss: 0.3438
# Epoch 22: val_loss did not improve from 0.30434
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9584 - loss: 0.3414 - val_accuracy: 0.9682 - val_loss: 0.3098 - learning_rate: 1.0000e-04
# Epoch 23/200
# 935/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9576 - loss: 0.3397
# Epoch 23: val_loss improved from 0.30434 to 0.28457, saving model to best_efficientnetb4_crop_smote_380.keras
#
# Epoch 23: finished saving model to best_efficientnetb4_crop_smote_380.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9584 - loss: 0.3349 - val_accuracy: 0.9748 - val_loss: 0.2846 - learning_rate: 1.0000e-04
# Epoch 24/200
# 930/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9599 - loss: 0.3209
# Epoch 24: val_loss improved from 0.28457 to 0.27636, saving model to best_efficientnetb4_crop_smote_380.keras
#
# Epoch 24: finished saving model to best_efficientnetb4_crop_smote_380.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9624 - loss: 0.3154 - val_accuracy: 0.9760 - val_loss: 0.2764 - learning_rate: 1.0000e-04
# Epoch 25/200
# 909/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9651 - loss: 0.2987
# Epoch 25: val_loss improved from 0.27636 to 0.26608, saving model to best_efficientnetb4_crop_smote_380.keras
#
# Epoch 25: finished saving model to best_efficientnetb4_crop_smote_380.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9633 - loss: 0.3033 - val_accuracy: 0.9754 - val_loss: 0.2661 - learning_rate: 1.0000e-04
# Epoch 26/200
# 932/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9630 - loss: 0.2969
# Epoch 26: val_loss improved from 0.26608 to 0.25804, saving model to best_efficientnetb4_crop_smote_380.keras
#
# Epoch 26: finished saving model to best_efficientnetb4_crop_smote_380.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9641 - loss: 0.2935 - val_accuracy: 0.9752 - val_loss: 0.2580 - learning_rate: 1.0000e-04
# Epoch 27/200
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9690 - loss: 0.2787
# Epoch 27: val_loss improved from 0.25804 to 0.24684, saving model to best_efficientnetb4_crop_smote_380.keras
#
# Epoch 27: finished saving model to best_efficientnetb4_crop_smote_380.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9682 - loss: 0.2780 - val_accuracy: 0.9786 - val_loss: 0.2468 - learning_rate: 1.0000e-04
# Epoch 28/200
# 916/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9643 - loss: 0.2833
# Epoch 28: val_loss did not improve from 0.24684
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9644 - loss: 0.2827 - val_accuracy: 0.9760 - val_loss: 0.2491 - learning_rate: 1.0000e-04
# Epoch 29/200
# 937/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9636 - loss: 0.2820
# Epoch 29: val_loss improved from 0.24684 to 0.24290, saving model to best_efficientnetb4_crop_smote_380.keras
#
# Epoch 29: finished saving model to best_efficientnetb4_crop_smote_380.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9644 - loss: 0.2778 - val_accuracy: 0.9766 - val_loss: 0.2429 - learning_rate: 1.0000e-04
# Epoch 30/200
# 934/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9657 - loss: 0.2663
# Epoch 30: val_loss did not improve from 0.24290
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9677 - loss: 0.2608 - val_accuracy: 0.9730 - val_loss: 0.2444 - learning_rate: 1.0000e-04
# Epoch 31/200
# 914/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9699 - loss: 0.2524
# Epoch 31: val_loss improved from 0.24290 to 0.22151, saving model to best_efficientnetb4_crop_smote_380.keras
#
# Epoch 31: finished saving model to best_efficientnetb4_crop_smote_380.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9679 - loss: 0.2545 - val_accuracy: 0.9822 - val_loss: 0.2215 - learning_rate: 1.0000e-04
# Epoch 32/200
# 930/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9667 - loss: 0.2572
# Epoch 32: val_loss improved from 0.22151 to 0.21794, saving model to best_efficientnetb4_crop_smote_380.keras
#
# Epoch 32: finished saving model to best_efficientnetb4_crop_smote_380.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9658 - loss: 0.2591 - val_accuracy: 0.9823 - val_loss: 0.2179 - learning_rate: 1.0000e-04
# Epoch 33/200
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9697 - loss: 0.2480
# Epoch 33: val_loss did not improve from 0.21794
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9699 - loss: 0.2461 - val_accuracy: 0.9738 - val_loss: 0.2299 - learning_rate: 1.0000e-04
# Epoch 34/200
# 924/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9676 - loss: 0.2513
# Epoch 34: val_loss did not improve from 0.21794
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9709 - loss: 0.2422 - val_accuracy: 0.9772 - val_loss: 0.2211 - learning_rate: 1.0000e-04
# Epoch 35/200
# 930/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9696 - loss: 0.2346
# Epoch 35: val_loss did not improve from 0.21794
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9699 - loss: 0.2346 - val_accuracy: 0.9746 - val_loss: 0.2292 - learning_rate: 1.0000e-04
# Epoch 36/200
# 929/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9704 - loss: 0.2324
# Epoch 36: ReduceLROnPlateau reducing learning rate to 1.9999999494757503e-05.
#
# Epoch 36: val_loss did not improve from 0.21794
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9686 - loss: 0.2341 - val_accuracy: 0.9663 - val_loss: 0.2463 - learning_rate: 1.0000e-04
# Epoch 37/200
# 931/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9761 - loss: 0.2177
# Epoch 37: val_loss improved from 0.21794 to 0.18758, saving model to best_efficientnetb4_crop_smote_380.keras
#
# Epoch 37: finished saving model to best_efficientnetb4_crop_smote_380.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9808 - loss: 0.2041 - val_accuracy: 0.9863 - val_loss: 0.1876 - learning_rate: 2.0000e-05
# Epoch 38/200
# 937/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9852 - loss: 0.1880
# Epoch 38: val_loss improved from 0.18758 to 0.18370, saving model to best_efficientnetb4_crop_smote_380.keras
#
# Epoch 38: finished saving model to best_efficientnetb4_crop_smote_380.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9864 - loss: 0.1843 - val_accuracy: 0.9862 - val_loss: 0.1837 - learning_rate: 2.0000e-05
# Epoch 39/200
# 929/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9873 - loss: 0.1802
# Epoch 39: val_loss improved from 0.18370 to 0.18048, saving model to best_efficientnetb4_crop_smote_380.keras
#
# Epoch 39: finished saving model to best_efficientnetb4_crop_smote_380.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9873 - loss: 0.1798 - val_accuracy: 0.9871 - val_loss: 0.1805 - learning_rate: 2.0000e-05
# Epoch 40/200
# 922/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9883 - loss: 0.1749
# Epoch 40: val_loss improved from 0.18048 to 0.17816, saving model to best_efficientnetb4_crop_smote_380.keras
#
# Epoch 40: finished saving model to best_efficientnetb4_crop_smote_380.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9883 - loss: 0.1746 - val_accuracy: 0.9862 - val_loss: 0.1782 - learning_rate: 2.0000e-05
# Epoch 41/200
# 912/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9881 - loss: 0.1730
# Epoch 41: val_loss improved from 0.17816 to 0.17627, saving model to best_efficientnetb4_crop_smote_380.keras
#
# Epoch 41: finished saving model to best_efficientnetb4_crop_smote_380.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9889 - loss: 0.1713 - val_accuracy: 0.9874 - val_loss: 0.1763 - learning_rate: 2.0000e-05
# Epoch 42/200
# 922/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9906 - loss: 0.1651
# Epoch 42: val_loss improved from 0.17627 to 0.16913, saving model to best_efficientnetb4_crop_smote_380.keras
#
# Epoch 42: finished saving model to best_efficientnetb4_crop_smote_380.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9907 - loss: 0.1647 - val_accuracy: 0.9896 - val_loss: 0.1691 - learning_rate: 2.0000e-05
# Epoch 43/200
# 926/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9906 - loss: 0.1641
# Epoch 43: val_loss did not improve from 0.16913
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9899 - loss: 0.1642 - val_accuracy: 0.9864 - val_loss: 0.1725 - learning_rate: 2.0000e-05
# Epoch 44/200
# 917/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9911 - loss: 0.1595
# Epoch 44: val_loss improved from 0.16913 to 0.16681, saving model to best_efficientnetb4_crop_smote_380.keras
#
# Epoch 44: finished saving model to best_efficientnetb4_crop_smote_380.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9913 - loss: 0.1584 - val_accuracy: 0.9884 - val_loss: 0.1668 - learning_rate: 2.0000e-05
# Epoch 45/200
# 930/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9906 - loss: 0.1571
# Epoch 45: val_loss improved from 0.16681 to 0.16407, saving model to best_efficientnetb4_crop_smote_380.keras
#
# Epoch 45: finished saving model to best_efficientnetb4_crop_smote_380.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9910 - loss: 0.1565 - val_accuracy: 0.9875 - val_loss: 0.1641 - learning_rate: 2.0000e-05
# Epoch 46/200
# 910/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9915 - loss: 0.1545
# Epoch 46: val_loss improved from 0.16407 to 0.16206, saving model to best_efficientnetb4_crop_smote_380.keras
#
# Epoch 46: finished saving model to best_efficientnetb4_crop_smote_380.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9918 - loss: 0.1535 - val_accuracy: 0.9877 - val_loss: 0.1621 - learning_rate: 2.0000e-05
# Epoch 47/200
# 926/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9921 - loss: 0.1515
# Epoch 47: val_loss improved from 0.16206 to 0.15918, saving model to best_efficientnetb4_crop_smote_380.keras
#
# Epoch 47: finished saving model to best_efficientnetb4_crop_smote_380.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9917 - loss: 0.1513 - val_accuracy: 0.9883 - val_loss: 0.1592 - learning_rate: 2.0000e-05
# Epoch 48/200
# 920/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9916 - loss: 0.1524
# Epoch 48: val_loss improved from 0.15918 to 0.15899, saving model to best_efficientnetb4_crop_smote_380.keras
#
# Epoch 48: finished saving model to best_efficientnetb4_crop_smote_380.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9923 - loss: 0.1488 - val_accuracy: 0.9889 - val_loss: 0.1590 - learning_rate: 2.0000e-05
# Epoch 49/200
# 915/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9927 - loss: 0.1472
# Epoch 49: val_loss did not improve from 0.15899
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9923 - loss: 0.1468 - val_accuracy: 0.9863 - val_loss: 0.1627 - learning_rate: 2.0000e-05
# Epoch 50/200
# 933/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9921 - loss: 0.1468
# Epoch 50: val_loss improved from 0.15899 to 0.15358, saving model to best_efficientnetb4_crop_smote_380.keras
#
# Epoch 50: finished saving model to best_efficientnetb4_crop_smote_380.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9926 - loss: 0.1448 - val_accuracy: 0.9900 - val_loss: 0.1536 - learning_rate: 2.0000e-05
# Epoch 51/200
# 918/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9923 - loss: 0.1444
# Epoch 51: val_loss did not improve from 0.15358
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9932 - loss: 0.1424 - val_accuracy: 0.9877 - val_loss: 0.1557 - learning_rate: 2.0000e-05
# Epoch 52/200
# 910/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9922 - loss: 0.1406
# Epoch 52: val_loss improved from 0.15358 to 0.15086, saving model to best_efficientnetb4_crop_smote_380.keras
#
# Epoch 52: finished saving model to best_efficientnetb4_crop_smote_380.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9920 - loss: 0.1412 - val_accuracy: 0.9897 - val_loss: 0.1509 - learning_rate: 2.0000e-05
# Epoch 53/200
# 926/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9939 - loss: 0.1381
# Epoch 53: val_loss did not improve from 0.15086
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9938 - loss: 0.1390 - val_accuracy: 0.9883 - val_loss: 0.1526 - learning_rate: 2.0000e-05
# Epoch 54/200
# 926/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9924 - loss: 0.1385
# Epoch 54: val_loss did not improve from 0.15086
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9926 - loss: 0.1378 - val_accuracy: 0.9883 - val_loss: 0.1510 - learning_rate: 2.0000e-05
# Epoch 55/200
# 916/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9934 - loss: 0.1361
# Epoch 55: val_loss improved from 0.15086 to 0.14882, saving model to best_efficientnetb4_crop_smote_380.keras
#
# Epoch 55: finished saving model to best_efficientnetb4_crop_smote_380.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9932 - loss: 0.1361 - val_accuracy: 0.9892 - val_loss: 0.1488 - learning_rate: 2.0000e-05
# Epoch 56/200
# 931/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9939 - loss: 0.1329
# Epoch 56: val_loss improved from 0.14882 to 0.14542, saving model to best_efficientnetb4_crop_smote_380.keras
#
# Epoch 56: finished saving model to best_efficientnetb4_crop_smote_380.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9936 - loss: 0.1339 - val_accuracy: 0.9900 - val_loss: 0.1454 - learning_rate: 2.0000e-05
# Epoch 57/200
# 911/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9945 - loss: 0.1323
# Epoch 57: val_loss improved from 0.14542 to 0.14339, saving model to best_efficientnetb4_crop_smote_380.keras
#
# Epoch 57: finished saving model to best_efficientnetb4_crop_smote_380.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9944 - loss: 0.1308 - val_accuracy: 0.9903 - val_loss: 0.1434 - learning_rate: 2.0000e-05
# Epoch 58/200
# 922/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9933 - loss: 0.1317
# Epoch 58: val_loss improved from 0.14339 to 0.13983, saving model to best_efficientnetb4_crop_smote_380.keras
#
# Epoch 58: finished saving model to best_efficientnetb4_crop_smote_380.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9935 - loss: 0.1314 - val_accuracy: 0.9912 - val_loss: 0.1398 - learning_rate: 2.0000e-05
# Epoch 59/200
# 923/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9947 - loss: 0.1284
# Epoch 59: val_loss improved from 0.13983 to 0.13946, saving model to best_efficientnetb4_crop_smote_380.keras
#
# Epoch 59: finished saving model to best_efficientnetb4_crop_smote_380.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9941 - loss: 0.1289 - val_accuracy: 0.9908 - val_loss: 0.1395 - learning_rate: 2.0000e-05
# Epoch 60/200
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9942 - loss: 0.1283
# Epoch 60: val_loss did not improve from 0.13946
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9936 - loss: 0.1293 - val_accuracy: 0.9874 - val_loss: 0.1476 - learning_rate: 2.0000e-05
# Epoch 61/200
# 926/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9923 - loss: 0.1307
# Epoch 61: val_loss improved from 0.13946 to 0.13744, saving model to best_efficientnetb4_crop_smote_380.keras
#
# Epoch 61: finished saving model to best_efficientnetb4_crop_smote_380.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9935 - loss: 0.1277 - val_accuracy: 0.9912 - val_loss: 0.1374 - learning_rate: 2.0000e-05
# Epoch 62/200
# 938/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9942 - loss: 0.1252
# Epoch 62: val_loss did not improve from 0.13744
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9946 - loss: 0.1245 - val_accuracy: 0.9888 - val_loss: 0.1409 - learning_rate: 2.0000e-05
# Epoch 63/200
# 927/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9944 - loss: 0.1244
# Epoch 63: val_loss improved from 0.13744 to 0.13707, saving model to best_efficientnetb4_crop_smote_380.keras
#
# Epoch 63: finished saving model to best_efficientnetb4_crop_smote_380.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9942 - loss: 0.1239 - val_accuracy: 0.9904 - val_loss: 0.1371 - learning_rate: 2.0000e-05
# Epoch 64/200
# 926/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9934 - loss: 0.1244
# Epoch 64: val_loss improved from 0.13707 to 0.13087, saving model to best_efficientnetb4_crop_smote_380.keras
#
# Epoch 64: finished saving model to best_efficientnetb4_crop_smote_380.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9944 - loss: 0.1222 - val_accuracy: 0.9916 - val_loss: 0.1309 - learning_rate: 2.0000e-05
# Epoch 65/200
# 908/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9946 - loss: 0.1202
# Epoch 65: val_loss did not improve from 0.13087
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9947 - loss: 0.1207 - val_accuracy: 0.9896 - val_loss: 0.1363 - learning_rate: 2.0000e-05
# Epoch 66/200
# 930/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9942 - loss: 0.1218
# Epoch 66: val_loss did not improve from 0.13087
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9945 - loss: 0.1203 - val_accuracy: 0.9907 - val_loss: 0.1318 - learning_rate: 2.0000e-05
# Epoch 67/200
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9955 - loss: 0.1173
# Epoch 67: val_loss did not improve from 0.13087
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9949 - loss: 0.1175 - val_accuracy: 0.9891 - val_loss: 0.1396 - learning_rate: 2.0000e-05
# Epoch 68/200
# 929/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9947 - loss: 0.1182
# Epoch 68: val_loss improved from 0.13087 to 0.13057, saving model to best_efficientnetb4_crop_smote_380.keras
#
# Epoch 68: finished saving model to best_efficientnetb4_crop_smote_380.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9948 - loss: 0.1176 - val_accuracy: 0.9905 - val_loss: 0.1306 - learning_rate: 2.0000e-05
# Epoch 69/200
# 927/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9948 - loss: 0.1158
# Epoch 69: val_loss did not improve from 0.13057
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9944 - loss: 0.1162 - val_accuracy: 0.9893 - val_loss: 0.1339 - learning_rate: 2.0000e-05
# Epoch 70/200
# 915/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9949 - loss: 0.1168
# Epoch 70: val_loss did not improve from 0.13057
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9944 - loss: 0.1168 - val_accuracy: 0.9893 - val_loss: 0.1317 - learning_rate: 2.0000e-05
# Epoch 71/200
# 926/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9936 - loss: 0.1165
# Epoch 71: val_loss improved from 0.13057 to 0.12743, saving model to best_efficientnetb4_crop_smote_380.keras
#
# Epoch 71: finished saving model to best_efficientnetb4_crop_smote_380.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9944 - loss: 0.1154 - val_accuracy: 0.9912 - val_loss: 0.1274 - learning_rate: 2.0000e-05
# Epoch 72/200
# 912/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9944 - loss: 0.1146
# Epoch 72: val_loss improved from 0.12743 to 0.12578, saving model to best_efficientnetb4_crop_smote_380.keras
#
# Epoch 72: finished saving model to best_efficientnetb4_crop_smote_380.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9950 - loss: 0.1130 - val_accuracy: 0.9901 - val_loss: 0.1258 - learning_rate: 2.0000e-05
# Epoch 73/200
# 926/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9948 - loss: 0.1123
# Epoch 73: val_loss improved from 0.12578 to 0.12394, saving model to best_efficientnetb4_crop_smote_380.keras
#
# Epoch 73: finished saving model to best_efficientnetb4_crop_smote_380.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9952 - loss: 0.1121 - val_accuracy: 0.9901 - val_loss: 0.1239 - learning_rate: 2.0000e-05
# Epoch 74/200
# 910/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9955 - loss: 0.1115
# Epoch 74: val_loss did not improve from 0.12394
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9953 - loss: 0.1114 - val_accuracy: 0.9908 - val_loss: 0.1255 - learning_rate: 2.0000e-05
# Epoch 75/200
# 922/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9956 - loss: 0.1093
# Epoch 75: val_loss improved from 0.12394 to 0.12190, saving model to best_efficientnetb4_crop_smote_380.keras
#
# Epoch 75: finished saving model to best_efficientnetb4_crop_smote_380.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9953 - loss: 0.1097 - val_accuracy: 0.9912 - val_loss: 0.1219 - learning_rate: 2.0000e-05
# Epoch 76/200
# 935/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9952 - loss: 0.1089
# Epoch 76: val_loss improved from 0.12190 to 0.12042, saving model to best_efficientnetb4_crop_smote_380.keras
#
# Epoch 76: finished saving model to best_efficientnetb4_crop_smote_380.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9944 - loss: 0.1099 - val_accuracy: 0.9912 - val_loss: 0.1204 - learning_rate: 2.0000e-05
# Epoch 77/200
# 928/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9947 - loss: 0.1088
# Epoch 77: val_loss did not improve from 0.12042
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9947 - loss: 0.1079 - val_accuracy: 0.9905 - val_loss: 0.1260 - learning_rate: 2.0000e-05
# Epoch 78/200
# 934/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9962 - loss: 0.1055
# Epoch 78: val_loss did not improve from 0.12042
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9960 - loss: 0.1056 - val_accuracy: 0.9909 - val_loss: 0.1210 - learning_rate: 2.0000e-05
# Epoch 79/200
# 909/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9954 - loss: 0.1062
# Epoch 79: val_loss improved from 0.12042 to 0.11795, saving model to best_efficientnetb4_crop_smote_380.keras
#
# Epoch 79: finished saving model to best_efficientnetb4_crop_smote_380.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9954 - loss: 0.1061 - val_accuracy: 0.9923 - val_loss: 0.1180 - learning_rate: 2.0000e-05
# Epoch 80/200
# 925/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9943 - loss: 0.1075
# Epoch 80: val_loss did not improve from 0.11795
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9949 - loss: 0.1053 - val_accuracy: 0.9897 - val_loss: 0.1220 - learning_rate: 2.0000e-05
# Epoch 81/200
# 917/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9948 - loss: 0.1058
# Epoch 81: val_loss did not improve from 0.11795
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9949 - loss: 0.1053 - val_accuracy: 0.9905 - val_loss: 0.1188 - learning_rate: 2.0000e-05
# Epoch 82/200
# 934/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9953 - loss: 0.1048
# Epoch 82: val_loss did not improve from 0.11795
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9955 - loss: 0.1045 - val_accuracy: 0.9913 - val_loss: 0.1183 - learning_rate: 2.0000e-05
# Epoch 83/200
# 913/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9962 - loss: 0.1022
# Epoch 83: val_loss improved from 0.11795 to 0.11594, saving model to best_efficientnetb4_crop_smote_380.keras
#
# Epoch 83: finished saving model to best_efficientnetb4_crop_smote_380.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9963 - loss: 0.1013 - val_accuracy: 0.9915 - val_loss: 0.1159 - learning_rate: 2.0000e-05
# Epoch 84/200
# 919/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9945 - loss: 0.1052
# Epoch 84: val_loss did not improve from 0.11594
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9946 - loss: 0.1048 - val_accuracy: 0.9907 - val_loss: 0.1174 - learning_rate: 2.0000e-05
# Epoch 85/200
# 927/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9964 - loss: 0.0994
# Epoch 85: val_loss did not improve from 0.11594
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9958 - loss: 0.0998 - val_accuracy: 0.9908 - val_loss: 0.1163 - learning_rate: 2.0000e-05
# Epoch 86/200
# 926/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9955 - loss: 0.1010
# Epoch 86: val_loss did not improve from 0.11594
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9945 - loss: 0.1027 - val_accuracy: 0.9908 - val_loss: 0.1179 - learning_rate: 2.0000e-05
# Epoch 87/200
# 930/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9955 - loss: 0.0993
# Epoch 87: val_loss improved from 0.11594 to 0.11375, saving model to best_efficientnetb4_crop_smote_380.keras
#
# Epoch 87: finished saving model to best_efficientnetb4_crop_smote_380.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9959 - loss: 0.0989 - val_accuracy: 0.9913 - val_loss: 0.1138 - learning_rate: 2.0000e-05
# Epoch 88/200
# 911/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9970 - loss: 0.0973
# Epoch 88: val_loss did not improve from 0.11375
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9962 - loss: 0.0975 - val_accuracy: 0.9895 - val_loss: 0.1183 - learning_rate: 2.0000e-05
# Epoch 89/200
# 927/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9950 - loss: 0.0995
# Epoch 89: val_loss improved from 0.11375 to 0.11315, saving model to best_efficientnetb4_crop_smote_380.keras
#
# Epoch 89: finished saving model to best_efficientnetb4_crop_smote_380.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9952 - loss: 0.0985 - val_accuracy: 0.9908 - val_loss: 0.1131 - learning_rate: 2.0000e-05
# Epoch 90/200
# 916/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9956 - loss: 0.0966
# Epoch 90: val_loss did not improve from 0.11315
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9953 - loss: 0.0970 - val_accuracy: 0.9908 - val_loss: 0.1141 - learning_rate: 2.0000e-05
# Epoch 91/200
# 909/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9944 - loss: 0.0984
# Epoch 91: val_loss improved from 0.11315 to 0.11279, saving model to best_efficientnetb4_crop_smote_380.keras
#
# Epoch 91: finished saving model to best_efficientnetb4_crop_smote_380.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9949 - loss: 0.0972 - val_accuracy: 0.9904 - val_loss: 0.1128 - learning_rate: 2.0000e-05
# Epoch 92/200
# 938/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9958 - loss: 0.0958
# Epoch 92: val_loss improved from 0.11279 to 0.11104, saving model to best_efficientnetb4_crop_smote_380.keras
#
# Epoch 92: finished saving model to best_efficientnetb4_crop_smote_380.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9960 - loss: 0.0956 - val_accuracy: 0.9909 - val_loss: 0.1110 - learning_rate: 2.0000e-05
# Epoch 93/200
# 929/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9966 - loss: 0.0938
# Epoch 93: val_loss did not improve from 0.11104
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9964 - loss: 0.0940 - val_accuracy: 0.9905 - val_loss: 0.1113 - learning_rate: 2.0000e-05
# Epoch 94/200
# 921/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9956 - loss: 0.0944
# Epoch 94: val_loss improved from 0.11104 to 0.10965, saving model to best_efficientnetb4_crop_smote_380.keras
#
# Epoch 94: finished saving model to best_efficientnetb4_crop_smote_380.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9955 - loss: 0.0942 - val_accuracy: 0.9909 - val_loss: 0.1096 - learning_rate: 2.0000e-05
# Epoch 95/200
# 920/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9958 - loss: 0.0938
# Epoch 95: val_loss did not improve from 0.10965
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9959 - loss: 0.0929 - val_accuracy: 0.9907 - val_loss: 0.1121 - learning_rate: 2.0000e-05
# Epoch 96/200
# 910/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9946 - loss: 0.0946
# Epoch 96: val_loss improved from 0.10965 to 0.10898, saving model to best_efficientnetb4_crop_smote_380.keras
#
# Epoch 96: finished saving model to best_efficientnetb4_crop_smote_380.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9952 - loss: 0.0935 - val_accuracy: 0.9915 - val_loss: 0.1090 - learning_rate: 2.0000e-05
# Epoch 97/200
# 932/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9956 - loss: 0.0928
# Epoch 97: val_loss did not improve from 0.10898
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9957 - loss: 0.0920 - val_accuracy: 0.9904 - val_loss: 0.1127 - learning_rate: 2.0000e-05
# Epoch 98/200
# 911/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9951 - loss: 0.0931
# Epoch 98: val_loss did not improve from 0.10898
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9952 - loss: 0.0928 - val_accuracy: 0.9900 - val_loss: 0.1115 - learning_rate: 2.0000e-05
# Epoch 99/200
# 933/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9954 - loss: 0.0922
# Epoch 99: val_loss improved from 0.10898 to 0.10450, saving model to best_efficientnetb4_crop_smote_380.keras
#
# Epoch 99: finished saving model to best_efficientnetb4_crop_smote_380.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9958 - loss: 0.0908 - val_accuracy: 0.9921 - val_loss: 0.1045 - learning_rate: 2.0000e-05
# Epoch 100/200
# 918/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9960 - loss: 0.0896
# Epoch 100: val_loss did not improve from 0.10450
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9961 - loss: 0.0894 - val_accuracy: 0.9911 - val_loss: 0.1054 - learning_rate: 2.0000e-05
# Epoch 101/200
# 927/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9964 - loss: 0.0891
# Epoch 101: val_loss improved from 0.10450 to 0.09980, saving model to best_efficientnetb4_crop_smote_380.keras
#
# Epoch 101: finished saving model to best_efficientnetb4_crop_smote_380.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9961 - loss: 0.0895 - val_accuracy: 0.9928 - val_loss: 0.0998 - learning_rate: 2.0000e-05
# Epoch 102/200
# 924/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9955 - loss: 0.0914
# Epoch 102: val_loss did not improve from 0.09980
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9956 - loss: 0.0900 - val_accuracy: 0.9905 - val_loss: 0.1067 - learning_rate: 2.0000e-05
# Epoch 103/200
# 933/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9968 - loss: 0.0862
# Epoch 103: val_loss improved from 0.09980 to 0.09972, saving model to best_efficientnetb4_crop_smote_380.keras
#
# Epoch 103: finished saving model to best_efficientnetb4_crop_smote_380.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9963 - loss: 0.0872 - val_accuracy: 0.9925 - val_loss: 0.0997 - learning_rate: 2.0000e-05
# Epoch 104/200
# 923/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9959 - loss: 0.0883
# Epoch 104: val_loss did not improve from 0.09972
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9959 - loss: 0.0877 - val_accuracy: 0.9904 - val_loss: 0.1038 - learning_rate: 2.0000e-05
# Epoch 105/200
# 914/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9960 - loss: 0.0868
# Epoch 105: ReduceLROnPlateau reducing learning rate to 3.999999898951501e-06.
#
# Epoch 105: val_loss did not improve from 0.09972
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9962 - loss: 0.0862 - val_accuracy: 0.9905 - val_loss: 0.1028 - learning_rate: 2.0000e-05
# Epoch 106/200
# 932/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9967 - loss: 0.0838
# Epoch 106: val_loss improved from 0.09972 to 0.09970, saving model to best_efficientnetb4_crop_smote_380.keras
#
# Epoch 106: finished saving model to best_efficientnetb4_crop_smote_380.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9970 - loss: 0.0830 - val_accuracy: 0.9917 - val_loss: 0.0997 - learning_rate: 4.0000e-06
# Epoch 107/200
# 923/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9972 - loss: 0.0820
# Epoch 107: val_loss did not improve from 0.09970
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9976 - loss: 0.0810 - val_accuracy: 0.9912 - val_loss: 0.1013 - learning_rate: 4.0000e-06
# Epoch 108/200
# 926/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9979 - loss: 0.0811
# Epoch 108: val_loss did not improve from 0.09970
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9978 - loss: 0.0811 - val_accuracy: 0.9911 - val_loss: 0.1010 - learning_rate: 4.0000e-06
# Epoch 109/200
# 924/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9982 - loss: 0.0798
# Epoch 109: val_loss improved from 0.09970 to 0.09898, saving model to best_efficientnetb4_crop_smote_380.keras
#
# Epoch 109: finished saving model to best_efficientnetb4_crop_smote_380.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9980 - loss: 0.0799 - val_accuracy: 0.9923 - val_loss: 0.0990 - learning_rate: 4.0000e-06
# Epoch 110/200
# 920/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9976 - loss: 0.0806
# Epoch 110: val_loss did not improve from 0.09898
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9980 - loss: 0.0798 - val_accuracy: 0.9920 - val_loss: 0.0991 - learning_rate: 4.0000e-06
# Epoch 111/200
# 909/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9980 - loss: 0.0787
# Epoch 111: val_loss improved from 0.09898 to 0.09801, saving model to best_efficientnetb4_crop_smote_380.keras
#
# Epoch 111: finished saving model to best_efficientnetb4_crop_smote_380.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9978 - loss: 0.0796 - val_accuracy: 0.9924 - val_loss: 0.0980 - learning_rate: 4.0000e-06
# Epoch 112/200
# 929/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9983 - loss: 0.0784
# Epoch 112: val_loss improved from 0.09801 to 0.09730, saving model to best_efficientnetb4_crop_smote_380.keras
#
# Epoch 112: finished saving model to best_efficientnetb4_crop_smote_380.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9984 - loss: 0.0783 - val_accuracy: 0.9928 - val_loss: 0.0973 - learning_rate: 4.0000e-06
# Epoch 113/200
# 910/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9981 - loss: 0.0795
# Epoch 113: val_loss improved from 0.09730 to 0.09711, saving model to best_efficientnetb4_crop_smote_380.keras
#
# Epoch 113: finished saving model to best_efficientnetb4_crop_smote_380.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9983 - loss: 0.0785 - val_accuracy: 0.9928 - val_loss: 0.0971 - learning_rate: 4.0000e-06
# Epoch 114/200
# 921/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9984 - loss: 0.0785
# Epoch 114: val_loss did not improve from 0.09711
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9982 - loss: 0.0783 - val_accuracy: 0.9923 - val_loss: 0.0988 - learning_rate: 4.0000e-06
# Epoch 115/200
# 925/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9982 - loss: 0.0789
# Epoch 115: val_loss did not improve from 0.09711
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9979 - loss: 0.0790 - val_accuracy: 0.9920 - val_loss: 0.0973 - learning_rate: 4.0000e-06
# Epoch 116/200
# 918/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9985 - loss: 0.0775
# Epoch 116: val_loss improved from 0.09711 to 0.09654, saving model to best_efficientnetb4_crop_smote_380.keras
#
# Epoch 116: finished saving model to best_efficientnetb4_crop_smote_380.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9986 - loss: 0.0777 - val_accuracy: 0.9923 - val_loss: 0.0965 - learning_rate: 4.0000e-06
# Epoch 117/200
# 918/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9986 - loss: 0.0770
# Epoch 117: val_loss improved from 0.09654 to 0.09652, saving model to best_efficientnetb4_crop_smote_380.keras
#
# Epoch 117: finished saving model to best_efficientnetb4_crop_smote_380.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9982 - loss: 0.0777 - val_accuracy: 0.9924 - val_loss: 0.0965 - learning_rate: 4.0000e-06
# Epoch 118/200
# 916/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9974 - loss: 0.0790
# Epoch 118: val_loss improved from 0.09652 to 0.09610, saving model to best_efficientnetb4_crop_smote_380.keras
#
# Epoch 118: finished saving model to best_efficientnetb4_crop_smote_380.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9977 - loss: 0.0783 - val_accuracy: 0.9925 - val_loss: 0.0961 - learning_rate: 4.0000e-06
# Epoch 119/200
# 930/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9983 - loss: 0.0776
# Epoch 119: val_loss did not improve from 0.09610
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9985 - loss: 0.0772 - val_accuracy: 0.9921 - val_loss: 0.0977 - learning_rate: 4.0000e-06
# Epoch 120/200
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9985 - loss: 0.0766
# Epoch 120: val_loss did not improve from 0.09610
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9983 - loss: 0.0769 - val_accuracy: 0.9919 - val_loss: 0.0975 - learning_rate: 4.0000e-06
# Epoch 121/200
# 924/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9986 - loss: 0.0759
# Epoch 121: val_loss did not improve from 0.09610
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9985 - loss: 0.0762 - val_accuracy: 0.9924 - val_loss: 0.0970 - learning_rate: 4.0000e-06
# Epoch 122/200
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9981 - loss: 0.0763
# Epoch 122: ReduceLROnPlateau reducing learning rate to 7.999999979801942e-07.
#
# Epoch 122: val_loss did not improve from 0.09610
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9984 - loss: 0.0761 - val_accuracy: 0.9924 - val_loss: 0.0965 - learning_rate: 4.0000e-06
# Epoch 123/200
# 924/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9986 - loss: 0.0761
# Epoch 123: val_loss improved from 0.09610 to 0.09577, saving model to best_efficientnetb4_crop_smote_380.keras
#
# Epoch 123: finished saving model to best_efficientnetb4_crop_smote_380.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9984 - loss: 0.0761 - val_accuracy: 0.9927 - val_loss: 0.0958 - learning_rate: 8.0000e-07
# Epoch 124/200
# 924/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9982 - loss: 0.0762
# Epoch 124: val_loss did not improve from 0.09577
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9984 - loss: 0.0759 - val_accuracy: 0.9925 - val_loss: 0.0962 - learning_rate: 8.0000e-07
# Epoch 125/200
# 912/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9986 - loss: 0.0753
# Epoch 125: val_loss improved from 0.09577 to 0.09555, saving model to best_efficientnetb4_crop_smote_380.keras
#
# Epoch 125: finished saving model to best_efficientnetb4_crop_smote_380.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9984 - loss: 0.0756 - val_accuracy: 0.9927 - val_loss: 0.0956 - learning_rate: 8.0000e-07
# Epoch 126/200
# 919/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9986 - loss: 0.0757
# Epoch 126: val_loss improved from 0.09555 to 0.09537, saving model to best_efficientnetb4_crop_smote_380.keras
#
# Epoch 126: finished saving model to best_efficientnetb4_crop_smote_380.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9988 - loss: 0.0754 - val_accuracy: 0.9927 - val_loss: 0.0954 - learning_rate: 8.0000e-07
# Epoch 127/200
# 935/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9988 - loss: 0.0752
# Epoch 127: val_loss improved from 0.09537 to 0.09523, saving model to best_efficientnetb4_crop_smote_380.keras
#
# Epoch 127: finished saving model to best_efficientnetb4_crop_smote_380.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9989 - loss: 0.0750 - val_accuracy: 0.9928 - val_loss: 0.0952 - learning_rate: 8.0000e-07
# Epoch 128/200
# 934/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9978 - loss: 0.0764
# Epoch 128: val_loss improved from 0.09523 to 0.09479, saving model to best_efficientnetb4_crop_smote_380.keras
#
# Epoch 128: finished saving model to best_efficientnetb4_crop_smote_380.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9984 - loss: 0.0754 - val_accuracy: 0.9931 - val_loss: 0.0948 - learning_rate: 8.0000e-07
# Epoch 129/200
# 915/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9988 - loss: 0.0750
# Epoch 129: val_loss did not improve from 0.09479
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9986 - loss: 0.0754 - val_accuracy: 0.9929 - val_loss: 0.0949 - learning_rate: 8.0000e-07
# Epoch 130/200
# 934/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9990 - loss: 0.0742
# Epoch 130: val_loss improved from 0.09479 to 0.09475, saving model to best_efficientnetb4_crop_smote_380.keras
#
# Epoch 130: finished saving model to best_efficientnetb4_crop_smote_380.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9987 - loss: 0.0748 - val_accuracy: 0.9931 - val_loss: 0.0947 - learning_rate: 8.0000e-07
# Epoch 131/200
# 930/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9988 - loss: 0.0748
# Epoch 131: val_loss did not improve from 0.09475
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9989 - loss: 0.0749 - val_accuracy: 0.9931 - val_loss: 0.0949 - learning_rate: 8.0000e-07
# Epoch 132/200
# 915/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9985 - loss: 0.0759
# Epoch 132: ReduceLROnPlateau reducing learning rate to 1.600000018697756e-07.
#
# Epoch 132: val_loss improved from 0.09475 to 0.09469, saving model to best_efficientnetb4_crop_smote_380.keras
#
# Epoch 132: finished saving model to best_efficientnetb4_crop_smote_380.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9987 - loss: 0.0753 - val_accuracy: 0.9931 - val_loss: 0.0947 - learning_rate: 8.0000e-07
# Epoch 133/200
# 916/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9980 - loss: 0.0755
# Epoch 133: val_loss did not improve from 0.09469
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9984 - loss: 0.0752 - val_accuracy: 0.9929 - val_loss: 0.0948 - learning_rate: 1.6000e-07
# Epoch 134/200
# 927/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9987 - loss: 0.0749
# Epoch 134: val_loss did not improve from 0.09469
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9986 - loss: 0.0749 - val_accuracy: 0.9931 - val_loss: 0.0947 - learning_rate: 1.6000e-07
# Epoch 135/200
# 933/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9981 - loss: 0.0760
# Epoch 135: val_loss did not improve from 0.09469
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9982 - loss: 0.0757 - val_accuracy: 0.9931 - val_loss: 0.0947 - learning_rate: 1.6000e-07
# Epoch 136/200
# 919/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9988 - loss: 0.0754
# Epoch 136: val_loss improved from 0.09469 to 0.09458, saving model to best_efficientnetb4_crop_smote_380.keras
#
# Epoch 136: finished saving model to best_efficientnetb4_crop_smote_380.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9989 - loss: 0.0748 - val_accuracy: 0.9931 - val_loss: 0.0946 - learning_rate: 1.6000e-07
# Epoch 137/200
# 913/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9988 - loss: 0.0744
# Epoch 137: val_loss did not improve from 0.09458
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9986 - loss: 0.0749 - val_accuracy: 0.9931 - val_loss: 0.0947 - learning_rate: 1.6000e-07
# Epoch 138/200
# 937/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9991 - loss: 0.0743
# Epoch 138: val_loss improved from 0.09458 to 0.09453, saving model to best_efficientnetb4_crop_smote_380.keras
#
# Epoch 138: finished saving model to best_efficientnetb4_crop_smote_380.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9990 - loss: 0.0745 - val_accuracy: 0.9931 - val_loss: 0.0945 - learning_rate: 1.6000e-07
# Epoch 139/200
# 923/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9984 - loss: 0.0754
# Epoch 139: val_loss improved from 0.09453 to 0.09449, saving model to best_efficientnetb4_crop_smote_380.keras
#
# Epoch 139: finished saving model to best_efficientnetb4_crop_smote_380.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9987 - loss: 0.0748 - val_accuracy: 0.9931 - val_loss: 0.0945 - learning_rate: 1.6000e-07
# Epoch 140/200
# 917/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9988 - loss: 0.0748
# Epoch 140: val_loss improved from 0.09449 to 0.09442, saving model to best_efficientnetb4_crop_smote_380.keras
#
# Epoch 140: finished saving model to best_efficientnetb4_crop_smote_380.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9988 - loss: 0.0751 - val_accuracy: 0.9931 - val_loss: 0.0944 - learning_rate: 1.6000e-07
# Epoch 141/200
# 929/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9983 - loss: 0.0756
# Epoch 141: val_loss did not improve from 0.09442
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9985 - loss: 0.0749 - val_accuracy: 0.9931 - val_loss: 0.0944 - learning_rate: 1.6000e-07
# Epoch 142/200
# 918/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9985 - loss: 0.0752
# Epoch 142: val_loss did not improve from 0.09442
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9984 - loss: 0.0753 - val_accuracy: 0.9931 - val_loss: 0.0945 - learning_rate: 1.6000e-07
# Epoch 143/200
# 911/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9987 - loss: 0.0754
# Epoch 143: val_loss improved from 0.09442 to 0.09441, saving model to best_efficientnetb4_crop_smote_380.keras
#
# Epoch 143: finished saving model to best_efficientnetb4_crop_smote_380.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9987 - loss: 0.0752 - val_accuracy: 0.9931 - val_loss: 0.0944 - learning_rate: 1.6000e-07
# Epoch 144/200
# 926/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9986 - loss: 0.0747
# Epoch 144: ReduceLROnPlateau reducing learning rate to 1e-07.
#
# Epoch 144: val_loss improved from 0.09441 to 0.09437, saving model to best_efficientnetb4_crop_smote_380.keras
#
# Epoch 144: finished saving model to best_efficientnetb4_crop_smote_380.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9987 - loss: 0.0745 - val_accuracy: 0.9931 - val_loss: 0.0944 - learning_rate: 1.6000e-07
# Epoch 145/200
# 917/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9988 - loss: 0.0748
# Epoch 145: val_loss improved from 0.09437 to 0.09434, saving model to best_efficientnetb4_crop_smote_380.keras
#
# Epoch 145: finished saving model to best_efficientnetb4_crop_smote_380.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9985 - loss: 0.0749 - val_accuracy: 0.9931 - val_loss: 0.0943 - learning_rate: 1.0000e-07
# Epoch 146/200
# 909/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9990 - loss: 0.0737
# Epoch 146: val_loss did not improve from 0.09434
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9990 - loss: 0.0739 - val_accuracy: 0.9931 - val_loss: 0.0944 - learning_rate: 1.0000e-07
# Epoch 147/200
# 922/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9989 - loss: 0.0743
# Epoch 147: val_loss did not improve from 0.09434
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9985 - loss: 0.0749 - val_accuracy: 0.9931 - val_loss: 0.0944 - learning_rate: 1.0000e-07
# Epoch 148/200
# 911/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9987 - loss: 0.0753
# Epoch 148: val_loss did not improve from 0.09434
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9986 - loss: 0.0749 - val_accuracy: 0.9931 - val_loss: 0.0945 - learning_rate: 1.0000e-07
# Epoch 149/200
# 912/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9983 - loss: 0.0750
# Epoch 149: val_loss did not improve from 0.09434
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9987 - loss: 0.0743 - val_accuracy: 0.9931 - val_loss: 0.0944 - learning_rate: 1.0000e-07
# Epoch 150/200
# 921/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9988 - loss: 0.0746
# Epoch 150: val_loss did not improve from 0.09434
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9987 - loss: 0.0746 - val_accuracy: 0.9931 - val_loss: 0.0944 - learning_rate: 1.0000e-07
# Epoch 151/200
# 910/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9985 - loss: 0.0749
# Epoch 151: val_loss improved from 0.09434 to 0.09432, saving model to best_efficientnetb4_crop_smote_380.keras
#
# Epoch 151: finished saving model to best_efficientnetb4_crop_smote_380.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9988 - loss: 0.0747 - val_accuracy: 0.9931 - val_loss: 0.0943 - learning_rate: 1.0000e-07
# Epoch 152/200
# 930/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9985 - loss: 0.0754
# Epoch 152: val_loss improved from 0.09432 to 0.09426, saving model to best_efficientnetb4_crop_smote_380.keras
#
# Epoch 152: finished saving model to best_efficientnetb4_crop_smote_380.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9986 - loss: 0.0752 - val_accuracy: 0.9931 - val_loss: 0.0943 - learning_rate: 1.0000e-07
# Epoch 153/200
# 917/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9989 - loss: 0.0747
# Epoch 153: val_loss did not improve from 0.09426
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9988 - loss: 0.0746 - val_accuracy: 0.9931 - val_loss: 0.0943 - learning_rate: 1.0000e-07
# Epoch 154/200
# 938/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9986 - loss: 0.0742
# Epoch 154: val_loss did not improve from 0.09426
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9985 - loss: 0.0744 - val_accuracy: 0.9931 - val_loss: 0.0943 - learning_rate: 1.0000e-07
# Epoch 155/200
# 938/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9992 - loss: 0.0736
# Epoch 155: val_loss did not improve from 0.09426
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9990 - loss: 0.0740 - val_accuracy: 0.9931 - val_loss: 0.0943 - learning_rate: 1.0000e-07
# Epoch 156/200
# 914/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9988 - loss: 0.0747
# Epoch 156: val_loss improved from 0.09426 to 0.09425, saving model to best_efficientnetb4_crop_smote_380.keras
#
# Epoch 156: finished saving model to best_efficientnetb4_crop_smote_380.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9985 - loss: 0.0749 - val_accuracy: 0.9931 - val_loss: 0.0943 - learning_rate: 1.0000e-07
# Epoch 157/200
# 927/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9986 - loss: 0.0747
# Epoch 157: val_loss improved from 0.09425 to 0.09417, saving model to best_efficientnetb4_crop_smote_380.keras
#
# Epoch 157: finished saving model to best_efficientnetb4_crop_smote_380.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9987 - loss: 0.0745 - val_accuracy: 0.9931 - val_loss: 0.0942 - learning_rate: 1.0000e-07
# Epoch 158/200
# 915/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9981 - loss: 0.0754
# Epoch 158: val_loss did not improve from 0.09417
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9986 - loss: 0.0747 - val_accuracy: 0.9931 - val_loss: 0.0942 - learning_rate: 1.0000e-07
# Epoch 159/200
# 929/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9987 - loss: 0.0750
# Epoch 159: val_loss improved from 0.09417 to 0.09413, saving model to best_efficientnetb4_crop_smote_380.keras
#
# Epoch 159: finished saving model to best_efficientnetb4_crop_smote_380.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9986 - loss: 0.0747 - val_accuracy: 0.9931 - val_loss: 0.0941 - learning_rate: 1.0000e-07
# Epoch 160/200
# 936/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9987 - loss: 0.0745
# Epoch 160: val_loss did not improve from 0.09413
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9988 - loss: 0.0742 - val_accuracy: 0.9931 - val_loss: 0.0942 - learning_rate: 1.0000e-07
# Epoch 161/200
# 918/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9985 - loss: 0.0749
# Epoch 161: val_loss improved from 0.09413 to 0.09407, saving model to best_efficientnetb4_crop_smote_380.keras
#
# Epoch 161: finished saving model to best_efficientnetb4_crop_smote_380.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9987 - loss: 0.0746 - val_accuracy: 0.9931 - val_loss: 0.0941 - learning_rate: 1.0000e-07
# Epoch 162/200
# 932/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9984 - loss: 0.0754
# Epoch 162: val_loss did not improve from 0.09407
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9985 - loss: 0.0751 - val_accuracy: 0.9931 - val_loss: 0.0941 - learning_rate: 1.0000e-07
# Epoch 163/200
# 920/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9989 - loss: 0.0742
# Epoch 163: val_loss did not improve from 0.09407
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9988 - loss: 0.0745 - val_accuracy: 0.9931 - val_loss: 0.0941 - learning_rate: 1.0000e-07
# Epoch 164/200
# 931/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9984 - loss: 0.0755
# Epoch 164: val_loss improved from 0.09407 to 0.09407, saving model to best_efficientnetb4_crop_smote_380.keras
#
# Epoch 164: finished saving model to best_efficientnetb4_crop_smote_380.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9985 - loss: 0.0749 - val_accuracy: 0.9931 - val_loss: 0.0941 - learning_rate: 1.0000e-07
# Epoch 165/200
# 937/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9980 - loss: 0.0752
# Epoch 165: val_loss improved from 0.09407 to 0.09400, saving model to best_efficientnetb4_crop_smote_380.keras
#
# Epoch 165: finished saving model to best_efficientnetb4_crop_smote_380.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9985 - loss: 0.0747 - val_accuracy: 0.9931 - val_loss: 0.0940 - learning_rate: 1.0000e-07
# Epoch 166/200
# 936/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9985 - loss: 0.0747
# Epoch 166: val_loss improved from 0.09400 to 0.09397, saving model to best_efficientnetb4_crop_smote_380.keras
#
# Epoch 166: finished saving model to best_efficientnetb4_crop_smote_380.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9985 - loss: 0.0747 - val_accuracy: 0.9931 - val_loss: 0.0940 - learning_rate: 1.0000e-07
# Epoch 167/200
# 913/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9992 - loss: 0.0737
# Epoch 167: val_loss did not improve from 0.09397
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9990 - loss: 0.0739 - val_accuracy: 0.9931 - val_loss: 0.0940 - learning_rate: 1.0000e-07
# Epoch 168/200
# 932/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9989 - loss: 0.0748
# Epoch 168: val_loss did not improve from 0.09397
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9988 - loss: 0.0745 - val_accuracy: 0.9931 - val_loss: 0.0941 - learning_rate: 1.0000e-07
# Epoch 169/200
# 916/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9983 - loss: 0.0752
# Epoch 169: val_loss did not improve from 0.09397
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9983 - loss: 0.0754 - val_accuracy: 0.9931 - val_loss: 0.0940 - learning_rate: 1.0000e-07
# Epoch 170/200
# 917/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9984 - loss: 0.0754
# Epoch 170: val_loss did not improve from 0.09397
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9986 - loss: 0.0748 - val_accuracy: 0.9931 - val_loss: 0.0941 - learning_rate: 1.0000e-07
# Epoch 171/200
# 916/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9986 - loss: 0.0747
# Epoch 171: val_loss did not improve from 0.09397
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9989 - loss: 0.0742 - val_accuracy: 0.9931 - val_loss: 0.0941 - learning_rate: 1.0000e-07
# Epoch 172/200
# 920/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9991 - loss: 0.0744
# Epoch 172: val_loss did not improve from 0.09397
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9990 - loss: 0.0745 - val_accuracy: 0.9931 - val_loss: 0.0941 - learning_rate: 1.0000e-07
# Epoch 173/200
# 931/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9983 - loss: 0.0755
# Epoch 173: val_loss did not improve from 0.09397
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9988 - loss: 0.0748 - val_accuracy: 0.9931 - val_loss: 0.0940 - learning_rate: 1.0000e-07
# Epoch 174/200
# 912/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9987 - loss: 0.0744
# Epoch 174: val_loss did not improve from 0.09397
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9986 - loss: 0.0748 - val_accuracy: 0.9931 - val_loss: 0.0941 - learning_rate: 1.0000e-07
# Epoch 175/200
# 930/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9991 - loss: 0.0739
# Epoch 175: val_loss did not improve from 0.09397
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9990 - loss: 0.0741 - val_accuracy: 0.9931 - val_loss: 0.0940 - learning_rate: 1.0000e-07
# Epoch 176/200
# 916/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9986 - loss: 0.0746
# Epoch 176: val_loss did not improve from 0.09397
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9988 - loss: 0.0743 - val_accuracy: 0.9931 - val_loss: 0.0940 - learning_rate: 1.0000e-07
# Epoch 176: early stopping
# Restoring model weights from the end of the best epoch: 166.

# %%
plt.figure(figsize=(8, 5))
plt.plot(history.history["accuracy"], label="Treino")
plt.plot(history.history["val_accuracy"], label="Validação")
plt.title("Acurácia durante o treinamento")
plt.xlabel("Época")
plt.ylabel("Acurácia")
plt.legend()
plt.grid(True, alpha=0.3)
plt.savefig("acuracia_efficientnetb3_crop_smote.png", dpi=300, bbox_inches="tight")
plt.show()

plt.figure(figsize=(8, 5))
plt.plot(history.history["loss"], label="Treino")
plt.plot(history.history["val_loss"], label="Validação")
plt.title("Perda durante o treinamento")
plt.xlabel("Época")
plt.ylabel("Loss")
plt.legend()
plt.grid(True, alpha=0.3)
plt.savefig("loss_efficientnetb3_crop_smote.png", dpi=300, bbox_inches="tight")
plt.show()

# %%
best_classifier = keras.models.load_model(BEST_MODEL_PATH)

pred_probs = best_classifier.predict(X_test_features, verbose=0)
y_pred = np.argmax(pred_probs, axis=1)

print("Relatório de Classificação:")
print(classification_report(
    y_test,
    y_pred,
    target_names=classes,
    digits=4,
    zero_division=0
))

acc = accuracy_score(y_test, y_pred)

macro_precision = precision_score(y_test, y_pred, average="macro", zero_division=0)
macro_recall = recall_score(y_test, y_pred, average="macro", zero_division=0)
macro_f1 = f1_score(y_test, y_pred, average="macro", zero_division=0)

weighted_precision = precision_score(y_test, y_pred, average="weighted", zero_division=0)
weighted_recall = recall_score(y_test, y_pred, average="weighted", zero_division=0)
weighted_f1 = f1_score(y_test, y_pred, average="weighted", zero_division=0)

print("\nMÉTRICAS GERAIS DO MODELO")
print(f"Accuracy: {acc:.4f}")

print("\nMacro Average:")
print(f"  Precision: {macro_precision:.4f}")
print(f"  Recall: {macro_recall:.4f}")
print(f"  F1-Score: {macro_f1:.4f}")

print("\nWeighted Average:")
print(f"  Precision: {weighted_precision:.4f}")
print(f"  Recall: {weighted_recall:.4f}")
print(f"  F1-Score: {weighted_f1:.4f}")
# Out:
# Relatório de Classificação:
#               precision    recall  f1-score   support
#
#          MEL     0.7433    0.6233    0.6780       223
#           NV     0.9137    0.9478    0.9305      1341
#          BCC     0.7248    0.7670    0.7453       103
#        AKIEC     0.5217    0.5538    0.5373        65
#          BKL     0.6939    0.6182    0.6538       220
#           DF     0.6667    0.6957    0.6809        23
#         VASC     0.8148    0.7857    0.8000        28
#
#     accuracy                         0.8482      2003
#    macro avg     0.7256    0.7131    0.7180      2003
# weighted avg     0.8440    0.8482    0.8450      2003
#
#
# MÉTRICAS GERAIS DO MODELO
# Accuracy: 0.8482
#
# Macro Average:
#   Precision: 0.7256
#   Recall: 0.7131
#   F1-Score: 0.7180
#
# Weighted Average:
#   Precision: 0.8440
#   Recall: 0.8482
#   F1-Score: 0.8450

# %%
cm = confusion_matrix(y_test, y_pred, labels=list(range(len(classes))))
cm_percent = cm.astype("float") / cm.sum(axis=1, keepdims=True) * 100
cm_percent = np.nan_to_num(cm_percent)

plt.figure(figsize=(8, 7))
im = plt.imshow(cm_percent, interpolation="nearest", cmap="Blues", vmin=0, vmax=100)
plt.title("Matriz de Confusão (%) - EfficientNetB3 + Crop + SMOTE + 256x256")
plt.colorbar(im, label="%")

tick_marks = np.arange(len(classes))
plt.xticks(tick_marks, classes, rotation=45)
plt.yticks(tick_marks, classes)

for i in range(cm_percent.shape[0]):
    for j in range(cm_percent.shape[1]):
        color = "white" if cm_percent[i, j] > 50 else "black"
        plt.text(
            j,
            i,
            f"{cm_percent[i, j]:.1f}",
            ha="center",
            va="center",
            color=color,
            fontsize=8
        )

plt.ylabel("Classe Real")
plt.xlabel("Classe Predita")
plt.tight_layout()
plt.savefig("matriz_confusao_percent_efficientnetb3_crop_smote.png", dpi=300, bbox_inches="tight")
plt.show()

# %%
test_eval_df = test_df.copy().reset_index(drop=True)
test_eval_df["y_true"] = y_test
test_eval_df["y_pred"] = y_pred
test_eval_df["correct"] = test_eval_df["y_true"] == test_eval_df["y_pred"]

correct_samples = test_eval_df[test_eval_df["correct"]].head(4)
incorrect_samples = test_eval_df[~test_eval_df["correct"]].head(4)

samples_to_plot = pd.concat([correct_samples, incorrect_samples], axis=0).reset_index(drop=True)

plt.figure(figsize=(12, 6))

for i, row in samples_to_plot.iterrows():
    image = preprocess_image_path(row["image_path"], row["mask_path"])
    image = np.clip(image, 0, 255).astype("uint8")

    plt.subplot(2, 4, i + 1)
    plt.imshow(image)

    true_label = class_name[int(row["y_true"])]
    pred_label = class_name[int(row["y_pred"])]

    plt.title(f"{true_label} → {pred_label}", fontsize=10)
    plt.axis("off")

plt.tight_layout()
plt.savefig("exemplos_classificacao_efficientnetb3_crop_smote.png", dpi=300, bbox_inches="tight")
plt.show()

# %%
feature_extractor.save(FEATURE_EXTRACTOR_PATH)
best_classifier.save(FINAL_MODEL_PATH)

print("Extratora EfficientNetB3 salva em:", FEATURE_EXTRACTOR_PATH)
print("Classificador final salvo em:", FINAL_MODEL_PATH)
print("Melhor checkpoint salvo em:", BEST_MODEL_PATH)
# Out:
# Extratora EfficientNetB3 salva em: efficientnetb4_crop_380_feature_extractor.keras
# Classificador final salvo em: efficientnetb4_crop_smote_380_final.keras
# Melhor checkpoint salvo em: best_efficientnetb4_crop_smote_380.keras
