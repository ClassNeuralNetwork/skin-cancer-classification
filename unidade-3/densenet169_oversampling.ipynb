# %%
import os
os.environ["KERAS_BACKEND"] = "tensorflow"

import random
from pathlib import Path
from collections import Counter

import cv2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import tensorflow as tf
import keras
from keras import layers, models, regularizers

from tensorflow.keras.applications import DenseNet169
from tensorflow.keras.applications.densenet import preprocess_input

from sklearn.model_selection import train_test_split
from sklearn.metrics import (
    classification_report,
    confusion_matrix,
    accuracy_score,
    precision_score,
    recall_score,
    f1_score
)

from imblearn.over_sampling import RandomOverSampler

# %%
SEED = 42
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)

DATA_DIR = Path("../data")
IMAGES_DIR = DATA_DIR / "images"
MASKS_DIR = DATA_DIR / "masks"
CSV_PATH = DATA_DIR / "GroundTruth.csv"

IMG_SIZE = (256, 256)
BATCH_SIZE = 32
EPOCHS = 200
LEARNING_RATE = 0.0001

TEST_SIZE = 0.20
VAL_SIZE = 0.20

USE_DULL_RAZOR = True

USE_MASK_SEGMENTATION = False

USE_MASK_CROP = True
CROP_MARGIN = 20

BEST_MODEL_PATH = "best_densenet169_dull_crop_oversampling.keras"
FINAL_MODEL_PATH = "densenet169_dull_crop_oversampling_final.keras"
FEATURE_EXTRACTOR_PATH = "densenet169_dull_crop_feature_extractor.keras"

classes = ["MEL", "NV", "BCC", "AKIEC", "BKL", "DF", "VASC"]
class_code = {label: idx for idx, label in enumerate(classes)}
class_name = {idx: label for label, idx in class_code.items()}

print("IMG_SIZE:", IMG_SIZE)
print("BATCH_SIZE:", BATCH_SIZE)
print("EPOCHS:", EPOCHS)
print("LEARNING_RATE:", LEARNING_RATE)
print("USE_DULL_RAZOR:", USE_DULL_RAZOR)
print("USE_MASK_SEGMENTATION:", USE_MASK_SEGMENTATION)
print("USE_MASK_CROP:", USE_MASK_CROP)
print("CROP_MARGIN:", CROP_MARGIN)
print(class_code)
# Out:
# IMG_SIZE: (256, 256)
# BATCH_SIZE: 32
# EPOCHS: 200
# LEARNING_RATE: 0.0001
# USE_DULL_RAZOR: True
# USE_MASK_SEGMENTATION: False
# USE_MASK_CROP: True
# CROP_MARGIN: 20
# {'MEL': 0, 'NV': 1, 'BCC': 2, 'AKIEC': 3, 'BKL': 4, 'DF': 5, 'VASC': 6}

# %%
def find_image_path(image_id, images_dir):
    for ext in [".jpg", ".jpeg", ".png"]:
        path = images_dir / f"{image_id}{ext}"
        if path.exists():
            return str(path)
    return None


def find_mask_path(image_id, masks_dir):
    if not masks_dir.exists():
        return None

    candidates = [
        masks_dir / f"{image_id}_segmentation.png",
        masks_dir / f"{image_id}_segmentation.jpg",
        masks_dir / f"{image_id}_mask.png",
        masks_dir / f"{image_id}_mask.jpg",
        masks_dir / f"{image_id}.png",
        masks_dir / f"{image_id}.jpg",
    ]

    for path in candidates:
        if path.exists():
            return str(path)

    matches = list(masks_dir.glob(f"{image_id}*"))
    if len(matches) > 0:
        return str(matches[0])

    return None


metadata = pd.read_csv(CSV_PATH)

rows = []
for _, row in metadata.iterrows():
    image_id = str(row["image"])
    image_path = find_image_path(image_id, IMAGES_DIR)
    mask_path = find_mask_path(image_id, MASKS_DIR)

    if image_path is None:
        continue

    label_name = row[classes].idxmax()
    label = class_code[label_name]

    rows.append({
        "image": image_id,
        "image_path": image_path,
        "mask_path": mask_path,
        "class_name": label_name,
        "label": label
    })

df = pd.DataFrame(rows)

print("Total de imagens localizadas:", len(df))
display(df.head())

print("\nDistribuição original:")
print(df["class_name"].value_counts().reindex(classes))

print("\nMáscaras encontradas:", df["mask_path"].notna().sum())
# Out:
# Total de imagens localizadas: 10015
#           image                       image_path  \
# 0  ISIC_0024306  ../data/images/ISIC_0024306.jpg
# 1  ISIC_0024307  ../data/images/ISIC_0024307.jpg
# 2  ISIC_0024308  ../data/images/ISIC_0024308.jpg
# 3  ISIC_0024309  ../data/images/ISIC_0024309.jpg
# 4  ISIC_0024310  ../data/images/ISIC_0024310.jpg
#
#                                      mask_path class_name  label
# 0  ../data/masks/ISIC_0024306_segmentation.png         NV      1
# 1  ../data/masks/ISIC_0024307_segmentation.png         NV      1
# 2  ../data/masks/ISIC_0024308_segmentation.png         NV      1
# 3  ../data/masks/ISIC_0024309_segmentation.png         NV      1
# 4  ../data/masks/ISIC_0024310_segmentation.png        MEL      0
# Distribuição original:
# class_name
# MEL      1113
# NV       6705
# BCC       514
# AKIEC     327
# BKL      1099
# DF        115
# VASC      142
# Name: count, dtype: int64
#
# Máscaras encontradas: 10015

# %%
train_df, test_df = train_test_split(
    df,
    test_size=TEST_SIZE,
    random_state=SEED,
    stratify=df["label"]
)

print("Treino original:", len(train_df))
print("Teste final:", len(test_df))

print("\nDistribuição treino original:")
print(train_df["class_name"].value_counts().reindex(classes))

print("\nDistribuição teste final:")
print(test_df["class_name"].value_counts().reindex(classes))
# Out:
# Treino original: 8012
# Teste final: 2003
#
# Distribuição treino original:
# class_name
# MEL       890
# NV       5364
# BCC       411
# AKIEC     262
# BKL       879
# DF         92
# VASC      114
# Name: count, dtype: int64
#
# Distribuição teste final:
# class_name
# MEL       223
# NV       1341
# BCC       103
# AKIEC      65
# BKL       220
# DF         23
# VASC       28
# Name: count, dtype: int64

# %%
def read_rgb_image(path):
    if isinstance(path, bytes):
        path = path.decode("utf-8")

    image_bgr = cv2.imread(str(path), cv2.IMREAD_COLOR)

    if image_bgr is None:
        raise ValueError(f"Não foi possível carregar a imagem: {path}")

    image_rgb = cv2.cvtColor(image_bgr, cv2.COLOR_BGR2RGB)

    return image_rgb


def dull_razor_remove_hair(image_rgb, kernel_size=(9, 9), threshold_value=10, inpaint_radius=6):
    image_rgb = image_rgb.astype(np.uint8)

    gray = cv2.cvtColor(image_rgb, cv2.COLOR_RGB2GRAY)

    kernel = cv2.getStructuringElement(cv2.MORPH_RECT, kernel_size)
    blackhat = cv2.morphologyEx(gray, cv2.MORPH_BLACKHAT, kernel)

    blackhat_blur = cv2.GaussianBlur(blackhat, (3, 3), 0)

    _, mask = cv2.threshold(
        blackhat_blur,
        threshold_value,
        255,
        cv2.THRESH_BINARY
    )

    image_bgr = cv2.cvtColor(image_rgb, cv2.COLOR_RGB2BGR)

    clean_bgr = cv2.inpaint(
        image_bgr,
        mask,
        inpaint_radius,
        cv2.INPAINT_TELEA
    )

    clean_rgb = cv2.cvtColor(clean_bgr, cv2.COLOR_BGR2RGB)

    return clean_rgb


def read_binary_mask(mask_path, target_shape):
    if mask_path is None or pd.isna(mask_path):
        return None

    if isinstance(mask_path, bytes):
        mask_path = mask_path.decode("utf-8")

    mask = cv2.imread(str(mask_path), cv2.IMREAD_GRAYSCALE)

    if mask is None:
        return None

    height, width = target_shape[:2]
    mask = cv2.resize(mask, (width, height))

    binary_mask = (mask > 127).astype(np.uint8)

    return binary_mask


def apply_mask_segmentation(image_rgb, mask_path):
    binary_mask = read_binary_mask(mask_path, target_shape=image_rgb.shape)

    if binary_mask is None:
        return image_rgb

    segmented = image_rgb * np.expand_dims(binary_mask, axis=-1)

    if np.mean(segmented) < 5:
        return image_rgb

    return segmented


def crop_lesion_with_margin(image_rgb, mask_path, margin=20):
    binary_mask = read_binary_mask(mask_path, target_shape=image_rgb.shape)

    if binary_mask is None:
        return image_rgb

    ys, xs = np.where(binary_mask > 0)

    if len(xs) == 0 or len(ys) == 0:
        return image_rgb

    height, width = image_rgb.shape[:2]

    x_min = max(xs.min() - margin, 0)
    x_max = min(xs.max() + margin, width - 1)
    y_min = max(ys.min() - margin, 0)
    y_max = min(ys.max() + margin, height - 1)

    cropped = image_rgb[y_min:y_max + 1, x_min:x_max + 1]

    if cropped.size == 0:
        return image_rgb

    return cropped


def preprocess_image_path(path, mask_path=None):
    image_rgb = read_rgb_image(path)

    if USE_DULL_RAZOR:
        image_rgb = dull_razor_remove_hair(image_rgb)

    if USE_MASK_CROP:
        image_rgb = crop_lesion_with_margin(
            image_rgb,
            mask_path,
            margin=CROP_MARGIN
        )
    elif USE_MASK_SEGMENTATION:
        image_rgb = apply_mask_segmentation(image_rgb, mask_path)

    image_rgb = cv2.resize(image_rgb, IMG_SIZE)

    return image_rgb.astype("float32")

# %%
sample_row = train_df.sample(1, random_state=SEED).iloc[0]

original = read_rgb_image(sample_row["image_path"])
dull = dull_razor_remove_hair(original) if USE_DULL_RAZOR else original
segmented = apply_mask_segmentation(dull, sample_row["mask_path"])
cropped = crop_lesion_with_margin(dull, sample_row["mask_path"], margin=CROP_MARGIN)
final_img = preprocess_image_path(sample_row["image_path"], sample_row["mask_path"])
final_img = np.clip(final_img, 0, 255).astype("uint8")

plt.figure(figsize=(16, 4))

plt.subplot(1, 5, 1)
plt.imshow(original)
plt.title("Original")
plt.axis("off")

plt.subplot(1, 5, 2)
plt.imshow(dull)
plt.title("Dull Razor")
plt.axis("off")

plt.subplot(1, 5, 3)
plt.imshow(np.clip(segmented, 0, 255).astype("uint8"))
plt.title("Máscara aplicada")
plt.axis("off")

plt.subplot(1, 5, 4)
plt.imshow(np.clip(cropped, 0, 255).astype("uint8"))
plt.title("Crop + margem")
plt.axis("off")

plt.subplot(1, 5, 5)
plt.imshow(final_img)
plt.title("Final 256x256")
plt.axis("off")

plt.tight_layout()
plt.savefig("pipeline_densenet169_dull_crop_oversampling.png", dpi=300, bbox_inches="tight")
plt.show()

# %%
def load_image_for_features_py(image_path, mask_path, label):
    if isinstance(image_path, bytes):
        image_path = image_path.decode("utf-8")

    if isinstance(mask_path, bytes):
        mask_path = mask_path.decode("utf-8")

    if mask_path == "None" or mask_path == "":
        mask_path = None

    image = preprocess_image_path(image_path, mask_path)

    return image.astype("float32"), np.int32(label)


def tf_load_image_for_features(image_path, mask_path, label):
    image, label = tf.numpy_function(
        load_image_for_features_py,
        [image_path, mask_path, label],
        [tf.float32, tf.int32]
    )

    image.set_shape((IMG_SIZE[0], IMG_SIZE[1], 3))
    label.set_shape(())

    return image, label


def build_image_dataset(dataframe, batch_size=BATCH_SIZE, shuffle=False):
    mask_values = dataframe["mask_path"].fillna("None").astype(str).values

    ds = tf.data.Dataset.from_tensor_slices((
        dataframe["image_path"].astype(str).values,
        mask_values,
        dataframe["label"].values.astype("int32")
    ))

    if shuffle:
        ds = ds.shuffle(buffer_size=len(dataframe), seed=SEED)

    ds = ds.map(tf_load_image_for_features, num_parallel_calls=tf.data.AUTOTUNE)
    ds = ds.batch(batch_size)
    ds = ds.prefetch(tf.data.AUTOTUNE)

    return ds


train_image_ds = build_image_dataset(train_df, shuffle=False)
test_image_ds = build_image_dataset(test_df, shuffle=False)

print(train_image_ds)
print(test_image_ds)
# Out:
# <_PrefetchDataset element_spec=(TensorSpec(shape=(None, 256, 256, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>
# <_PrefetchDataset element_spec=(TensorSpec(shape=(None, 256, 256, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
def build_feature_extractor(input_shape=(256, 256, 3)):
    inputs = layers.Input(shape=input_shape)

    x = preprocess_input(inputs)

    base_model = DenseNet169(
        weights="imagenet",
        include_top=False,
        input_shape=input_shape
    )

    base_model.trainable = False

    x = base_model(x, training=False)
    x = layers.GlobalAveragePooling2D()(x)

    feature_extractor = models.Model(
        inputs=inputs,
        outputs=x,
        name="densenet169_dull_crop_feature_extractor"
    )

    return feature_extractor


feature_extractor = build_feature_extractor(
    input_shape=(IMG_SIZE[0], IMG_SIZE[1], 3)
)

feature_extractor.summary()
# Out:
# Model: "densenet169_dull_crop_feature_extractor"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 256, 256, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ true_divide (TrueDivide)        │ (None, 256, 256, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ add (Add)                       │ (None, 256, 256, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ true_divide_1 (TrueDivide)      │ (None, 256, 256, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ densenet169 (Functional)        │ (None, 8, 8, 1664)     │    12,642,880 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 1664)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 12,642,880 (48.23 MB)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 12,642,880 (48.23 MB)

# %%
def extract_features(dataset, feature_extractor):
    features_list = []
    labels_list = []

    for images, labels in dataset:
        features = feature_extractor.predict(images, verbose=0)
        features_list.append(features)
        labels_list.append(labels.numpy())

    X = np.concatenate(features_list, axis=0)
    y = np.concatenate(labels_list, axis=0)

    return X.astype("float32"), y.astype("int32")


X_train_features, y_train = extract_features(train_image_ds, feature_extractor)
X_test_features, y_test = extract_features(test_image_ds, feature_extractor)

print("X_train_features:", X_train_features.shape)
print("y_train:", y_train.shape)
print("X_test_features:", X_test_features.shape)
print("y_test:", y_test.shape)

print("\nDistribuição treino antes do Oversampling:")
print(Counter(y_train))
# Out:
# X_train_features: (8012, 1664)
# y_train: (8012,)
# X_test_features: (2003, 1664)
# y_test: (2003,)
#
# Distribuição treino antes do Oversampling:
# Counter({np.int32(1): 5364, np.int32(0): 890, np.int32(4): 879, np.int32(2): 411, np.int32(3): 262, np.int32(6): 114, np.int32(5): 92})

# %%
print("Distribuição treino antes do Random Oversampling:")
print(Counter(y_train))

oversampling = RandomOverSampler(
    random_state=SEED
)

X_train_oversampling, y_train_oversampling = oversampling.fit_resample(
    X_train_features,
    y_train
)

print("X_train_oversampling:", X_train_oversampling.shape)
print("y_train_oversampling:", y_train_oversampling.shape)

print("\nDistribuição treino após Random Oversampling:")
print(Counter(y_train_oversampling))
# Out:
# Distribuição treino antes do Random Oversampling:
# Counter({np.int32(1): 5364, np.int32(0): 890, np.int32(4): 879, np.int32(2): 411, np.int32(3): 262, np.int32(6): 114, np.int32(5): 92})
# X_train_oversampling: (37548, 1664)
# y_train_oversampling: (37548,)
#
# Distribuição treino após Random Oversampling:
# Counter({np.int32(1): 5364, np.int32(0): 5364, np.int32(4): 5364, np.int32(2): 5364, np.int32(5): 5364, np.int32(3): 5364, np.int32(6): 5364})

# %%
X_fit, X_val, y_fit, y_val = train_test_split(
    X_train_oversampling,
    y_train_oversampling,
    test_size=VAL_SIZE,
    random_state=SEED,
    stratify=y_train_oversampling
)

print("Treino para fit:", X_fit.shape)
print("Validação:", X_val.shape)
print("Teste final:", X_test_features.shape)

print("\nDistribuição fit:")
print(Counter(y_fit))

print("\nDistribuição validação:")
print(Counter(y_val))
# Out:
# Treino para fit: (30038, 1664)
# Validação: (7510, 1664)
# Teste final: (2003, 1664)
#
# Distribuição fit:
# Counter({np.int32(0): 4292, np.int32(4): 4291, np.int32(5): 4291, np.int32(6): 4291, np.int32(2): 4291, np.int32(3): 4291, np.int32(1): 4291})
#
# Distribuição validação:
# Counter({np.int32(2): 1073, np.int32(3): 1073, np.int32(6): 1073, np.int32(4): 1073, np.int32(1): 1073, np.int32(5): 1073, np.int32(0): 1072})

# %%
def build_classifier_head(input_dim, num_classes=len(classes)):
    inputs = layers.Input(shape=(input_dim,))

    x = layers.Dense(
        256,
        activation="relu",
        kernel_regularizer=regularizers.l2(0.001)
    )(inputs)

    x = layers.BatchNormalization()(x)
    x = layers.Dropout(0.5)(x)

    x = layers.Dense(
        128,
        activation="relu",
        kernel_regularizer=regularizers.l2(0.001)
    )(x)

    x = layers.Dropout(0.3)(x)

    outputs = layers.Dense(num_classes, activation="softmax")(x)

    model = models.Model(
        inputs=inputs,
        outputs=outputs,
        name="densenet169_dull_crop_oversampling_classifier"
    )

    return model


classifier = build_classifier_head(
    input_dim=X_train_oversampling.shape[1],
    num_classes=len(classes)
)

classifier.compile(
    optimizer=keras.optimizers.Adam(learning_rate=LEARNING_RATE),
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)

classifier.summary()
# Out:
# Model: "densenet169_dull_crop_oversampling_classifier"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_2 (InputLayer)      │ (None, 1664)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │       426,240 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 7)              │           903 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 461,063 (1.76 MB)
#  Trainable params: 460,551 (1.76 MB)
#  Non-trainable params: 512 (2.00 KB)

# %%
callbacks = [
    keras.callbacks.EarlyStopping(
        monitor="val_loss",
        patience=10,
        restore_best_weights=True,
        verbose=1
    ),
    keras.callbacks.ReduceLROnPlateau(
        monitor="val_loss",
        factor=0.2,
        patience=4,
        min_lr=1e-7,
        verbose=1
    ),
    keras.callbacks.ModelCheckpoint(
        BEST_MODEL_PATH,
        monitor="val_loss",
        save_best_only=True,
        verbose=1
    )
]

history = classifier.fit(
    X_fit,
    y_fit,
    validation_data=(X_val, y_val),
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    callbacks=callbacks
)
# Out:
# Epoch 1/200
# 923/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4110 - loss: 2.2010
# Epoch 1: val_loss improved from None to 1.09109, saving model to best_densenet169_dull_crop_oversampling.keras
#
# Epoch 1: finished saving model to best_densenet169_dull_crop_oversampling.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.5210 - loss: 1.7846 - val_accuracy: 0.7533 - val_loss: 1.0911 - learning_rate: 1.0000e-04
# Epoch 2/200
# 925/939 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6545 - loss: 1.3032
# Epoch 2: val_loss improved from 1.09109 to 0.89747, saving model to best_densenet169_dull_crop_oversampling.keras
#
# Epoch 2: finished saving model to best_densenet169_dull_crop_oversampling.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.6757 - loss: 1.2404 - val_accuracy: 0.8210 - val_loss: 0.8975 - learning_rate: 1.0000e-04
# Epoch 3/200
# 923/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7235 - loss: 1.0868
# Epoch 3: val_loss improved from 0.89747 to 0.76140, saving model to best_densenet169_dull_crop_oversampling.keras
#
# Epoch 3: finished saving model to best_densenet169_dull_crop_oversampling.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7429 - loss: 1.0346 - val_accuracy: 0.8546 - val_loss: 0.7614 - learning_rate: 1.0000e-04
# Epoch 4/200
# 929/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7734 - loss: 0.9361
# Epoch 4: val_loss improved from 0.76140 to 0.66722, saving model to best_densenet169_dull_crop_oversampling.keras
#
# Epoch 4: finished saving model to best_densenet169_dull_crop_oversampling.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7837 - loss: 0.9053 - val_accuracy: 0.8786 - val_loss: 0.6672 - learning_rate: 1.0000e-04
# Epoch 5/200
# 921/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8090 - loss: 0.8189
# Epoch 5: val_loss improved from 0.66722 to 0.59653, saving model to best_densenet169_dull_crop_oversampling.keras
#
# Epoch 5: finished saving model to best_densenet169_dull_crop_oversampling.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8162 - loss: 0.8016 - val_accuracy: 0.8981 - val_loss: 0.5965 - learning_rate: 1.0000e-04
# Epoch 6/200
# 925/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8310 - loss: 0.7422
# Epoch 6: val_loss improved from 0.59653 to 0.53888, saving model to best_densenet169_dull_crop_oversampling.keras
#
# Epoch 6: finished saving model to best_densenet169_dull_crop_oversampling.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8384 - loss: 0.7218 - val_accuracy: 0.9084 - val_loss: 0.5389 - learning_rate: 1.0000e-04
# Epoch 7/200
# 937/939 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8527 - loss: 0.6683
# Epoch 7: val_loss improved from 0.53888 to 0.50106, saving model to best_densenet169_dull_crop_oversampling.keras
#
# Epoch 7: finished saving model to best_densenet169_dull_crop_oversampling.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8562 - loss: 0.6543 - val_accuracy: 0.9153 - val_loss: 0.5011 - learning_rate: 1.0000e-04
# Epoch 8/200
# 933/939 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8677 - loss: 0.6120
# Epoch 8: val_loss improved from 0.50106 to 0.44993, saving model to best_densenet169_dull_crop_oversampling.keras
#
# Epoch 8: finished saving model to best_densenet169_dull_crop_oversampling.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8727 - loss: 0.5990 - val_accuracy: 0.9342 - val_loss: 0.4499 - learning_rate: 1.0000e-04
# Epoch 9/200
# 921/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8806 - loss: 0.5647
# Epoch 9: val_loss improved from 0.44993 to 0.42281, saving model to best_densenet169_dull_crop_oversampling.keras
#
# Epoch 9: finished saving model to best_densenet169_dull_crop_oversampling.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8837 - loss: 0.5572 - val_accuracy: 0.9375 - val_loss: 0.4228 - learning_rate: 1.0000e-04
# Epoch 10/200
# 917/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8901 - loss: 0.5339
# Epoch 10: val_loss improved from 0.42281 to 0.39913, saving model to best_densenet169_dull_crop_oversampling.keras
#
# Epoch 10: finished saving model to best_densenet169_dull_crop_oversampling.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8945 - loss: 0.5188 - val_accuracy: 0.9415 - val_loss: 0.3991 - learning_rate: 1.0000e-04
# Epoch 11/200
# 918/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9012 - loss: 0.4923
# Epoch 11: val_loss improved from 0.39913 to 0.37988, saving model to best_densenet169_dull_crop_oversampling.keras
#
# Epoch 11: finished saving model to best_densenet169_dull_crop_oversampling.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9034 - loss: 0.4854 - val_accuracy: 0.9438 - val_loss: 0.3799 - learning_rate: 1.0000e-04
# Epoch 12/200
# 932/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9079 - loss: 0.4682
# Epoch 12: val_loss improved from 0.37988 to 0.35605, saving model to best_densenet169_dull_crop_oversampling.keras
#
# Epoch 12: finished saving model to best_densenet169_dull_crop_oversampling.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9120 - loss: 0.4587 - val_accuracy: 0.9515 - val_loss: 0.3561 - learning_rate: 1.0000e-04
# Epoch 13/200
# 936/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9125 - loss: 0.4407
# Epoch 13: val_loss improved from 0.35605 to 0.33468, saving model to best_densenet169_dull_crop_oversampling.keras
#
# Epoch 13: finished saving model to best_densenet169_dull_crop_oversampling.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9172 - loss: 0.4339 - val_accuracy: 0.9557 - val_loss: 0.3347 - learning_rate: 1.0000e-04
# Epoch 14/200
# 932/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9211 - loss: 0.4144
# Epoch 14: val_loss improved from 0.33468 to 0.32112, saving model to best_densenet169_dull_crop_oversampling.keras
#
# Epoch 14: finished saving model to best_densenet169_dull_crop_oversampling.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9234 - loss: 0.4081 - val_accuracy: 0.9605 - val_loss: 0.3211 - learning_rate: 1.0000e-04
# Epoch 15/200
# 936/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9265 - loss: 0.3976
# Epoch 15: val_loss improved from 0.32112 to 0.30379, saving model to best_densenet169_dull_crop_oversampling.keras
#
# Epoch 15: finished saving model to best_densenet169_dull_crop_oversampling.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9304 - loss: 0.3892 - val_accuracy: 0.9618 - val_loss: 0.3038 - learning_rate: 1.0000e-04
# Epoch 16/200
# 926/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9331 - loss: 0.3771
# Epoch 16: val_loss improved from 0.30379 to 0.30335, saving model to best_densenet169_dull_crop_oversampling.keras
#
# Epoch 16: finished saving model to best_densenet169_dull_crop_oversampling.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9352 - loss: 0.3704 - val_accuracy: 0.9610 - val_loss: 0.3033 - learning_rate: 1.0000e-04
# Epoch 17/200
# 915/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9359 - loss: 0.3606
# Epoch 17: val_loss improved from 0.30335 to 0.27630, saving model to best_densenet169_dull_crop_oversampling.keras
#
# Epoch 17: finished saving model to best_densenet169_dull_crop_oversampling.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9376 - loss: 0.3538 - val_accuracy: 0.9676 - val_loss: 0.2763 - learning_rate: 1.0000e-04
# Epoch 18/200
# 924/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9385 - loss: 0.3430
# Epoch 18: val_loss improved from 0.27630 to 0.26966, saving model to best_densenet169_dull_crop_oversampling.keras
#
# Epoch 18: finished saving model to best_densenet169_dull_crop_oversampling.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9374 - loss: 0.3433 - val_accuracy: 0.9690 - val_loss: 0.2697 - learning_rate: 1.0000e-04
# Epoch 19/200
# 915/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9412 - loss: 0.3309
# Epoch 19: val_loss improved from 0.26966 to 0.26480, saving model to best_densenet169_dull_crop_oversampling.keras
#
# Epoch 19: finished saving model to best_densenet169_dull_crop_oversampling.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9422 - loss: 0.3289 - val_accuracy: 0.9682 - val_loss: 0.2648 - learning_rate: 1.0000e-04
# Epoch 20/200
# 934/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9425 - loss: 0.3260
# Epoch 20: val_loss improved from 0.26480 to 0.24721, saving model to best_densenet169_dull_crop_oversampling.keras
#
# Epoch 20: finished saving model to best_densenet169_dull_crop_oversampling.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9439 - loss: 0.3218 - val_accuracy: 0.9726 - val_loss: 0.2472 - learning_rate: 1.0000e-04
# Epoch 21/200
# 921/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9470 - loss: 0.3057
# Epoch 21: val_loss improved from 0.24721 to 0.24155, saving model to best_densenet169_dull_crop_oversampling.keras
#
# Epoch 21: finished saving model to best_densenet169_dull_crop_oversampling.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9479 - loss: 0.3035 - val_accuracy: 0.9723 - val_loss: 0.2416 - learning_rate: 1.0000e-04
# Epoch 22/200
# 935/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9472 - loss: 0.3045
# Epoch 22: val_loss improved from 0.24155 to 0.23773, saving model to best_densenet169_dull_crop_oversampling.keras
#
# Epoch 22: finished saving model to best_densenet169_dull_crop_oversampling.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9474 - loss: 0.3021 - val_accuracy: 0.9724 - val_loss: 0.2377 - learning_rate: 1.0000e-04
# Epoch 23/200
# 934/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9491 - loss: 0.2922
# Epoch 23: val_loss improved from 0.23773 to 0.23094, saving model to best_densenet169_dull_crop_oversampling.keras
#
# Epoch 23: finished saving model to best_densenet169_dull_crop_oversampling.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9514 - loss: 0.2880 - val_accuracy: 0.9740 - val_loss: 0.2309 - learning_rate: 1.0000e-04
# Epoch 24/200
# 923/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9497 - loss: 0.2798
# Epoch 24: val_loss improved from 0.23094 to 0.22281, saving model to best_densenet169_dull_crop_oversampling.keras
#
# Epoch 24: finished saving model to best_densenet169_dull_crop_oversampling.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9526 - loss: 0.2764 - val_accuracy: 0.9770 - val_loss: 0.2228 - learning_rate: 1.0000e-04
# Epoch 25/200
# 931/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9549 - loss: 0.2735
# Epoch 25: val_loss improved from 0.22281 to 0.21451, saving model to best_densenet169_dull_crop_oversampling.keras
#
# Epoch 25: finished saving model to best_densenet169_dull_crop_oversampling.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9540 - loss: 0.2726 - val_accuracy: 0.9760 - val_loss: 0.2145 - learning_rate: 1.0000e-04
# Epoch 26/200
# 925/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9538 - loss: 0.2694
# Epoch 26: val_loss did not improve from 0.21451
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9537 - loss: 0.2689 - val_accuracy: 0.9767 - val_loss: 0.2151 - learning_rate: 1.0000e-04
# Epoch 27/200
# 936/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9529 - loss: 0.2696
# Epoch 27: val_loss improved from 0.21451 to 0.20625, saving model to best_densenet169_dull_crop_oversampling.keras
#
# Epoch 27: finished saving model to best_densenet169_dull_crop_oversampling.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9565 - loss: 0.2598 - val_accuracy: 0.9770 - val_loss: 0.2062 - learning_rate: 1.0000e-04
# Epoch 28/200
# 936/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9522 - loss: 0.2576
# Epoch 28: val_loss improved from 0.20625 to 0.20119, saving model to best_densenet169_dull_crop_oversampling.keras
#
# Epoch 28: finished saving model to best_densenet169_dull_crop_oversampling.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9550 - loss: 0.2561 - val_accuracy: 0.9787 - val_loss: 0.2012 - learning_rate: 1.0000e-04
# Epoch 29/200
# 926/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9582 - loss: 0.2509
# Epoch 29: val_loss did not improve from 0.20119
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9589 - loss: 0.2469 - val_accuracy: 0.9726 - val_loss: 0.2123 - learning_rate: 1.0000e-04
# Epoch 30/200
# 921/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9568 - loss: 0.2430
# Epoch 30: val_loss improved from 0.20119 to 0.18744, saving model to best_densenet169_dull_crop_oversampling.keras
#
# Epoch 30: finished saving model to best_densenet169_dull_crop_oversampling.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9602 - loss: 0.2380 - val_accuracy: 0.9812 - val_loss: 0.1874 - learning_rate: 1.0000e-04
# Epoch 31/200
# 915/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9606 - loss: 0.2336
# Epoch 31: val_loss improved from 0.18744 to 0.18660, saving model to best_densenet169_dull_crop_oversampling.keras
#
# Epoch 31: finished saving model to best_densenet169_dull_crop_oversampling.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9612 - loss: 0.2313 - val_accuracy: 0.9808 - val_loss: 0.1866 - learning_rate: 1.0000e-04
# Epoch 32/200
# 931/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9615 - loss: 0.2272
# Epoch 32: val_loss did not improve from 0.18660
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9617 - loss: 0.2272 - val_accuracy: 0.9798 - val_loss: 0.1901 - learning_rate: 1.0000e-04
# Epoch 33/200
# 932/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9599 - loss: 0.2310
# Epoch 33: val_loss did not improve from 0.18660
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9606 - loss: 0.2294 - val_accuracy: 0.9746 - val_loss: 0.1989 - learning_rate: 1.0000e-04
# Epoch 34/200
# 937/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9595 - loss: 0.2264
# Epoch 34: val_loss did not improve from 0.18660
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9617 - loss: 0.2221 - val_accuracy: 0.9767 - val_loss: 0.1937 - learning_rate: 1.0000e-04
# Epoch 35/200
# 922/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9625 - loss: 0.2221
# Epoch 35: val_loss improved from 0.18660 to 0.17811, saving model to best_densenet169_dull_crop_oversampling.keras
#
# Epoch 35: finished saving model to best_densenet169_dull_crop_oversampling.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9609 - loss: 0.2236 - val_accuracy: 0.9808 - val_loss: 0.1781 - learning_rate: 1.0000e-04
# Epoch 36/200
# 930/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9607 - loss: 0.2214
# Epoch 36: val_loss did not improve from 0.17811
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9610 - loss: 0.2198 - val_accuracy: 0.9790 - val_loss: 0.1807 - learning_rate: 1.0000e-04
# Epoch 37/200
# 923/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9593 - loss: 0.2193
# Epoch 37: val_loss did not improve from 0.17811
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9610 - loss: 0.2179 - val_accuracy: 0.9771 - val_loss: 0.1801 - learning_rate: 1.0000e-04
# Epoch 38/200
# 923/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9620 - loss: 0.2127
# Epoch 38: val_loss improved from 0.17811 to 0.17452, saving model to best_densenet169_dull_crop_oversampling.keras
#
# Epoch 38: finished saving model to best_densenet169_dull_crop_oversampling.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9634 - loss: 0.2102 - val_accuracy: 0.9800 - val_loss: 0.1745 - learning_rate: 1.0000e-04
# Epoch 39/200
# 931/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9614 - loss: 0.2102
# Epoch 39: val_loss improved from 0.17452 to 0.16805, saving model to best_densenet169_dull_crop_oversampling.keras
#
# Epoch 39: finished saving model to best_densenet169_dull_crop_oversampling.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9617 - loss: 0.2090 - val_accuracy: 0.9803 - val_loss: 0.1681 - learning_rate: 1.0000e-04
# Epoch 40/200
# 938/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9598 - loss: 0.2127
# Epoch 40: val_loss improved from 0.16805 to 0.16408, saving model to best_densenet169_dull_crop_oversampling.keras
#
# Epoch 40: finished saving model to best_densenet169_dull_crop_oversampling.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9617 - loss: 0.2071 - val_accuracy: 0.9818 - val_loss: 0.1641 - learning_rate: 1.0000e-04
# Epoch 41/200
# 934/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9641 - loss: 0.2004
# Epoch 41: val_loss improved from 0.16408 to 0.15784, saving model to best_densenet169_dull_crop_oversampling.keras
#
# Epoch 41: finished saving model to best_densenet169_dull_crop_oversampling.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9669 - loss: 0.1959 - val_accuracy: 0.9814 - val_loss: 0.1578 - learning_rate: 1.0000e-04
# Epoch 42/200
# 915/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9638 - loss: 0.2010
# Epoch 42: val_loss did not improve from 0.15784
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9640 - loss: 0.1988 - val_accuracy: 0.9803 - val_loss: 0.1614 - learning_rate: 1.0000e-04
# Epoch 43/200
# 923/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9641 - loss: 0.1975
# Epoch 43: val_loss did not improve from 0.15784
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9643 - loss: 0.1988 - val_accuracy: 0.9800 - val_loss: 0.1611 - learning_rate: 1.0000e-04
# Epoch 44/200
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9610 - loss: 0.2072
# Epoch 44: val_loss improved from 0.15784 to 0.15776, saving model to best_densenet169_dull_crop_oversampling.keras
#
# Epoch 44: finished saving model to best_densenet169_dull_crop_oversampling.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9624 - loss: 0.2020 - val_accuracy: 0.9814 - val_loss: 0.1578 - learning_rate: 1.0000e-04
# Epoch 45/200
# 924/939 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9644 - loss: 0.1955
# Epoch 45: val_loss improved from 0.15776 to 0.15099, saving model to best_densenet169_dull_crop_oversampling.keras
#
# Epoch 45: finished saving model to best_densenet169_dull_crop_oversampling.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9657 - loss: 0.1922 - val_accuracy: 0.9830 - val_loss: 0.1510 - learning_rate: 1.0000e-04
# Epoch 46/200
# 935/939 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9626 - loss: 0.1973
# Epoch 46: val_loss did not improve from 0.15099
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.9642 - loss: 0.1941 - val_accuracy: 0.9799 - val_loss: 0.1536 - learning_rate: 1.0000e-04
# Epoch 47/200
# 926/939 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9664 - loss: 0.1884
# Epoch 47: val_loss improved from 0.15099 to 0.15001, saving model to best_densenet169_dull_crop_oversampling.keras
#
# Epoch 47: finished saving model to best_densenet169_dull_crop_oversampling.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9681 - loss: 0.1833 - val_accuracy: 0.9816 - val_loss: 0.1500 - learning_rate: 1.0000e-04
# Epoch 48/200
# 915/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9637 - loss: 0.1895
# Epoch 48: val_loss did not improve from 0.15001
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9649 - loss: 0.1877 - val_accuracy: 0.9806 - val_loss: 0.1512 - learning_rate: 1.0000e-04
# Epoch 49/200
# 931/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9664 - loss: 0.1832
# Epoch 49: val_loss improved from 0.15001 to 0.14210, saving model to best_densenet169_dull_crop_oversampling.keras
#
# Epoch 49: finished saving model to best_densenet169_dull_crop_oversampling.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9672 - loss: 0.1821 - val_accuracy: 0.9846 - val_loss: 0.1421 - learning_rate: 1.0000e-04
# Epoch 50/200
# 934/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9708 - loss: 0.1707
# Epoch 50: val_loss did not improve from 0.14210
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9703 - loss: 0.1703 - val_accuracy: 0.9790 - val_loss: 0.1551 - learning_rate: 1.0000e-04
# Epoch 51/200
# 915/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9644 - loss: 0.1890
# Epoch 51: val_loss did not improve from 0.14210
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9660 - loss: 0.1823 - val_accuracy: 0.9847 - val_loss: 0.1446 - learning_rate: 1.0000e-04
# Epoch 52/200
# 922/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9684 - loss: 0.1717
# Epoch 52: val_loss did not improve from 0.14210
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9701 - loss: 0.1686 - val_accuracy: 0.9802 - val_loss: 0.1463 - learning_rate: 1.0000e-04
# Epoch 53/200
# 937/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9685 - loss: 0.1733
# Epoch 53: ReduceLROnPlateau reducing learning rate to 1.9999999494757503e-05.
#
# Epoch 53: val_loss did not improve from 0.14210
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9677 - loss: 0.1739 - val_accuracy: 0.9795 - val_loss: 0.1496 - learning_rate: 1.0000e-04
# Epoch 54/200
# 927/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9725 - loss: 0.1591
# Epoch 54: val_loss improved from 0.14210 to 0.13007, saving model to best_densenet169_dull_crop_oversampling.keras
#
# Epoch 54: finished saving model to best_densenet169_dull_crop_oversampling.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9769 - loss: 0.1491 - val_accuracy: 0.9859 - val_loss: 0.1301 - learning_rate: 2.0000e-05
# Epoch 55/200
# 928/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9797 - loss: 0.1409
# Epoch 55: val_loss improved from 0.13007 to 0.12760, saving model to best_densenet169_dull_crop_oversampling.keras
#
# Epoch 55: finished saving model to best_densenet169_dull_crop_oversampling.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9812 - loss: 0.1368 - val_accuracy: 0.9874 - val_loss: 0.1276 - learning_rate: 2.0000e-05
# Epoch 56/200
# 934/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9833 - loss: 0.1320
# Epoch 56: val_loss did not improve from 0.12760
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9840 - loss: 0.1303 - val_accuracy: 0.9870 - val_loss: 0.1278 - learning_rate: 2.0000e-05
# Epoch 57/200
# 921/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9823 - loss: 0.1320
# Epoch 57: val_loss improved from 0.12760 to 0.12589, saving model to best_densenet169_dull_crop_oversampling.keras
#
# Epoch 57: finished saving model to best_densenet169_dull_crop_oversampling.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9832 - loss: 0.1300 - val_accuracy: 0.9867 - val_loss: 0.1259 - learning_rate: 2.0000e-05
# Epoch 58/200
# 934/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9838 - loss: 0.1245
# Epoch 58: val_loss improved from 0.12589 to 0.12489, saving model to best_densenet169_dull_crop_oversampling.keras
#
# Epoch 58: finished saving model to best_densenet169_dull_crop_oversampling.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9846 - loss: 0.1246 - val_accuracy: 0.9870 - val_loss: 0.1249 - learning_rate: 2.0000e-05
# Epoch 59/200
# 922/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9856 - loss: 0.1230
# Epoch 59: val_loss did not improve from 0.12489
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9866 - loss: 0.1211 - val_accuracy: 0.9862 - val_loss: 0.1266 - learning_rate: 2.0000e-05
# Epoch 60/200
# 937/939 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9858 - loss: 0.1216
# Epoch 60: val_loss did not improve from 0.12489
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.9861 - loss: 0.1200 - val_accuracy: 0.9867 - val_loss: 0.1255 - learning_rate: 2.0000e-05
# Epoch 61/200
# 932/939 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9860 - loss: 0.1197
# Epoch 61: val_loss improved from 0.12489 to 0.11865, saving model to best_densenet169_dull_crop_oversampling.keras
#
# Epoch 61: finished saving model to best_densenet169_dull_crop_oversampling.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9870 - loss: 0.1165 - val_accuracy: 0.9880 - val_loss: 0.1186 - learning_rate: 2.0000e-05
# Epoch 62/200
# 929/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9871 - loss: 0.1155
# Epoch 62: val_loss improved from 0.11865 to 0.11798, saving model to best_densenet169_dull_crop_oversampling.keras
#
# Epoch 62: finished saving model to best_densenet169_dull_crop_oversampling.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9873 - loss: 0.1144 - val_accuracy: 0.9884 - val_loss: 0.1180 - learning_rate: 2.0000e-05
# Epoch 63/200
# 933/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9867 - loss: 0.1147
# Epoch 63: val_loss improved from 0.11798 to 0.11762, saving model to best_densenet169_dull_crop_oversampling.keras
#
# Epoch 63: finished saving model to best_densenet169_dull_crop_oversampling.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9880 - loss: 0.1104 - val_accuracy: 0.9884 - val_loss: 0.1176 - learning_rate: 2.0000e-05
# Epoch 64/200
# 935/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9894 - loss: 0.1081
# Epoch 64: val_loss did not improve from 0.11762
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9898 - loss: 0.1077 - val_accuracy: 0.9876 - val_loss: 0.1187 - learning_rate: 2.0000e-05
# Epoch 65/200
# 933/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9879 - loss: 0.1127
# Epoch 65: val_loss did not improve from 0.11762
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9885 - loss: 0.1102 - val_accuracy: 0.9875 - val_loss: 0.1185 - learning_rate: 2.0000e-05
# Epoch 66/200
# 917/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9893 - loss: 0.1081
# Epoch 66: val_loss improved from 0.11762 to 0.11641, saving model to best_densenet169_dull_crop_oversampling.keras
#
# Epoch 66: finished saving model to best_densenet169_dull_crop_oversampling.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9891 - loss: 0.1075 - val_accuracy: 0.9883 - val_loss: 0.1164 - learning_rate: 2.0000e-05
# Epoch 67/200
# 920/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9882 - loss: 0.1092
# Epoch 67: val_loss improved from 0.11641 to 0.11626, saving model to best_densenet169_dull_crop_oversampling.keras
#
# Epoch 67: finished saving model to best_densenet169_dull_crop_oversampling.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9890 - loss: 0.1075 - val_accuracy: 0.9883 - val_loss: 0.1163 - learning_rate: 2.0000e-05
# Epoch 68/200
# 928/939 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9892 - loss: 0.1061
# Epoch 68: val_loss improved from 0.11626 to 0.11552, saving model to best_densenet169_dull_crop_oversampling.keras
#
# Epoch 68: finished saving model to best_densenet169_dull_crop_oversampling.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9890 - loss: 0.1072 - val_accuracy: 0.9887 - val_loss: 0.1155 - learning_rate: 2.0000e-05
# Epoch 69/200
# 922/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9900 - loss: 0.1006
# Epoch 69: val_loss improved from 0.11552 to 0.11505, saving model to best_densenet169_dull_crop_oversampling.keras
#
# Epoch 69: finished saving model to best_densenet169_dull_crop_oversampling.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9900 - loss: 0.1012 - val_accuracy: 0.9888 - val_loss: 0.1151 - learning_rate: 2.0000e-05
# Epoch 70/200
# 919/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9888 - loss: 0.1050
# Epoch 70: val_loss did not improve from 0.11505
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9894 - loss: 0.1042 - val_accuracy: 0.9881 - val_loss: 0.1170 - learning_rate: 2.0000e-05
# Epoch 71/200
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9906 - loss: 0.1026
# Epoch 71: val_loss improved from 0.11505 to 0.11261, saving model to best_densenet169_dull_crop_oversampling.keras
#
# Epoch 71: finished saving model to best_densenet169_dull_crop_oversampling.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9907 - loss: 0.1010 - val_accuracy: 0.9896 - val_loss: 0.1126 - learning_rate: 2.0000e-05
# Epoch 72/200
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9885 - loss: 0.1052
# Epoch 72: val_loss did not improve from 0.11261
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.9897 - loss: 0.1022 - val_accuracy: 0.9877 - val_loss: 0.1145 - learning_rate: 2.0000e-05
# Epoch 73/200
# 930/939 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9896 - loss: 0.1035
# Epoch 73: val_loss did not improve from 0.11261
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9893 - loss: 0.1034 - val_accuracy: 0.9871 - val_loss: 0.1183 - learning_rate: 2.0000e-05
# Epoch 74/200
# 933/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9902 - loss: 0.1016
# Epoch 74: val_loss did not improve from 0.11261
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9903 - loss: 0.1004 - val_accuracy: 0.9885 - val_loss: 0.1143 - learning_rate: 2.0000e-05
# Epoch 75/200
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9896 - loss: 0.1009
# Epoch 75: ReduceLROnPlateau reducing learning rate to 3.999999898951501e-06.
#
# Epoch 75: val_loss did not improve from 0.11261
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9907 - loss: 0.0985 - val_accuracy: 0.9876 - val_loss: 0.1151 - learning_rate: 2.0000e-05
# Epoch 76/200
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9904 - loss: 0.0979
# Epoch 76: val_loss improved from 0.11261 to 0.11215, saving model to best_densenet169_dull_crop_oversampling.keras
#
# Epoch 76: finished saving model to best_densenet169_dull_crop_oversampling.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9912 - loss: 0.0963 - val_accuracy: 0.9887 - val_loss: 0.1121 - learning_rate: 4.0000e-06
# Epoch 77/200
# 929/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9917 - loss: 0.0953
# Epoch 77: val_loss improved from 0.11215 to 0.11169, saving model to best_densenet169_dull_crop_oversampling.keras
#
# Epoch 77: finished saving model to best_densenet169_dull_crop_oversampling.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9918 - loss: 0.0949 - val_accuracy: 0.9887 - val_loss: 0.1117 - learning_rate: 4.0000e-06
# Epoch 78/200
# 916/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9905 - loss: 0.0954
# Epoch 78: val_loss improved from 0.11169 to 0.11042, saving model to best_densenet169_dull_crop_oversampling.keras
#
# Epoch 78: finished saving model to best_densenet169_dull_crop_oversampling.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9914 - loss: 0.0945 - val_accuracy: 0.9895 - val_loss: 0.1104 - learning_rate: 4.0000e-06
# Epoch 79/200
# 927/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9921 - loss: 0.0947
# Epoch 79: val_loss improved from 0.11042 to 0.10973, saving model to best_densenet169_dull_crop_oversampling.keras
#
# Epoch 79: finished saving model to best_densenet169_dull_crop_oversampling.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9923 - loss: 0.0940 - val_accuracy: 0.9896 - val_loss: 0.1097 - learning_rate: 4.0000e-06
# Epoch 80/200
# 917/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9919 - loss: 0.0937
# Epoch 80: val_loss did not improve from 0.10973
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9926 - loss: 0.0921 - val_accuracy: 0.9896 - val_loss: 0.1106 - learning_rate: 4.0000e-06
# Epoch 81/200
# 920/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9914 - loss: 0.0956
# Epoch 81: val_loss did not improve from 0.10973
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9920 - loss: 0.0938 - val_accuracy: 0.9895 - val_loss: 0.1099 - learning_rate: 4.0000e-06
# Epoch 82/200
# 925/939 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9920 - loss: 0.0941
# Epoch 82: val_loss did not improve from 0.10973
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9920 - loss: 0.0937 - val_accuracy: 0.9895 - val_loss: 0.1104 - learning_rate: 4.0000e-06
# Epoch 83/200
# 921/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9923 - loss: 0.0921
# Epoch 83: ReduceLROnPlateau reducing learning rate to 7.999999979801942e-07.
#
# Epoch 83: val_loss did not improve from 0.10973
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9926 - loss: 0.0922 - val_accuracy: 0.9889 - val_loss: 0.1102 - learning_rate: 4.0000e-06
# Epoch 84/200
# 935/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9925 - loss: 0.0936
# Epoch 84: val_loss did not improve from 0.10973
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9924 - loss: 0.0929 - val_accuracy: 0.9897 - val_loss: 0.1098 - learning_rate: 8.0000e-07
# Epoch 85/200
# 925/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9911 - loss: 0.0942
# Epoch 85: val_loss did not improve from 0.10973
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9921 - loss: 0.0926 - val_accuracy: 0.9891 - val_loss: 0.1099 - learning_rate: 8.0000e-07
# Epoch 86/200
# 926/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9928 - loss: 0.0926
# Epoch 86: val_loss did not improve from 0.10973
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9932 - loss: 0.0915 - val_accuracy: 0.9889 - val_loss: 0.1099 - learning_rate: 8.0000e-07
# Epoch 87/200
# 924/939 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9921 - loss: 0.0919
# Epoch 87: ReduceLROnPlateau reducing learning rate to 1.600000018697756e-07.
#
# Epoch 87: val_loss improved from 0.10973 to 0.10968, saving model to best_densenet169_dull_crop_oversampling.keras
#
# Epoch 87: finished saving model to best_densenet169_dull_crop_oversampling.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9922 - loss: 0.0919 - val_accuracy: 0.9895 - val_loss: 0.1097 - learning_rate: 8.0000e-07
# Epoch 88/200
# 932/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9926 - loss: 0.0906
# Epoch 88: val_loss did not improve from 0.10968
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9926 - loss: 0.0908 - val_accuracy: 0.9895 - val_loss: 0.1097 - learning_rate: 1.6000e-07
# Epoch 89/200
# 932/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9914 - loss: 0.0933
# Epoch 89: val_loss did not improve from 0.10968
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9926 - loss: 0.0916 - val_accuracy: 0.9895 - val_loss: 0.1097 - learning_rate: 1.6000e-07
# Epoch 90/200
# 936/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9932 - loss: 0.0916
# Epoch 90: val_loss did not improve from 0.10968
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9932 - loss: 0.0912 - val_accuracy: 0.9895 - val_loss: 0.1098 - learning_rate: 1.6000e-07
# Epoch 91/200
# 915/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9924 - loss: 0.0913
# Epoch 91: ReduceLROnPlateau reducing learning rate to 1e-07.
#
# Epoch 91: val_loss did not improve from 0.10968
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9922 - loss: 0.0918 - val_accuracy: 0.9893 - val_loss: 0.1098 - learning_rate: 1.6000e-07
# Epoch 92/200
# 925/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9934 - loss: 0.0906
# Epoch 92: val_loss did not improve from 0.10968
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9935 - loss: 0.0910 - val_accuracy: 0.9893 - val_loss: 0.1098 - learning_rate: 1.0000e-07
# Epoch 93/200
# 930/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9926 - loss: 0.0913
# Epoch 93: val_loss did not improve from 0.10968
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9935 - loss: 0.0907 - val_accuracy: 0.9893 - val_loss: 0.1098 - learning_rate: 1.0000e-07
# Epoch 94/200
# 922/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9941 - loss: 0.0891
# Epoch 94: val_loss did not improve from 0.10968
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9939 - loss: 0.0905 - val_accuracy: 0.9893 - val_loss: 0.1098 - learning_rate: 1.0000e-07
# Epoch 95/200
# 929/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9938 - loss: 0.0904
# Epoch 95: val_loss did not improve from 0.10968
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9936 - loss: 0.0902 - val_accuracy: 0.9893 - val_loss: 0.1098 - learning_rate: 1.0000e-07
# Epoch 96/200
# 938/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9931 - loss: 0.0915
# Epoch 96: val_loss did not improve from 0.10968
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9934 - loss: 0.0910 - val_accuracy: 0.9893 - val_loss: 0.1098 - learning_rate: 1.0000e-07
# Epoch 97/200
# 916/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9929 - loss: 0.0905
# Epoch 97: val_loss did not improve from 0.10968
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9930 - loss: 0.0910 - val_accuracy: 0.9893 - val_loss: 0.1098 - learning_rate: 1.0000e-07
# Epoch 97: early stopping
# Restoring model weights from the end of the best epoch: 87.

# %%
plt.figure(figsize=(8, 5))
plt.plot(history.history["accuracy"], label="Treino")
plt.plot(history.history["val_accuracy"], label="Validação")
plt.title("Acurácia durante o treinamento")
plt.xlabel("Época")
plt.ylabel("Acurácia")
plt.legend()
plt.grid(True, alpha=0.3)
plt.savefig("acuracia_densenet169_dull_crop_oversampling.png", dpi=300, bbox_inches="tight")
plt.show()

plt.figure(figsize=(8, 5))
plt.plot(history.history["loss"], label="Treino")
plt.plot(history.history["val_loss"], label="Validação")
plt.title("Perda durante o treinamento")
plt.xlabel("Época")
plt.ylabel("Loss")
plt.legend()
plt.grid(True, alpha=0.3)
plt.savefig("loss_densenet169_dull_crop_oversampling.png", dpi=300, bbox_inches="tight")
plt.show()

# %%
best_classifier = keras.models.load_model(BEST_MODEL_PATH)

pred_probs = best_classifier.predict(X_test_features, verbose=0)
y_pred = np.argmax(pred_probs, axis=1)

print("Relatório de Classificação:")
print(classification_report(
    y_test,
    y_pred,
    target_names=classes,
    digits=4,
    zero_division=0
))

acc = accuracy_score(y_test, y_pred)

macro_precision = precision_score(y_test, y_pred, average="macro", zero_division=0)
macro_recall = recall_score(y_test, y_pred, average="macro", zero_division=0)
macro_f1 = f1_score(y_test, y_pred, average="macro", zero_division=0)

weighted_precision = precision_score(y_test, y_pred, average="weighted", zero_division=0)
weighted_recall = recall_score(y_test, y_pred, average="weighted", zero_division=0)
weighted_f1 = f1_score(y_test, y_pred, average="weighted", zero_division=0)

print("\nMÉTRICAS GERAIS DO MODELO")
print(f"Accuracy: {acc:.4f}")

print("\nMacro Average:")
print(f"  Precision: {macro_precision:.4f}")
print(f"  Recall: {macro_recall:.4f}")
print(f"  F1-Score: {macro_f1:.4f}")

print("\nWeighted Average:")
print(f"  Precision: {weighted_precision:.4f}")
print(f"  Recall: {weighted_recall:.4f}")
print(f"  F1-Score: {weighted_f1:.4f}")
# Out:
# Relatório de Classificação:
#               precision    recall  f1-score   support
#
#          MEL     0.5404    0.5695    0.5546       223
#           NV     0.9151    0.9083    0.9117      1341
#          BCC     0.7094    0.8058    0.7545       103
#        AKIEC     0.6182    0.5231    0.5667        65
#          BKL     0.6872    0.6591    0.6729       220
#           DF     0.7083    0.7391    0.7234        23
#         VASC     0.8000    0.8571    0.8276        28
#
#     accuracy                         0.8228      2003
#    macro avg     0.7112    0.7232    0.7159      2003
# weighted avg     0.8242    0.8228    0.8231      2003
#
#
# MÉTRICAS GERAIS DO MODELO
# Accuracy: 0.8228
#
# Macro Average:
#   Precision: 0.7112
#   Recall: 0.7232
#   F1-Score: 0.7159
#
# Weighted Average:
#   Precision: 0.8242
#   Recall: 0.8228
#   F1-Score: 0.8231

# %%
cm = confusion_matrix(y_test, y_pred, labels=list(range(len(classes))))
cm_percent = cm.astype("float") / cm.sum(axis=1, keepdims=True) * 100
cm_percent = np.nan_to_num(cm_percent)

plt.figure(figsize=(8, 7))
im = plt.imshow(cm_percent, interpolation="nearest", cmap="Blues", vmin=0, vmax=100)
plt.title("Matriz de Confusão (%) - DenseNet169 + Dull Razor + Crop + Oversampling")
plt.colorbar(im, label="%")

tick_marks = np.arange(len(classes))
plt.xticks(tick_marks, classes, rotation=45)
plt.yticks(tick_marks, classes)

for i in range(cm_percent.shape[0]):
    for j in range(cm_percent.shape[1]):
        color = "white" if cm_percent[i, j] > 50 else "black"
        plt.text(
            j,
            i,
            f"{cm_percent[i, j]:.1f}",
            ha="center",
            va="center",
            color=color,
            fontsize=8
        )

plt.ylabel("Classe Real")
plt.xlabel("Classe Predita")
plt.tight_layout()
plt.savefig("matriz_confusao_percent_densenet169_dull_crop_oversampling.png", dpi=300, bbox_inches="tight")
plt.show()

# %%
test_eval_df = test_df.copy().reset_index(drop=True)
test_eval_df["y_true"] = y_test
test_eval_df["y_pred"] = y_pred
test_eval_df["correct"] = test_eval_df["y_true"] == test_eval_df["y_pred"]

correct_samples = test_eval_df[test_eval_df["correct"]].head(4)
incorrect_samples = test_eval_df[~test_eval_df["correct"]].head(4)

samples_to_plot = pd.concat([correct_samples, incorrect_samples], axis=0).reset_index(drop=True)

plt.figure(figsize=(12, 6))

for i, row in samples_to_plot.iterrows():
    image = preprocess_image_path(row["image_path"], row["mask_path"])
    image = np.clip(image, 0, 255).astype("uint8")

    plt.subplot(2, 4, i + 1)
    plt.imshow(image)

    true_label = class_name[int(row["y_true"])]
    pred_label = class_name[int(row["y_pred"])]

    plt.title(f"{true_label} → {pred_label}", fontsize=10)
    plt.axis("off")

plt.tight_layout()
plt.savefig("exemplos_classificacao_densenet169_dull_crop_oversampling.png", dpi=300, bbox_inches="tight")
plt.show()

# %%
feature_extractor.save(FEATURE_EXTRACTOR_PATH)
best_classifier.save(FINAL_MODEL_PATH)

print("Extratora DenseNet169 salva em:", FEATURE_EXTRACTOR_PATH)
print("Classificador final salvo em:", FINAL_MODEL_PATH)
print("Melhor checkpoint salvo em:", BEST_MODEL_PATH)
# Out:
# Extratora DenseNet169 salva em: densenet169_dull_crop_feature_extractor.keras
# Classificador final salvo em: densenet169_dull_crop_oversampling_final.keras
# Melhor checkpoint salvo em: best_densenet169_dull_crop_oversampling.keras
