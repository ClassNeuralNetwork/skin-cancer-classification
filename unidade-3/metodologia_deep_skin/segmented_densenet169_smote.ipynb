# %%
import os
os.environ["KERAS_BACKEND"] = "tensorflow"

import random
from pathlib import Path
from collections import Counter

import cv2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import tensorflow as tf
import keras
from keras import layers, models, regularizers

from tensorflow.keras.applications import DenseNet169
from tensorflow.keras.applications.densenet import preprocess_input

from sklearn.model_selection import train_test_split
from sklearn.metrics import (
    classification_report,
    confusion_matrix,
    accuracy_score,
    precision_score,
    recall_score,
    f1_score
)

from imblearn.over_sampling import SMOTE

# %%
SEED = 42
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)

DATA_DIR = Path("../data")
IMAGES_DIR = DATA_DIR / "images"
MASKS_DIR = DATA_DIR / "masks"
CSV_PATH = DATA_DIR / "GroundTruth.csv"

IMG_SIZE = (256, 256)
BATCH_SIZE = 32
EPOCHS = 200
LEARNING_RATE = 0.0001
TEST_SIZE = 0.20
VAL_SIZE = 0.20

USE_DULL_RAZOR = True
USE_MASK_SEGMENTATION = True

USE_MASK_CROP = False
CROP_MARGIN = 20

classes = ["MEL", "NV", "BCC", "AKIEC", "BKL", "DF", "VASC"]
class_code = {label: idx for idx, label in enumerate(classes)}
class_name = {idx: label for label, idx in class_code.items()}

print("IMG_SIZE:", IMG_SIZE)
print("BATCH_SIZE:", BATCH_SIZE)
print("EPOCHS:", EPOCHS)
print("LEARNING_RATE:", LEARNING_RATE)
print("USE_DULL_RAZOR:", USE_DULL_RAZOR)
print("USE_MASK_SEGMENTATION:", USE_MASK_SEGMENTATION)
print("USE_MASK_CROP:", USE_MASK_CROP)
print(class_code)
# Out:
# IMG_SIZE: (256, 256)
# BATCH_SIZE: 32
# EPOCHS: 200
# LEARNING_RATE: 0.0001
# USE_DULL_RAZOR: True
# USE_MASK_SEGMENTATION: True
# USE_MASK_CROP: False
# {'MEL': 0, 'NV': 1, 'BCC': 2, 'AKIEC': 3, 'BKL': 4, 'DF': 5, 'VASC': 6}

# %%
def find_file(directory, base_name, extensions):
    for extension in extensions:
        path = directory / f"{base_name}{extension}"
        if path.exists():
            return str(path)
    return None


def find_mask_path(image_id, masks_dir):
    if not masks_dir.exists():
        return None

    candidates = [
        masks_dir / f"{image_id}_segmentation.png",
        masks_dir / f"{image_id}_segmentation.jpg",
        masks_dir / f"{image_id}_mask.png",
        masks_dir / f"{image_id}_mask.jpg",
        masks_dir / f"{image_id}.png",
        masks_dir / f"{image_id}.jpg",
    ]

    for path in candidates:
        if path.exists():
            return str(path)

    matches = list(masks_dir.glob(f"{image_id}*"))
    if len(matches) > 0:
        return str(matches[0])

    return None


metadata = pd.read_csv(CSV_PATH)

rows = []
for _, row in metadata.iterrows():
    image_id = str(row["image"])
    image_path = find_file(IMAGES_DIR, image_id, [".jpg", ".jpeg", ".png"])
    mask_path = find_mask_path(image_id, MASKS_DIR)

    if image_path is None or mask_path is None:
        continue

    label_name = row[classes].idxmax()
    label = class_code[label_name]

    rows.append({
        "image": image_id,
        "image_path": image_path,
        "mask_path": mask_path,
        "class_name": label_name,
        "label": label
    })

df = pd.DataFrame(rows)

print("Total de pares imagem/máscara localizados:", len(df))
display(df.head())

print("\nDistribuição original:")
print(df["class_name"].value_counts().reindex(classes))

print("\nMáscaras encontradas:", df["mask_path"].notna().sum())
# Out:
# Total de pares imagem/máscara localizados: 10015
#           image                       image_path  \
# 0  ISIC_0024306  ../data/images/ISIC_0024306.jpg
# 1  ISIC_0024307  ../data/images/ISIC_0024307.jpg
# 2  ISIC_0024308  ../data/images/ISIC_0024308.jpg
# 3  ISIC_0024309  ../data/images/ISIC_0024309.jpg
# 4  ISIC_0024310  ../data/images/ISIC_0024310.jpg
#
#                                      mask_path class_name  label
# 0  ../data/masks/ISIC_0024306_segmentation.png         NV      1
# 1  ../data/masks/ISIC_0024307_segmentation.png         NV      1
# 2  ../data/masks/ISIC_0024308_segmentation.png         NV      1
# 3  ../data/masks/ISIC_0024309_segmentation.png         NV      1
# 4  ../data/masks/ISIC_0024310_segmentation.png        MEL      0
# Distribuição original:
# class_name
# MEL      1113
# NV       6705
# BCC       514
# AKIEC     327
# BKL      1099
# DF        115
# VASC      142
# Name: count, dtype: int64
#
# Máscaras encontradas: 10015

# %%
def read_rgb_image(path):
    if isinstance(path, bytes):
        path = path.decode("utf-8")

    image_bgr = cv2.imread(str(path), cv2.IMREAD_COLOR)

    if image_bgr is None:
        raise ValueError(f"Não foi possível carregar a imagem: {path}")

    return cv2.cvtColor(image_bgr, cv2.COLOR_BGR2RGB)


def read_mask(mask_path, target_shape=None):
    if isinstance(mask_path, bytes):
        mask_path = mask_path.decode("utf-8")

    mask = cv2.imread(str(mask_path), cv2.IMREAD_GRAYSCALE)

    if mask is None:
        raise ValueError(f"Não foi possível carregar a máscara: {mask_path}")

    if target_shape is not None:
        height, width = target_shape[:2]
        mask = cv2.resize(mask, (width, height))

    binary_mask = (mask > 127).astype(np.uint8)

    return binary_mask


def dull_razor_remove_hair(image_rgb, kernel_size=(9, 9), threshold_value=10, inpaint_radius=6):
    image_rgb = image_rgb.astype(np.uint8)

    gray = cv2.cvtColor(image_rgb, cv2.COLOR_RGB2GRAY)

    kernel = cv2.getStructuringElement(cv2.MORPH_RECT, kernel_size)
    blackhat = cv2.morphologyEx(gray, cv2.MORPH_BLACKHAT, kernel)

    blackhat_blur = cv2.GaussianBlur(blackhat, (3, 3), 0)

    _, mask = cv2.threshold(
        blackhat_blur,
        threshold_value,
        255,
        cv2.THRESH_BINARY
    )

    image_bgr = cv2.cvtColor(image_rgb, cv2.COLOR_RGB2BGR)

    clean_bgr = cv2.inpaint(
        image_bgr,
        mask,
        inpaint_radius,
        cv2.INPAINT_TELEA
    )

    clean_rgb = cv2.cvtColor(clean_bgr, cv2.COLOR_BGR2RGB)

    return clean_rgb


def apply_mask_segmentation(image_rgb, mask_path):
    binary_mask = read_mask(mask_path, target_shape=image_rgb.shape)

    segmented = image_rgb * np.expand_dims(binary_mask, axis=-1)

    # Proteção contra máscara ruim: evita imagem totalmente preta.
    if np.mean(segmented) < 5:
        return image_rgb

    return segmented


def crop_lesion_with_margin(image_rgb, mask_path, margin=CROP_MARGIN):
    binary_mask = read_mask(mask_path, target_shape=image_rgb.shape)

    ys, xs = np.where(binary_mask > 0)

    if len(xs) == 0 or len(ys) == 0:
        return image_rgb

    height, width = image_rgb.shape[:2]

    x_min = max(xs.min() - margin, 0)
    x_max = min(xs.max() + margin, width - 1)
    y_min = max(ys.min() - margin, 0)
    y_max = min(ys.max() + margin, height - 1)

    cropped = image_rgb[y_min:y_max + 1, x_min:x_max + 1]

    if cropped.size == 0:
        return image_rgb

    return cropped


def preprocess_segmented_image(image_path, mask_path):
    image_rgb = read_rgb_image(image_path)

    if USE_DULL_RAZOR:
        image_rgb = dull_razor_remove_hair(image_rgb)

    if USE_MASK_SEGMENTATION:
        if USE_MASK_CROP:
            image_rgb = crop_lesion_with_margin(image_rgb, mask_path)
        else:
            image_rgb = apply_mask_segmentation(image_rgb, mask_path)

    image_rgb = cv2.resize(image_rgb, IMG_SIZE)

    return image_rgb.astype("float32")

# %%
sample_row = df.sample(1, random_state=SEED).iloc[0]

original = read_rgb_image(sample_row["image_path"])
dull = dull_razor_remove_hair(original) if USE_DULL_RAZOR else original
segmented = apply_mask_segmentation(dull, sample_row["mask_path"])
final_image = preprocess_segmented_image(sample_row["image_path"], sample_row["mask_path"])
final_image = np.clip(final_image, 0, 255).astype("uint8")

plt.figure(figsize=(14, 4))

plt.subplot(1, 4, 1)
plt.imshow(original)
plt.title("Original")
plt.axis("off")

plt.subplot(1, 4, 2)
plt.imshow(dull)
plt.title("Dull Razor")
plt.axis("off")

plt.subplot(1, 4, 3)
plt.imshow(np.clip(segmented, 0, 255).astype("uint8"))
plt.title("Segmentada")
plt.axis("off")

plt.subplot(1, 4, 4)
plt.imshow(final_image)
plt.title("Final 256x256")
plt.axis("off")

plt.tight_layout()
plt.savefig("pipeline_segmentado_dull_razor.png", dpi=300, bbox_inches="tight")
plt.show()

# %%
train_df, test_df = train_test_split(
    df,
    test_size=TEST_SIZE,
    random_state=SEED,
    stratify=df["label"]
)

print("Treino original:", len(train_df))
print("Teste final:", len(test_df))

print("\nDistribuição treino original:")
print(train_df["class_name"].value_counts().reindex(classes))

print("\nDistribuição teste final:")
print(test_df["class_name"].value_counts().reindex(classes))
# Out:
# Treino original: 8012
# Teste final: 2003
#
# Distribuição treino original:
# class_name
# MEL       890
# NV       5364
# BCC       411
# AKIEC     262
# BKL       879
# DF         92
# VASC      114
# Name: count, dtype: int64
#
# Distribuição teste final:
# class_name
# MEL       223
# NV       1341
# BCC       103
# AKIEC      65
# BKL       220
# DF         23
# VASC       28
# Name: count, dtype: int64

# %%
def load_image_for_features_py(image_path, mask_path, label):
    if isinstance(image_path, bytes):
        image_path = image_path.decode("utf-8")

    if isinstance(mask_path, bytes):
        mask_path = mask_path.decode("utf-8")

    image = preprocess_segmented_image(image_path, mask_path)

    return image.astype("float32"), np.int32(label)


def tf_load_image_for_features(image_path, mask_path, label):
    image, label = tf.numpy_function(
        load_image_for_features_py,
        [image_path, mask_path, label],
        [tf.float32, tf.int32]
    )

    image.set_shape((IMG_SIZE[0], IMG_SIZE[1], 3))
    label.set_shape(())

    return image, label


def build_image_dataset(dataframe, batch_size=BATCH_SIZE, shuffle=False):
    ds = tf.data.Dataset.from_tensor_slices((
        dataframe["image_path"].astype(str).values,
        dataframe["mask_path"].astype(str).values,
        dataframe["label"].values.astype("int32")
    ))

    if shuffle:
        ds = ds.shuffle(buffer_size=len(dataframe), seed=SEED)

    ds = ds.map(tf_load_image_for_features, num_parallel_calls=tf.data.AUTOTUNE)
    ds = ds.batch(batch_size)
    ds = ds.prefetch(tf.data.AUTOTUNE)

    return ds


train_image_ds = build_image_dataset(train_df, shuffle=False)
test_image_ds = build_image_dataset(test_df, shuffle=False)

print(train_image_ds)
print(test_image_ds)
# Out:
# <_PrefetchDataset element_spec=(TensorSpec(shape=(None, 256, 256, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>
# <_PrefetchDataset element_spec=(TensorSpec(shape=(None, 256, 256, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
BEST_MODEL_PATH = "best_segmented_densenet169_dull_smote.keras"
FINAL_MODEL_PATH = "segmented_densenet169_dull_smote_final.keras"
FEATURE_EXTRACTOR_PATH = "segmented_densenet169_feature_extractor.keras"


def build_feature_extractor(input_shape=(256, 256, 3)):
    inputs = layers.Input(shape=input_shape)

    x = preprocess_input(inputs)

    base_model = DenseNet169(
        weights="imagenet",
        include_top=False,
        input_shape=input_shape
    )

    base_model.trainable = False

    x = base_model(x, training=False)
    x = layers.GlobalAveragePooling2D()(x)

    feature_extractor = models.Model(
        inputs=inputs,
        outputs=x,
        name="segmented_densenet169_feature_extractor"
    )

    return feature_extractor


feature_extractor = build_feature_extractor(
    input_shape=(IMG_SIZE[0], IMG_SIZE[1], 3)
)

feature_extractor.summary()
# Out:
# Model: "segmented_densenet169_feature_extractor"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 256, 256, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ true_divide (TrueDivide)        │ (None, 256, 256, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ add (Add)                       │ (None, 256, 256, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ true_divide_1 (TrueDivide)      │ (None, 256, 256, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ densenet169 (Functional)        │ (None, 8, 8, 1664)     │    12,642,880 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 1664)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 12,642,880 (48.23 MB)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 12,642,880 (48.23 MB)

# %%
def extract_features(dataset, feature_extractor):
    features_list = []
    labels_list = []

    for images, labels in dataset:
        features = feature_extractor.predict(images, verbose=0)
        features_list.append(features)
        labels_list.append(labels.numpy())

    X = np.concatenate(features_list, axis=0)
    y = np.concatenate(labels_list, axis=0)

    return X.astype("float32"), y.astype("int32")


X_train_features, y_train = extract_features(train_image_ds, feature_extractor)
X_test_features, y_test = extract_features(test_image_ds, feature_extractor)

print("X_train_features:", X_train_features.shape)
print("y_train:", y_train.shape)
print("X_test_features:", X_test_features.shape)
print("y_test:", y_test.shape)

print("\nDistribuição treino antes do SMOTE:")
print(Counter(y_train))
# Out:
# X_train_features: (8012, 1664)
# y_train: (8012,)
# X_test_features: (2003, 1664)
# y_test: (2003,)
#
# Distribuição treino antes do SMOTE:
# Counter({np.int32(1): 5364, np.int32(0): 890, np.int32(4): 879, np.int32(2): 411, np.int32(3): 262, np.int32(6): 114, np.int32(5): 92})

# %%
min_class_count = min(Counter(y_train).values())
k_neighbors = min(5, min_class_count - 1)

print("Menor classe no treino:", min_class_count)
print("k_neighbors usado no SMOTE:", k_neighbors)

smote = SMOTE(
    random_state=SEED,
    k_neighbors=k_neighbors
)

X_train_smote, y_train_smote = smote.fit_resample(
    X_train_features,
    y_train
)

print("X_train_smote:", X_train_smote.shape)
print("y_train_smote:", y_train_smote.shape)

print("\nDistribuição treino após SMOTE:")
print(Counter(y_train_smote))
# Out:
# Menor classe no treino: 92
# k_neighbors usado no SMOTE: 5
# X_train_smote: (37548, 1664)
# y_train_smote: (37548,)
#
# Distribuição treino após SMOTE:
# Counter({np.int32(1): 5364, np.int32(0): 5364, np.int32(4): 5364, np.int32(2): 5364, np.int32(5): 5364, np.int32(3): 5364, np.int32(6): 5364})

# %%
X_fit, X_val, y_fit, y_val = train_test_split(
    X_train_smote,
    y_train_smote,
    test_size=VAL_SIZE,
    random_state=SEED,
    stratify=y_train_smote
)

print("Treino para fit:", X_fit.shape)
print("Validação:", X_val.shape)
print("Teste final:", X_test_features.shape)

print("\nDistribuição fit:")
print(Counter(y_fit))

print("\nDistribuição validação:")
print(Counter(y_val))
# Out:
# Treino para fit: (30038, 1664)
# Validação: (7510, 1664)
# Teste final: (2003, 1664)
#
# Distribuição fit:
# Counter({np.int32(0): 4292, np.int32(4): 4291, np.int32(5): 4291, np.int32(6): 4291, np.int32(2): 4291, np.int32(3): 4291, np.int32(1): 4291})
#
# Distribuição validação:
# Counter({np.int32(2): 1073, np.int32(3): 1073, np.int32(6): 1073, np.int32(4): 1073, np.int32(1): 1073, np.int32(5): 1073, np.int32(0): 1072})

# %%
def build_classifier_head(input_dim, num_classes=len(classes)):
    inputs = layers.Input(shape=(input_dim,))

    x = layers.Dense(
        256,
        activation="relu",
        kernel_regularizer=regularizers.l2(0.001)
    )(inputs)

    x = layers.BatchNormalization()(x)
    x = layers.Dropout(0.5)(x)

    x = layers.Dense(
        128,
        activation="relu",
        kernel_regularizer=regularizers.l2(0.001)
    )(x)

    x = layers.Dropout(0.3)(x)

    outputs = layers.Dense(num_classes, activation="softmax")(x)

    model = models.Model(
        inputs=inputs,
        outputs=outputs,
        name="segmented_densenet169_dull_smote_classifier"
    )

    return model


classifier = build_classifier_head(
    input_dim=X_train_smote.shape[1],
    num_classes=len(classes)
)

classifier.compile(
    optimizer=keras.optimizers.Adam(learning_rate=LEARNING_RATE),
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)

classifier.summary()
# Out:
# Model: "segmented_densenet169_dull_smote_classifier"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_2 (InputLayer)      │ (None, 1664)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │       426,240 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 7)              │           903 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 461,063 (1.76 MB)
#  Trainable params: 460,551 (1.76 MB)
#  Non-trainable params: 512 (2.00 KB)

# %%
callbacks = [
    keras.callbacks.EarlyStopping(
        monitor="val_loss",
        patience=10,
        restore_best_weights=True,
        verbose=1
    ),
    keras.callbacks.ReduceLROnPlateau(
        monitor="val_loss",
        factor=0.2,
        patience=4,
        min_lr=1e-7,
        verbose=1
    ),
    keras.callbacks.ModelCheckpoint(
        BEST_MODEL_PATH,
        monitor="val_loss",
        save_best_only=True,
        verbose=1
    )
]

history = classifier.fit(
    X_fit,
    y_fit,
    validation_data=(X_val, y_val),
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    callbacks=callbacks
)
# Out:
# Epoch 1/200
# 934/939 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4075 - loss: 2.2142
# Epoch 1: val_loss improved from None to 1.09787, saving model to best_segmented_densenet169_dull_smote.keras
#
# Epoch 1: finished saving model to best_segmented_densenet169_dull_smote.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.5171 - loss: 1.7887 - val_accuracy: 0.7442 - val_loss: 1.0979 - learning_rate: 1.0000e-04
# Epoch 2/200
# 914/939 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6587 - loss: 1.2946
# Epoch 2: val_loss improved from 1.09787 to 0.89057, saving model to best_segmented_densenet169_dull_smote.keras
#
# Epoch 2: finished saving model to best_segmented_densenet169_dull_smote.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6806 - loss: 1.2287 - val_accuracy: 0.8099 - val_loss: 0.8906 - learning_rate: 1.0000e-04
# Epoch 3/200
# 922/939 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7281 - loss: 1.0696
# Epoch 3: val_loss improved from 0.89057 to 0.79396, saving model to best_segmented_densenet169_dull_smote.keras
#
# Epoch 3: finished saving model to best_segmented_densenet169_dull_smote.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7434 - loss: 1.0348 - val_accuracy: 0.8401 - val_loss: 0.7940 - learning_rate: 1.0000e-04
# Epoch 4/200
# 906/939 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7675 - loss: 0.9477
# Epoch 4: val_loss improved from 0.79396 to 0.68247, saving model to best_segmented_densenet169_dull_smote.keras
#
# Epoch 4: finished saving model to best_segmented_densenet169_dull_smote.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7796 - loss: 0.9141 - val_accuracy: 0.8687 - val_loss: 0.6825 - learning_rate: 1.0000e-04
# Epoch 5/200
# 911/939 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8039 - loss: 0.8437
# Epoch 5: val_loss improved from 0.68247 to 0.64106, saving model to best_segmented_densenet169_dull_smote.keras
#
# Epoch 5: finished saving model to best_segmented_densenet169_dull_smote.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8104 - loss: 0.8144 - val_accuracy: 0.8762 - val_loss: 0.6411 - learning_rate: 1.0000e-04
# Epoch 6/200
# 934/939 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8215 - loss: 0.7660
# Epoch 6: val_loss improved from 0.64106 to 0.57603, saving model to best_segmented_densenet169_dull_smote.keras
#
# Epoch 6: finished saving model to best_segmented_densenet169_dull_smote.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8284 - loss: 0.7465 - val_accuracy: 0.8920 - val_loss: 0.5760 - learning_rate: 1.0000e-04
# Epoch 7/200
# 906/939 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8453 - loss: 0.6956
# Epoch 7: val_loss improved from 0.57603 to 0.56044, saving model to best_segmented_densenet169_dull_smote.keras
#
# Epoch 7: finished saving model to best_segmented_densenet169_dull_smote.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8483 - loss: 0.6805 - val_accuracy: 0.8969 - val_loss: 0.5604 - learning_rate: 1.0000e-04
# Epoch 8/200
# 937/939 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8504 - loss: 0.6588
# Epoch 8: val_loss improved from 0.56044 to 0.51402, saving model to best_segmented_densenet169_dull_smote.keras
#
# Epoch 8: finished saving model to best_segmented_densenet169_dull_smote.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8575 - loss: 0.6393 - val_accuracy: 0.9073 - val_loss: 0.5140 - learning_rate: 1.0000e-04
# Epoch 9/200
# 915/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8678 - loss: 0.6059
# Epoch 9: val_loss improved from 0.51402 to 0.50042, saving model to best_segmented_densenet169_dull_smote.keras
#
# Epoch 9: finished saving model to best_segmented_densenet169_dull_smote.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8702 - loss: 0.5921 - val_accuracy: 0.9064 - val_loss: 0.5004 - learning_rate: 1.0000e-04
# Epoch 10/200
# 905/939 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8732 - loss: 0.5707
# Epoch 10: val_loss improved from 0.50042 to 0.46826, saving model to best_segmented_densenet169_dull_smote.keras
#
# Epoch 10: finished saving model to best_segmented_densenet169_dull_smote.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8771 - loss: 0.5610 - val_accuracy: 0.9176 - val_loss: 0.4683 - learning_rate: 1.0000e-04
# Epoch 11/200
# 909/939 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8801 - loss: 0.5466
# Epoch 11: val_loss improved from 0.46826 to 0.44035, saving model to best_segmented_densenet169_dull_smote.keras
#
# Epoch 11: finished saving model to best_segmented_densenet169_dull_smote.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8814 - loss: 0.5370 - val_accuracy: 0.9216 - val_loss: 0.4404 - learning_rate: 1.0000e-04
# Epoch 12/200
# 938/939 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8881 - loss: 0.5195
# Epoch 12: val_loss improved from 0.44035 to 0.40522, saving model to best_segmented_densenet169_dull_smote.keras
#
# Epoch 12: finished saving model to best_segmented_densenet169_dull_smote.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8904 - loss: 0.5073 - val_accuracy: 0.9332 - val_loss: 0.4052 - learning_rate: 1.0000e-04
# Epoch 13/200
# 938/939 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8876 - loss: 0.4979
# Epoch 13: val_loss improved from 0.40522 to 0.40507, saving model to best_segmented_densenet169_dull_smote.keras
#
# Epoch 13: finished saving model to best_segmented_densenet169_dull_smote.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8924 - loss: 0.4847 - val_accuracy: 0.9242 - val_loss: 0.4051 - learning_rate: 1.0000e-04
# Epoch 14/200
# 907/939 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8986 - loss: 0.4707
# Epoch 14: val_loss improved from 0.40507 to 0.37804, saving model to best_segmented_densenet169_dull_smote.keras
#
# Epoch 14: finished saving model to best_segmented_densenet169_dull_smote.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9000 - loss: 0.4650 - val_accuracy: 0.9368 - val_loss: 0.3780 - learning_rate: 1.0000e-04
# Epoch 15/200
# 908/939 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9005 - loss: 0.4518
# Epoch 15: val_loss improved from 0.37804 to 0.36642, saving model to best_segmented_densenet169_dull_smote.keras
#
# Epoch 15: finished saving model to best_segmented_densenet169_dull_smote.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9029 - loss: 0.4460 - val_accuracy: 0.9374 - val_loss: 0.3664 - learning_rate: 1.0000e-04
# Epoch 16/200
# 938/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9048 - loss: 0.4362
# Epoch 16: val_loss improved from 0.36642 to 0.36605, saving model to best_segmented_densenet169_dull_smote.keras
#
# Epoch 16: finished saving model to best_segmented_densenet169_dull_smote.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9059 - loss: 0.4289 - val_accuracy: 0.9342 - val_loss: 0.3660 - learning_rate: 1.0000e-04
# Epoch 17/200
# 937/939 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9056 - loss: 0.4315
# Epoch 17: val_loss improved from 0.36605 to 0.34535, saving model to best_segmented_densenet169_dull_smote.keras
#
# Epoch 17: finished saving model to best_segmented_densenet169_dull_smote.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9108 - loss: 0.4208 - val_accuracy: 0.9418 - val_loss: 0.3453 - learning_rate: 1.0000e-04
# Epoch 18/200
# 910/939 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9064 - loss: 0.4181
# Epoch 18: val_loss did not improve from 0.34535
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9094 - loss: 0.4082 - val_accuracy: 0.9364 - val_loss: 0.3468 - learning_rate: 1.0000e-04
# Epoch 19/200
# 926/939 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9126 - loss: 0.3979
# Epoch 19: val_loss improved from 0.34535 to 0.33251, saving model to best_segmented_densenet169_dull_smote.keras
#
# Epoch 19: finished saving model to best_segmented_densenet169_dull_smote.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9157 - loss: 0.3920 - val_accuracy: 0.9435 - val_loss: 0.3325 - learning_rate: 1.0000e-04
# Epoch 20/200
# 936/939 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9188 - loss: 0.3863
# Epoch 20: val_loss improved from 0.33251 to 0.32085, saving model to best_segmented_densenet169_dull_smote.keras
#
# Epoch 20: finished saving model to best_segmented_densenet169_dull_smote.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9173 - loss: 0.3831 - val_accuracy: 0.9443 - val_loss: 0.3208 - learning_rate: 1.0000e-04
# Epoch 21/200
# 923/939 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9175 - loss: 0.3751
# Epoch 21: val_loss improved from 0.32085 to 0.30013, saving model to best_segmented_densenet169_dull_smote.keras
#
# Epoch 21: finished saving model to best_segmented_densenet169_dull_smote.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9223 - loss: 0.3646 - val_accuracy: 0.9503 - val_loss: 0.3001 - learning_rate: 1.0000e-04
# Epoch 22/200
# 932/939 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9206 - loss: 0.3602
# Epoch 22: val_loss did not improve from 0.30013
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9220 - loss: 0.3558 - val_accuracy: 0.9467 - val_loss: 0.3008 - learning_rate: 1.0000e-04
# Epoch 23/200
# 937/939 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9267 - loss: 0.3436
# Epoch 23: val_loss improved from 0.30013 to 0.29665, saving model to best_segmented_densenet169_dull_smote.keras
#
# Epoch 23: finished saving model to best_segmented_densenet169_dull_smote.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9279 - loss: 0.3411 - val_accuracy: 0.9458 - val_loss: 0.2966 - learning_rate: 1.0000e-04
# Epoch 24/200
# 935/939 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9270 - loss: 0.3435
# Epoch 24: val_loss did not improve from 0.29665
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9288 - loss: 0.3344 - val_accuracy: 0.9350 - val_loss: 0.3163 - learning_rate: 1.0000e-04
# Epoch 25/200
# 937/939 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9292 - loss: 0.3277
# Epoch 25: val_loss improved from 0.29665 to 0.27588, saving model to best_segmented_densenet169_dull_smote.keras
#
# Epoch 25: finished saving model to best_segmented_densenet169_dull_smote.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9303 - loss: 0.3234 - val_accuracy: 0.9541 - val_loss: 0.2759 - learning_rate: 1.0000e-04
# Epoch 26/200
# 920/939 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9290 - loss: 0.3249
# Epoch 26: val_loss did not improve from 0.27588
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9291 - loss: 0.3241 - val_accuracy: 0.9489 - val_loss: 0.2803 - learning_rate: 1.0000e-04
# Epoch 27/200
# 929/939 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9279 - loss: 0.3212
# Epoch 27: val_loss improved from 0.27588 to 0.26970, saving model to best_segmented_densenet169_dull_smote.keras
#
# Epoch 27: finished saving model to best_segmented_densenet169_dull_smote.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9298 - loss: 0.3143 - val_accuracy: 0.9517 - val_loss: 0.2697 - learning_rate: 1.0000e-04
# Epoch 28/200
# 929/939 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9299 - loss: 0.3219
# Epoch 28: val_loss improved from 0.26970 to 0.25960, saving model to best_segmented_densenet169_dull_smote.keras
#
# Epoch 28: finished saving model to best_segmented_densenet169_dull_smote.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9312 - loss: 0.3126 - val_accuracy: 0.9546 - val_loss: 0.2596 - learning_rate: 1.0000e-04
# Epoch 29/200
# 924/939 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9299 - loss: 0.3074
# Epoch 29: val_loss did not improve from 0.25960
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9321 - loss: 0.3053 - val_accuracy: 0.9518 - val_loss: 0.2636 - learning_rate: 1.0000e-04
# Epoch 30/200
# 912/939 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9307 - loss: 0.3071
# Epoch 30: val_loss improved from 0.25960 to 0.24038, saving model to best_segmented_densenet169_dull_smote.keras
#
# Epoch 30: finished saving model to best_segmented_densenet169_dull_smote.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9337 - loss: 0.2992 - val_accuracy: 0.9582 - val_loss: 0.2404 - learning_rate: 1.0000e-04
# Epoch 31/200
# 922/939 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9335 - loss: 0.2981
# Epoch 31: val_loss did not improve from 0.24038
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9348 - loss: 0.2931 - val_accuracy: 0.9575 - val_loss: 0.2453 - learning_rate: 1.0000e-04
# Epoch 32/200
# 916/939 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9328 - loss: 0.2942
# Epoch 32: val_loss did not improve from 0.24038
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9356 - loss: 0.2879 - val_accuracy: 0.9570 - val_loss: 0.2433 - learning_rate: 1.0000e-04
# Epoch 33/200
# 926/939 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9337 - loss: 0.2903
# Epoch 33: val_loss did not improve from 0.24038
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9355 - loss: 0.2862 - val_accuracy: 0.9530 - val_loss: 0.2481 - learning_rate: 1.0000e-04
# Epoch 34/200
# 924/939 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9333 - loss: 0.2920
# Epoch 34: val_loss improved from 0.24038 to 0.23338, saving model to best_segmented_densenet169_dull_smote.keras
#
# Epoch 34: finished saving model to best_segmented_densenet169_dull_smote.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9337 - loss: 0.2900 - val_accuracy: 0.9581 - val_loss: 0.2334 - learning_rate: 1.0000e-04
# Epoch 35/200
# 913/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9366 - loss: 0.2791
# Epoch 35: val_loss did not improve from 0.23338
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9363 - loss: 0.2772 - val_accuracy: 0.9550 - val_loss: 0.2358 - learning_rate: 1.0000e-04
# Epoch 36/200
# 923/939 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9386 - loss: 0.2700
# Epoch 36: val_loss did not improve from 0.23338
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9399 - loss: 0.2662 - val_accuracy: 0.9529 - val_loss: 0.2379 - learning_rate: 1.0000e-04
# Epoch 37/200
# 922/939 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9400 - loss: 0.2671
# Epoch 37: val_loss improved from 0.23338 to 0.23297, saving model to best_segmented_densenet169_dull_smote.keras
#
# Epoch 37: finished saving model to best_segmented_densenet169_dull_smote.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9385 - loss: 0.2706 - val_accuracy: 0.9586 - val_loss: 0.2330 - learning_rate: 1.0000e-04
# Epoch 38/200
# 924/939 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9393 - loss: 0.2672
# Epoch 38: val_loss improved from 0.23297 to 0.22830, saving model to best_segmented_densenet169_dull_smote.keras
#
# Epoch 38: finished saving model to best_segmented_densenet169_dull_smote.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9402 - loss: 0.2642 - val_accuracy: 0.9566 - val_loss: 0.2283 - learning_rate: 1.0000e-04
# Epoch 39/200
# 906/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9404 - loss: 0.2608
# Epoch 39: val_loss improved from 0.22830 to 0.21340, saving model to best_segmented_densenet169_dull_smote.keras
#
# Epoch 39: finished saving model to best_segmented_densenet169_dull_smote.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9413 - loss: 0.2579 - val_accuracy: 0.9630 - val_loss: 0.2134 - learning_rate: 1.0000e-04
# Epoch 40/200
# 921/939 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9374 - loss: 0.2683
# Epoch 40: val_loss did not improve from 0.21340
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9381 - loss: 0.2636 - val_accuracy: 0.9632 - val_loss: 0.2159 - learning_rate: 1.0000e-04
# Epoch 41/200
# 921/939 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9414 - loss: 0.2581
# Epoch 41: val_loss did not improve from 0.21340
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9413 - loss: 0.2552 - val_accuracy: 0.9523 - val_loss: 0.2347 - learning_rate: 1.0000e-04
# Epoch 42/200
# 912/939 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9416 - loss: 0.2554
# Epoch 42: val_loss did not improve from 0.21340
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9427 - loss: 0.2514 - val_accuracy: 0.9570 - val_loss: 0.2310 - learning_rate: 1.0000e-04
# Epoch 43/200
# 908/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9424 - loss: 0.2516
# Epoch 43: ReduceLROnPlateau reducing learning rate to 1.9999999494757503e-05.
#
# Epoch 43: val_loss did not improve from 0.21340
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9403 - loss: 0.2578 - val_accuracy: 0.9635 - val_loss: 0.2158 - learning_rate: 1.0000e-04
# Epoch 44/200
# 917/939 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9431 - loss: 0.2454
# Epoch 44: val_loss improved from 0.21340 to 0.19431, saving model to best_segmented_densenet169_dull_smote.keras
#
# Epoch 44: finished saving model to best_segmented_densenet169_dull_smote.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9518 - loss: 0.2297 - val_accuracy: 0.9686 - val_loss: 0.1943 - learning_rate: 2.0000e-05
# Epoch 45/200
# 913/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9546 - loss: 0.2198
# Epoch 45: val_loss improved from 0.19431 to 0.18852, saving model to best_segmented_densenet169_dull_smote.keras
#
# Epoch 45: finished saving model to best_segmented_densenet169_dull_smote.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9572 - loss: 0.2133 - val_accuracy: 0.9698 - val_loss: 0.1885 - learning_rate: 2.0000e-05
# Epoch 46/200
# 916/939 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9581 - loss: 0.2079
# Epoch 46: val_loss improved from 0.18852 to 0.18438, saving model to best_segmented_densenet169_dull_smote.keras
#
# Epoch 46: finished saving model to best_segmented_densenet169_dull_smote.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9609 - loss: 0.2017 - val_accuracy: 0.9704 - val_loss: 0.1844 - learning_rate: 2.0000e-05
# Epoch 47/200
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9593 - loss: 0.2004
# Epoch 47: val_loss improved from 0.18438 to 0.18156, saving model to best_segmented_densenet169_dull_smote.keras
#
# Epoch 47: finished saving model to best_segmented_densenet169_dull_smote.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9615 - loss: 0.1971 - val_accuracy: 0.9712 - val_loss: 0.1816 - learning_rate: 2.0000e-05
# Epoch 48/200
# 917/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9624 - loss: 0.1935
# Epoch 48: val_loss did not improve from 0.18156
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9632 - loss: 0.1907 - val_accuracy: 0.9711 - val_loss: 0.1817 - learning_rate: 2.0000e-05
# Epoch 49/200
# 936/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9637 - loss: 0.1891
# Epoch 49: val_loss improved from 0.18156 to 0.17722, saving model to best_segmented_densenet169_dull_smote.keras
#
# Epoch 49: finished saving model to best_segmented_densenet169_dull_smote.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9636 - loss: 0.1866 - val_accuracy: 0.9704 - val_loss: 0.1772 - learning_rate: 2.0000e-05
# Epoch 50/200
# 923/939 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9637 - loss: 0.1899
# Epoch 50: val_loss improved from 0.17722 to 0.17602, saving model to best_segmented_densenet169_dull_smote.keras
#
# Epoch 50: finished saving model to best_segmented_densenet169_dull_smote.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9648 - loss: 0.1857 - val_accuracy: 0.9710 - val_loss: 0.1760 - learning_rate: 2.0000e-05
# Epoch 51/200
# 938/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9661 - loss: 0.1800
# Epoch 51: val_loss improved from 0.17602 to 0.17210, saving model to best_segmented_densenet169_dull_smote.keras
#
# Epoch 51: finished saving model to best_segmented_densenet169_dull_smote.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9661 - loss: 0.1781 - val_accuracy: 0.9722 - val_loss: 0.1721 - learning_rate: 2.0000e-05
# Epoch 52/200
# 908/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9655 - loss: 0.1791
# Epoch 52: val_loss improved from 0.17210 to 0.17166, saving model to best_segmented_densenet169_dull_smote.keras
#
# Epoch 52: finished saving model to best_segmented_densenet169_dull_smote.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9669 - loss: 0.1747 - val_accuracy: 0.9718 - val_loss: 0.1717 - learning_rate: 2.0000e-05
# Epoch 53/200
# 915/939 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9672 - loss: 0.1759
# Epoch 53: val_loss improved from 0.17166 to 0.17031, saving model to best_segmented_densenet169_dull_smote.keras
#
# Epoch 53: finished saving model to best_segmented_densenet169_dull_smote.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9676 - loss: 0.1731 - val_accuracy: 0.9718 - val_loss: 0.1703 - learning_rate: 2.0000e-05
# Epoch 54/200
# 938/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9657 - loss: 0.1769
# Epoch 54: val_loss improved from 0.17031 to 0.16532, saving model to best_segmented_densenet169_dull_smote.keras
#
# Epoch 54: finished saving model to best_segmented_densenet169_dull_smote.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9678 - loss: 0.1737 - val_accuracy: 0.9734 - val_loss: 0.1653 - learning_rate: 2.0000e-05
# Epoch 55/200
# 938/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9685 - loss: 0.1685
# Epoch 55: val_loss improved from 0.16532 to 0.16486, saving model to best_segmented_densenet169_dull_smote.keras
#
# Epoch 55: finished saving model to best_segmented_densenet169_dull_smote.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9692 - loss: 0.1667 - val_accuracy: 0.9738 - val_loss: 0.1649 - learning_rate: 2.0000e-05
# Epoch 56/200
# 915/939 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9677 - loss: 0.1673
# Epoch 56: val_loss improved from 0.16486 to 0.16250, saving model to best_segmented_densenet169_dull_smote.keras
#
# Epoch 56: finished saving model to best_segmented_densenet169_dull_smote.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9685 - loss: 0.1656 - val_accuracy: 0.9744 - val_loss: 0.1625 - learning_rate: 2.0000e-05
# Epoch 57/200
# 930/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9701 - loss: 0.1680
# Epoch 57: val_loss did not improve from 0.16250
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9701 - loss: 0.1649 - val_accuracy: 0.9723 - val_loss: 0.1680 - learning_rate: 2.0000e-05
# Epoch 58/200
# 936/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9705 - loss: 0.1652
# Epoch 58: val_loss did not improve from 0.16250
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9703 - loss: 0.1634 - val_accuracy: 0.9736 - val_loss: 0.1654 - learning_rate: 2.0000e-05
# Epoch 59/200
# 914/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9690 - loss: 0.1644
# Epoch 59: val_loss improved from 0.16250 to 0.16232, saving model to best_segmented_densenet169_dull_smote.keras
#
# Epoch 59: finished saving model to best_segmented_densenet169_dull_smote.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9702 - loss: 0.1628 - val_accuracy: 0.9743 - val_loss: 0.1623 - learning_rate: 2.0000e-05
# Epoch 60/200
# 930/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9700 - loss: 0.1620
# Epoch 60: val_loss improved from 0.16232 to 0.15740, saving model to best_segmented_densenet169_dull_smote.keras
#
# Epoch 60: finished saving model to best_segmented_densenet169_dull_smote.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9713 - loss: 0.1595 - val_accuracy: 0.9747 - val_loss: 0.1574 - learning_rate: 2.0000e-05
# Epoch 61/200
# 910/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9701 - loss: 0.1613
# Epoch 61: val_loss did not improve from 0.15740
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9722 - loss: 0.1588 - val_accuracy: 0.9747 - val_loss: 0.1588 - learning_rate: 2.0000e-05
# Epoch 62/200
# 915/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9718 - loss: 0.1591
# Epoch 62: val_loss did not improve from 0.15740
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9721 - loss: 0.1575 - val_accuracy: 0.9743 - val_loss: 0.1590 - learning_rate: 2.0000e-05
# Epoch 63/200
# 932/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9746 - loss: 0.1531
# Epoch 63: val_loss did not improve from 0.15740
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9736 - loss: 0.1539 - val_accuracy: 0.9758 - val_loss: 0.1588 - learning_rate: 2.0000e-05
# Epoch 64/200
# 910/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9726 - loss: 0.1551
# Epoch 64: val_loss improved from 0.15740 to 0.15710, saving model to best_segmented_densenet169_dull_smote.keras
#
# Epoch 64: finished saving model to best_segmented_densenet169_dull_smote.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9730 - loss: 0.1531 - val_accuracy: 0.9750 - val_loss: 0.1571 - learning_rate: 2.0000e-05
# Epoch 65/200
# 910/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9748 - loss: 0.1490
# Epoch 65: val_loss improved from 0.15710 to 0.15476, saving model to best_segmented_densenet169_dull_smote.keras
#
# Epoch 65: finished saving model to best_segmented_densenet169_dull_smote.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9743 - loss: 0.1508 - val_accuracy: 0.9748 - val_loss: 0.1548 - learning_rate: 2.0000e-05
# Epoch 66/200
# 932/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9749 - loss: 0.1499
# Epoch 66: val_loss did not improve from 0.15476
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9757 - loss: 0.1468 - val_accuracy: 0.9763 - val_loss: 0.1562 - learning_rate: 2.0000e-05
# Epoch 67/200
# 909/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9756 - loss: 0.1493
# Epoch 67: val_loss did not improve from 0.15476
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9745 - loss: 0.1501 - val_accuracy: 0.9747 - val_loss: 0.1588 - learning_rate: 2.0000e-05
# Epoch 68/200
# 911/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9745 - loss: 0.1501
# Epoch 68: val_loss improved from 0.15476 to 0.15424, saving model to best_segmented_densenet169_dull_smote.keras
#
# Epoch 68: finished saving model to best_segmented_densenet169_dull_smote.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9749 - loss: 0.1496 - val_accuracy: 0.9751 - val_loss: 0.1542 - learning_rate: 2.0000e-05
# Epoch 69/200
# 931/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9743 - loss: 0.1472
# Epoch 69: val_loss did not improve from 0.15424
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9746 - loss: 0.1472 - val_accuracy: 0.9752 - val_loss: 0.1556 - learning_rate: 2.0000e-05
# Epoch 70/200
# 909/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9754 - loss: 0.1444
# Epoch 70: val_loss improved from 0.15424 to 0.15347, saving model to best_segmented_densenet169_dull_smote.keras
#
# Epoch 70: finished saving model to best_segmented_densenet169_dull_smote.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9761 - loss: 0.1434 - val_accuracy: 0.9764 - val_loss: 0.1535 - learning_rate: 2.0000e-05
# Epoch 71/200
# 937/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9762 - loss: 0.1452
# Epoch 71: val_loss improved from 0.15347 to 0.14983, saving model to best_segmented_densenet169_dull_smote.keras
#
# Epoch 71: finished saving model to best_segmented_densenet169_dull_smote.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9765 - loss: 0.1438 - val_accuracy: 0.9767 - val_loss: 0.1498 - learning_rate: 2.0000e-05
# Epoch 72/200
# 917/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9769 - loss: 0.1396
# Epoch 72: val_loss did not improve from 0.14983
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9776 - loss: 0.1401 - val_accuracy: 0.9756 - val_loss: 0.1552 - learning_rate: 2.0000e-05
# Epoch 73/200
# 937/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9787 - loss: 0.1412
# Epoch 73: val_loss did not improve from 0.14983
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9785 - loss: 0.1393 - val_accuracy: 0.9762 - val_loss: 0.1530 - learning_rate: 2.0000e-05
# Epoch 74/200
# 937/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9785 - loss: 0.1394
# Epoch 74: val_loss did not improve from 0.14983
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9784 - loss: 0.1384 - val_accuracy: 0.9758 - val_loss: 0.1515 - learning_rate: 2.0000e-05
# Epoch 75/200
# 916/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9783 - loss: 0.1401
# Epoch 75: ReduceLROnPlateau reducing learning rate to 3.999999898951501e-06.
#
# Epoch 75: val_loss did not improve from 0.14983
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9781 - loss: 0.1399 - val_accuracy: 0.9743 - val_loss: 0.1607 - learning_rate: 2.0000e-05
# Epoch 76/200
# 907/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9794 - loss: 0.1342
# Epoch 76: val_loss did not improve from 0.14983
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9801 - loss: 0.1322 - val_accuracy: 0.9760 - val_loss: 0.1525 - learning_rate: 4.0000e-06
# Epoch 77/200
# 933/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9805 - loss: 0.1319
# Epoch 77: val_loss did not improve from 0.14983
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9801 - loss: 0.1314 - val_accuracy: 0.9763 - val_loss: 0.1515 - learning_rate: 4.0000e-06
# Epoch 78/200
# 917/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9807 - loss: 0.1318
# Epoch 78: val_loss did not improve from 0.14983
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9810 - loss: 0.1311 - val_accuracy: 0.9766 - val_loss: 0.1505 - learning_rate: 4.0000e-06
# Epoch 79/200
# 931/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9814 - loss: 0.1316
# Epoch 79: val_loss improved from 0.14983 to 0.14911, saving model to best_segmented_densenet169_dull_smote.keras
#
# Epoch 79: finished saving model to best_segmented_densenet169_dull_smote.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9817 - loss: 0.1294 - val_accuracy: 0.9775 - val_loss: 0.1491 - learning_rate: 4.0000e-06
# Epoch 80/200
# 926/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9804 - loss: 0.1304
# Epoch 80: val_loss did not improve from 0.14911
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9809 - loss: 0.1294 - val_accuracy: 0.9771 - val_loss: 0.1497 - learning_rate: 4.0000e-06
# Epoch 81/200
# 917/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9815 - loss: 0.1285
# Epoch 81: val_loss did not improve from 0.14911
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9813 - loss: 0.1275 - val_accuracy: 0.9766 - val_loss: 0.1497 - learning_rate: 4.0000e-06
# Epoch 82/200
# 928/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9802 - loss: 0.1301
# Epoch 82: val_loss did not improve from 0.14911
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9801 - loss: 0.1307 - val_accuracy: 0.9770 - val_loss: 0.1500 - learning_rate: 4.0000e-06
# Epoch 83/200
# 933/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9810 - loss: 0.1296
# Epoch 83: ReduceLROnPlateau reducing learning rate to 7.999999979801942e-07.
#
# Epoch 83: val_loss did not improve from 0.14911
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9809 - loss: 0.1280 - val_accuracy: 0.9776 - val_loss: 0.1501 - learning_rate: 4.0000e-06
# Epoch 84/200
# 914/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9822 - loss: 0.1283
# Epoch 84: val_loss did not improve from 0.14911
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9821 - loss: 0.1270 - val_accuracy: 0.9770 - val_loss: 0.1503 - learning_rate: 8.0000e-07
# Epoch 85/200
# 932/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9816 - loss: 0.1271
# Epoch 85: val_loss did not improve from 0.14911
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9822 - loss: 0.1252 - val_accuracy: 0.9772 - val_loss: 0.1500 - learning_rate: 8.0000e-07
# Epoch 86/200
# 931/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9832 - loss: 0.1266
# Epoch 86: val_loss did not improve from 0.14911
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9826 - loss: 0.1263 - val_accuracy: 0.9771 - val_loss: 0.1502 - learning_rate: 8.0000e-07
# Epoch 87/200
# 927/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9826 - loss: 0.1249
# Epoch 87: ReduceLROnPlateau reducing learning rate to 1.600000018697756e-07.
#
# Epoch 87: val_loss did not improve from 0.14911
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9827 - loss: 0.1247 - val_accuracy: 0.9772 - val_loss: 0.1495 - learning_rate: 8.0000e-07
# Epoch 88/200
# 927/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9820 - loss: 0.1302
# Epoch 88: val_loss did not improve from 0.14911
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9817 - loss: 0.1287 - val_accuracy: 0.9772 - val_loss: 0.1496 - learning_rate: 1.6000e-07
# Epoch 89/200
# 916/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9823 - loss: 0.1254
# Epoch 89: val_loss did not improve from 0.14911
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9827 - loss: 0.1248 - val_accuracy: 0.9772 - val_loss: 0.1496 - learning_rate: 1.6000e-07
# Epoch 89: early stopping
# Restoring model weights from the end of the best epoch: 79.

# %%
plt.figure(figsize=(8, 5))
plt.plot(history.history["accuracy"], label="Treino")
plt.plot(history.history["val_accuracy"], label="Validação")
plt.title("Acurácia durante o treinamento")
plt.xlabel("Época")
plt.ylabel("Acurácia")
plt.legend()
plt.grid(True, alpha=0.3)
plt.savefig("acuracia_segmented_densenet169_smote.png", dpi=300, bbox_inches="tight")
plt.show()

plt.figure(figsize=(8, 5))
plt.plot(history.history["loss"], label="Treino")
plt.plot(history.history["val_loss"], label="Validação")
plt.title("Perda durante o treinamento")
plt.xlabel("Época")
plt.ylabel("Loss")
plt.legend()
plt.grid(True, alpha=0.3)
plt.savefig("loss_segmented_densenet169_smote.png", dpi=300, bbox_inches="tight")
plt.show()

best_classifier = keras.models.load_model(BEST_MODEL_PATH)

pred_probs = best_classifier.predict(X_test_features, verbose=0)
y_pred = np.argmax(pred_probs, axis=1)

print("Relatório de Classificação:")
print(classification_report(y_test, y_pred, target_names=classes, digits=4, zero_division=0))

acc = accuracy_score(y_test, y_pred)
macro_precision = precision_score(y_test, y_pred, average="macro", zero_division=0)
macro_recall = recall_score(y_test, y_pred, average="macro", zero_division=0)
macro_f1 = f1_score(y_test, y_pred, average="macro", zero_division=0)
weighted_precision = precision_score(y_test, y_pred, average="weighted", zero_division=0)
weighted_recall = recall_score(y_test, y_pred, average="weighted", zero_division=0)
weighted_f1 = f1_score(y_test, y_pred, average="weighted", zero_division=0)

print("\nMÉTRICAS GERAIS DO MODELO")
print(f"Accuracy: {acc:.4f}")
print("\nMacro Average:")
print(f"  Precision: {macro_precision:.4f}")
print(f"  Recall: {macro_recall:.4f}")
print(f"  F1-Score: {macro_f1:.4f}")
print("\nWeighted Average:")
print(f"  Precision: {weighted_precision:.4f}")
print(f"  Recall: {weighted_recall:.4f}")
print(f"  F1-Score: {weighted_f1:.4f}")

cm = confusion_matrix(y_test, y_pred, labels=list(range(len(classes))))
cm_percent = cm.astype("float") / cm.sum(axis=1, keepdims=True) * 100
cm_percent = np.nan_to_num(cm_percent)

plt.figure(figsize=(8, 7))
im = plt.imshow(cm_percent, interpolation="nearest", cmap="Blues", vmin=0, vmax=100)
plt.title("Matriz de Confusão (%) - DenseNet169 + Dull Razor + SMOTE")
plt.colorbar(im, label="%")

tick_marks = np.arange(len(classes))
plt.xticks(tick_marks, classes, rotation=45)
plt.yticks(tick_marks, classes)

for i in range(cm_percent.shape[0]):
    for j in range(cm_percent.shape[1]):
        color = "white" if cm_percent[i, j] > 50 else "black"
        plt.text(j, i, f"{cm_percent[i, j]:.1f}", ha="center", va="center", color=color, fontsize=8)

plt.ylabel("Classe Real")
plt.xlabel("Classe Predita")
plt.tight_layout()
plt.savefig("matriz_confusao_segmented_densenet169_smote.png", dpi=300, bbox_inches="tight")
plt.show()
# Out:
# Relatório de Classificação:
#               precision    recall  f1-score   support
#
#          MEL     0.4557    0.4843    0.4696       223
#           NV     0.8884    0.8665    0.8773      1341
#          BCC     0.6250    0.6311    0.6280       103
#        AKIEC     0.4930    0.5385    0.5147        65
#          BKL     0.5068    0.5045    0.5057       220
#           DF     0.4545    0.6522    0.5357        23
#         VASC     0.6452    0.7143    0.6780        28
#
#     accuracy                         0.7569      2003
#    macro avg     0.5812    0.6273    0.6013      2003
# weighted avg     0.7635    0.7569    0.7598      2003
#
#
# MÉTRICAS GERAIS DO MODELO
# Accuracy: 0.7569
#
# Macro Average:
#   Precision: 0.5812
#   Recall: 0.6273
#   F1-Score: 0.6013
#
# Weighted Average:
#   Precision: 0.7635
#   Recall: 0.7569
#   F1-Score: 0.7598

# %%
feature_extractor.save(FEATURE_EXTRACTOR_PATH)
best_classifier.save(FINAL_MODEL_PATH)

print("Extratora DenseNet169 salva em:", FEATURE_EXTRACTOR_PATH)
print("Classificador final salvo em:", FINAL_MODEL_PATH)
print("Melhor checkpoint salvo em:", BEST_MODEL_PATH)
# Out:
# Extratora DenseNet169 salva em: segmented_densenet169_feature_extractor.keras
# Classificador final salvo em: segmented_densenet169_dull_smote_final.keras
# Melhor checkpoint salvo em: best_segmented_densenet169_dull_smote.keras
