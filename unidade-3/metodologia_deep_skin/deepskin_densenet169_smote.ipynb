# %%
import os
os.environ["KERAS_BACKEND"] = "tensorflow"

import random
from pathlib import Path
from collections import Counter

import cv2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import tensorflow as tf
import keras
from keras import layers, models, regularizers

from tensorflow.keras.applications import DenseNet169
from tensorflow.keras.applications.densenet import preprocess_input

from sklearn.model_selection import train_test_split
from sklearn.metrics import (
    classification_report,
    confusion_matrix,
    accuracy_score,
    precision_score,
    recall_score,
    f1_score
)

from imblearn.over_sampling import SMOTE

# %%
SEED = 42
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)

DATA_DIR = Path("../data")
IMAGES_DIR = DATA_DIR / "images"
MASKS_DIR = DATA_DIR / "masks"
CSV_PATH = DATA_DIR / "GroundTruth.csv"

SPLIT_RATIO = "80:20"
TEST_SIZE = 0.20

IMG_SIZE = (256, 256)
BATCH_SIZE = 32
EPOCHS = 200
LEARNING_RATE = 0.0001

USE_DULL_RAZOR = True

USE_MASK_SEGMENTATION = False

BEST_MODEL_PATH = "best_deepskin_densenet169_smote.keras"
FINAL_MODEL_PATH = "deepskin_densenet169_smote_final.keras"
FEATURE_EXTRACTOR_PATH = "densenet169_feature_extractor.keras"

classes = ["MEL", "NV", "BCC", "AKIEC", "BKL", "DF", "VASC"]
class_code = {label: idx for idx, label in enumerate(classes)}
class_name = {idx: label for label, idx in class_code.items()}

print("IMG_SIZE:", IMG_SIZE)
print("BATCH_SIZE:", BATCH_SIZE)
print("EPOCHS:", EPOCHS)
print("LEARNING_RATE:", LEARNING_RATE)
print("USE_DULL_RAZOR:", USE_DULL_RAZOR)
print("USE_MASK_SEGMENTATION:", USE_MASK_SEGMENTATION)
print(class_code)
# Out:
# IMG_SIZE: (256, 256)
# BATCH_SIZE: 32
# EPOCHS: 200
# LEARNING_RATE: 0.0001
# USE_DULL_RAZOR: True
# USE_MASK_SEGMENTATION: False
# {'MEL': 0, 'NV': 1, 'BCC': 2, 'AKIEC': 3, 'BKL': 4, 'DF': 5, 'VASC': 6}

# %%
def find_image_path(image_id, images_dir):
    for ext in [".jpg", ".jpeg", ".png"]:
        path = images_dir / f"{image_id}{ext}"
        if path.exists():
            return str(path)
    return None


def find_mask_path(image_id, masks_dir):
    if not masks_dir.exists():
        return None

    candidates = [
        masks_dir / f"{image_id}.png",
        masks_dir / f"{image_id}.jpg",
        masks_dir / f"{image_id}_segmentation.png",
        masks_dir / f"{image_id}_mask.png",
        masks_dir / f"{image_id}_segmentation.jpg",
        masks_dir / f"{image_id}_mask.jpg",
    ]

    for path in candidates:
        if path.exists():
            return str(path)

    matches = list(masks_dir.glob(f"{image_id}*"))
    if len(matches) > 0:
        return str(matches[0])

    return None


metadata = pd.read_csv(CSV_PATH)

rows = []
for _, row in metadata.iterrows():
    image_id = str(row["image"])
    image_path = find_image_path(image_id, IMAGES_DIR)

    if image_path is None:
        continue

    label_name = row[classes].idxmax()
    label = class_code[label_name]
    mask_path = find_mask_path(image_id, MASKS_DIR)

    rows.append({
        "image": image_id,
        "image_path": image_path,
        "mask_path": mask_path,
        "class_name": label_name,
        "label": label
    })

df = pd.DataFrame(rows)

print("Total de imagens localizadas:", len(df))
display(df.head())

print("\nDistribuição original:")
print(df["class_name"].value_counts().reindex(classes))

print("\nMáscaras encontradas:", df["mask_path"].notna().sum())
# Out:
# Total de imagens localizadas: 10015
#           image                       image_path  \
# 0  ISIC_0024306  ../data/images/ISIC_0024306.jpg
# 1  ISIC_0024307  ../data/images/ISIC_0024307.jpg
# 2  ISIC_0024308  ../data/images/ISIC_0024308.jpg
# 3  ISIC_0024309  ../data/images/ISIC_0024309.jpg
# 4  ISIC_0024310  ../data/images/ISIC_0024310.jpg
#
#                                      mask_path class_name  label
# 0  ../data/masks/ISIC_0024306_segmentation.png         NV      1
# 1  ../data/masks/ISIC_0024307_segmentation.png         NV      1
# 2  ../data/masks/ISIC_0024308_segmentation.png         NV      1
# 3  ../data/masks/ISIC_0024309_segmentation.png         NV      1
# 4  ../data/masks/ISIC_0024310_segmentation.png        MEL      0
# Distribuição original:
# class_name
# MEL      1113
# NV       6705
# BCC       514
# AKIEC     327
# BKL      1099
# DF        115
# VASC      142
# Name: count, dtype: int64
#
# Máscaras encontradas: 10015

# %%
train_df, test_df = train_test_split(
    df,
    test_size=TEST_SIZE,
    random_state=SEED,
    stratify=df["label"]
)

print("Treino original:", len(train_df))
print("Teste final:", len(test_df))

print("\nDistribuição treino original:")
print(train_df["class_name"].value_counts().reindex(classes))

print("\nDistribuição teste final:")
print(test_df["class_name"].value_counts().reindex(classes))
# Out:
# Treino original: 8012
# Teste final: 2003
#
# Distribuição treino original:
# class_name
# MEL       890
# NV       5364
# BCC       411
# AKIEC     262
# BKL       879
# DF         92
# VASC      114
# Name: count, dtype: int64
#
# Distribuição teste final:
# class_name
# MEL       223
# NV       1341
# BCC       103
# AKIEC      65
# BKL       220
# DF         23
# VASC       28
# Name: count, dtype: int64

# %%
def dull_razor_remove_hair(image_rgb, kernel_size=(9, 9), threshold_value=10, inpaint_radius=6):
    image_rgb = image_rgb.astype(np.uint8)

    gray = cv2.cvtColor(image_rgb, cv2.COLOR_RGB2GRAY)

    kernel = cv2.getStructuringElement(cv2.MORPH_RECT, kernel_size)
    blackhat = cv2.morphologyEx(gray, cv2.MORPH_BLACKHAT, kernel)

    blackhat_blur = cv2.GaussianBlur(blackhat, (3, 3), 0)

    _, mask = cv2.threshold(
        blackhat_blur,
        threshold_value,
        255,
        cv2.THRESH_BINARY
    )

    image_bgr = cv2.cvtColor(image_rgb, cv2.COLOR_RGB2BGR)

    clean_bgr = cv2.inpaint(
        image_bgr,
        mask,
        inpaint_radius,
        cv2.INPAINT_TELEA
    )

    clean_rgb = cv2.cvtColor(clean_bgr, cv2.COLOR_BGR2RGB)

    return clean_rgb


def read_rgb_image(path):
    if isinstance(path, bytes):
        path = path.decode("utf-8")

    image_bgr = cv2.imread(str(path), cv2.IMREAD_COLOR)

    if image_bgr is None:
        raise ValueError(f"Não foi possível carregar a imagem: {path}")

    image_rgb = cv2.cvtColor(image_bgr, cv2.COLOR_BGR2RGB)

    return image_rgb


def apply_mask_segmentation(image_rgb, mask_path):
    if mask_path is None or pd.isna(mask_path):
        return image_rgb

    mask = cv2.imread(str(mask_path), cv2.IMREAD_GRAYSCALE)

    if mask is None:
        return image_rgb

    mask = cv2.resize(mask, (image_rgb.shape[1], image_rgb.shape[0]))
    binary_mask = (mask > 127).astype(np.uint8)

    segmented = image_rgb * np.expand_dims(binary_mask, axis=-1)

    # Proteção: se a imagem ficar quase toda preta, mantém a imagem original
    if np.mean(segmented) < 5:
        return image_rgb

    return segmented


def preprocess_image_path(path, mask_path=None):
    image_rgb = read_rgb_image(path)

    if USE_DULL_RAZOR:
        image_rgb = dull_razor_remove_hair(image_rgb)

    if USE_MASK_SEGMENTATION:
        image_rgb = apply_mask_segmentation(image_rgb, mask_path)

    image_rgb = cv2.resize(image_rgb, IMG_SIZE)

    return image_rgb.astype("float32")

# %%
sample_row = train_df.sample(1, random_state=SEED).iloc[0]

original = read_rgb_image(sample_row["image_path"])
dull = dull_razor_remove_hair(original) if USE_DULL_RAZOR else original
final_img = preprocess_image_path(sample_row["image_path"], sample_row["mask_path"])
final_img = np.clip(final_img, 0, 255).astype("uint8")

plt.figure(figsize=(12, 4))

plt.subplot(1, 3, 1)
plt.imshow(original)
plt.title("Original")
plt.axis("off")

plt.subplot(1, 3, 2)
plt.imshow(dull)
plt.title("Dull Razor")
plt.axis("off")

plt.subplot(1, 3, 3)
plt.imshow(final_img)
plt.title("Imagem final")
plt.axis("off")

plt.tight_layout()
plt.savefig("pipeline_deepskin_smote_preprocessamento.png", dpi=300, bbox_inches="tight")
plt.show()

# %%
def load_image_for_features_py(path, mask_path, label):
    if isinstance(path, bytes):
        path = path.decode("utf-8")

    if isinstance(mask_path, bytes):
        mask_path = mask_path.decode("utf-8")

    if mask_path == "None" or mask_path == "":
        mask_path = None

    image = preprocess_image_path(path, mask_path)

    return image.astype("float32"), np.int32(label)


def tf_load_image_for_features(path, mask_path, label):
    image, label = tf.numpy_function(
        load_image_for_features_py,
        [path, mask_path, label],
        [tf.float32, tf.int32]
    )

    image.set_shape((IMG_SIZE[0], IMG_SIZE[1], 3))
    label.set_shape(())

    return image, label


def build_image_dataset(dataframe, batch_size=BATCH_SIZE, shuffle=False):
    mask_values = dataframe["mask_path"].fillna("None").astype(str).values

    ds = tf.data.Dataset.from_tensor_slices((
        dataframe["image_path"].astype(str).values,
        mask_values,
        dataframe["label"].values.astype("int32")
    ))

    if shuffle:
        ds = ds.shuffle(buffer_size=len(dataframe), seed=SEED)

    ds = ds.map(tf_load_image_for_features, num_parallel_calls=tf.data.AUTOTUNE)
    ds = ds.batch(batch_size)
    ds = ds.prefetch(tf.data.AUTOTUNE)

    return ds


train_image_ds = build_image_dataset(train_df, shuffle=False)
test_image_ds = build_image_dataset(test_df, shuffle=False)

print(train_image_ds)
print(test_image_ds)
# Out:
# <_PrefetchDataset element_spec=(TensorSpec(shape=(None, 256, 256, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>
# <_PrefetchDataset element_spec=(TensorSpec(shape=(None, 256, 256, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
def build_feature_extractor(input_shape=(160, 160, 3)):
    inputs = layers.Input(shape=input_shape)

    x = preprocess_input(inputs)

    base_model = DenseNet169(
        weights="imagenet",
        include_top=False,
        input_shape=input_shape
    )

    base_model.trainable = False

    x = base_model(x, training=False)
    x = layers.GlobalAveragePooling2D()(x)

    feature_extractor = models.Model(
        inputs=inputs,
        outputs=x,
        name="densenet169_feature_extractor"
    )

    return feature_extractor


feature_extractor = build_feature_extractor(input_shape=(IMG_SIZE[0], IMG_SIZE[1], 3))

feature_extractor.summary()
# Out:
# Model: "densenet169_feature_extractor"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 256, 256, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ true_divide (TrueDivide)        │ (None, 256, 256, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ add (Add)                       │ (None, 256, 256, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ true_divide_1 (TrueDivide)      │ (None, 256, 256, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ densenet169 (Functional)        │ (None, 8, 8, 1664)     │    12,642,880 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 1664)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 12,642,880 (48.23 MB)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 12,642,880 (48.23 MB)

# %%
def extract_features(dataset, feature_extractor):
    features_list = []
    labels_list = []

    for images, labels in dataset:
        features = feature_extractor.predict(images, verbose=0)
        features_list.append(features)
        labels_list.append(labels.numpy())

    X = np.concatenate(features_list, axis=0)
    y = np.concatenate(labels_list, axis=0)

    return X.astype("float32"), y.astype("int32")


X_train_features, y_train = extract_features(train_image_ds, feature_extractor)
X_test_features, y_test = extract_features(test_image_ds, feature_extractor)

print("X_train_features:", X_train_features.shape)
print("y_train:", y_train.shape)
print("X_test_features:", X_test_features.shape)
print("y_test:", y_test.shape)

print("\nDistribuição treino antes do SMOTE:")
print(Counter(y_train))
# Out:
# X_train_features: (8012, 1664)
# y_train: (8012,)
# X_test_features: (2003, 1664)
# y_test: (2003,)
#
# Distribuição treino antes do SMOTE:
# Counter({np.int32(1): 5364, np.int32(0): 890, np.int32(4): 879, np.int32(2): 411, np.int32(3): 262, np.int32(6): 114, np.int32(5): 92})

# %%
min_class_count = min(Counter(y_train).values())
k_neighbors = min(5, min_class_count - 1)

print("Menor classe no treino:", min_class_count)
print("k_neighbors usado no SMOTE:", k_neighbors)

smote = SMOTE(
    random_state=SEED,
    k_neighbors=k_neighbors
)

X_train_smote, y_train_smote = smote.fit_resample(
    X_train_features,
    y_train
)

print("X_train_smote:", X_train_smote.shape)
print("y_train_smote:", y_train_smote.shape)

print("\nDistribuição treino após SMOTE:")
print(Counter(y_train_smote))
# Out:
# Menor classe no treino: 92
# k_neighbors usado no SMOTE: 5
# X_train_smote: (37548, 1664)
# y_train_smote: (37548,)
#
# Distribuição treino após SMOTE:
# Counter({np.int32(1): 5364, np.int32(0): 5364, np.int32(4): 5364, np.int32(2): 5364, np.int32(5): 5364, np.int32(3): 5364, np.int32(6): 5364})

# %%
X_fit, X_val, y_fit, y_val = train_test_split(
    X_train_smote,
    y_train_smote,
    test_size=0.20,
    random_state=SEED,
    stratify=y_train_smote
)

print("Treino para fit:", X_fit.shape)
print("Validação:", X_val.shape)
print("Teste final:", X_test_features.shape)

print("\nDistribuição fit:")
print(Counter(y_fit))

print("\nDistribuição validação:")
print(Counter(y_val))
# Out:
# Treino para fit: (30038, 1664)
# Validação: (7510, 1664)
# Teste final: (2003, 1664)
#
# Distribuição fit:
# Counter({np.int32(0): 4292, np.int32(4): 4291, np.int32(5): 4291, np.int32(6): 4291, np.int32(2): 4291, np.int32(3): 4291, np.int32(1): 4291})
#
# Distribuição validação:
# Counter({np.int32(2): 1073, np.int32(3): 1073, np.int32(6): 1073, np.int32(4): 1073, np.int32(1): 1073, np.int32(5): 1073, np.int32(0): 1072})

# %%
def build_classifier_head(input_dim, num_classes=len(classes)):
    inputs = layers.Input(shape=(input_dim,))

    x = layers.Dense(
        256,
        activation="relu",
        kernel_regularizer=regularizers.l2(0.001)
    )(inputs)

    x = layers.BatchNormalization()(x)
    x = layers.Dropout(0.5)(x)

    x = layers.Dense(
        128,
        activation="relu",
        kernel_regularizer=regularizers.l2(0.001)
    )(x)

    x = layers.Dropout(0.3)(x)

    outputs = layers.Dense(num_classes, activation="softmax")(x)

    model = models.Model(
        inputs=inputs,
        outputs=outputs,
        name="deepskin_densenet169_smote_classifier"
    )

    return model


classifier = build_classifier_head(
    input_dim=X_train_smote.shape[1],
    num_classes=len(classes)
)

classifier.compile(
    optimizer=keras.optimizers.Adam(learning_rate=LEARNING_RATE),
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)

classifier.summary()
# Out:
# Model: "deepskin_densenet169_smote_classifier"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_2 (InputLayer)      │ (None, 1664)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │       426,240 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 7)              │           903 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 461,063 (1.76 MB)
#  Trainable params: 460,551 (1.76 MB)
#  Non-trainable params: 512 (2.00 KB)

# %%
callbacks = [
    keras.callbacks.EarlyStopping(
        monitor="val_loss",
        patience=10,
        restore_best_weights=True,
        verbose=1
    ),
    keras.callbacks.ReduceLROnPlateau(
        monitor="val_loss",
        factor=0.2,
        patience=4,
        min_lr=1e-7,
        verbose=1
    ),
    keras.callbacks.ModelCheckpoint(
        BEST_MODEL_PATH,
        monitor="val_loss",
        save_best_only=True,
        verbose=1
    )
]

history = classifier.fit(
    X_fit,
    y_fit,
    validation_data=(X_val, y_val),
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    callbacks=callbacks
)
# Out:
# Epoch 1/200
# 922/939 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4103 - loss: 2.2141
# Epoch 1: val_loss improved from None to 1.03356, saving model to best_deepskin_densenet169_smote.keras
#
# Epoch 1: finished saving model to best_deepskin_densenet169_smote.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.5256 - loss: 1.7726 - val_accuracy: 0.7619 - val_loss: 1.0336 - learning_rate: 1.0000e-04
# Epoch 2/200
# 916/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6763 - loss: 1.2535
# Epoch 2: val_loss improved from 1.03356 to 0.83019, saving model to best_deepskin_densenet169_smote.keras
#
# Epoch 2: finished saving model to best_deepskin_densenet169_smote.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7005 - loss: 1.1834 - val_accuracy: 0.8356 - val_loss: 0.8302 - learning_rate: 1.0000e-04
# Epoch 3/200
# 909/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7514 - loss: 1.0294
# Epoch 3: val_loss improved from 0.83019 to 0.71902, saving model to best_deepskin_densenet169_smote.keras
#
# Epoch 3: finished saving model to best_deepskin_densenet169_smote.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7664 - loss: 0.9832 - val_accuracy: 0.8694 - val_loss: 0.7190 - learning_rate: 1.0000e-04
# Epoch 4/200
# 936/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7930 - loss: 0.8911
# Epoch 4: val_loss improved from 0.71902 to 0.63673, saving model to best_deepskin_densenet169_smote.keras
#
# Epoch 4: finished saving model to best_deepskin_densenet169_smote.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8007 - loss: 0.8592 - val_accuracy: 0.8903 - val_loss: 0.6367 - learning_rate: 1.0000e-04
# Epoch 5/200
# 927/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8228 - loss: 0.7893
# Epoch 5: val_loss improved from 0.63673 to 0.58704, saving model to best_deepskin_densenet169_smote.keras
#
# Epoch 5: finished saving model to best_deepskin_densenet169_smote.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8266 - loss: 0.7744 - val_accuracy: 0.8956 - val_loss: 0.5870 - learning_rate: 1.0000e-04
# Epoch 6/200
# 917/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8463 - loss: 0.7076
# Epoch 6: val_loss improved from 0.58704 to 0.53685, saving model to best_deepskin_densenet169_smote.keras
#
# Epoch 6: finished saving model to best_deepskin_densenet169_smote.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8492 - loss: 0.6969 - val_accuracy: 0.9064 - val_loss: 0.5368 - learning_rate: 1.0000e-04
# Epoch 7/200
# 927/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8640 - loss: 0.6499
# Epoch 7: val_loss improved from 0.53685 to 0.49145, saving model to best_deepskin_densenet169_smote.keras
#
# Epoch 7: finished saving model to best_deepskin_densenet169_smote.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8674 - loss: 0.6361 - val_accuracy: 0.9220 - val_loss: 0.4915 - learning_rate: 1.0000e-04
# Epoch 8/200
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8740 - loss: 0.6020
# Epoch 8: val_loss improved from 0.49145 to 0.46072, saving model to best_deepskin_densenet169_smote.keras
#
# Epoch 8: finished saving model to best_deepskin_densenet169_smote.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8796 - loss: 0.5868 - val_accuracy: 0.9241 - val_loss: 0.4607 - learning_rate: 1.0000e-04
# Epoch 9/200
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8827 - loss: 0.5641
# Epoch 9: val_loss improved from 0.46072 to 0.42292, saving model to best_deepskin_densenet169_smote.keras
#
# Epoch 9: finished saving model to best_deepskin_densenet169_smote.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8872 - loss: 0.5497 - val_accuracy: 0.9393 - val_loss: 0.4229 - learning_rate: 1.0000e-04
# Epoch 10/200
# 919/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8935 - loss: 0.5246
# Epoch 10: val_loss improved from 0.42292 to 0.40584, saving model to best_deepskin_densenet169_smote.keras
#
# Epoch 10: finished saving model to best_deepskin_densenet169_smote.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8964 - loss: 0.5132 - val_accuracy: 0.9402 - val_loss: 0.4058 - learning_rate: 1.0000e-04
# Epoch 11/200
# 931/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9055 - loss: 0.4833
# Epoch 11: val_loss improved from 0.40584 to 0.37788, saving model to best_deepskin_densenet169_smote.keras
#
# Epoch 11: finished saving model to best_deepskin_densenet169_smote.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9071 - loss: 0.4787 - val_accuracy: 0.9457 - val_loss: 0.3779 - learning_rate: 1.0000e-04
# Epoch 12/200
# 920/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9139 - loss: 0.4536
# Epoch 12: val_loss improved from 0.37788 to 0.36218, saving model to best_deepskin_densenet169_smote.keras
#
# Epoch 12: finished saving model to best_deepskin_densenet169_smote.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9142 - loss: 0.4483 - val_accuracy: 0.9489 - val_loss: 0.3622 - learning_rate: 1.0000e-04
# Epoch 13/200
# 926/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9170 - loss: 0.4332
# Epoch 13: val_loss improved from 0.36218 to 0.34943, saving model to best_deepskin_densenet169_smote.keras
#
# Epoch 13: finished saving model to best_deepskin_densenet169_smote.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9168 - loss: 0.4323 - val_accuracy: 0.9521 - val_loss: 0.3494 - learning_rate: 1.0000e-04
# Epoch 14/200
# 914/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9225 - loss: 0.4134
# Epoch 14: val_loss improved from 0.34943 to 0.33494, saving model to best_deepskin_densenet169_smote.keras
#
# Epoch 14: finished saving model to best_deepskin_densenet169_smote.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9236 - loss: 0.4106 - val_accuracy: 0.9562 - val_loss: 0.3349 - learning_rate: 1.0000e-04
# Epoch 15/200
# 919/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9243 - loss: 0.4018
# Epoch 15: val_loss did not improve from 0.33494
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9267 - loss: 0.3970 - val_accuracy: 0.9519 - val_loss: 0.3369 - learning_rate: 1.0000e-04
# Epoch 16/200
# 920/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9299 - loss: 0.3758
# Epoch 16: val_loss improved from 0.33494 to 0.30828, saving model to best_deepskin_densenet169_smote.keras
#
# Epoch 16: finished saving model to best_deepskin_densenet169_smote.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9331 - loss: 0.3703 - val_accuracy: 0.9590 - val_loss: 0.3083 - learning_rate: 1.0000e-04
# Epoch 17/200
# 929/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9370 - loss: 0.3555
# Epoch 17: val_loss improved from 0.30828 to 0.29732, saving model to best_deepskin_densenet169_smote.keras
#
# Epoch 17: finished saving model to best_deepskin_densenet169_smote.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9384 - loss: 0.3540 - val_accuracy: 0.9603 - val_loss: 0.2973 - learning_rate: 1.0000e-04
# Epoch 18/200
# 923/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9379 - loss: 0.3477
# Epoch 18: val_loss improved from 0.29732 to 0.29085, saving model to best_deepskin_densenet169_smote.keras
#
# Epoch 18: finished saving model to best_deepskin_densenet169_smote.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9392 - loss: 0.3434 - val_accuracy: 0.9634 - val_loss: 0.2909 - learning_rate: 1.0000e-04
# Epoch 19/200
# 910/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9387 - loss: 0.3403
# Epoch 19: val_loss improved from 0.29085 to 0.28006, saving model to best_deepskin_densenet169_smote.keras
#
# Epoch 19: finished saving model to best_deepskin_densenet169_smote.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9398 - loss: 0.3360 - val_accuracy: 0.9631 - val_loss: 0.2801 - learning_rate: 1.0000e-04
# Epoch 20/200
# 926/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9439 - loss: 0.3230
# Epoch 20: val_loss improved from 0.28006 to 0.26603, saving model to best_deepskin_densenet169_smote.keras
#
# Epoch 20: finished saving model to best_deepskin_densenet169_smote.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9435 - loss: 0.3235 - val_accuracy: 0.9636 - val_loss: 0.2660 - learning_rate: 1.0000e-04
# Epoch 21/200
# 920/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9480 - loss: 0.3080
# Epoch 21: val_loss improved from 0.26603 to 0.25932, saving model to best_deepskin_densenet169_smote.keras
#
# Epoch 21: finished saving model to best_deepskin_densenet169_smote.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9467 - loss: 0.3094 - val_accuracy: 0.9674 - val_loss: 0.2593 - learning_rate: 1.0000e-04
# Epoch 22/200
# 924/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9463 - loss: 0.3061
# Epoch 22: val_loss did not improve from 0.25932
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9472 - loss: 0.3040 - val_accuracy: 0.9636 - val_loss: 0.2601 - learning_rate: 1.0000e-04
# Epoch 23/200
# 930/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9493 - loss: 0.2967
# Epoch 23: val_loss improved from 0.25932 to 0.25071, saving model to best_deepskin_densenet169_smote.keras
#
# Epoch 23: finished saving model to best_deepskin_densenet169_smote.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9492 - loss: 0.2947 - val_accuracy: 0.9666 - val_loss: 0.2507 - learning_rate: 1.0000e-04
# Epoch 24/200
# 928/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9510 - loss: 0.2867
# Epoch 24: val_loss did not improve from 0.25071
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9536 - loss: 0.2811 - val_accuracy: 0.9650 - val_loss: 0.2536 - learning_rate: 1.0000e-04
# Epoch 25/200
# 910/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9534 - loss: 0.2788
# Epoch 25: val_loss improved from 0.25071 to 0.23897, saving model to best_deepskin_densenet169_smote.keras
#
# Epoch 25: finished saving model to best_deepskin_densenet169_smote.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9533 - loss: 0.2768 - val_accuracy: 0.9676 - val_loss: 0.2390 - learning_rate: 1.0000e-04
# Epoch 26/200
# 910/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9536 - loss: 0.2693
# Epoch 26: val_loss improved from 0.23897 to 0.23346, saving model to best_deepskin_densenet169_smote.keras
#
# Epoch 26: finished saving model to best_deepskin_densenet169_smote.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9541 - loss: 0.2687 - val_accuracy: 0.9694 - val_loss: 0.2335 - learning_rate: 1.0000e-04
# Epoch 27/200
# 920/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9573 - loss: 0.2597
# Epoch 27: val_loss improved from 0.23346 to 0.22805, saving model to best_deepskin_densenet169_smote.keras
#
# Epoch 27: finished saving model to best_deepskin_densenet169_smote.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9570 - loss: 0.2586 - val_accuracy: 0.9680 - val_loss: 0.2280 - learning_rate: 1.0000e-04
# Epoch 28/200
# 931/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9580 - loss: 0.2537
# Epoch 28: val_loss improved from 0.22805 to 0.21529, saving model to best_deepskin_densenet169_smote.keras
#
# Epoch 28: finished saving model to best_deepskin_densenet169_smote.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9577 - loss: 0.2531 - val_accuracy: 0.9723 - val_loss: 0.2153 - learning_rate: 1.0000e-04
# Epoch 29/200
# 927/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9533 - loss: 0.2602
# Epoch 29: val_loss improved from 0.21529 to 0.20878, saving model to best_deepskin_densenet169_smote.keras
#
# Epoch 29: finished saving model to best_deepskin_densenet169_smote.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9535 - loss: 0.2604 - val_accuracy: 0.9743 - val_loss: 0.2088 - learning_rate: 1.0000e-04
# Epoch 30/200
# 927/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9556 - loss: 0.2524
# Epoch 30: val_loss did not improve from 0.20878
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9569 - loss: 0.2484 - val_accuracy: 0.9692 - val_loss: 0.2200 - learning_rate: 1.0000e-04
# Epoch 31/200
# 920/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9590 - loss: 0.2441
# Epoch 31: val_loss did not improve from 0.20878
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9586 - loss: 0.2443 - val_accuracy: 0.9704 - val_loss: 0.2132 - learning_rate: 1.0000e-04
# Epoch 32/200
# 925/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9592 - loss: 0.2351
# Epoch 32: val_loss improved from 0.20878 to 0.20172, saving model to best_deepskin_densenet169_smote.keras
#
# Epoch 32: finished saving model to best_deepskin_densenet169_smote.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9599 - loss: 0.2344 - val_accuracy: 0.9738 - val_loss: 0.2017 - learning_rate: 1.0000e-04
# Epoch 33/200
# 911/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9624 - loss: 0.2278
# Epoch 33: val_loss improved from 0.20172 to 0.19916, saving model to best_deepskin_densenet169_smote.keras
#
# Epoch 33: finished saving model to best_deepskin_densenet169_smote.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9623 - loss: 0.2269 - val_accuracy: 0.9742 - val_loss: 0.1992 - learning_rate: 1.0000e-04
# Epoch 34/200
# 934/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9647 - loss: 0.2220
# Epoch 34: val_loss did not improve from 0.19916
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9624 - loss: 0.2260 - val_accuracy: 0.9676 - val_loss: 0.2137 - learning_rate: 1.0000e-04
# Epoch 35/200
# 922/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9649 - loss: 0.2153
# Epoch 35: val_loss did not improve from 0.19916
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9635 - loss: 0.2163 - val_accuracy: 0.9696 - val_loss: 0.2045 - learning_rate: 1.0000e-04
# Epoch 36/200
# 918/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9653 - loss: 0.2158
# Epoch 36: val_loss did not improve from 0.19916
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9631 - loss: 0.2186 - val_accuracy: 0.9714 - val_loss: 0.1994 - learning_rate: 1.0000e-04
# Epoch 37/200
# 919/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9656 - loss: 0.2088
# Epoch 37: val_loss improved from 0.19916 to 0.19767, saving model to best_deepskin_densenet169_smote.keras
#
# Epoch 37: finished saving model to best_deepskin_densenet169_smote.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9650 - loss: 0.2116 - val_accuracy: 0.9714 - val_loss: 0.1977 - learning_rate: 1.0000e-04
# Epoch 38/200
# 931/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9625 - loss: 0.2109
# Epoch 38: val_loss did not improve from 0.19767
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9648 - loss: 0.2079 - val_accuracy: 0.9695 - val_loss: 0.1996 - learning_rate: 1.0000e-04
# Epoch 39/200
# 910/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9668 - loss: 0.1981
# Epoch 39: val_loss improved from 0.19767 to 0.18120, saving model to best_deepskin_densenet169_smote.keras
#
# Epoch 39: finished saving model to best_deepskin_densenet169_smote.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9651 - loss: 0.2033 - val_accuracy: 0.9758 - val_loss: 0.1812 - learning_rate: 1.0000e-04
# Epoch 40/200
# 925/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9644 - loss: 0.2053
# Epoch 40: val_loss did not improve from 0.18120
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9628 - loss: 0.2105 - val_accuracy: 0.9707 - val_loss: 0.1868 - learning_rate: 1.0000e-04
# Epoch 41/200
# 937/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9639 - loss: 0.2082
# Epoch 41: val_loss did not improve from 0.18120
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9659 - loss: 0.2022 - val_accuracy: 0.9742 - val_loss: 0.1843 - learning_rate: 1.0000e-04
# Epoch 42/200
# 912/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9644 - loss: 0.2016
# Epoch 42: val_loss improved from 0.18120 to 0.17714, saving model to best_deepskin_densenet169_smote.keras
#
# Epoch 42: finished saving model to best_deepskin_densenet169_smote.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9656 - loss: 0.1998 - val_accuracy: 0.9763 - val_loss: 0.1771 - learning_rate: 1.0000e-04
# Epoch 43/200
# 918/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9639 - loss: 0.1965
# Epoch 43: val_loss did not improve from 0.17714
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9655 - loss: 0.1962 - val_accuracy: 0.9724 - val_loss: 0.1847 - learning_rate: 1.0000e-04
# Epoch 44/200
# 936/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9688 - loss: 0.1898
# Epoch 44: val_loss did not improve from 0.17714
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9680 - loss: 0.1905 - val_accuracy: 0.9743 - val_loss: 0.1777 - learning_rate: 1.0000e-04
# Epoch 45/200
# 927/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9689 - loss: 0.1859
# Epoch 45: val_loss did not improve from 0.17714
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9678 - loss: 0.1869 - val_accuracy: 0.9724 - val_loss: 0.1799 - learning_rate: 1.0000e-04
# Epoch 46/200
# 913/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9675 - loss: 0.1883
# Epoch 46: val_loss improved from 0.17714 to 0.17672, saving model to best_deepskin_densenet169_smote.keras
#
# Epoch 46: finished saving model to best_deepskin_densenet169_smote.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9660 - loss: 0.1912 - val_accuracy: 0.9744 - val_loss: 0.1767 - learning_rate: 1.0000e-04
# Epoch 47/200
# 916/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9670 - loss: 0.1907
# Epoch 47: val_loss did not improve from 0.17672
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9657 - loss: 0.1932 - val_accuracy: 0.9719 - val_loss: 0.1840 - learning_rate: 1.0000e-04
# Epoch 48/200
# 924/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9652 - loss: 0.1957
# Epoch 48: val_loss improved from 0.17672 to 0.17401, saving model to best_deepskin_densenet169_smote.keras
#
# Epoch 48: finished saving model to best_deepskin_densenet169_smote.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9659 - loss: 0.1912 - val_accuracy: 0.9752 - val_loss: 0.1740 - learning_rate: 1.0000e-04
# Epoch 49/200
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9651 - loss: 0.1926
# Epoch 49: val_loss improved from 0.17401 to 0.17281, saving model to best_deepskin_densenet169_smote.keras
#
# Epoch 49: finished saving model to best_deepskin_densenet169_smote.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9664 - loss: 0.1889 - val_accuracy: 0.9750 - val_loss: 0.1728 - learning_rate: 1.0000e-04
# Epoch 50/200
# 915/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9690 - loss: 0.1788
# Epoch 50: val_loss improved from 0.17281 to 0.17020, saving model to best_deepskin_densenet169_smote.keras
#
# Epoch 50: finished saving model to best_deepskin_densenet169_smote.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9693 - loss: 0.1793 - val_accuracy: 0.9744 - val_loss: 0.1702 - learning_rate: 1.0000e-04
# Epoch 51/200
# 915/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9681 - loss: 0.1827
# Epoch 51: val_loss improved from 0.17020 to 0.16430, saving model to best_deepskin_densenet169_smote.keras
#
# Epoch 51: finished saving model to best_deepskin_densenet169_smote.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9672 - loss: 0.1847 - val_accuracy: 0.9767 - val_loss: 0.1643 - learning_rate: 1.0000e-04
# Epoch 52/200
# 937/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9673 - loss: 0.1847
# Epoch 52: val_loss did not improve from 0.16430
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9680 - loss: 0.1813 - val_accuracy: 0.9760 - val_loss: 0.1690 - learning_rate: 1.0000e-04
# Epoch 53/200
# 918/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9673 - loss: 0.1791
# Epoch 53: val_loss did not improve from 0.16430
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9676 - loss: 0.1793 - val_accuracy: 0.9762 - val_loss: 0.1675 - learning_rate: 1.0000e-04
# Epoch 54/200
# 938/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9666 - loss: 0.1816
# Epoch 54: val_loss did not improve from 0.16430
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9659 - loss: 0.1834 - val_accuracy: 0.9708 - val_loss: 0.1810 - learning_rate: 1.0000e-04
# Epoch 55/200
# 923/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9695 - loss: 0.1752
# Epoch 55: ReduceLROnPlateau reducing learning rate to 1.9999999494757503e-05.
#
# Epoch 55: val_loss did not improve from 0.16430
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9685 - loss: 0.1754 - val_accuracy: 0.9742 - val_loss: 0.1711 - learning_rate: 1.0000e-04
# Epoch 56/200
# 920/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9747 - loss: 0.1590
# Epoch 56: val_loss improved from 0.16430 to 0.14301, saving model to best_deepskin_densenet169_smote.keras
#
# Epoch 56: finished saving model to best_deepskin_densenet169_smote.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9772 - loss: 0.1513 - val_accuracy: 0.9820 - val_loss: 0.1430 - learning_rate: 2.0000e-05
# Epoch 57/200
# 927/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9820 - loss: 0.1395
# Epoch 57: val_loss did not improve from 0.14301
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9814 - loss: 0.1412 - val_accuracy: 0.9811 - val_loss: 0.1441 - learning_rate: 2.0000e-05
# Epoch 58/200
# 924/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9821 - loss: 0.1368
# Epoch 58: val_loss improved from 0.14301 to 0.14266, saving model to best_deepskin_densenet169_smote.keras
#
# Epoch 58: finished saving model to best_deepskin_densenet169_smote.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9826 - loss: 0.1349 - val_accuracy: 0.9816 - val_loss: 0.1427 - learning_rate: 2.0000e-05
# Epoch 59/200
# 937/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9831 - loss: 0.1318
# Epoch 59: val_loss improved from 0.14266 to 0.13989, saving model to best_deepskin_densenet169_smote.keras
#
# Epoch 59: finished saving model to best_deepskin_densenet169_smote.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9843 - loss: 0.1299 - val_accuracy: 0.9827 - val_loss: 0.1399 - learning_rate: 2.0000e-05
# Epoch 60/200
# 932/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9840 - loss: 0.1276
# Epoch 60: val_loss did not improve from 0.13989
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9845 - loss: 0.1271 - val_accuracy: 0.9823 - val_loss: 0.1408 - learning_rate: 2.0000e-05
# Epoch 61/200
# 925/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9844 - loss: 0.1252
# Epoch 61: val_loss improved from 0.13989 to 0.13690, saving model to best_deepskin_densenet169_smote.keras
#
# Epoch 61: finished saving model to best_deepskin_densenet169_smote.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9851 - loss: 0.1240 - val_accuracy: 0.9828 - val_loss: 0.1369 - learning_rate: 2.0000e-05
# Epoch 62/200
# 910/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9849 - loss: 0.1242
# Epoch 62: val_loss improved from 0.13690 to 0.13400, saving model to best_deepskin_densenet169_smote.keras
#
# Epoch 62: finished saving model to best_deepskin_densenet169_smote.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9855 - loss: 0.1221 - val_accuracy: 0.9827 - val_loss: 0.1340 - learning_rate: 2.0000e-05
# Epoch 63/200
# 920/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9855 - loss: 0.1207
# Epoch 63: val_loss improved from 0.13400 to 0.13157, saving model to best_deepskin_densenet169_smote.keras
#
# Epoch 63: finished saving model to best_deepskin_densenet169_smote.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9873 - loss: 0.1177 - val_accuracy: 0.9839 - val_loss: 0.1316 - learning_rate: 2.0000e-05
# Epoch 64/200
# 938/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9861 - loss: 0.1183
# Epoch 64: val_loss did not improve from 0.13157
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9877 - loss: 0.1144 - val_accuracy: 0.9840 - val_loss: 0.1326 - learning_rate: 2.0000e-05
# Epoch 65/200
# 932/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9889 - loss: 0.1120
# Epoch 65: val_loss improved from 0.13157 to 0.12924, saving model to best_deepskin_densenet169_smote.keras
#
# Epoch 65: finished saving model to best_deepskin_densenet169_smote.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9884 - loss: 0.1121 - val_accuracy: 0.9840 - val_loss: 0.1292 - learning_rate: 2.0000e-05
# Epoch 66/200
# 934/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9878 - loss: 0.1134
# Epoch 66: val_loss improved from 0.12924 to 0.12889, saving model to best_deepskin_densenet169_smote.keras
#
# Epoch 66: finished saving model to best_deepskin_densenet169_smote.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9878 - loss: 0.1135 - val_accuracy: 0.9836 - val_loss: 0.1289 - learning_rate: 2.0000e-05
# Epoch 67/200
# 926/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9898 - loss: 0.1083
# Epoch 67: val_loss did not improve from 0.12889
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9893 - loss: 0.1084 - val_accuracy: 0.9836 - val_loss: 0.1321 - learning_rate: 2.0000e-05
# Epoch 68/200
# 917/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9901 - loss: 0.1068
# Epoch 68: val_loss did not improve from 0.12889
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9892 - loss: 0.1086 - val_accuracy: 0.9844 - val_loss: 0.1290 - learning_rate: 2.0000e-05
# Epoch 69/200
# 936/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9882 - loss: 0.1109
# Epoch 69: val_loss improved from 0.12889 to 0.12698, saving model to best_deepskin_densenet169_smote.keras
#
# Epoch 69: finished saving model to best_deepskin_densenet169_smote.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9882 - loss: 0.1104 - val_accuracy: 0.9843 - val_loss: 0.1270 - learning_rate: 2.0000e-05
# Epoch 70/200
# 923/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9886 - loss: 0.1085
# Epoch 70: val_loss improved from 0.12698 to 0.12625, saving model to best_deepskin_densenet169_smote.keras
#
# Epoch 70: finished saving model to best_deepskin_densenet169_smote.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9881 - loss: 0.1094 - val_accuracy: 0.9851 - val_loss: 0.1262 - learning_rate: 2.0000e-05
# Epoch 71/200
# 910/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9904 - loss: 0.1043
# Epoch 71: val_loss did not improve from 0.12625
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9893 - loss: 0.1048 - val_accuracy: 0.9842 - val_loss: 0.1291 - learning_rate: 2.0000e-05
# Epoch 72/200
# 934/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9902 - loss: 0.1041
# Epoch 72: val_loss did not improve from 0.12625
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9899 - loss: 0.1040 - val_accuracy: 0.9843 - val_loss: 0.1284 - learning_rate: 2.0000e-05
# Epoch 73/200
# 929/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9908 - loss: 0.1022
# Epoch 73: val_loss did not improve from 0.12625
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9900 - loss: 0.1037 - val_accuracy: 0.9848 - val_loss: 0.1264 - learning_rate: 2.0000e-05
# Epoch 74/200
# 938/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9910 - loss: 0.1022
# Epoch 74: ReduceLROnPlateau reducing learning rate to 3.999999898951501e-06.
#
# Epoch 74: val_loss did not improve from 0.12625
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9905 - loss: 0.1016 - val_accuracy: 0.9839 - val_loss: 0.1276 - learning_rate: 2.0000e-05
# Epoch 75/200
# 927/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9901 - loss: 0.1018
# Epoch 75: val_loss improved from 0.12625 to 0.12380, saving model to best_deepskin_densenet169_smote.keras
#
# Epoch 75: finished saving model to best_deepskin_densenet169_smote.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9900 - loss: 0.1014 - val_accuracy: 0.9852 - val_loss: 0.1238 - learning_rate: 4.0000e-06
# Epoch 76/200
# 928/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9903 - loss: 0.1001
# Epoch 76: val_loss improved from 0.12380 to 0.12327, saving model to best_deepskin_densenet169_smote.keras
#
# Epoch 76: finished saving model to best_deepskin_densenet169_smote.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9914 - loss: 0.0985 - val_accuracy: 0.9859 - val_loss: 0.1233 - learning_rate: 4.0000e-06
# Epoch 77/200
# 912/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9909 - loss: 0.0991
# Epoch 77: val_loss improved from 0.12327 to 0.12314, saving model to best_deepskin_densenet169_smote.keras
#
# Epoch 77: finished saving model to best_deepskin_densenet169_smote.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9912 - loss: 0.0989 - val_accuracy: 0.9852 - val_loss: 0.1231 - learning_rate: 4.0000e-06
# Epoch 78/200
# 938/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9911 - loss: 0.0997
# Epoch 78: val_loss improved from 0.12314 to 0.12213, saving model to best_deepskin_densenet169_smote.keras
#
# Epoch 78: finished saving model to best_deepskin_densenet169_smote.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9914 - loss: 0.0993 - val_accuracy: 0.9856 - val_loss: 0.1221 - learning_rate: 4.0000e-06
# Epoch 79/200
# 934/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9917 - loss: 0.0984
# Epoch 79: val_loss improved from 0.12213 to 0.12151, saving model to best_deepskin_densenet169_smote.keras
#
# Epoch 79: finished saving model to best_deepskin_densenet169_smote.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9920 - loss: 0.0979 - val_accuracy: 0.9858 - val_loss: 0.1215 - learning_rate: 4.0000e-06
# Epoch 80/200
# 915/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9927 - loss: 0.0970
# Epoch 80: val_loss did not improve from 0.12151
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9922 - loss: 0.0971 - val_accuracy: 0.9854 - val_loss: 0.1217 - learning_rate: 4.0000e-06
# Epoch 81/200
# 938/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9928 - loss: 0.0944
# Epoch 81: val_loss improved from 0.12151 to 0.12145, saving model to best_deepskin_densenet169_smote.keras
#
# Epoch 81: finished saving model to best_deepskin_densenet169_smote.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9920 - loss: 0.0965 - val_accuracy: 0.9854 - val_loss: 0.1215 - learning_rate: 4.0000e-06
# Epoch 82/200
# 916/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9926 - loss: 0.0942
# Epoch 82: val_loss improved from 0.12145 to 0.12100, saving model to best_deepskin_densenet169_smote.keras
#
# Epoch 82: finished saving model to best_deepskin_densenet169_smote.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9926 - loss: 0.0950 - val_accuracy: 0.9856 - val_loss: 0.1210 - learning_rate: 4.0000e-06
# Epoch 83/200
# 938/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9927 - loss: 0.0959
# Epoch 83: val_loss did not improve from 0.12100
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9922 - loss: 0.0962 - val_accuracy: 0.9854 - val_loss: 0.1213 - learning_rate: 4.0000e-06
# Epoch 84/200
# 927/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9914 - loss: 0.0969
# Epoch 84: val_loss improved from 0.12100 to 0.12045, saving model to best_deepskin_densenet169_smote.keras
#
# Epoch 84: finished saving model to best_deepskin_densenet169_smote.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9913 - loss: 0.0965 - val_accuracy: 0.9855 - val_loss: 0.1205 - learning_rate: 4.0000e-06
# Epoch 85/200
# 930/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9926 - loss: 0.0952
# Epoch 85: val_loss did not improve from 0.12045
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9928 - loss: 0.0940 - val_accuracy: 0.9855 - val_loss: 0.1205 - learning_rate: 4.0000e-06
# Epoch 86/200
# 926/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9922 - loss: 0.0941
# Epoch 86: val_loss improved from 0.12045 to 0.11990, saving model to best_deepskin_densenet169_smote.keras
#
# Epoch 86: finished saving model to best_deepskin_densenet169_smote.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9924 - loss: 0.0942 - val_accuracy: 0.9858 - val_loss: 0.1199 - learning_rate: 4.0000e-06
# Epoch 87/200
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9938 - loss: 0.0938
# Epoch 87: val_loss improved from 0.11990 to 0.11964, saving model to best_deepskin_densenet169_smote.keras
#
# Epoch 87: finished saving model to best_deepskin_densenet169_smote.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9929 - loss: 0.0956 - val_accuracy: 0.9860 - val_loss: 0.1196 - learning_rate: 4.0000e-06
# Epoch 88/200
# 917/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9927 - loss: 0.0938
# Epoch 88: val_loss improved from 0.11964 to 0.11933, saving model to best_deepskin_densenet169_smote.keras
#
# Epoch 88: finished saving model to best_deepskin_densenet169_smote.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9922 - loss: 0.0949 - val_accuracy: 0.9859 - val_loss: 0.1193 - learning_rate: 4.0000e-06
# Epoch 89/200
# 936/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9916 - loss: 0.0948
# Epoch 89: val_loss did not improve from 0.11933
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9921 - loss: 0.0951 - val_accuracy: 0.9856 - val_loss: 0.1195 - learning_rate: 4.0000e-06
# Epoch 90/200
# 926/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9918 - loss: 0.0961
# Epoch 90: val_loss improved from 0.11933 to 0.11904, saving model to best_deepskin_densenet169_smote.keras
#
# Epoch 90: finished saving model to best_deepskin_densenet169_smote.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9925 - loss: 0.0952 - val_accuracy: 0.9859 - val_loss: 0.1190 - learning_rate: 4.0000e-06
# Epoch 91/200
# 924/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9931 - loss: 0.0922
# Epoch 91: val_loss did not improve from 0.11904
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9932 - loss: 0.0928 - val_accuracy: 0.9854 - val_loss: 0.1193 - learning_rate: 4.0000e-06
# Epoch 92/200
# 911/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9932 - loss: 0.0935
# Epoch 92: val_loss improved from 0.11904 to 0.11886, saving model to best_deepskin_densenet169_smote.keras
#
# Epoch 92: finished saving model to best_deepskin_densenet169_smote.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9929 - loss: 0.0937 - val_accuracy: 0.9856 - val_loss: 0.1189 - learning_rate: 4.0000e-06
# Epoch 93/200
# 925/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9928 - loss: 0.0942
# Epoch 93: val_loss did not improve from 0.11886
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9936 - loss: 0.0920 - val_accuracy: 0.9855 - val_loss: 0.1193 - learning_rate: 4.0000e-06
# Epoch 94/200
# 910/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9935 - loss: 0.0919
# Epoch 94: val_loss did not improve from 0.11886
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9934 - loss: 0.0929 - val_accuracy: 0.9851 - val_loss: 0.1202 - learning_rate: 4.0000e-06
# Epoch 95/200
# 922/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9921 - loss: 0.0940
# Epoch 95: val_loss did not improve from 0.11886
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9924 - loss: 0.0933 - val_accuracy: 0.9852 - val_loss: 0.1189 - learning_rate: 4.0000e-06
# Epoch 96/200
# 914/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9941 - loss: 0.0910
# Epoch 96: ReduceLROnPlateau reducing learning rate to 7.999999979801942e-07.
#
# Epoch 96: val_loss did not improve from 0.11886
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9931 - loss: 0.0935 - val_accuracy: 0.9852 - val_loss: 0.1194 - learning_rate: 4.0000e-06
# Epoch 97/200
# 933/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9923 - loss: 0.0951
# Epoch 97: val_loss did not improve from 0.11886
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9928 - loss: 0.0941 - val_accuracy: 0.9856 - val_loss: 0.1189 - learning_rate: 8.0000e-07
# Epoch 98/200
# 912/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9934 - loss: 0.0915
# Epoch 98: val_loss improved from 0.11886 to 0.11886, saving model to best_deepskin_densenet169_smote.keras
#
# Epoch 98: finished saving model to best_deepskin_densenet169_smote.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9932 - loss: 0.0922 - val_accuracy: 0.9858 - val_loss: 0.1189 - learning_rate: 8.0000e-07
# Epoch 99/200
# 920/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9930 - loss: 0.0926
# Epoch 99: val_loss improved from 0.11886 to 0.11881, saving model to best_deepskin_densenet169_smote.keras
#
# Epoch 99: finished saving model to best_deepskin_densenet169_smote.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9933 - loss: 0.0917 - val_accuracy: 0.9854 - val_loss: 0.1188 - learning_rate: 8.0000e-07
# Epoch 100/200
# 924/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9933 - loss: 0.0918
# Epoch 100: val_loss improved from 0.11881 to 0.11868, saving model to best_deepskin_densenet169_smote.keras
#
# Epoch 100: finished saving model to best_deepskin_densenet169_smote.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9926 - loss: 0.0927 - val_accuracy: 0.9855 - val_loss: 0.1187 - learning_rate: 8.0000e-07
# Epoch 101/200
# 936/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9923 - loss: 0.0918
# Epoch 101: val_loss improved from 0.11868 to 0.11859, saving model to best_deepskin_densenet169_smote.keras
#
# Epoch 101: finished saving model to best_deepskin_densenet169_smote.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9933 - loss: 0.0911 - val_accuracy: 0.9855 - val_loss: 0.1186 - learning_rate: 8.0000e-07
# Epoch 102/200
# 921/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9936 - loss: 0.0927
# Epoch 102: val_loss improved from 0.11859 to 0.11833, saving model to best_deepskin_densenet169_smote.keras
#
# Epoch 102: finished saving model to best_deepskin_densenet169_smote.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9936 - loss: 0.0912 - val_accuracy: 0.9856 - val_loss: 0.1183 - learning_rate: 8.0000e-07
# Epoch 103/200
# 936/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9929 - loss: 0.0906
# Epoch 103: val_loss did not improve from 0.11833
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9927 - loss: 0.0915 - val_accuracy: 0.9858 - val_loss: 0.1184 - learning_rate: 8.0000e-07
# Epoch 104/200
# 930/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9933 - loss: 0.0918
# Epoch 104: val_loss did not improve from 0.11833
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9932 - loss: 0.0917 - val_accuracy: 0.9856 - val_loss: 0.1183 - learning_rate: 8.0000e-07
# Epoch 105/200
# 910/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9936 - loss: 0.0910
# Epoch 105: val_loss improved from 0.11833 to 0.11815, saving model to best_deepskin_densenet169_smote.keras
#
# Epoch 105: finished saving model to best_deepskin_densenet169_smote.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9936 - loss: 0.0908 - val_accuracy: 0.9858 - val_loss: 0.1181 - learning_rate: 8.0000e-07
# Epoch 106/200
# 929/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9912 - loss: 0.0938
# Epoch 106: val_loss did not improve from 0.11815
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9920 - loss: 0.0936 - val_accuracy: 0.9856 - val_loss: 0.1183 - learning_rate: 8.0000e-07
# Epoch 107/200
# 932/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9950 - loss: 0.0883
# Epoch 107: val_loss did not improve from 0.11815
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9939 - loss: 0.0900 - val_accuracy: 0.9855 - val_loss: 0.1182 - learning_rate: 8.0000e-07
# Epoch 108/200
# 938/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9924 - loss: 0.0932
# Epoch 108: val_loss improved from 0.11815 to 0.11794, saving model to best_deepskin_densenet169_smote.keras
#
# Epoch 108: finished saving model to best_deepskin_densenet169_smote.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9925 - loss: 0.0937 - val_accuracy: 0.9856 - val_loss: 0.1179 - learning_rate: 8.0000e-07
# Epoch 109/200
# 925/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9928 - loss: 0.0921
# Epoch 109: val_loss did not improve from 0.11794
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9932 - loss: 0.0912 - val_accuracy: 0.9856 - val_loss: 0.1181 - learning_rate: 8.0000e-07
# Epoch 110/200
# 917/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9933 - loss: 0.0915
# Epoch 110: val_loss did not improve from 0.11794
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9932 - loss: 0.0912 - val_accuracy: 0.9858 - val_loss: 0.1182 - learning_rate: 8.0000e-07
# Epoch 111/200
# 926/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9933 - loss: 0.0921
# Epoch 111: val_loss improved from 0.11794 to 0.11782, saving model to best_deepskin_densenet169_smote.keras
#
# Epoch 111: finished saving model to best_deepskin_densenet169_smote.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9934 - loss: 0.0915 - val_accuracy: 0.9855 - val_loss: 0.1178 - learning_rate: 8.0000e-07
# Epoch 112/200
# 924/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9935 - loss: 0.0925
# Epoch 112: val_loss improved from 0.11782 to 0.11763, saving model to best_deepskin_densenet169_smote.keras
#
# Epoch 112: finished saving model to best_deepskin_densenet169_smote.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9939 - loss: 0.0904 - val_accuracy: 0.9856 - val_loss: 0.1176 - learning_rate: 8.0000e-07
# Epoch 113/200
# 918/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9937 - loss: 0.0901
# Epoch 113: val_loss did not improve from 0.11763
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9935 - loss: 0.0908 - val_accuracy: 0.9856 - val_loss: 0.1178 - learning_rate: 8.0000e-07
# Epoch 114/200
# 925/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9925 - loss: 0.0921
# Epoch 114: val_loss did not improve from 0.11763
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9926 - loss: 0.0930 - val_accuracy: 0.9856 - val_loss: 0.1178 - learning_rate: 8.0000e-07
# Epoch 115/200
# 909/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9932 - loss: 0.0920
# Epoch 115: val_loss did not improve from 0.11763
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9932 - loss: 0.0915 - val_accuracy: 0.9858 - val_loss: 0.1178 - learning_rate: 8.0000e-07
# Epoch 116/200
# 920/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9927 - loss: 0.0918
# Epoch 116: ReduceLROnPlateau reducing learning rate to 1.600000018697756e-07.
#
# Epoch 116: val_loss improved from 0.11763 to 0.11761, saving model to best_deepskin_densenet169_smote.keras
#
# Epoch 116: finished saving model to best_deepskin_densenet169_smote.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9931 - loss: 0.0918 - val_accuracy: 0.9859 - val_loss: 0.1176 - learning_rate: 8.0000e-07
# Epoch 117/200
# 925/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9939 - loss: 0.0924
# Epoch 117: val_loss improved from 0.11761 to 0.11749, saving model to best_deepskin_densenet169_smote.keras
#
# Epoch 117: finished saving model to best_deepskin_densenet169_smote.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9940 - loss: 0.0905 - val_accuracy: 0.9859 - val_loss: 0.1175 - learning_rate: 1.6000e-07
# Epoch 118/200
# 927/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9927 - loss: 0.0901
# Epoch 118: val_loss improved from 0.11749 to 0.11746, saving model to best_deepskin_densenet169_smote.keras
#
# Epoch 118: finished saving model to best_deepskin_densenet169_smote.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9932 - loss: 0.0901 - val_accuracy: 0.9858 - val_loss: 0.1175 - learning_rate: 1.6000e-07
# Epoch 119/200
# 917/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9934 - loss: 0.0934
# Epoch 119: val_loss improved from 0.11746 to 0.11744, saving model to best_deepskin_densenet169_smote.keras
#
# Epoch 119: finished saving model to best_deepskin_densenet169_smote.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9933 - loss: 0.0923 - val_accuracy: 0.9858 - val_loss: 0.1174 - learning_rate: 1.6000e-07
# Epoch 120/200
# 925/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9916 - loss: 0.0936
# Epoch 120: val_loss improved from 0.11744 to 0.11743, saving model to best_deepskin_densenet169_smote.keras
#
# Epoch 120: finished saving model to best_deepskin_densenet169_smote.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9926 - loss: 0.0922 - val_accuracy: 0.9858 - val_loss: 0.1174 - learning_rate: 1.6000e-07
# Epoch 121/200
# 913/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9949 - loss: 0.0880
# Epoch 121: ReduceLROnPlateau reducing learning rate to 1e-07.
#
# Epoch 121: val_loss did not improve from 0.11743
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9941 - loss: 0.0894 - val_accuracy: 0.9858 - val_loss: 0.1174 - learning_rate: 1.6000e-07
# Epoch 122/200
# 914/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9931 - loss: 0.0903
# Epoch 122: val_loss did not improve from 0.11743
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9933 - loss: 0.0911 - val_accuracy: 0.9858 - val_loss: 0.1174 - learning_rate: 1.0000e-07
# Epoch 123/200
# 933/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9939 - loss: 0.0907
# Epoch 123: val_loss did not improve from 0.11743
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9940 - loss: 0.0905 - val_accuracy: 0.9856 - val_loss: 0.1174 - learning_rate: 1.0000e-07
# Epoch 124/200
# 925/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9932 - loss: 0.0918
# Epoch 124: val_loss did not improve from 0.11743
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9932 - loss: 0.0919 - val_accuracy: 0.9856 - val_loss: 0.1174 - learning_rate: 1.0000e-07
# Epoch 125/200
# 911/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9943 - loss: 0.0916
# Epoch 125: val_loss improved from 0.11743 to 0.11739, saving model to best_deepskin_densenet169_smote.keras
#
# Epoch 125: finished saving model to best_deepskin_densenet169_smote.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9938 - loss: 0.0917 - val_accuracy: 0.9858 - val_loss: 0.1174 - learning_rate: 1.0000e-07
# Epoch 126/200
# 933/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9932 - loss: 0.0902
# Epoch 126: val_loss did not improve from 0.11739
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9938 - loss: 0.0904 - val_accuracy: 0.9856 - val_loss: 0.1174 - learning_rate: 1.0000e-07
# Epoch 127/200
# 926/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9938 - loss: 0.0918
# Epoch 127: val_loss improved from 0.11739 to 0.11738, saving model to best_deepskin_densenet169_smote.keras
#
# Epoch 127: finished saving model to best_deepskin_densenet169_smote.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9939 - loss: 0.0907 - val_accuracy: 0.9858 - val_loss: 0.1174 - learning_rate: 1.0000e-07
# Epoch 128/200
# 934/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9926 - loss: 0.0912
# Epoch 128: val_loss improved from 0.11738 to 0.11736, saving model to best_deepskin_densenet169_smote.keras
#
# Epoch 128: finished saving model to best_deepskin_densenet169_smote.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9929 - loss: 0.0910 - val_accuracy: 0.9858 - val_loss: 0.1174 - learning_rate: 1.0000e-07
# Epoch 129/200
# 920/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9928 - loss: 0.0918
# Epoch 129: val_loss improved from 0.11736 to 0.11736, saving model to best_deepskin_densenet169_smote.keras
#
# Epoch 129: finished saving model to best_deepskin_densenet169_smote.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9932 - loss: 0.0919 - val_accuracy: 0.9858 - val_loss: 0.1174 - learning_rate: 1.0000e-07
# Epoch 130/200
# 937/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9932 - loss: 0.0921
# Epoch 130: val_loss did not improve from 0.11736
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9930 - loss: 0.0921 - val_accuracy: 0.9858 - val_loss: 0.1174 - learning_rate: 1.0000e-07
# Epoch 131/200
# 927/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9935 - loss: 0.0907
# Epoch 131: val_loss did not improve from 0.11736
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9939 - loss: 0.0899 - val_accuracy: 0.9858 - val_loss: 0.1174 - learning_rate: 1.0000e-07
# Epoch 132/200
# 937/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9935 - loss: 0.0921
# Epoch 132: val_loss did not improve from 0.11736
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9939 - loss: 0.0907 - val_accuracy: 0.9858 - val_loss: 0.1174 - learning_rate: 1.0000e-07
# Epoch 133/200
# 914/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9932 - loss: 0.0918
# Epoch 133: val_loss did not improve from 0.11736
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9931 - loss: 0.0914 - val_accuracy: 0.9858 - val_loss: 0.1174 - learning_rate: 1.0000e-07
# Epoch 134/200
# 930/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9934 - loss: 0.0907
# Epoch 134: val_loss improved from 0.11736 to 0.11735, saving model to best_deepskin_densenet169_smote.keras
#
# Epoch 134: finished saving model to best_deepskin_densenet169_smote.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9934 - loss: 0.0909 - val_accuracy: 0.9858 - val_loss: 0.1173 - learning_rate: 1.0000e-07
# Epoch 135/200
# 925/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9928 - loss: 0.0929
# Epoch 135: val_loss improved from 0.11735 to 0.11734, saving model to best_deepskin_densenet169_smote.keras
#
# Epoch 135: finished saving model to best_deepskin_densenet169_smote.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9934 - loss: 0.0917 - val_accuracy: 0.9858 - val_loss: 0.1173 - learning_rate: 1.0000e-07
# Epoch 136/200
# 922/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9934 - loss: 0.0893
# Epoch 136: val_loss improved from 0.11734 to 0.11732, saving model to best_deepskin_densenet169_smote.keras
#
# Epoch 136: finished saving model to best_deepskin_densenet169_smote.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9934 - loss: 0.0904 - val_accuracy: 0.9858 - val_loss: 0.1173 - learning_rate: 1.0000e-07
# Epoch 137/200
# 936/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9938 - loss: 0.0907
# Epoch 137: val_loss improved from 0.11732 to 0.11728, saving model to best_deepskin_densenet169_smote.keras
#
# Epoch 137: finished saving model to best_deepskin_densenet169_smote.keras
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9934 - loss: 0.0912 - val_accuracy: 0.9858 - val_loss: 0.1173 - learning_rate: 1.0000e-07
# Epoch 138/200
# 929/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9940 - loss: 0.0887
# Epoch 138: val_loss did not improve from 0.11728
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9937 - loss: 0.0894 - val_accuracy: 0.9858 - val_loss: 0.1173 - learning_rate: 1.0000e-07
# Epoch 139/200
# 909/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9938 - loss: 0.0917
# Epoch 139: val_loss did not improve from 0.11728
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9931 - loss: 0.0915 - val_accuracy: 0.9858 - val_loss: 0.1173 - learning_rate: 1.0000e-07
# Epoch 140/200
# 927/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9948 - loss: 0.0885
# Epoch 140: val_loss did not improve from 0.11728
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9943 - loss: 0.0891 - val_accuracy: 0.9858 - val_loss: 0.1173 - learning_rate: 1.0000e-07
# Epoch 141/200
# 935/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9927 - loss: 0.0922
# Epoch 141: val_loss did not improve from 0.11728
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9928 - loss: 0.0919 - val_accuracy: 0.9858 - val_loss: 0.1173 - learning_rate: 1.0000e-07
# Epoch 142/200
# 912/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9937 - loss: 0.0904
# Epoch 142: val_loss did not improve from 0.11728
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9937 - loss: 0.0900 - val_accuracy: 0.9858 - val_loss: 0.1174 - learning_rate: 1.0000e-07
# Epoch 143/200
# 934/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9935 - loss: 0.0906
# Epoch 143: val_loss did not improve from 0.11728
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9937 - loss: 0.0902 - val_accuracy: 0.9858 - val_loss: 0.1174 - learning_rate: 1.0000e-07
# Epoch 144/200
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9919 - loss: 0.0936
# Epoch 144: val_loss did not improve from 0.11728
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9923 - loss: 0.0922 - val_accuracy: 0.9858 - val_loss: 0.1174 - learning_rate: 1.0000e-07
# Epoch 145/200
# 925/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9929 - loss: 0.0916
# Epoch 145: val_loss did not improve from 0.11728
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9934 - loss: 0.0905 - val_accuracy: 0.9858 - val_loss: 0.1173 - learning_rate: 1.0000e-07
# Epoch 146/200
# 910/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9929 - loss: 0.0900
# Epoch 146: val_loss did not improve from 0.11728
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9928 - loss: 0.0912 - val_accuracy: 0.9858 - val_loss: 0.1173 - learning_rate: 1.0000e-07
# Epoch 147/200
# 928/939 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9922 - loss: 0.0917
# Epoch 147: val_loss did not improve from 0.11728
# 939/939 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9927 - loss: 0.0916 - val_accuracy: 0.9858 - val_loss: 0.1173 - learning_rate: 1.0000e-07
# Epoch 147: early stopping
# Restoring model weights from the end of the best epoch: 137.

# %%
plt.figure(figsize=(8, 5))
plt.plot(history.history["accuracy"], label="Treino")
plt.plot(history.history["val_accuracy"], label="Validação")
plt.title("Acurácia durante o treinamento")
plt.xlabel("Época")
plt.ylabel("Acurácia")
plt.legend()
plt.grid(True, alpha=0.3)
plt.savefig("acuracia_densenet169_smote.png", dpi=300, bbox_inches="tight")
plt.show()

plt.figure(figsize=(8, 5))
plt.plot(history.history["loss"], label="Treino")
plt.plot(history.history["val_loss"], label="Validação")
plt.title("Perda durante o treinamento")
plt.xlabel("Época")
plt.ylabel("Loss")
plt.legend()
plt.grid(True, alpha=0.3)
plt.savefig("loss_densenet169_smote.png", dpi=300, bbox_inches="tight")
plt.show()

# %%
best_classifier = keras.models.load_model(BEST_MODEL_PATH)

pred_probs = best_classifier.predict(X_test_features, verbose=0)
y_pred = np.argmax(pred_probs, axis=1)

print("Relatório de Classificação:")
print(classification_report(
    y_test,
    y_pred,
    target_names=classes,
    digits=4,
    zero_division=0
))

acc = accuracy_score(y_test, y_pred)

macro_precision = precision_score(y_test, y_pred, average="macro", zero_division=0)
macro_recall = recall_score(y_test, y_pred, average="macro", zero_division=0)
macro_f1 = f1_score(y_test, y_pred, average="macro", zero_division=0)

weighted_precision = precision_score(y_test, y_pred, average="weighted", zero_division=0)
weighted_recall = recall_score(y_test, y_pred, average="weighted", zero_division=0)
weighted_f1 = f1_score(y_test, y_pred, average="weighted", zero_division=0)

print("\nMÉTRICAS GERAIS DO MODELO")
print(f"Accuracy: {acc:.4f}")

print("\nMacro Average:")
print(f"  Precision: {macro_precision:.4f}")
print(f"  Recall: {macro_recall:.4f}")
print(f"  F1-Score: {macro_f1:.4f}")

print("\nWeighted Average:")
print(f"  Precision: {weighted_precision:.4f}")
print(f"  Recall: {weighted_recall:.4f}")
print(f"  F1-Score: {weighted_f1:.4f}")
# Out:
# Relatório de Classificação:
#               precision    recall  f1-score   support
#
#          MEL     0.5486    0.4305    0.4824       223
#           NV     0.8975    0.9202    0.9087      1341
#          BCC     0.6667    0.7184    0.6916       103
#        AKIEC     0.5645    0.5385    0.5512        65
#          BKL     0.5489    0.5864    0.5670       220
#           DF     0.6875    0.4783    0.5641        23
#         VASC     0.8276    0.8571    0.8421        28
#
#     accuracy                         0.8003      2003
#    macro avg     0.6773    0.6471    0.6582      2003
# weighted avg     0.7943    0.8003    0.7961      2003
#
#
# MÉTRICAS GERAIS DO MODELO
# Accuracy: 0.8003
#
# Macro Average:
#   Precision: 0.6773
#   Recall: 0.6471
#   F1-Score: 0.6582
#
# Weighted Average:
#   Precision: 0.7943
#   Recall: 0.8003
#   F1-Score: 0.7961

# %%
cm = confusion_matrix(y_test, y_pred, labels=list(range(len(classes))))
cm_percent = cm.astype("float") / cm.sum(axis=1, keepdims=True) * 100
cm_percent = np.nan_to_num(cm_percent)

plt.figure(figsize=(8, 7))
im = plt.imshow(cm_percent, interpolation="nearest", cmap="Blues", vmin=0, vmax=100)
plt.title("Matriz de Confusão (%) - DenseNet169 + SMOTE")
plt.colorbar(im, label="%")

tick_marks = np.arange(len(classes))
plt.xticks(tick_marks, classes, rotation=45)
plt.yticks(tick_marks, classes)

for i in range(cm_percent.shape[0]):
    for j in range(cm_percent.shape[1]):
        color = "white" if cm_percent[i, j] > 50 else "black"
        plt.text(
            j,
            i,
            f"{cm_percent[i, j]:.1f}",
            ha="center",
            va="center",
            color=color,
            fontsize=8
        )

plt.ylabel("Classe Real")
plt.xlabel("Classe Predita")
plt.tight_layout()
plt.savefig("matriz_confusao_percent_densenet169_smote.png", dpi=300, bbox_inches="tight")
plt.show()

# %%
test_eval_df = test_df.copy().reset_index(drop=True)
test_eval_df["y_true"] = y_test
test_eval_df["y_pred"] = y_pred
test_eval_df["correct"] = test_eval_df["y_true"] == test_eval_df["y_pred"]

correct_samples = test_eval_df[test_eval_df["correct"]].head(4)
incorrect_samples = test_eval_df[~test_eval_df["correct"]].head(4)

samples_to_plot = pd.concat([correct_samples, incorrect_samples], axis=0).reset_index(drop=True)

plt.figure(figsize=(12, 6))

for i, row in samples_to_plot.iterrows():
    image = preprocess_image_path(row["image_path"], row["mask_path"])
    image = np.clip(image, 0, 255).astype("uint8")

    plt.subplot(2, 4, i + 1)
    plt.imshow(image)

    true_label = class_name[int(row["y_true"])]
    pred_label = class_name[int(row["y_pred"])]

    plt.title(f"{true_label} → {pred_label}", fontsize=10)
    plt.axis("off")

plt.tight_layout()
plt.savefig("exemplos_classificacao_densenet169_smote.png", dpi=300, bbox_inches="tight")
plt.show()

# %%
feature_extractor.save(FEATURE_EXTRACTOR_PATH)
best_classifier.save(FINAL_MODEL_PATH)

print("Extratora DenseNet169 salva em:", FEATURE_EXTRACTOR_PATH)
print("Classificador final salvo em:", FINAL_MODEL_PATH)
print("Melhor checkpoint salvo em:", BEST_MODEL_PATH)
# Out:
# Extratora DenseNet169 salva em: densenet169_feature_extractor.keras
# Classificador final salvo em: deepskin_densenet169_smote_final.keras
# Melhor checkpoint salvo em: best_deepskin_densenet169_smote.keras
